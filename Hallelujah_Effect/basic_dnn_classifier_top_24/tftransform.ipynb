# %% [markdown]
# # "Hallelujah Effect" Analysis
#
# This notebook models the "Hallelujah Effect" in terms of all basic features available in the dataset for those subjects that listened to the song and had an EDA quality >80%.

# %%
# %bash
pip uninstall -y google-cloud-dataflow
pip install --upgrade --force tensorflow_transform==0.6.0 apache-beam[gcp]

# %% [markdown]
# <b>Restart the kernel</b> after you do a pip install (click on the <b>Reset</b> button in Datalab)

# %%
# %bash
pip freeze | grep -e 'flow\|beam'
# Out:
# apache-airflow==1.9.0
# apache-beam==2.5.0
# tensorflow==1.8.0
# tensorflow-transform==0.6.0
# You are using pip version 9.0.3, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import tensorflow as tf
import tensorflow_transform as tft
import shutil
print(tf.__version__)
# Out:
# 1.8.0
# /usr/local/envs/py2env/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# Set bucket, project, and region
BUCKET = 'eim-muse'
PROJECT = 'eim-muse'
REGION = 'us-central1'

# %%
import os
os.environ['BUCKET'] = BUCKET
os.environ['PROJECT'] = PROJECT
os.environ['REGION'] = REGION

# %%
# %bash
gcloud config set project $PROJECT
gcloud config set compute/region $REGION
# Out:
# Updated property [core/project].
# Updated property [compute/region].

# %% [markdown]
# ## Retrieve and Subset Datasource
#
# Get data from BigQuery but defer filtering, etc. to Beam. Data in BigQuery has been pre-processed with Dataprep.

# %%
import google.datalab.bigquery as bq
def create_query(phase, EVERY_N):
  """
  phase: 1=train 2=valid
  """
  base_query = """
SELECT *
FROM
  `eim-muse.hallelujah_effect.full_hallelujah_trials_cleaned`
  """

  if EVERY_N == None:
    if phase < 2:
      # Training
      query = "{0} WHERE MOD(FARM_FINGERPRINT(id), 10) < 7".format(base_query)
    else:
      # Validation
      query = "{0} WHERE MOD(FARM_FINGERPRINT(id), 10) >= 7".format(base_query)
  else:
      query = "{0} WHERE MOD(FARM_FINGERPRINT(id), {1}) = {2}".format(base_query, EVERY_N, phase)
    
  return query

query = create_query(1, None)

# %%
df_valid = bq.Query(query).execute().result().to_dataframe()
df_valid.head()
df_valid.describe()
# Out:
#               age  concentration  musical_expertise    artistic       fault  \
# count  303.000000     303.000000         303.000000  303.000000  303.000000
# mean    24.726073       3.993500           2.547224    2.344099    3.175612
# std     13.931034       0.795258           1.009324    0.988361    0.891464
# min      1.000000       1.000000           1.000000    1.000000    1.000000
# 25%     16.000000       3.991266           2.000000    2.000000    3.000000
# 50%     21.000000       3.991266           2.529880    2.353712    3.144737
# 75%     31.000000       4.000000           3.000000    2.353712    4.000000
# max    121.000000       5.000000           5.000000    5.000000    5.000000
#
#        imagination        lazy     nervous    outgoing    reserved  \
# count   303.000000  303.000000  303.000000  303.000000  303.000000
# mean      3.852643    3.690403    3.629726    3.213016    3.145503
# std       0.821620    0.905895    0.875898    0.961299    0.891699
# min       1.000000    1.000000    1.000000    1.000000    1.000000
# 25%       3.824561    3.659389    3.596491    3.000000    3.000000
# 50%       3.824561    3.659389    3.596491    3.228070    3.117904
# 75%       4.000000    4.000000    4.000000    4.000000    4.000000
# max       5.000000    5.000000    5.000000    5.000000    5.000000
#
#                    ...               music_pref_none  music_pref_hiphop  \
# count              ...                    303.000000         303.000000
# mean               ...                      0.006601           0.138614
# std                ...                      0.081110           0.346115
# min                ...                      0.000000           0.000000
# 25%                ...                      0.000000           0.000000
# 50%                ...                      0.000000           0.000000
# 75%                ...                      0.000000           0.000000
# max                ...                      1.000000           1.000000
#
#        music_pref_dance  music_pref_world  music_pref_rock  music_pref_pop  \
# count        303.000000        303.000000       303.000000      303.000000
# mean           0.188119          0.132013         0.432343        0.673267
# std            0.391454          0.339065         0.496221        0.469794
# min            0.000000          0.000000         0.000000        0.000000
# 25%            0.000000          0.000000         0.000000        0.000000
# 50%            0.000000          0.000000         0.000000        1.000000
# 75%            0.000000          0.000000         1.000000        1.000000
# max            1.000000          1.000000         1.000000        1.000000
#
#        music_pref_classical  music_pref_jazz  music_pref_folk  \
# count            303.000000       303.000000       303.000000
# mean               0.306931         0.171617         0.089109
# std                0.461983         0.377671         0.285372
# min                0.000000         0.000000         0.000000
# 25%                0.000000         0.000000         0.000000
# 50%                0.000000         0.000000         0.000000
# 75%                1.000000         0.000000         0.000000
# max                1.000000         1.000000         1.000000
#
#        music_pref_traditional_irish
# count                    303.000000
# mean                       0.059406
# std                        0.236774
# min                        0.000000
# 25%                        0.000000
# 50%                        0.000000
# 75%                        0.000000
# max                        1.000000
#
# [8 rows x 29 columns]

# %%
train_query = create_query(1, None)
train_n = len(list(bq.Query(train_query).execute().result()))

eval_query = create_query(2, None)
eval_n = len(list(bq.Query(eval_query).execute().result()))

os.environ['TRAIN_N'] = str(train_n)
os.environ['EVAL_N'] = str(eval_n)

print('{} training examples / {} evaluation examples'.format(train_n, eval_n))
# Out:
# 303 training examples / 61 evaluation examples

# %%
df_valid.columns
# Out:
# Index([u'id', u'age', u'concentration', u'hearing_impairments',
#        u'musical_expertise', u'nationality', u'artistic', u'fault',
#        u'imagination', u'lazy', u'nervous', u'outgoing', u'reserved',
#        u'stress', u'thorough', u'trusting', u'activity', u'engagement',
#        u'familiarity', u'like_dislike', u'positivity', u'tension', u'sex',
#        u'hallelujah_reaction', u'location', u'language', u'music_pref_none',
#        u'music_pref_hiphop', u'music_pref_dance', u'music_pref_world',
#        u'music_pref_rock', u'music_pref_pop', u'music_pref_classical',
#        u'music_pref_jazz', u'music_pref_folk',
#        u'music_pref_traditional_irish'],
#       dtype='object')

# %% [markdown]
# ## Create ML dataset using tf.transform and Dataflow
#
# Let's use Cloud Dataflow to read in the BigQuery data and write it out as CSV files. Along the way, let's use tf.transform to do scaling and transforming. Using tf.transform allows us to save the metadata to ensure that the appropriate transformations get carried out during prediction as well.

# %%
# %writefile requirements.txt
tensorflow-transform==0.6.0
# Out:
# Overwriting requirements.txt

# %%
import datetime
import tensorflow as tf
import apache_beam as beam
import tensorflow_transform as tft
from tensorflow_transform.beam import impl as beam_impl

def is_valid(inputs):
    try:
        return True
    except:
        return False

float_features = [
    'activity',
    'age',
    'artistic',
    'concentration',
    'engagement',
    'familiarity',
    'fault',
    'imagination',
    'lazy',
    'like_dislike',
    'musical_expertise',
    'nervous',
    'outgoing',
    'positivity',
    'reserved',
    'stress',
    'tension',
    'thorough',
    'trusting'
]

boolean_features = [
    'hallelujah_reaction',
    'hearing_impairments',
    'music_pref_classical',
    'music_pref_dance',
    'music_pref_folk',
    'music_pref_hiphop',
    'music_pref_jazz',
    'music_pref_none',
    'music_pref_pop',
    'music_pref_rock',
    'music_pref_traditional_irish',
    'music_pref_world'
]

categorical_features = [
    'language',
    'location',
    'nationality',
    'sex'
]

def preprocess_tft(inputs):
    import datetime
    result = {}
    
    for feature in float_features:
        result[feature] = tft.scale_to_0_1(inputs[feature])
    
    for feature in boolean_features:
        result[feature] = tf.cast(inputs[feature], tf.int64)
    
    for feature in categorical_features:
        result[feature] = tf.identity(inputs[feature])
    
    return result

def preprocess(in_test_mode, EVERY_N=None):
  import os
  import os.path
  import tempfile
  from apache_beam.io import tfrecordio
  from tensorflow_transform.coders import example_proto_coder
  from tensorflow_transform.tf_metadata import dataset_metadata
  from tensorflow_transform.tf_metadata import dataset_schema
  from tensorflow_transform.beam import tft_beam_io
  from tensorflow_transform.beam.tft_beam_io import transform_fn_io

  job_name = 'hallelujah-effect-features' + '-' + datetime.datetime.now().strftime('%y%m%d-%H%M%S')    
  if in_test_mode:
    import shutil
    print 'Launching local job ... hang on'
    OUTPUT_DIR = './preproc_tft'
    shutil.rmtree(OUTPUT_DIR, ignore_errors=True)
    
  else:
    print 'Launching Dataflow job {} ... hang on'.format(job_name)
    OUTPUT_DIR = 'gs://{0}/analysis/hallelujah-effect/preproc_tft/'.format(BUCKET)
    import subprocess
    subprocess.call('gsutil rm -r {}'.format(OUTPUT_DIR).split())
  
  # Configure Beam pipeline options
  options = {
    'staging_location': os.path.join(OUTPUT_DIR, 'tmp', 'staging'),
    'temp_location': os.path.join(OUTPUT_DIR, 'tmp'),
    'job_name': job_name,
    'project': PROJECT,
    'max_num_workers': 24,
    'teardown_policy': 'TEARDOWN_ALWAYS',
    'no_save_main_session': True,
    'requirements_file': 'requirements.txt'
  }
  opts = beam.pipeline.PipelineOptions(flags=[], **options)
  if in_test_mode:
    RUNNER = 'DirectRunner'
  else:
    RUNNER = 'DataflowRunner'

  # Setup metadata
  raw_data_schema = {
    colname : dataset_schema.ColumnSchema(tf.string, [], dataset_schema.FixedColumnRepresentation())
                   for colname in categorical_features
  }
  raw_data_schema.update({
      colname : dataset_schema.ColumnSchema(tf.float32, [], dataset_schema.FixedColumnRepresentation())
                   for colname in float_features
    })
  raw_data_schema.update({
      colname : dataset_schema.ColumnSchema(tf.int64, [], dataset_schema.FixedColumnRepresentation())
                   for colname in boolean_features
    })
  raw_data_metadata = dataset_metadata.DatasetMetadata(dataset_schema.Schema(raw_data_schema))
  
  # run Beam  
  with beam.Pipeline(RUNNER, options=opts) as p:
    with beam_impl.Context(temp_dir=os.path.join(OUTPUT_DIR, 'tmp')):
      
      # Write the raw data metadata to disk
      # Without the overloaded operators: p.apply(tft_beam_io.WriteMetadata(os.path.join(OUTPUT_DIR, 'metadata/rawdata_metadata'), raw_data_metadata)
      _ = (raw_data_metadata
        | 'WriteInputMetadata' >> tft_beam_io.WriteMetadata(
            os.path.join(OUTPUT_DIR, 'metadata/rawdata_metadata'),
            pipeline=p))
           
      # Analyze and transform training data
      this_query = create_query(1, EVERY_N)
      
      # Read in training data from BigQuery table
      raw_data = (p
        # Get raw training data from BigQuery
        | 'train_read' >> beam.io.Read(beam.io.BigQuerySource(query=this_query, use_standard_sql=True))
        # Use our is_valid function to only retain valid examples from training data
        | 'train_filter' >> beam.Filter(is_valid))

      # Package raw training data and its metadata into a 'dataset'
      raw_dataset = (raw_data, raw_data_metadata)
      
      # Using the preprocessing function `preprocess_tft`, preprocess the training data
      # and produce a transformed training dataset and a function to transform other data later
      transformed_dataset, transform_fn = (
          raw_dataset | beam_impl.AnalyzeAndTransformDataset(preprocess_tft))
      
      # Break out the transformed training data and its metadata
      transformed_data, transformed_metadata = transformed_dataset
      
      # Write the transformed training data to files
      _ = transformed_data | 'WriteTrainData' >> tfrecordio.WriteToTFRecord(
          os.path.join(OUTPUT_DIR, 'train'),
          file_name_suffix='.gz',
          coder=example_proto_coder.ExampleProtoCoder(
              transformed_metadata.schema))
      
      # Read in test data from BigQuery table and filter as we did with training data
      raw_test_data = (p 
        | 'eval_read' >> beam.io.Read(beam.io.BigQuerySource(query=create_query(2, EVERY_N), use_standard_sql=True))
        | 'eval_filter' >> beam.Filter(is_valid))
      
      # Package test data and metadata into a dataset
      raw_test_dataset = (raw_test_data, raw_data_metadata)
      
      # Using the same transformation function that was calculated above, transform the test dataset
      transformed_test_dataset = (
          (raw_test_dataset, transform_fn) | beam_impl.TransformDataset())
      
      # Write the transformed test data to files
      transformed_test_data, _ = transformed_test_dataset
      _ = transformed_test_data | 'WriteTestData' >> tfrecordio.WriteToTFRecord(
          os.path.join(OUTPUT_DIR, 'eval'),
          file_name_suffix='.gz',
          coder=example_proto_coder.ExampleProtoCoder(
              transformed_metadata.schema))
      
      # Write the transformation function to a file, as well
      _ = (transform_fn
           | 'WriteTransformFn' >>
           transform_fn_io.WriteTransformFn(os.path.join(OUTPUT_DIR, 'metadata')))

# Preprocess the training/test data
preprocess(in_test_mode=True, EVERY_N=None)
# Out:
# Launching local job ... hang on
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./preproc_tft/tmp/tftransform_tmp/19bb5413bd4b4b0f8e36621e3922af0c/saved_model.pb
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./preproc_tft/tmp/tftransform_tmp/b65580123bf9446cb74310cb4a9f1128/saved_model.pb
# /usr/local/envs/py2env/lib/python2.7/site-packages/apache_beam/runners/direct/direct_runner.py:342: DeprecationWarning: options is deprecated since First stable release.. References to <pipeline>.options will not be supported
#   pipeline.replace_all(_get_transform_overrides(pipeline.options))
# WARNING:root:Dataset eim-muse:temp_dataset_5a0af3dc468743a38e880d08169800c5 does not exist so we will create it as temporary with location=None
# WARNING:root:Dataset eim-muse:temp_dataset_879b26de5073457cb0f8af39f9ec4a87 does not exist so we will create it as temporary with location=None
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./preproc_tft/tmp/tftransform_tmp/9ca1a4d8d57945c898e9ad464331262c/saved_model.pb
# INFO:tensorflow:SavedModel written to: ./preproc_tft/tmp/tftransform_tmp/9ca1a4d8d57945c898e9ad464331262c/saved_model.pb
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-10 01:20:05.224311. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
# %bash
ls -ls preproc_tft
ls -ls preproc_tft/metadata
# gsutil ls -l gs://${BUCKET}/analysis/hallelujah-effect/preproc_tft/
# gsutil ls -l gs://${BUCKET}/analysis/hallelujah-effect/preproc_tft/metadata
# Out:
# total 24
#  4 -rw-r--r-- 1 root root  3071 Jul 11 16:24 eval-00000-of-00001.gz
#  4 drwxr-xr-x 5 root root  4096 Jul 11 16:24 metadata
#  4 drwxr-xr-x 3 root root  4096 Jul 11 16:24 tmp
# 12 -rw-r--r-- 1 root root 11567 Jul 11 16:24 train-00000-of-00001.gz
# total 12
# 4 drwxr-xr-x 3 root root 4096 Jul 11 16:24 rawdata_metadata
# 4 drwxr-xr-x 3 root root 4096 Jul 11 16:24 transformed_metadata
# 4 drwxr-xr-x 3 root root 4096 Jul 11 16:24 transform_fn

# %% [markdown]
# <h2> Train off preprocessed data </h2>

# %% [markdown]
# ### Local Manual Training

# %%
MODEL_NAME = 'basic_dnn_classifier_top_24'
os.environ['MODEL_NAME'] = MODEL_NAME

# %%
# %%bash
#
# OUTPUT_DIR=${PWD}/../models/${MODEL_NAME}
# rm -rf ${OUTPUT_DIR}
# export PYTHONPATH=${PYTHONPATH}:$PWD/trainer
# python -m trainer.task \
#    --train_data_paths="${PWD}/preproc_tft/train*" \
#    --eval_data_paths="${PWD}/preproc_tft/eval*" \
#    --train_steps=2500 \
#    --train_batch_size=${TRAIN_N} \
#    --eval_steps=1 \
#    --output_dir=${OUTPUT_DIR} \
#    --job-dir=/tmp \
#    --metadata_path="${PWD}/preproc_tft/metadata"
# Out:
# /usr/local/envs/py2env/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 60, '_session_config': None, '_keep_checkpoint_max': 10, '_task_type': 'worker', '_train_distribute': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f4e47618e50>, '_evaluation_master': '', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': '/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24', '_global_id_in_cluster': 0, '_save_summary_steps': 100}
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 60, '_session_config': None, '_keep_checkpoint_max': 10, '_task_type': 'worker', '_train_distribute': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f4e47618e90>, '_evaluation_master': '', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': '/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24', '_global_id_in_cluster': 0, '_save_summary_steps': 100}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 5 secs (eval_spec.throttle_secs) or training is finished.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow_transform/saved/input_fn_maker.py:557: read_batch_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:833: read_keyed_batch_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:542: read_keyed_batch_examples (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:550: queue_parsed_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# 2018-07-11 17:27:51.103909: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt.
# INFO:tensorflow:loss = 214.35573, step = 1
# INFO:tensorflow:global_step/sec: 100.49
# INFO:tensorflow:loss = 109.71012, step = 101 (0.995 sec)
# INFO:tensorflow:global_step/sec: 80.2246
# INFO:tensorflow:loss = 41.639908, step = 201 (1.250 sec)
# INFO:tensorflow:Saving checkpoints for 275 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt.
# INFO:tensorflow:Loss for final step: 22.565908.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-17:27:59
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt-275
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-11-17:28:01
# INFO:tensorflow:Saving dict for global step 275: accuracy = 0.5409836, accuracy_baseline = 0.6721312, auc = 0.43597564, auc_precision_recall = 0.27392733, average_loss = 2.3209226, f1_score = 0.06666667, false_negatives = 19.0, false_positives = 9.0, global_step = 275, label/mean = 0.32786885, loss = 141.57628, precision = 0.1, prediction/mean = 0.17913726, recall = 0.05, true_negatives = 32.0, true_positives = 1.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt-275
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/export/exporter/temp-1531330082/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt-275
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 276 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt.
# INFO:tensorflow:loss = 24.218775, step = 276
# INFO:tensorflow:global_step/sec: 67.4242
# INFO:tensorflow:loss = 11.955156, step = 376 (1.484 sec)
# INFO:tensorflow:global_step/sec: 104.898
# INFO:tensorflow:loss = 7.8124633, step = 476 (0.953 sec)
# INFO:tensorflow:Saving checkpoints for 515 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt.
# INFO:tensorflow:Loss for final step: 9.055705.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-17:28:12
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt-515
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-11-17:28:13
# INFO:tensorflow:Saving dict for global step 515: accuracy = 0.55737704, accuracy_baseline = 0.6721312, auc = 0.45243907, auc_precision_recall = 0.30683523, average_loss = 3.306655, f1_score = 0.18181819, false_negatives = 17.0, false_positives = 10.0, global_step = 515, label/mean = 0.32786885, loss = 201.70595, precision = 0.23076923, prediction/mean = 0.2109951, recall = 0.15, true_negatives = 31.0, true_positives = 3.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt-515
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/export/exporter/temp-1531330094/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt-515
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 516 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt.
# INFO:tensorflow:loss = 8.776111, step = 516
# INFO:tensorflow:global_step/sec: 61.451
# INFO:tensorflow:loss = 6.9256864, step = 616 (1.629 sec)
# INFO:tensorflow:global_step/sec: 126.514
# INFO:tensorflow:loss = 3.7339768, step = 716 (0.789 sec)
# INFO:tensorflow:Saving checkpoints for 724 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.674673.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-17:28:24
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt-724
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-11-17:28:25
# INFO:tensorflow:Saving dict for global step 724: accuracy = 0.59016395, accuracy_baseline = 0.6721312, auc = 0.4359756, auc_precision_recall = 0.29680198, average_loss = 3.857318, f1_score = 0.1935484, false_negatives = 17.0, false_positives = 8.0, global_step = 724, label/mean = 0.32786885, loss = 235.29639, precision = 0.27272728, prediction/mean = 0.19972982, recall = 0.15, true_negatives = 33.0, true_positives = 3.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt-724
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/export/exporter/temp-1531330107/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt-724
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 725 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt.
# INFO:tensorflow:loss = 2.5956798, step = 725
# INFO:tensorflow:global_step/sec: 113.017
# INFO:tensorflow:loss = 2.0813584, step = 825 (0.885 sec)
# INFO:tensorflow:global_step/sec: 144.475
# INFO:tensorflow:loss = 2.3461428, step = 925 (0.692 sec)
# INFO:tensorflow:global_step/sec: 166.832
# INFO:tensorflow:loss = 1.4303477, step = 1025 (0.600 sec)
# INFO:tensorflow:Saving checkpoints for 1120 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt.
# INFO:tensorflow:Loss for final step: 20.48448.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-17:28:36
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt-1120
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-11-17:28:37
# INFO:tensorflow:Saving dict for global step 1120: accuracy = 0.60655737, accuracy_baseline = 0.6721312, auc = 0
0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt-2500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/export/exporter/temp-1531330145/saved_model.pb

# %% [markdown]
# Results for 2500 batches of 303 cases (2500 training epochs using a `DNNClassifier`):
#
# - accuracy = 0.59016395
# - accuracy baseline = 0.6721312
# - auc = 0.42926833
# - auc precision recall = 0.28366017
# - average loss = 5.0143166
# - f1 score = 0.1935484
# - false negatives = 17.0
# - false positives = 8.0
# - global step = 2500
# - label/mean = 0.32786885
# - loss = 305.87332
# - precision = 0.27272728
# - prediction/mean = 0.19047841
# - recall = 0.15
# - true negatives = 33.0
# - true positives = 3.0

# %% [markdown]
# ### Local ML Engine Training

# %%
# %%bash
#
# OUTPUT_DIR=${PWD}/../models/${MODEL_NAME}
# rm -rf ${OUTPUT_DIR}
# gcloud ml-engine local train \
#    --module-name=trainer.task \
#    --package-path=${PWD}/trainer/trainer \
#    --job-dir=$OUTPUT_DIR \
#    -- \
#    --train_data_paths="${PWD}/preproc_tft/train*" \
#    --eval_data_paths="${PWD}/preproc_tft/eval*" \
#    --train_steps=2500 \
#    --train_batch_size=${TRAIN_N} \
#    --eval_steps=1 \
#    --output_dir=${OUTPUT_DIR} \
#    --metadata_path="${PWD}/preproc_tft/metadata/"
# Out:
# /usr/local/envs/py2env/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:tensorflow:TF_CONFIG environment variable: {u'environment': u'cloud', u'cluster': {}, u'job': {u'args': [u'--train_data_paths=/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/preproc_tft/train*', u'--eval_data_paths=/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/preproc_tft/eval*', u'--train_steps=2500', u'--train_batch_size=303', u'--eval_steps=1', u'--output_dir=/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24', u'--metadata_path=/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/preproc_tft/metadata/', u'--job-dir', u'/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24'], u'job_name': u'trainer.task'}, u'task': {}}
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 60, '_session_config': None, '_keep_checkpoint_max': 10, '_task_type': 'worker', '_train_distribute': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fc0f799f650>, '_evaluation_master': '', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': '/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24', '_global_id_in_cluster': 0, '_save_summary_steps': 100}
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 60, '_session_config': None, '_keep_checkpoint_max': 10, '_task_type': 'worker', '_train_distribute': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fc0f799f690>, '_evaluation_master': '', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': '/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24', '_global_id_in_cluster': 0, '_save_summary_steps': 100}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 5 secs (eval_spec.throttle_secs) or training is finished.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow_transform/saved/input_fn_maker.py:557: read_batch_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:833: read_keyed_batch_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:542: read_keyed_batch_examples (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:550: queue_parsed_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# 2018-07-11 17:29:10.081041: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt.
# INFO:tensorflow:loss = 205.78596, step = 1
# INFO:tensorflow:global_step/sec: 123.514
# INFO:tensorflow:loss = 149.34395, step = 101 (0.810 sec)
# INFO:tensorflow:global_step/sec: 167.106
# INFO:tensorflow:loss = 67.2919, step = 201 (0.598 sec)
# INFO:tensorflow:global_step/sec: 170.565
# INFO:tensorflow:loss = 39.20951, step = 301 (0.586 sec)
# INFO:tensorflow:global_step/sec: 171.342
# INFO:tensorflow:loss = 32.583233, step = 401 (0.583 sec)
# INFO:tensorflow:global_step/sec: 179.149
# INFO:tensorflow:loss = 25.189482, step = 501 (0.559 sec)
# INFO:tensorflow:Saving checkpoints for 546 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt.
# INFO:tensorflow:Loss for final step: 23.081173.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-17:29:16
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt-546
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-11-17:29:17
# INFO:tensorflow:Saving dict for global step 546: accuracy = 0.59016395, accuracy_baseline = 0.6721312, auc = 0.41585368, auc_precision_recall = 0.28218603, average_loss = 3.9916978, f1_score = 0.074074075, false_negatives = 19.0, false_positives = 6.0, global_step = 546, label/mean = 0.32786885, loss = 243.49356, precision = 0.14285715, prediction/mean = 0.112002485, recall = 0.05, true_negatives = 35.0, true_positives = 1.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt-546
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/export/exporter/temp-1531330158/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt-546
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 547 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt.
# INFO:tensorflow:loss = 27.262917, step = 547
# INFO:tensorflow:global_step/sec: 124.311
# INFO:tensorflow:loss = 21.04236, step = 647 (0.805 sec)
# INFO:tensorflow:global_step/sec: 167.896
# INFO:tensorflow:loss = 27.85762, step = 747 (0.597 sec)
# INFO:tensorflow:global_step/sec: 143.812
# INFO:tensorflow:loss = 16.211052, step = 847 (0.694 sec)
# INFO:tensorflow:global_step/sec: 154.765
# INFO:tensorflow:loss = 19.56578, step = 947 (0.646 sec)
# INFO:tensorflow:global_step/sec: 155.799
# INFO:tensorflow:loss = 11.332242, step = 1047 (0.643 sec)
# INFO:tensorflow:Saving checkpoints for 1050 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt.
# INFO:tensorflow:Loss for final step: 14.644075.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-17:29:26
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt-1050
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-11-17:29:27
# INFO:tensorflow:Saving dict for global step 1050: accuracy = 0.60655737, accuracy_baseline = 0.6721312, auc = 0
accuracy = 0.59016395, accuracy_baseline = 0.6721312, auc = 0.46219516, auc_precision_recall = 0.30570674, average_loss = 6.2266383, f1_score = 0.074074075, false_negatives = 19.0, false_positives = 6.0, global_step = 2500, label/mean = 0.32786885, loss = 379.82495, precision = 0.14285715, prediction/mean = 0.11079619, recall = 0.05, true_negatives = 35.0, true_positives = 1.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/model.ckpt-2500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_24/../models/basic_dnn_classifier_top_24/export/exporter/temp-1531330195/saved_model.pb

# %% [markdown]
# Results for 2500 batches of 303 cases (2500 training epochs using a `DNNClassifier`):
#
# - accuracy = 0.59016395
# - accuracy baseline = 0.6721312
# - auc = 0.46219516
# - auc precision recall = 0.30570674
# - average loss = 6.2266383
# - f1 score = 0.074074075
# - false negatives = 19.0
# - false positives = 6.0
# - global step = 2500
# - label/mean = 0.32786885
# - loss = 379.82495
# - precision = 0.14285715
# - prediction/mean = 0.11079619
# - recall = 0.05
# - true negatives = 35.0
# - true positives = 1.0

# %% [markdown]
# ### Cloud ML Engine Training

# %%
# %%bash
#
# OUTPUT_DIR=gs://${BUCKET}/analysis/hallelujah-effect/models/${MODEL_NAME}
# JOBNAME=hallelujah_effect$(date -u +%y%m%d_%H%M%S)
# echo ${OUTPUT_DIR} $REGION $JOBNAME
# gsutil -m rm -rf ${OUTPUT_DIR}
# gcloud ml-engine jobs submit training $JOBNAME \
#    --region=$REGION \
#    --package-path=${PWD}/trainer/trainer \
#    --module-name=trainer.task \
#    --job-dir=${OUTPUT_DIR} \
#    --scale-tier=STANDARD_1 \
#    --runtime-version=1.8 \
#    -- \
#    --train_data_paths="gs://${BUCKET}/analysis/hallelujah-effect/preproc_tft/train*" \
#    --eval_data_paths="gs://${BUCKET}/analysis/hallelujah-effect/preproc_tft/eval*" \
#    --output_dir=$OUTPUT_DIR \
#    --train_steps=25000 \
#    --train_batch_size=${TRAIN_N} \
#    --eval_steps=1 \
#    --metadata_path=gs://${BUCKET}/analysis/hallelujah-effect/preproc_tft/metadata/
# Out:
# gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24 us-central1 hallelujah_effect180711_172735
# jobId: hallelujah_effect180711_172735
# state: QUEUED
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/#1531329882701130...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/checkpoint#1531329886972995...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/eval/#1531329846675320...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/eval/events.out.tfevents.1531329846.cmle-training-master-26f024e42c-0-q2q9w#1531329892559784...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/events.out.tfevents.1531329754.cmle-training-master-26f024e42c-0-q2q9w#1531329901972666...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/export/exporter/#1531329850836931...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/export/#1531329850537328...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/export/exporter/1531329849/#1531329857144616...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/export/exporter/1531329849/saved_model.pb#1531329857490673...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/export/exporter/1531329849/variables/#1531329857821353...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/export/exporter/1531329849/variables/variables.data-00000-of-00001#1531329858137923...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/export/exporter/1531329849/variables/variables.index#1531329858424689...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/export/exporter/1531329893/#1531329900067341...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/export/exporter/1531329893/saved_model.pb#1531329900359573...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/export/exporter/1531329893/variables/#1531329900723062...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/export/exporter/1531329893/variables/variables.data-00000-of-00001#1531329901012023...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/export/exporter/1531329893/variables/variables.index#1531329901355443...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/graph.pbtxt#1531329832305129...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/model.ckpt-143.data-00000-of-00003#1531329838726250...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/model.ckpt-143.data-00001-of-00003#1531329837223969...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/model.ckpt-143.data-00002-of-00003#1531329836765346...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/model.ckpt-143.index#1531329839146303...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/model.ckpt-25005.data-00000-of-00003#1531329885248972...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/model.ckpt-143.meta#1531329841732950...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/model.ckpt-25005.data-00001-of-00003#1531329884740883...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/model.ckpt-25005.data-00002-of-00003#1531329884255469...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/model.ckpt-25005.index#1531329885680498...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/model.ckpt-25005.meta#1531329888110079...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_24/packages/dd320a75e5291946c2b1714c1c018582c2f01cb3ac693b2653938b0bd74634a6/trainer-0.1.tar.gz#1531329366413106...
# / [29/29 objects] 100% Done
# Operation completed over 29 objects.
# Job [hallelujah_effect180711_172735] submitted successfully.
# Your job is still active. You may view the status of your job with the command
#
#   $ gcloud ml-engine jobs describe hallelujah_effect180711_172735
#
# or continue streaming the logs with the command
#
#   $ gcloud ml-engine jobs stream-logs hallelujah_effect180711_172735

# %% [markdown]
# Results for 25000 batches of 303 cases (25000 training epochs using a `DNNClassifier`):
#
# - accuracy = 0.5409836
# - accuracy baseline = 0.6721312
# - auc = 0.4347561
# - auc precision recall = 0.28552037
# - average loss = 9.090888
# - f1 score = 0.06666667
# - false negatives = 19.0
# - false positives = 9.0
# - global step = 25006
# - label/mean = 0.32786885
# - loss = 554.5442
# - precision = 0.1
# - prediction/mean = 0.14751263
# - recall = 0.05
# - true negatives = 32.0
# - true positives = 1.0

# %% [markdown]
# ## View Results in TensorBoard

# %%
from google.datalab.ml import TensorBoard
TensorBoard().start('gs://eim-muse/analysis/hallelujah-effect/models/')
# Out:
# /usr/local/envs/py2env/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# <p>TensorBoard was started successfully with pid 189. Click <a href="/_proxy/57583/" target="_blank">here</a> to access it.</p>
# 189

# %%
TensorBoard.stop(327)

# %%
TensorBoard().start('gs://eim-muse/analysis/hallelujah-effect/models/')
# Out:
# <p>TensorBoard was started successfully with pid 20606. Click <a href="/_proxy/56999/" target="_blank">here</a> to access it.</p>
# 20606

# %%
TensorBoard.stop(20336)

# %%
# %writefile /tmp/test.json
{"age":"29.0","activity":3.0}

# %%
# %bash
model_dir=$(ls $PWD/hallelujah-effect_trained/export/exporter/)
gcloud ml-engine local predict \
    --model-dir=./hallelujah-effect_trained/export/exporter/${model_dir} \
    --json-instances=/tmp/test.json

# %% [markdown]
# # To Do
#
# - Double-check that Dublin ratings are inverted properly
# - LASSO to identify important features
# - Hyperparameter search
# - More plots and statistics from the dataset with which I'm working here
# - Bring in rows with missing values
# - Feature engineering (physiological signals, MIR, feature crosses, variable-width binning)
# - Include signals with good quality only in reaction range
# - Customize estimator to add additional metrics

# %%
print('gs://{}/analysis/hallelujah-effect/models/{}'.format(BUCKET, MODEL_NAME))
# Out:
# gs://eim-muse/analysis/hallelujah-effect/models/basic_features
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-01 20:34:08.418586. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
# %%bash
#
# tensorboard --inspect --logdir gs://eim-muse/analysis/hallelujah-effect/models/basic_features
# Out:
# ======================================================================
# Processing event files... (this can take a few minutes)
# ======================================================================
#
# Found event files in:
# gs://eim-muse/analysis/hallelujah-effect/models/basic_features
# gs://eim-muse/analysis/hallelujah-effect/models/basic_features/eval/
#
# These tags are in gs://eim-muse/analysis/hallelujah-effect/models/basic_features:
# audio -
# histograms
#    dnn/dnn/hiddenlayer_0/activation
#    dnn/dnn/hiddenlayer_1/activation
#    dnn/dnn/hiddenlayer_2/activation
#    dnn/dnn/logits/activation
# images -
# scalars
#    average_loss
#    dnn/dnn/hiddenlayer_0/fraction_of_zero_values
#    dnn/dnn/hiddenlayer_1/fraction_of_zero_values
#    dnn/dnn/hiddenlayer_2/fraction_of_zero_values
#    dnn/dnn/logits/fraction_of_zero_values
#    loss
#    read_batch_features/file_name_queue/fraction_of_32_full
#    read_batch_features/fraction_over_9970_of_30_full
#    read_batch_features/queue/parsed_features/read_batch_features/fifo_queue/fraction_of_100_full
# tensor -
# ======================================================================
#
# Event statistics for gs://eim-muse/analysis/hallelujah-effect/models/basic_features:
# audio -
# graph
#    first_step           0
#    last_step            0
#    max_step             0
#    min_step             0
#    num_steps            1
#    outoforder_steps     []
# histograms
#    first_step           1
#    last_step            1
#    max_step             1
#    min_step             1
#    num_steps            1
#    outoforder_steps     []
# images -
# scalars
#    first_step           1
#    last_step            1
#    max_step             1
#    min_step             1
#    num_steps            1
#    outoforder_steps     []
# sessionlog:checkpoint
#    first_step           1
#    last_step            8
#    max_step             8
#    min_step             1
#    num_steps            8
#    outoforder_steps     []
# sessionlog:start
#    outoforder_steps     []
#    steps                [1L]
# sessionlog:stop -
# tensor -
# ======================================================================
#
# These tags are in gs://eim-muse/analysis/hallelujah-effect/models/basic_features/eval/:
# audio -
# histograms -
# images -
# scalars
#    accuracy
#    accuracy_baseline
#    auc
#    auc_precision_recall
#    average_loss
#    label/mean
#    loss
#    prediction/mean
# tensor -
# ======================================================================
#
# Event statistics for gs://eim-muse/analysis/hallelujah-effect/models/basic_features/eval/:
# audio -
# graph
#    first_step           0
#    last_step            0
#    max_step             0
#    min_step             0
#    num_steps            1
#    outoforder_steps     []
# histograms -
# images -
# scalars
#    first_step           1
#    last_step            14
#    max_step             14
#    min_step             1
#    num_steps            14
#    outoforder_steps     []
# sessionlog:checkpoint -
# sessionlog:start -
# sessionlog:stop -
# tensor -
# ======================================================================
# /usr/local/envs/py2env/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
ml = """
This is
a
multiline string.
"""

with open('./test.txt', 'w') as file:
  file.write(ml)
# Out:
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-04 00:58:42.778246. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
