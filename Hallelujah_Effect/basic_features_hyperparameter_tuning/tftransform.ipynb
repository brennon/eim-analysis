# %% [markdown]
# # "Hallelujah Effect" Analysis
#
# This notebook models the "Hallelujah Effect" in terms of all basic features available in the dataset for those subjects that listened to the song and had an EDA quality >80%.

# %%
# %bash
pip uninstall -y google-cloud-dataflow
pip install --upgrade --force tensorflow_transform==0.6.0 apache-beam[gcp]

# %% [markdown]
# <b>Restart the kernel</b> after you do a pip install (click on the <b>Reset</b> button in Datalab)

# %%
# %bash
pip freeze | grep -e 'flow\|beam'
# Out:
# apache-airflow==1.9.0
# apache-beam==2.5.0
# tensorflow==1.8.0
# tensorflow-transform==0.6.0
# You are using pip version 9.0.3, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import tensorflow as tf
import tensorflow_transform as tft
import shutil
print(tf.__version__)
# Out:
# 1.8.0
# /usr/local/envs/py2env/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# Set bucket, project, and region
BUCKET = 'eim-muse'
PROJECT = 'eim-muse'
REGION = 'us-central1'

# %%
import os
os.environ['BUCKET'] = BUCKET
os.environ['PROJECT'] = PROJECT
os.environ['REGION'] = REGION

# %%
# %bash
gcloud config set project $PROJECT
gcloud config set compute/region $REGION
# Out:
# Updated property [core/project].
# Updated property [compute/region].

# %% [markdown]
# ## Retrieve and Subset Datasource
#
# Get data from BigQuery but defer filtering, etc. to Beam. Data in BigQuery has been pre-processed with Dataprep.

# %%
import google.datalab.bigquery as bq
def create_query(phase, EVERY_N):
  """
  phase: 1=train 2=valid
  """
  base_query = """
SELECT *
FROM
  `eim-muse.hallelujah_effect.full_hallelujah_trials_cleaned`
  """

  if EVERY_N == None:
    if phase < 2:
      # Training
      query = "{0} WHERE MOD(FARM_FINGERPRINT(id), 10) < 7".format(base_query)
    else:
      # Validation
      query = "{0} WHERE MOD(FARM_FINGERPRINT(id), 10) >= 7".format(base_query)
  else:
      query = "{0} WHERE MOD(FARM_FINGERPRINT(id), {1}) = {2}".format(base_query, EVERY_N, phase)
    
  return query

query = create_query(1, None)
# Out:
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-08 18:09:21.887251. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
df_valid = bq.Query(query).execute().result().to_dataframe()
df_valid.head()
df_valid.describe()
# Out:
#               age  concentration  musical_expertise    artistic       fault  \
# count  303.000000     303.000000         303.000000  303.000000  303.000000
# mean    24.726073       3.993500           2.547224    2.344099    3.175612
# std     13.931034       0.795258           1.009324    0.988361    0.891464
# min      1.000000       1.000000           1.000000    1.000000    1.000000
# 25%     16.000000       3.991266           2.000000    2.000000    3.000000
# 50%     21.000000       3.991266           2.529880    2.353712    3.144737
# 75%     31.000000       4.000000           3.000000    2.353712    4.000000
# max    121.000000       5.000000           5.000000    5.000000    5.000000
#
#        imagination        lazy     nervous    outgoing    reserved  \
# count   303.000000  303.000000  303.000000  303.000000  303.000000
# mean      3.852643    3.690403    3.629726    3.213016    3.145503
# std       0.821620    0.905895    0.875898    0.961299    0.891699
# min       1.000000    1.000000    1.000000    1.000000    1.000000
# 25%       3.824561    3.659389    3.596491    3.000000    3.000000
# 50%       3.824561    3.659389    3.596491    3.228070    3.117904
# 75%       4.000000    4.000000    4.000000    4.000000    4.000000
# max       5.000000    5.000000    5.000000    5.000000    5.000000
#
#                    ...               music_pref_none  music_pref_hiphop  \
# count              ...                    303.000000         303.000000
# mean               ...                      0.006601           0.138614
# std                ...                      0.081110           0.346115
# min                ...                      0.000000           0.000000
# 25%                ...                      0.000000           0.000000
# 50%                ...                      0.000000           0.000000
# 75%                ...                      0.000000           0.000000
# max                ...                      1.000000           1.000000
#
#        music_pref_dance  music_pref_world  music_pref_rock  music_pref_pop  \
# count        303.000000        303.000000       303.000000      303.000000
# mean           0.188119          0.132013         0.432343        0.673267
# std            0.391454          0.339065         0.496221        0.469794
# min            0.000000          0.000000         0.000000        0.000000
# 25%            0.000000          0.000000         0.000000        0.000000
# 50%            0.000000          0.000000         0.000000        1.000000
# 75%            0.000000          0.000000         1.000000        1.000000
# max            1.000000          1.000000         1.000000        1.000000
#
#        music_pref_classical  music_pref_jazz  music_pref_folk  \
# count            303.000000       303.000000       303.000000
# mean               0.306931         0.171617         0.089109
# std                0.461983         0.377671         0.285372
# min                0.000000         0.000000         0.000000
# 25%                0.000000         0.000000         0.000000
# 50%                0.000000         0.000000         0.000000
# 75%                1.000000         0.000000         0.000000
# max                1.000000         1.000000         1.000000
#
#        music_pref_traditional_irish
# count                    303.000000
# mean                       0.059406
# std                        0.236774
# min                        0.000000
# 25%                        0.000000
# 50%                        0.000000
# 75%                        0.000000
# max                        1.000000
#
# [8 rows x 29 columns]
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-08 18:09:25.257121. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
train_query = create_query(1, None)
train_n = len(list(bq.Query(train_query).execute().result()))

eval_query = create_query(2, None)
eval_n = len(list(bq.Query(eval_query).execute().result()))

os.environ['TRAIN_N'] = str(train_n)
os.environ['EVAL_N'] = str(eval_n)

print('{} training examples / {} evaluation examples'.format(train_n, eval_n))
# Out:
# 303 training examples / 61 evaluation examples
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-08 18:17:10.083117. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
df_valid.columns
# Out:
# Index([u'id', u'age', u'concentration', u'hearing_impairments',
#        u'musical_expertise', u'nationality', u'artistic', u'fault',
#        u'imagination', u'lazy', u'nervous', u'outgoing', u'reserved',
#        u'stress', u'thorough', u'trusting', u'activity', u'engagement',
#        u'familiarity', u'like_dislike', u'positivity', u'tension', u'sex',
#        u'hallelujah_reaction', u'location', u'language', u'music_pref_none',
#        u'music_pref_hiphop', u'music_pref_dance', u'music_pref_world',
#        u'music_pref_rock', u'music_pref_pop', u'music_pref_classical',
#        u'music_pref_jazz', u'music_pref_folk',
#        u'music_pref_traditional_irish'],
#       dtype='object')

# %% [markdown]
# ## Create ML dataset using tf.transform and Dataflow
#
# Let's use Cloud Dataflow to read in the BigQuery data and write it out as CSV files. Along the way, let's use tf.transform to do scaling and transforming. Using tf.transform allows us to save the metadata to ensure that the appropriate transformations get carried out during prediction as well.

# %%
# %writefile requirements.txt
tensorflow-transform==0.6.0
# Out:
# Overwriting requirements.txt
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-08 18:09:43.216248. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
import datetime
import tensorflow as tf
import apache_beam as beam
import tensorflow_transform as tft
from tensorflow_transform.beam import impl as beam_impl

def is_valid(inputs):
    try:
        return True
    except:
        return False

float_features = [
    'activity',
    'age',
    'artistic',
    'concentration',
    'engagement',
    'familiarity',
    'fault',
    'imagination',
    'lazy',
    'like_dislike',
    'musical_expertise',
    'nervous',
    'outgoing',
    'positivity',
    'reserved',
    'stress',
    'tension',
    'thorough',
    'trusting'
]

boolean_features = [
    'hallelujah_reaction',
    'hearing_impairments',
    'music_pref_classical',
    'music_pref_dance',
    'music_pref_folk',
    'music_pref_hiphop',
    'music_pref_jazz',
    'music_pref_none',
    'music_pref_pop',
    'music_pref_rock',
    'music_pref_traditional_irish',
    'music_pref_world'
]

categorical_features = [
    'language',
    'location',
    'nationality',
    'sex'
]

def preprocess_tft(inputs):
    import datetime
    result = {}
    
    for feature in float_features:
        result[feature] = tft.scale_to_0_1(inputs[feature])
    
    for feature in boolean_features:
        result[feature] = tf.cast(inputs[feature], tf.int64)
    
    for feature in categorical_features:
        result[feature] = tf.identity(inputs[feature])
    
    return result

def preprocess(in_test_mode, EVERY_N=None):
  import os
  import os.path
  import tempfile
  from apache_beam.io import tfrecordio
  from tensorflow_transform.coders import example_proto_coder
  from tensorflow_transform.tf_metadata import dataset_metadata
  from tensorflow_transform.tf_metadata import dataset_schema
  from tensorflow_transform.beam import tft_beam_io
  from tensorflow_transform.beam.tft_beam_io import transform_fn_io

  job_name = 'hallelujah-effect-features' + '-' + datetime.datetime.now().strftime('%y%m%d-%H%M%S')    
  if in_test_mode:
    import shutil
    print 'Launching local job ... hang on'
    OUTPUT_DIR = './preproc_tft'
    shutil.rmtree(OUTPUT_DIR, ignore_errors=True)
    
  else:
    print 'Launching Dataflow job {} ... hang on'.format(job_name)
    OUTPUT_DIR = 'gs://{0}/analysis/hallelujah-effect/preproc_tft/'.format(BUCKET)
    import subprocess
    subprocess.call('gsutil rm -r {}'.format(OUTPUT_DIR).split())
  
  # Configure Beam pipeline options
  options = {
    'staging_location': os.path.join(OUTPUT_DIR, 'tmp', 'staging'),
    'temp_location': os.path.join(OUTPUT_DIR, 'tmp'),
    'job_name': job_name,
    'project': PROJECT,
    'max_num_workers': 24,
    'teardown_policy': 'TEARDOWN_ALWAYS',
    'no_save_main_session': True,
    'requirements_file': 'requirements.txt'
  }
  opts = beam.pipeline.PipelineOptions(flags=[], **options)
  if in_test_mode:
    RUNNER = 'DirectRunner'
  else:
    RUNNER = 'DataflowRunner'

  # Setup metadata
  raw_data_schema = {
    colname : dataset_schema.ColumnSchema(tf.string, [], dataset_schema.FixedColumnRepresentation())
                   for colname in categorical_features
  }
  raw_data_schema.update({
      colname : dataset_schema.ColumnSchema(tf.float32, [], dataset_schema.FixedColumnRepresentation())
                   for colname in float_features
    })
  raw_data_schema.update({
      colname : dataset_schema.ColumnSchema(tf.int64, [], dataset_schema.FixedColumnRepresentation())
                   for colname in boolean_features
    })
  raw_data_metadata = dataset_metadata.DatasetMetadata(dataset_schema.Schema(raw_data_schema))
  
  # run Beam  
  with beam.Pipeline(RUNNER, options=opts) as p:
    with beam_impl.Context(temp_dir=os.path.join(OUTPUT_DIR, 'tmp')):
      
      # Write the raw data metadata to disk
      # Without the overloaded operators: p.apply(tft_beam_io.WriteMetadata(os.path.join(OUTPUT_DIR, 'metadata/rawdata_metadata'), raw_data_metadata)
      _ = (raw_data_metadata
        | 'WriteInputMetadata' >> tft_beam_io.WriteMetadata(
            os.path.join(OUTPUT_DIR, 'metadata/rawdata_metadata'),
            pipeline=p))
           
      # Analyze and transform training data
      this_query = create_query(1, EVERY_N)
      
      # Read in training data from BigQuery table
      raw_data = (p
        # Get raw training data from BigQuery
        | 'train_read' >> beam.io.Read(beam.io.BigQuerySource(query=this_query, use_standard_sql=True))
        # Use our is_valid function to only retain valid examples from training data
        | 'train_filter' >> beam.Filter(is_valid))

      # Package raw training data and its metadata into a 'dataset'
      raw_dataset = (raw_data, raw_data_metadata)
      
      # Using the preprocessing function `preprocess_tft`, preprocess the training data
      # and produce a transformed training dataset and a function to transform other data later
      transformed_dataset, transform_fn = (
          raw_dataset | beam_impl.AnalyzeAndTransformDataset(preprocess_tft))
      
      # Break out the transformed training data and its metadata
      transformed_data, transformed_metadata = transformed_dataset
      
      # Write the transformed training data to files
      _ = transformed_data | 'WriteTrainData' >> tfrecordio.WriteToTFRecord(
          os.path.join(OUTPUT_DIR, 'train'),
          file_name_suffix='.gz',
          coder=example_proto_coder.ExampleProtoCoder(
              transformed_metadata.schema))
      
      # Read in test data from BigQuery table and filter as we did with training data
      raw_test_data = (p 
        | 'eval_read' >> beam.io.Read(beam.io.BigQuerySource(query=create_query(2, EVERY_N), use_standard_sql=True))
        | 'eval_filter' >> beam.Filter(is_valid))
      
      # Package test data and metadata into a dataset
      raw_test_dataset = (raw_test_data, raw_data_metadata)
      
      # Using the same transformation function that was calculated above, transform the test dataset
      transformed_test_dataset = (
          (raw_test_dataset, transform_fn) | beam_impl.TransformDataset())
      
      # Write the transformed test data to files
      transformed_test_data, _ = transformed_test_dataset
      _ = transformed_test_data | 'WriteTestData' >> tfrecordio.WriteToTFRecord(
          os.path.join(OUTPUT_DIR, 'eval'),
          file_name_suffix='.gz',
          coder=example_proto_coder.ExampleProtoCoder(
              transformed_metadata.schema))
      
      # Write the transformation function to a file, as well
      _ = (transform_fn
           | 'WriteTransformFn' >>
           transform_fn_io.WriteTransformFn(os.path.join(OUTPUT_DIR, 'metadata')))

# Preprocess the training/test data
preprocess(in_test_mode=False, EVERY_N=None)
# Out:
# Launching Dataflow job hallelujah-effect-features-180709-001944 ... hang on
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: gs://eim-muse/analysis/hallelujah-effect/preproc_tft/tmp/tftransform_tmp/2e07322dc43945e8ae66b1c567915c18/saved_model.pb
# INFO:tensorflow:SavedModel written to: gs://eim-muse/analysis/hallelujah-effect/preproc_tft/tmp/tftransform_tmp/2e07322dc43945e8ae66b1c567915c18/saved_model.pb
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: gs://eim-muse/analysis/hallelujah-effect/preproc_tft/tmp/tftransform_tmp/c382f5a85f7944af8404045c7c8cd021/saved_model.pb
# INFO:tensorflow:SavedModel written to: gs://eim-muse/analysis/hallelujah-effect/preproc_tft/tmp/tftransform_tmp/c382f5a85f7944af8404045c7c8cd021/saved_model.pb
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-09 00:19:44.132155. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
# %bash
ls -ls preproc_tft
ls -ls preproc_tft/metadata
# gsutil ls -l gs://${BUCKET}/analysis/hallelujah-effect/preproc_tft/
# gsutil ls -l gs://${BUCKET}/analysis/hallelujah-effect/preproc_tft/metadata
# Out:
# total 24
#  4 -rw-r--r-- 1 root root  3049 Jul  8 18:09 eval-00000-of-00001.gz
#  4 drwxr-xr-x 5 root root  4096 Jul  8 18:09 metadata
#  4 drwxr-xr-x 3 root root  4096 Jul  8 18:09 tmp
# 12 -rw-r--r-- 1 root root 11801 Jul  8 18:09 train-00000-of-00001.gz
# total 12
# 4 drwxr-xr-x 3 root root 4096 Jul  8 18:09 rawdata_metadata
# 4 drwxr-xr-x 3 root root 4096 Jul  8 18:09 transformed_metadata
# 4 drwxr-xr-x 3 root root 4096 Jul  8 18:09 transform_fn
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-08 18:10:08.188633. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %% [markdown]
# <h2> Train off preprocessed data </h2>

# %% [markdown]
# ### Local Manual Training

# %%
MODEL_NAME = 'basic_features_basic_dnn_classifier'
os.environ['MODEL_NAME'] = MODEL_NAME
# Out:
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-08 18:52:22.646908. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
# %%bash
#
# rm -rf ${PWD}/models/${MODEL_NAME}
# export PYTHONPATH=${PYTHONPATH}:$PWD/trainer
# python -m trainer.task \
#    --train_data_paths="${PWD}/preproc_tft/train*" \
#    --eval_data_paths="${PWD}/preproc_tft/eval*" \
#    --train_steps=25000 \
#    --train_batch_size=${TRAIN_N} \
#    --eval_steps=1 \
#    --output_dir=${PWD}/models/${MODEL_NAME} \
#    --job-dir=/tmp \
#    --metadata_path="${PWD}/preproc_tft/metadata"
# Out:
# /usr/local/envs/py2env/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 60, '_session_config': None, '_keep_checkpoint_max': 10, '_task_type': 'worker', '_train_distribute': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f5e2722ee50>, '_evaluation_master': '', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': '/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier', '_global_id_in_cluster': 0, '_save_summary_steps': 100}
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 60, '_session_config': None, '_keep_checkpoint_max': 10, '_task_type': 'worker', '_train_distribute': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f5e2722ee90>, '_evaluation_master': '', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': '/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier', '_global_id_in_cluster': 0, '_save_summary_steps': 100}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 5 secs (eval_spec.throttle_secs) or training is finished.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow_transform/saved/input_fn_maker.py:557: read_batch_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:833: read_keyed_batch_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:542: read_keyed_batch_examples (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:550: queue_parsed_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# 2018-07-08 18:52:54.402205: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt.
# INFO:tensorflow:loss = 208.26308, step = 1
# INFO:tensorflow:global_step/sec: 105.813
# INFO:tensorflow:loss = 171.94917, step = 101 (0.946 sec)
# INFO:tensorflow:global_step/sec: 136.608
# INFO:tensorflow:loss = 83.73861, step = 201 (0.731 sec)
# INFO:tensorflow:global_step/sec: 134.434
# INFO:tensorflow:loss = 13.005212, step = 301 (0.744 sec)
# INFO:tensorflow:Saving checkpoints for 384 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.9465861.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-08-18:53:01
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt-384
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-08-18:53:02
# INFO:tensorflow:Saving dict for global step 384: accuracy = 0.55737704, accuracy_baseline = 0.6721312, auc = 0.4384146, auc_precision_recall = 0.2791386, average_loss = 2.6640036, f1_score = 0.06896552, false_negatives = 19.0, false_positives = 8.0, global_step = 384, label/mean = 0.32786885, loss = 162.50423, precision = 0.11111111, prediction/mean = 0.17997983, recall = 0.05, true_negatives = 33.0, true_positives = 1.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt-384
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/export/exporter/temp-1531075983/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt-384
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 385 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt.
# INFO:tensorflow:loss = 2.2565415, step = 385
# INFO:tensorflow:global_step/sec: 109.269
# INFO:tensorflow:loss = 1.7953203, step = 485 (0.916 sec)
# INFO:tensorflow:global_step/sec: 160.92
# INFO:tensorflow:loss = 0.7909841, step = 585 (0.621 sec)
# INFO:tensorflow:global_step/sec: 156.977
# INFO:tensorflow:loss = 2.033701, step = 685 (0.637 sec)
# INFO:tensorflow:global_step/sec: 156.234
# INFO:tensorflow:loss = 0.5263117, step = 785 (0.640 sec)
# INFO:tensorflow:Saving checkpoints for 838 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.4489334.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-08-18:53:11
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt-838
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-08-18:53:12
# INFO:tensorflow:Saving dict for global step 838: accuracy = 0.57377046, accuracy_baseline = 0.6721312, auc = 0.4408537, auc_precision_recall = 0.30212283, average_loss = 3.3863988, f1_score = 0.13333334, false_negatives = 18.0, false_positives = 8.0, global_step = 838, label/mean = 0.32786885, loss = 206.57033, precision = 0.2, prediction/mean = 0.1714067, recall = 0.1, true_negatives = 33.0, true_positives = 2.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt-838
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/export/exporter/temp-1531075993/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt-838
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 839 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt.
# INFO:tensorflow:loss = 0.76670855, step = 839
# INFO:tensorflow:global_step/sec: 107.623
# INFO:tensorflow:loss = 0.33115703, step = 939 (0.929 sec)
# INFO:tensorflow:global_step/sec: 141.024
# INFO:tensorflow:loss = 0.2189987, step = 1039 (0.709 sec)
# INFO:tensorflow:global_step/sec: 140.697
# INFO:tensorflow:loss = 0.3532897, step = 1139 (0.711 sec)
# INFO:tensorflow:global_step/sec: 141.794
# INFO:tensorflow:loss = 0.18535377, step = 1239 (0.706 sec)
# INFO:tensorflow:Saving checkpoints for 1253 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.20102395.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-08-18:53:21
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt-1253
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-08-18:53:22
# INFO:tensorflow:Saving dict for global step 1253: accuracy = 0.55737704, accuracy_baseline = 0.6721312, auc = 0.45548785, auc_precision_recall = 0.31047878, average_loss = 3.666414, f1_score = 0.12903225, false_negatives = 18.0, false_positives = 9.0, global_step = 1253, label/mean = 0.32786885, loss = 223.65126, precision = 0.18181819, prediction/mean = 0.17273724, recall = 0.1, true_negatives = 32.0, true_positives = 2.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt-1253
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/export/exporter/temp-1531076002/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt-1253
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1254 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt.
# INFO:tensorflow:loss = 0
into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.021058.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# ...
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-08-19:01:56
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt-24029
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-08-19:01:57
# INFO:tensorflow:Saving dict for global step 24029: accuracy = 0.55737704, accuracy_baseline = 0.6721312, auc = 0.49146342, auc_precision_recall = 0.32910493, average_loss = 5.1765504, f1_score = 0.12903225, false_negatives = 18.0, false_positives = 9.0, global_step = 24029, label/mean = 0.32786885, loss = 315.76956, precision = 0.18181819, prediction/mean = 0.17951371, recall = 0.1, true_negatives = 32.0, true_positives = 2.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt-24029
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/export/exporter/temp-1531076518/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt-24029
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 24030 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt.
# INFO:tensorflow:loss = 0.002883499, step = 24030
# INFO:tensorflow:global_step/sec: 94.1429
# INFO:tensorflow:loss = 0.0027673326, step = 24130 (1.062 sec)
# INFO:tensorflow:global_step/sec: 138.601
# INFO:tensorflow:loss = 0.002875697, step = 24230 (0.721 sec)
# INFO:tensorflow:global_step/sec: 139.378
# INFO:tensorflow:loss = 0.0028170513, step = 24330 (0.718 sec)
# INFO:tensorflow:global_step/sec: 140.402
# INFO:tensorflow:loss = 0.0015355228, step = 24430 (0.712 sec)
# INFO:tensorflow:Saving checkpoints for 24433 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0031395417.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-08-19:02:06
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt-24433
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-08-19:02:07
# INFO:tensorflow:Saving dict for global step 24433: accuracy = 0.55737704, accuracy_baseline = 0.6721312, auc = 0.49146342, auc_precision_recall = 0.32910493, average_loss = 5.184654, f1_score = 0.12903225, false_negatives = 18.0, false_positives = 9.0, global_step = 24433, label/mean = 0.32786885, loss = 316.26392, precision = 0.18181819, prediction/mean = 0.17950559, recall = 0.1, true_negatives = 32.0, true_positives = 2.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt-24433
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/export/exporter/temp-1531076528/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt-24433
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 24434 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt.
# INFO:tensorflow:loss = 0.003512102, step = 24434
# INFO:tensorflow:global_step/sec: 107.774
# INFO:tensorflow:loss = 0.001988107, step = 24534 (0.928 sec)
# INFO:tensorflow:global_step/sec: 138.929
# INFO:tensorflow:loss = 0.0026214323, step = 24634 (0.720 sec)
# INFO:tensorflow:global_step/sec: 141.856
# INFO:tensorflow:loss = 0.0034420926, step = 24734 (0.707 sec)
# INFO:tensorflow:global_step/sec: 138.203
# INFO:tensorflow:loss = 0.0034916692, step = 24834 (0.722 sec)
# INFO:tensorflow:Saving checkpoints for 24860 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.002820946.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-08-19:02:16
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt-24860
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-08-19:02:17
# INFO:tensorflow:Saving dict for global step 24860: accuracy = 0.55737704, accuracy_baseline = 0.6721312, auc = 0.49146342, auc_precision_recall = 0.32910493, average_loss = 5.193046, f1_score = 0.12903225, false_negatives = 18.0, false_positives = 9.0, global_step = 24860, label/mean = 0.32786885, loss = 316.77582, precision = 0.18181819, prediction/mean = 0.17960021, recall = 0.1, true_negatives = 32.0, true_positives = 2.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt-24860
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/export/exporter/temp-1531076538/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt-24860
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 24861 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt.
# INFO:tensorflow:loss = 0.002279651, step = 24861
# INFO:tensorflow:global_step/sec: 118.466
# INFO:tensorflow:loss = 0.0019230784, step = 24961 (0.844 sec)
# INFO:tensorflow:Saving checkpoints for 25000 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0030030832.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-08-19:02:23
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt-25000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-08-19:02:24
# INFO:tensorflow:Saving dict for global step 25000: accuracy = 0.55737704, accuracy_baseline = 0.6721312, auc = 0.49146342, auc_precision_recall = 0.32910493, average_loss = 5.195824, f1_score = 0.12903225, false_negatives = 18.0, false_positives = 9.0, global_step = 25000, label/mean = 0.32786885, loss = 316.94528, precision = 0.18181819, prediction/mean = 0.17960645, recall = 0.1, true_negatives = 32.0, true_positives = 2.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/model.ckpt-25000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_basic_dnn_classifier/export/exporter/temp-1531076545/saved_model.pb
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-08 18:52:50.399019. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %% [markdown]
# Results for 25000 batches of 303 cases (using a DNNLinearCombinedClassifier with all features as deep columns):
#
# - Accuracy = 0.6557377
# - Accuracy baseline = 0.6721312
# - AUC = 0.4292683
# - AUC-PR = 0.26934606
# - Average loss = 1.7968603
# - F1 score = 0.0
# - False negatives = 20.0
# - False positives = 1.0
# - Label/mean = 0.32786885
# - Loss = 109.60848
# - Precision = 0.0
# - Prediction/mean = 0.073216155
# - Recall = 0.0
# - True negatives = 40.0
# - True positives = 0.0

# %% [markdown]
# ### Local ML Engine Training

# %%
# %%bash
#
# OUTDIR=${PWD}/models/${MODEL_NAME}
# rm -rf $OUTDIR
# gcloud ml-engine local train \
#    --module-name=trainer.task \
#    --package-path=${PWD}/trainer/trainer \
#    --job-dir=$OUTDIR \
#    -- \
#    --train_data_paths="${PWD}/preproc_tft/train*" \
#    --eval_data_paths="${PWD}/preproc_tft/eval*" \
#    --train_steps=250 \
#    --train_batch_size=64 \
#    --eval_steps=5 \
#    --output_dir=$OUTDIR \
#    --metadata_path="${PWD}/preproc_tft/metadata/"
# Out:
# /usr/local/envs/py2env/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:tensorflow:TF_CONFIG environment variable: {u'environment': u'cloud', u'cluster': {}, u'job': {u'args': [u'--train_data_paths=/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/preproc_tft/train*', u'--eval_data_paths=/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/preproc_tft/eval*', u'--train_steps=250', u'--train_batch_size=64', u'--eval_steps=5', u'--output_dir=/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_hyperparameter_tuning', u'--metadata_path=/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/preproc_tft/metadata/', u'--job-dir', u'/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_hyperparameter_tuning'], u'job_name': u'trainer.task'}, u'task': {}}
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 60, '_session_config': None, '_keep_checkpoint_max': 10, '_task_type': 'worker', '_train_distribute': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f62463f4650>, '_evaluation_master': '', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': '/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_hyperparameter_tuning', '_global_id_in_cluster': 0, '_save_summary_steps': 100}
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 60, '_session_config': None, '_keep_checkpoint_max': 10, '_task_type': 'worker', '_train_distribute': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f62463f4690>, '_evaluation_master': '', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': '/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_hyperparameter_tuning', '_global_id_in_cluster': 0, '_save_summary_steps': 100}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 5 secs (eval_spec.throttle_secs) or training is finished.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow_transform/saved/input_fn_maker.py:557: read_batch_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:833: read_keyed_batch_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:542: read_keyed_batch_examples (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:550: queue_parsed_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# 2018-07-08 18:03:11.866052: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_hyperparameter_tuning/model.ckpt.
# INFO:tensorflow:loss = 44.479042, step = 1
# INFO:tensorflow:global_step/sec: 109.983
# INFO:tensorflow:loss = 29.472254, step = 101 (0.909 sec)
# INFO:tensorflow:global_step/sec: 416.594
# INFO:tensorflow:loss = 37.62726, step = 201 (0.240 sec)
# INFO:tensorflow:Saving checkpoints for 250 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_hyperparameter_tuning/model.ckpt.
# INFO:tensorflow:Loss for final step: 39.98821.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-08-18:03:16
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_hyperparameter_tuning/model.ckpt-250
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/5]
# INFO:tensorflow:Finished evaluation at 2018-07-08-18:03:17
# INFO:tensorflow:Saving dict for global step 250: accuracy = 0.7352941, accuracy_baseline = 0.7352941, auc = 0.47111112, auc_precision_recall = 0.25333524, average_loss = 0.58816004, f1_score = 0.0, false_negatives = 9.0, false_positives = 0.0, global_step = 250, label/mean = 0.2647059, loss = 19.99744, precision = 0.0, prediction/mean = 0.2542435, recall = 0.0, true_negatives = 25.0, true_positives = 0.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_hyperparameter_tuning/model.ckpt-250
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features_hyperparameter_tuning/models/basic_features_hyperparameter_tuning/export/exporter/temp-1531072998/saved_model.pb
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-08 18:03:07.135976. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %% [markdown]
# Results for 100000 batches of 128 cases:
#
# - Accuracy = 0.9375
# - Accuracy baseline = 0.9375
# - AUC = 0.5000004
# - AUC-PR = 0.53124946
# - Average loss = 1.0002984
# - F1 score = 0.0
# - Label/mean = 0.0625
# - Loss = 16.004774
# - Precision = 0.0
# - Prediction/mean = 0.0004200352
# - Recall = 0.0

# %% [markdown]
# ### Cloud ML Engine Training

# %%
# %%bash
#
# OUTDIR=gs://${BUCKET}/analysis/hallelujah-effect/models/${MODEL_NAME}
# JOBNAME=hallelujah_effect$(date -u +%y%m%d_%H%M%S)
# echo $OUTDIR $REGION $JOBNAME
# gsutil -m rm -rf $OUTDIR
# gcloud ml-engine jobs submit training $JOBNAME \
#    --region=$REGION \
#    --package-path=${PWD}/trainer/trainer \
#    --module-name=trainer.task \
#    --job-dir=$OUTDIR \
#    --scale-tier=STANDARD_1 \
#    --runtime-version=1.4 \
#    -- \
#    --train_data_paths="gs://${BUCKET}/analysis/hallelujah-effect/preproc_tft/train*" \
#    --eval_data_paths="gs://${BUCKET}/analysis/hallelujah-effect/preproc_tft/eval*" \
#    --output_dir=$OUTDIR \
#    --train_steps=100000 \
#    --train_batch_size=128 \
#    --eval_steps=1 \
#    --metadata_path=gs://${BUCKET}/analysis/hallelujah-effect/preproc_tft/metadata/
#
# #    --config=hyperparam.yaml
# # --staging-bucket=gs://eim-muse-staging \
# Out:
# gs://eim-muse/analysis/hallelujah-effect/models/basic_features_hyperparameter_tuning us-central1 hallelujah_effect180707_210333
# jobId: hallelujah_effect180707_210333
# state: QUEUED
# CommandException: 1 files/objects could not be removed.
# Job [hallelujah_effect180707_210333] submitted successfully.
# Your job is still active. You may view the status of your job with the command
#
#   $ gcloud ml-engine jobs describe hallelujah_effect180707_210333
#
# or continue streaming the logs with the command
#
#   $ gcloud ml-engine jobs stream-logs hallelujah_effect180707_210333

# %% [markdown]
# Results:
#
# - Accuracy = 0.588235
# - Accuracy baseline = 0.735294
# - AUC = 0.328889
# - AUC-PR = 0.176113
# - Average loss = 2.61672
# - Label/mean = 0.264706
# - Loss = 88.9685
# - Prediction/mean = 0.151901

# %% [markdown]
# ## View Results in TensorBoard

# %%
from google.datalab.ml import TensorBoard
TensorBoard().start('./')
# Out:
# /usr/local/envs/py2env/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# <p>TensorBoard was started successfully with pid 30392. Click <a href="/_proxy/58455/" target="_blank">here</a> to access it.</p>
# 30392

# %%
TensorBoard.stop(327)

# %%
TensorBoard().start('gs://eim-muse/analysis/hallelujah-effect/models/')
# Out:
# <p>TensorBoard was started successfully with pid 20606. Click <a href="/_proxy/56999/" target="_blank">here</a> to access it.</p>
# 20606

# %%
TensorBoard.stop(20336)

# %%
# %writefile /tmp/test.json
{"age":"29.0","activity":3.0}

# %%
# %bash
model_dir=$(ls $PWD/hallelujah-effect_trained/export/exporter/)
gcloud ml-engine local predict \
    --model-dir=./hallelujah-effect_trained/export/exporter/${model_dir} \
    --json-instances=/tmp/test.json

# %% [markdown]
# # To Do
#
# - Double-check that Dublin ratings are inverted properly
# - LASSO to identify important features
# - Hyperparameter search
# - More plots and statistics from the dataset with which I'm working here
# - Bring in rows with missing values
# - Feature engineering (physiological signals, MIR, feature crosses, variable-width binning)
# - Include signals with good quality only in reaction range
# - Customize estimator to add additional metrics

# %%
print('gs://{}/analysis/hallelujah-effect/models/{}'.format(BUCKET, MODEL_NAME))
# Out:
# gs://eim-muse/analysis/hallelujah-effect/models/basic_features
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-01 20:34:08.418586. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
# %%bash
#
# tensorboard --inspect --logdir gs://eim-muse/analysis/hallelujah-effect/models/basic_features
# Out:
# ======================================================================
# Processing event files... (this can take a few minutes)
# ======================================================================
#
# Found event files in:
# gs://eim-muse/analysis/hallelujah-effect/models/basic_features
# gs://eim-muse/analysis/hallelujah-effect/models/basic_features/eval/
#
# These tags are in gs://eim-muse/analysis/hallelujah-effect/models/basic_features:
# audio -
# histograms
#    dnn/dnn/hiddenlayer_0/activation
#    dnn/dnn/hiddenlayer_1/activation
#    dnn/dnn/hiddenlayer_2/activation
#    dnn/dnn/logits/activation
# images -
# scalars
#    average_loss
#    dnn/dnn/hiddenlayer_0/fraction_of_zero_values
#    dnn/dnn/hiddenlayer_1/fraction_of_zero_values
#    dnn/dnn/hiddenlayer_2/fraction_of_zero_values
#    dnn/dnn/logits/fraction_of_zero_values
#    loss
#    read_batch_features/file_name_queue/fraction_of_32_full
#    read_batch_features/fraction_over_9970_of_30_full
#    read_batch_features/queue/parsed_features/read_batch_features/fifo_queue/fraction_of_100_full
# tensor -
# ======================================================================
#
# Event statistics for gs://eim-muse/analysis/hallelujah-effect/models/basic_features:
# audio -
# graph
#    first_step           0
#    last_step            0
#    max_step             0
#    min_step             0
#    num_steps            1
#    outoforder_steps     []
# histograms
#    first_step           1
#    last_step            1
#    max_step             1
#    min_step             1
#    num_steps            1
#    outoforder_steps     []
# images -
# scalars
#    first_step           1
#    last_step            1
#    max_step             1
#    min_step             1
#    num_steps            1
#    outoforder_steps     []
# sessionlog:checkpoint
#    first_step           1
#    last_step            8
#    max_step             8
#    min_step             1
#    num_steps            8
#    outoforder_steps     []
# sessionlog:start
#    outoforder_steps     []
#    steps                [1L]
# sessionlog:stop -
# tensor -
# ======================================================================
#
# These tags are in gs://eim-muse/analysis/hallelujah-effect/models/basic_features/eval/:
# audio -
# histograms -
# images -
# scalars
#    accuracy
#    accuracy_baseline
#    auc
#    auc_precision_recall
#    average_loss
#    label/mean
#    loss
#    prediction/mean
# tensor -
# ======================================================================
#
# Event statistics for gs://eim-muse/analysis/hallelujah-effect/models/basic_features/eval/:
# audio -
# graph
#    first_step           0
#    last_step            0
#    max_step             0
#    min_step             0
#    num_steps            1
#    outoforder_steps     []
# histograms -
# images -
# scalars
#    first_step           1
#    last_step            14
#    max_step             14
#    min_step             1
#    num_steps            14
#    outoforder_steps     []
# sessionlog:checkpoint -
# sessionlog:start -
# sessionlog:stop -
# tensor -
# ======================================================================
# /usr/local/envs/py2env/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
ml = """
This is
a
multiline string.
"""

with open('./test.txt', 'w') as file:
  file.write(ml)
# Out:
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-04 00:58:42.778246. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
