# %%
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# Read each CSV into a `DataFrame`.

# %%
hallelujah_path = Path('data', 'good_hallelujah_trials_and_signals_q90_javier_all_no_bastards.csv')
# into_dust_path = Path('data', 'good_into_dust_trials_and_signals_q90_javier_all.csv')
# raining_blood_path = Path('data', 'good_raining_blood_trials_and_signals_q90_javier_all.csv')

hallelujah_df = pd.read_csv(hallelujah_path, index_col='_id')
# into_dust_df = pd.read_csv(into_dust_path, index_col='_id')
# raining_blood_df = pd.read_csv(raining_blood_path, index_col='_id')

# %% [markdown]
# Concatenate all song `DataFrame`s into a master `DataFrame`.

# %%
# all_df = pd.concat([hallelujah_df, into_dust_df, raining_blood_df], axis=0, sort=False)
all_df = hallelujah_df

# %%
pd.set_option('display.max_columns', None)
all_df.describe()
# Out:
#        answers.age  answers.personality.trusting  \
# count   156.000000                     63.000000
# mean     24.019231                      3.698413
# std      13.222889                      1.130728
# min       1.000000                      1.000000
# 25%      15.750000                      3.000000
# 50%      21.000000                      4.000000
# 75%      31.000000                      4.000000
# max      81.000000                      5.000000
#
#        answers.personality.artistic  answers.personality.imagination  \
# count                     63.000000                        63.000000
# mean                       2.492063                         3.920635
# std                        1.330450                         1.082136
# min                        1.000000                         1.000000
# 25%                        1.000000                         3.000000
# 50%                        2.000000                         4.000000
# 75%                        3.000000                         5.000000
# max                        5.000000                         5.000000
#
#        answers.personality.reserved  answers.personality.outgoing  \
# count                     63.000000                     63.000000
# mean                       3.317460                      3.206349
# std                        1.075015                      1.309503
# min                        1.000000                      1.000000
# 25%                        3.000000                      2.000000
# 50%                        4.000000                      3.000000
# 75%                        4.000000                      4.000000
# max                        5.000000                      5.000000
#
#        answers.personality.lazy  answers.personality.stress  \
# count                 63.000000                   63.000000
# mean                   3.619048                    3.190476
# std                    1.288016                    1.133893
# min                    1.000000                    1.000000
# 25%                    3.000000                    2.000000
# 50%                    4.000000                    3.000000
# 75%                    5.000000                    4.000000
# max                    5.000000                    5.000000
#
#        answers.personality.nervous  answers.personality.fault  \
# count                    63.000000                  63.000000
# mean                      3.365079                   3.269841
# std                       1.261100                   1.220872
# min                       1.000000                   1.000000
# 25%                       2.000000                   2.500000
# 50%                       4.000000                   4.000000
# 75%                       4.000000                   4.000000
# max                       5.000000                   5.000000
#
#        answers.personality.thorough  answers.musical_expertise  \
# count                     63.000000                  99.000000
# mean                       3.063492                   2.616162
# std                        1.119807                   1.201250
# min                        1.000000                   1.000000
# 25%                        2.000000                   2.000000
# 50%                        3.000000                   3.000000
# 75%                        4.000000                   3.000000
# max                        5.000000                   5.000000
#
#        answers.concentration  control_power  control_like_dislike  \
# count              63.000000      63.000000             63.000000
# mean                4.142857       3.349206              3.396825
# std                 0.947954       1.193514              1.442888
# min                 2.000000       1.000000              1.000000
# 25%                 3.500000       3.000000              2.000000
# 50%                 4.000000       3.000000              4.000000
# 75%                 5.000000       4.000000              5.000000
# max                 5.000000       5.000000              5.000000
#
#        control_tension  control_engagement  control_activity  \
# count        63.000000           63.000000         63.000000
# mean          3.746032            3.460317          3.222222
# std           1.092028            1.254995          1.156252
# min           1.000000            1.000000          1.000000
# 25%           3.000000            3.000000          2.000000
# 50%           4.000000            4.000000          3.000000
# 75%           5.000000            4.000000          4.000000
# max           5.000000            5.000000          5.000000
#
#        control_positivity  control_familiarity  song_power  song_like_dislike  \
# count           63.000000                 63.0   72.000000         135.000000
# mean             3.571429                 -1.0    3.486111           3.192593
# std              1.088270                  0.0    1.310769           1.478686
# min              1.000000                 -1.0    1.000000           1.000000
# 25%              3.000000                 -1.0    3.000000           2.000000
# 50%              4.000000                 -1.0    4.000000           3.000000
# 75%              4.000000                 -1.0    5.000000           5.000000
# max              5.000000                 -1.0    5.000000           5.000000
#
#        song_tension  song_engagement  song_activity  song_positivity  \
# count    144.000000       135.000000     135.000000       135.000000
# mean       3.826389         3.148148       3.370370         3.318519
# std        1.172707         1.543008       1.020248         1.308137
# min        1.000000         1.000000       1.000000         1.000000
# 25%        3.000000         2.000000       3.000000         2.000000
# 50%        4.000000         3.000000       3.000000         4.000000
# 75%        5.000000         5.000000       4.000000         4.000000
# max        5.000000         5.000000       5.000000         5.000000
#
#        song_familiarity  answers.visual_impairments  control_inspired  \
# count        135.000000                         0.0               0.0
# mean           3.259259                         NaN               NaN
# std            1.440165                         NaN               NaN
# min            1.000000                         NaN               NaN
# 25%            2.000000                         NaN               NaN
# 50%            4.000000                         NaN               NaN
# 75%            4.000000                         NaN               NaN
# max            5.000000                         NaN               NaN
#
#        control_wonder  control_spirituality  control_thrills  control_chills  \
# count             0.0                   0.0              0.0             0.0
# mean              NaN                   NaN              NaN             NaN
# std               NaN                   NaN              NaN             NaN
# min               NaN                   NaN              NaN             NaN
# 25%               NaN                   NaN              NaN             NaN
# 50%               NaN                   NaN              NaN             NaN
# 75%               NaN                   NaN              NaN             NaN
# max               NaN                   NaN              NaN             NaN
#
#        control_tenderness  control_nostalgia  control_goosebumps  \
# count                 0.0                0.0                 0.0
# mean                  NaN                NaN                 NaN
# std                   NaN                NaN                 NaN
# min                   NaN                NaN                 NaN
# 25%                   NaN                NaN                 NaN
# 50%                   NaN                NaN                 NaN
# 75%                   NaN                NaN                 NaN
# max                   NaN                NaN                 NaN
#
#        control_overwhelmed  control_shivers  song_inspired  song_wonder  \
# count                  0.0              0.0      22.000000    31.000000
# mean                   NaN              NaN       2.681818     2.967742
# std                    NaN              NaN       1.170525     1.353609
# min                    NaN              NaN       1.000000     1.000000
# 25%                    NaN              NaN       2.000000     2.000000
# 50%                    NaN              NaN       3.000000     3.000000
# 75%                    NaN              NaN       3.750000     4.000000
# max                    NaN              NaN       5.000000     5.000000
#
#        song_spirituality  song_thrills  song_chills  song_tenderness  \
# count          22.000000     22.000000    22.000000        31.000000
# mean            2.863636      2.000000     2.545455         3.419355
# std             1.355604      1.154701     1.335496         1.310832
# min             1.000000      1.000000     1.000000         1.000000
# 25%             2.000000      1.000000     1.000000         2.500000
# 50%             3.000000      2.000000     2.000000         4.000000
# 75%             4.000000      2.750000     4.000000         4.000000
# max             5.000000      4.000000     4.000000         5.000000
#
#        song_nostalgia  song_goosebumps  song_overwhelmed  song_shivers  \
# count       31.000000        22.000000         22.000000     22.000000
# mean         3.548387         2.363636          2.727273      2.136364
# std          1.362319         1.328997          1.351606      1.082126
# min          1.000000         1.000000          1.000000      1.000000
# 25%          2.000000         1.000000          1.250000      1.000000
# 50%          4.000000         2.500000          3.000000      2.000000
# 75%          5.000000         3.000000          4.000000      3.000000
# max          5.000000         5.000000          5.000000      4.000000
#
#        control_chillsshiversthrills  song_chillsshiversthrills  \
# count                           0.0                  50.000000
# mean                            NaN                   2.440000
# std                             NaN                   1.430855
# min                             NaN                   1.000000
# 25%                             NaN                   1.000000
# 50%                             NaN                   2.000000
# 75%                             NaN                   4.000000
# max                             NaN                   5.000000
#
#        control_transcendence  control_sadness  control_joyfulactivation  \
# count                    0.0              0.0                       0.0
# mean                     NaN              NaN                       NaN
# std                      NaN              NaN                       NaN
# min                      NaN              NaN                       NaN
# 25%                      NaN              NaN                       NaN
# 50%                      NaN              NaN                       NaN
# 75%                      NaN              NaN                       NaN
# max                      NaN              NaN                       NaN
#
#        control_peacefulness  song_transcendence  song_sadness  \
# count                   0.0            9.000000      9.000000
# mean                    NaN            3.444444      3.555556
# std                     NaN            0.881917      1.236033
# min                     NaN            2.000000      2.000000
# 25%                     NaN            3.000000      2.000000
# 50%                     NaN            3.000000      4.000000
# 75%                     NaN            4.000000      4.000000
# max                     NaN            5.000000      5.000000
#
#        song_joyfulactivation  song_peacefulness  answers.musicpref.hip_hop  \
# count               9.000000           9.000000                 156.000000
# mean                1.444444           3.444444                   0.128205
# std                 0.726483           0.726483                   0.335395
# min                 1.000000           2.000000                   0.000000
# 25%                 1.000000           3.000000                   0.000000
# 50%                 1.000000           4.000000                   0.000000
# 75%                 2.000000           4.000000                   0.000000
# max                 3.000000           4.000000                   1.000000
#
#        answers.musicpref.traditional_irish  answers.musicpref.classical  \
# count                           156.000000                   156.000000
# mean                              0.115385                     0.269231
# std                               0.320514                     0.444989
# min                               0.000000                     0.000000
# 25%                               0.000000                     0.000000
# 50%                               0.000000                     0.000000
# 75%                               0.000000                     1.000000
# max                               1.000000                     1.000000
#
#        answers.musicpref.hiphop  answers.musicpref.folk  \
# count                156.000000              156.000000
# mean                   0.051282                0.057692
# std                    0.221283                0.233912
# min                    0.000000                0.000000
# 25%                    0.000000                0.000000
# 50%                    0.000000                0.000000
# 75%                    0.000000                0.000000
# max                    1.000000                1.000000
#
#        answers.musicpref.jazz  answers.musicpref.dance  \
# count              156.000000               156.000000
# mean                 0.192308                 0.217949
# std                  0.395383                 0.414182
# min                  0.000000                 0.000000
# 25%                  0.000000                 0.000000
# 50%                  0.000000                 0.000000
# 75%                  0.000000                 0.000000
# max                  1.000000                 1.000000
#
#        answers.musicpref.world  answers.musicpref.rock  \
# count               156.000000              156.000000
# mean                  0.141026                0.525641
# std                   0.349169                0.500950
# min                   0.000000                0.000000
# 25%                   0.000000                0.000000
# 50%                   0.000000                1.000000
# 75%                   0.000000                1.000000
# max                   1.000000                1.000000
#
#        answers.musicpref.none  answers.musicpref.pop
# count              156.000000             156.000000
# mean                 0.019231               0.615385
# std                  0.137777               0.488071
# min                  0.000000               0.000000
# 25%                  0.000000               0.000000
# 50%                  0.000000               1.000000
# 75%                  0.000000               1.000000
# max                  1.000000               1.000000

# %% [markdown]
# # Data Cleanup

# %% [markdown]
# Drop `answers.` and `metadata.` from column names.

# %%
def strip_prefix(prefix=''):
    def strip_fn(s):
        if s.startswith(prefix):
            return s[len(prefix):]
        return s
    return strip_fn

# %%
strip_answers = strip_prefix('answers.')
all_df = all_df.rename(strip_answers, axis='columns')

strip_metadata = strip_prefix('metadata.')
all_df = all_df.rename(strip_metadata, axis='columns')

# %%
for c in all_df.columns:
    new_c = c.replace('.', '_')
    mapper_dict = {}
    mapper_dict[c] = new_c
    all_df = all_df.rename(mapper=mapper_dict, axis='columns')

# %%
all_df.describe()
# Out:
#               age  personality_trusting  personality_artistic  \
# count  156.000000             63.000000             63.000000
# mean    24.019231              3.698413              2.492063
# std     13.222889              1.130728              1.330450
# min      1.000000              1.000000              1.000000
# 25%     15.750000              3.000000              1.000000
# 50%     21.000000              4.000000              2.000000
# 75%     31.000000              4.000000              3.000000
# max     81.000000              5.000000              5.000000
#
#        personality_imagination  personality_reserved  personality_outgoing  \
# count                63.000000             63.000000             63.000000
# mean                  3.920635              3.317460              3.206349
# std                   1.082136              1.075015              1.309503
# min                   1.000000              1.000000              1.000000
# 25%                   3.000000              3.000000              2.000000
# 50%                   4.000000              4.000000              3.000000
# 75%                   5.000000              4.000000              4.000000
# max                   5.000000              5.000000              5.000000
#
#        personality_lazy  personality_stress  personality_nervous  \
# count         63.000000           63.000000            63.000000
# mean           3.619048            3.190476             3.365079
# std            1.288016            1.133893             1.261100
# min            1.000000            1.000000             1.000000
# 25%            3.000000            2.000000             2.000000
# 50%            4.000000            3.000000             4.000000
# 75%            5.000000            4.000000             4.000000
# max            5.000000            5.000000             5.000000
#
#        personality_fault  personality_thorough  musical_expertise  \
# count          63.000000             63.000000          99.000000
# mean            3.269841              3.063492           2.616162
# std             1.220872              1.119807           1.201250
# min             1.000000              1.000000           1.000000
# 25%             2.500000              2.000000           2.000000
# 50%             4.000000              3.000000           3.000000
# 75%             4.000000              4.000000           3.000000
# max             5.000000              5.000000           5.000000
#
#        concentration  control_power  control_like_dislike  control_tension  \
# count      63.000000      63.000000             63.000000        63.000000
# mean        4.142857       3.349206              3.396825         3.746032
# std         0.947954       1.193514              1.442888         1.092028
# min         2.000000       1.000000              1.000000         1.000000
# 25%         3.500000       3.000000              2.000000         3.000000
# 50%         4.000000       3.000000              4.000000         4.000000
# 75%         5.000000       4.000000              5.000000         5.000000
# max         5.000000       5.000000              5.000000         5.000000
#
#        control_engagement  control_activity  control_positivity  \
# count           63.000000         63.000000           63.000000
# mean             3.460317          3.222222            3.571429
# std              1.254995          1.156252            1.088270
# min              1.000000          1.000000            1.000000
# 25%              3.000000          2.000000            3.000000
# 50%              4.000000          3.000000            4.000000
# 75%              4.000000          4.000000            4.000000
# max              5.000000          5.000000            5.000000
#
#        control_familiarity  song_power  song_like_dislike  song_tension  \
# count                 63.0   72.000000         135.000000    144.000000
# mean                  -1.0    3.486111           3.192593      3.826389
# std                    0.0    1.310769           1.478686      1.172707
# min                   -1.0    1.000000           1.000000      1.000000
# 25%                   -1.0    3.000000           2.000000      3.000000
# 50%                   -1.0    4.000000           3.000000      4.000000
# 75%                   -1.0    5.000000           5.000000      5.000000
# max                   -1.0    5.000000           5.000000      5.000000
#
#        song_engagement  song_activity  song_positivity  song_familiarity  \
# count       135.000000     135.000000       135.000000        135.000000
# mean          3.148148       3.370370         3.318519          3.259259
# std           1.543008       1.020248         1.308137          1.440165
# min           1.000000       1.000000         1.000000          1.000000
# 25%           2.000000       3.000000         2.000000          2.000000
# 50%           3.000000       3.000000         4.000000          4.000000
# 75%           5.000000       4.000000         4.000000          4.000000
# max           5.000000       5.000000         5.000000          5.000000
#
#        visual_impairments  control_inspired  control_wonder  \
# count                 0.0               0.0             0.0
# mean                  NaN               NaN             NaN
# std                   NaN               NaN             NaN
# min                   NaN               NaN             NaN
# 25%                   NaN               NaN             NaN
# 50%                   NaN               NaN             NaN
# 75%                   NaN               NaN             NaN
# max                   NaN               NaN             NaN
#
#        control_spirituality  control_thrills  control_chills  \
# count                   0.0              0.0             0.0
# mean                    NaN              NaN             NaN
# std                     NaN              NaN             NaN
# min                     NaN              NaN             NaN
# 25%                     NaN              NaN             NaN
# 50%                     NaN              NaN             NaN
# 75%                     NaN              NaN             NaN
# max                     NaN              NaN             NaN
#
#        control_tenderness  control_nostalgia  control_goosebumps  \
# count                 0.0                0.0                 0.0
# mean                  NaN                NaN                 NaN
# std                   NaN                NaN                 NaN
# min                   NaN                NaN                 NaN
# 25%                   NaN                NaN                 NaN
# 50%                   NaN                NaN                 NaN
# 75%                   NaN                NaN                 NaN
# max                   NaN                NaN                 NaN
#
#        control_overwhelmed  control_shivers  song_inspired  song_wonder  \
# count                  0.0              0.0      22.000000    31.000000
# mean                   NaN              NaN       2.681818     2.967742
# std                    NaN              NaN       1.170525     1.353609
# min                    NaN              NaN       1.000000     1.000000
# 25%                    NaN              NaN       2.000000     2.000000
# 50%                    NaN              NaN       3.000000     3.000000
# 75%                    NaN              NaN       3.750000     4.000000
# max                    NaN              NaN       5.000000     5.000000
#
#        song_spirituality  song_thrills  song_chills  song_tenderness  \
# count          22.000000     22.000000    22.000000        31.000000
# mean            2.863636      2.000000     2.545455         3.419355
# std             1.355604      1.154701     1.335496         1.310832
# min             1.000000      1.000000     1.000000         1.000000
# 25%             2.000000      1.000000     1.000000         2.500000
# 50%             3.000000      2.000000     2.000000         4.000000
# 75%             4.000000      2.750000     4.000000         4.000000
# max             5.000000      4.000000     4.000000         5.000000
#
#        song_nostalgia  song_goosebumps  song_overwhelmed  song_shivers  \
# count       31.000000        22.000000         22.000000     22.000000
# mean         3.548387         2.363636          2.727273      2.136364
# std          1.362319         1.328997          1.351606      1.082126
# min          1.000000         1.000000          1.000000      1.000000
# 25%          2.000000         1.000000          1.250000      1.000000
# 50%          4.000000         2.500000          3.000000      2.000000
# 75%          5.000000         3.000000          4.000000      3.000000
# max          5.000000         5.000000          5.000000      4.000000
#
#        control_chillsshiversthrills  song_chillsshiversthrills  \
# count                           0.0                  50.000000
# mean                            NaN                   2.440000
# std                             NaN                   1.430855
# min                             NaN                   1.000000
# 25%                             NaN                   1.000000
# 50%                             NaN                   2.000000
# 75%                             NaN                   4.000000
# max                             NaN                   5.000000
#
#        control_transcendence  control_sadness  control_joyfulactivation  \
# count                    0.0              0.0                       0.0
# mean                     NaN              NaN                       NaN
# std                      NaN              NaN                       NaN
# min                      NaN              NaN                       NaN
# 25%                      NaN              NaN                       NaN
# 50%                      NaN              NaN                       NaN
# 75%                      NaN              NaN                       NaN
# max                      NaN              NaN                       NaN
#
#        control_peacefulness  song_transcendence  song_sadness  \
# count                   0.0            9.000000      9.000000
# mean                    NaN            3.444444      3.555556
# std                     NaN            0.881917      1.236033
# min                     NaN            2.000000      2.000000
# 25%                     NaN            3.000000      2.000000
# 50%                     NaN            3.000000      4.000000
# 75%                     NaN            4.000000      4.000000
# max                     NaN            5.000000      5.000000
#
#        song_joyfulactivation  song_peacefulness  musicpref_hip_hop  \
# count               9.000000           9.000000         156.000000
# mean                1.444444           3.444444           0.128205
# std                 0.726483           0.726483           0.335395
# min                 1.000000           2.000000           0.000000
# 25%                 1.000000           3.000000           0.000000
# 50%                 1.000000           4.000000           0.000000
# 75%                 2.000000           4.000000           0.000000
# max                 3.000000           4.000000           1.000000
#
#        musicpref_traditional_irish  musicpref_classical  musicpref_hiphop  \
# count                   156.000000           156.000000        156.000000
# mean                      0.115385             0.269231          0.051282
# std                       0.320514             0.444989          0.221283
# min                       0.000000             0.000000          0.000000
# 25%                       0.000000             0.000000          0.000000
# 50%                       0.000000             0.000000          0.000000
# 75%                       0.000000             1.000000          0.000000
# max                       1.000000             1.000000          1.000000
#
#        musicpref_folk  musicpref_jazz  musicpref_dance  musicpref_world  \
# count      156.000000      156.000000       156.000000       156.000000
# mean         0.057692        0.192308         0.217949         0.141026
# std          0.233912        0.395383         0.414182         0.349169
# min          0.000000        0.000000         0.000000         0.000000
# 25%          0.000000        0.000000         0.000000         0.000000
# 50%          0.000000        0.000000         0.000000         0.000000
# 75%          0.000000        0.000000         0.000000         0.000000
# max          1.000000        1.000000         1.000000         1.000000
#
#        musicpref_rock  musicpref_none  musicpref_pop
# count      156.000000      156.000000     156.000000
# mean         0.525641        0.019231       0.615385
# std          0.500950        0.137777       0.488071
# min          0.000000        0.000000       0.000000
# 25%          0.000000        0.000000       0.000000
# 50%          1.000000        0.000000       1.000000
# 75%          1.000000        0.000000       1.000000
# max          1.000000        1.000000       1.000000

# %% [markdown]
# ## `answers.musical_expertise`

# %% [markdown]
# Replace missing values with column median.

# %%
np.any(all_df.musical_expertise.isna())
# Out:
# True

# %%
all_df.musical_expertise.fillna(0, inplace=True)

# %%
def column_hist(col):
    bins = np.arange(col.min() - 0.5, col.max() + 1.5, 1)
    plt.hist(col, bins=bins)
    plt.title('Histogram for ' + col.name);

# %%
column_hist(all_df.musical_expertise)

# %%
all_df.musical_expertise.value_counts()
# Out:
# 0.0    57
# 3.0    33
# 2.0    23
# 1.0    22
# 4.0    13
# 5.0     8
# Name: musical_expertise, dtype: int64

# %%
np.any(all_df.musical_expertise.isna())
# Out:
# False

# %%
all_df.loc[:, 'musical_expertise'] = all_df.loc[:, 'musical_expertise'].astype('int').astype('category')

# %% [markdown]
# ## `age`

# %% [markdown]
# Check for missing values.

# %%
np.any(all_df.age.isna())
# Out:
# False

# %%
q25, q75 = all_df.age.quantile(q=.25), all_df.age.quantile(q=.75)
q25, q75
# Out:
# (15.75, 31.0)

# %%
iqr = q75 - q25
iqr
# Out:
# 15.25

# %%
low_cut, high_cut = q25 - (2 * iqr), q75 + (2 * iqr)
low_cut, high_cut
# Out:
# (-14.75, 61.5)

# %%
age_outliers = all_df.age[(all_df.age < 6) | (all_df.age > 100)]
age_outliers
# Out:
# _id
# 570eb76d83a73509d0e0359e    1.0
# 570eb72b83a73509d0e01f7c    5.0
# Name: age, dtype: float64

# %%
age_outlier_idx = age_outliers.index
age_outlier_idx
# Out:
# Index(['570eb76d83a73509d0e0359e', '570eb72b83a73509d0e01f7c'], dtype='object', name='_id')

# %%
all_df = all_df.drop(index=age_outlier_idx)
age_outliers = all_df.age[(all_df.age < 6) | (all_df.age > 100)]
age_outliers
# Out:
# Series([], Name: age, dtype: float64)

# %% [markdown]
# ## `control_chillsshiversthrills`

# %%
np.any(all_df.control_chillsshiversthrills.isna())
# Out:
# True

# %%
all_df.control_chillsshiversthrills.value_counts()
# Out:
# Series([], Name: control_chillsshiversthrills, dtype: int64)

# %% [markdown]
# Drop column, as there are no valid values.

# %%
all_df = all_df.drop(columns='control_chillsshiversthrills')

# %%
all_df.describe()
# Out:
#               age  personality_trusting  personality_artistic  \
# count  154.000000             61.000000             61.000000
# mean    24.292208              3.655738              2.459016
# std     13.085403              1.123762              1.311154
# min      6.000000              1.000000              1.000000
# 25%     16.000000              3.000000              1.000000
# 50%     21.000000              4.000000              2.000000
# 75%     31.000000              4.000000              3.000000
# max     81.000000              5.000000              5.000000
#
#        personality_imagination  personality_reserved  personality_outgoing  \
# count                61.000000             61.000000             61.000000
# mean                  3.885246              3.278689              3.196721
# std                   1.081640              1.066633              1.301533
# min                   1.000000              1.000000              1.000000
# 25%                   3.000000              3.000000              2.000000
# 50%                   4.000000              4.000000              3.000000
# 75%                   5.000000              4.000000              4.000000
# max                   5.000000              5.000000              5.000000
#
#        personality_lazy  personality_stress  personality_nervous  \
# count         61.000000           61.000000            61.000000
# mean           3.606557            3.163934             3.327869
# std            1.294587            1.128130             1.261234
# min            1.000000            1.000000             1.000000
# 25%            3.000000            2.000000             2.000000
# 50%            4.000000            3.000000             4.000000
# 75%            5.000000            4.000000             4.000000
# max            5.000000            5.000000             5.000000
#
#        personality_fault  personality_thorough  concentration  control_power  \
# count          61.000000             61.000000      61.000000      61.000000
# mean            3.245902              3.016393       4.147541       3.327869
# std             1.220051              1.102902       0.945799       1.193333
# min             1.000000              1.000000       2.000000       1.000000
# 25%             2.000000              2.000000       4.000000       3.000000
# 50%             4.000000              3.000000       4.000000       3.000000
# 75%             4.000000              4.000000       5.000000       4.000000
# max             5.000000              5.000000       5.000000       5.000000
#
#        control_like_dislike  control_tension  control_engagement  \
# count             61.000000        61.000000           61.000000
# mean               3.377049         3.721311            3.426230
# std                1.451022         1.097439            1.257763
# min                1.000000         1.000000            1.000000
# 25%                2.000000         3.000000            3.000000
# 50%                4.000000         4.000000            4.000000
# 75%                5.000000         5.000000            4.000000
# max                5.000000         5.000000            5.000000
#
#        control_activity  control_positivity  control_familiarity  song_power  \
# count         61.000000           61.000000                 61.0   70.000000
# mean           3.213115            3.557377                 -1.0    3.485714
# std            1.170680            1.088188                  0.0    1.304872
# min            1.000000            1.000000                 -1.0    1.000000
# 25%            2.000000            3.000000                 -1.0    3.000000
# 50%            3.000000            4.000000                 -1.0    4.000000
# 75%            4.000000            4.000000                 -1.0    5.000000
# max            5.000000            5.000000                 -1.0    5.000000
#
#        song_like_dislike  song_tension  song_engagement  song_activity  \
# count         133.000000    142.000000       133.000000     133.000000
# mean            3.165414      3.809859         3.120301       3.345865
# std             1.472889      1.172577         1.537597       1.007886
# min             1.000000      1.000000         1.000000       1.000000
# 25%             2.000000      3.000000         2.000000       3.000000
# 50%             3.000000      4.000000         3.000000       3.000000
# 75%             5.000000      5.000000         5.000000       4.000000
# max             5.000000      5.000000         5.000000       5.000000
#
#        song_positivity  song_familiarity  visual_impairments  \
# count       133.000000        133.000000                 0.0
# mean          3.293233          3.263158                 NaN
# std           1.301409          1.429636                 NaN
# min           1.000000          1.000000                 NaN
# 25%           2.000000          2.000000                 NaN
# 50%           3.000000          4.000000                 NaN
# 75%           4.000000          4.000000                 NaN
# max           5.000000          5.000000                 NaN
#
#        control_inspired  control_wonder  control_spirituality  \
# count               0.0             0.0                   0.0
# mean                NaN             NaN                   NaN
# std                 NaN             NaN                   NaN
# min                 NaN             NaN                   NaN
# 25%                 NaN             NaN                   NaN
# 50%                 NaN             NaN                   NaN
# 75%                 NaN             NaN                   NaN
# max                 NaN             NaN                   NaN
#
#        control_thrills  control_chills  control_tenderness  control_nostalgia  \
# count              0.0             0.0                 0.0                0.0
# mean               NaN             NaN                 NaN                NaN
# std                NaN             NaN                 NaN                NaN
# min                NaN             NaN                 NaN                NaN
# 25%                NaN             NaN                 NaN                NaN
# 50%                NaN             NaN                 NaN                NaN
# 75%                NaN             NaN                 NaN                NaN
# max                NaN             NaN                 NaN                NaN
#
#        control_goosebumps  control_overwhelmed  control_shivers  \
# count                 0.0                  0.0              0.0
# mean                  NaN                  NaN              NaN
# std                   NaN                  NaN              NaN
# min                   NaN                  NaN              NaN
# 25%                   NaN                  NaN              NaN
# 50%                   NaN                  NaN              NaN
# 75%                   NaN                  NaN              NaN
# max                   NaN                  NaN              NaN
#
#        song_inspired  song_wonder  song_spirituality  song_thrills  \
# count      22.000000    31.000000          22.000000     22.000000
# mean        2.681818     2.967742           2.863636      2.000000
# std         1.170525     1.353609           1.355604      1.154701
# min         1.000000     1.000000           1.000000      1.000000
# 25%         2.000000     2.000000           2.000000      1.000000
# 50%         3.000000     3.000000           3.000000      2.000000
# 75%         3.750000     4.000000           4.000000      2.750000
# max         5.000000     5.000000           5.000000      4.000000
#
#        song_chills  song_tenderness  song_nostalgia  song_goosebumps  \
# count    22.000000        31.000000       31.000000        22.000000
# mean      2.545455         3.419355        3.548387         2.363636
# std       1.335496         1.310832        1.362319         1.328997
# min       1.000000         1.000000        1.000000         1.000000
# 25%       1.000000         2.500000        2.000000         1.000000
# 50%       2.000000         4.000000        4.000000         2.500000
# 75%       4.000000         4.000000        5.000000         3.000000
# max       4.000000         5.000000        5.000000         5.000000
#
#        song_overwhelmed  song_shivers  song_chillsshiversthrills  \
# count         22.000000     22.000000                  50.000000
# mean           2.727273      2.136364                   2.440000
# std            1.351606      1.082126                   1.430855
# min            1.000000      1.000000                   1.000000
# 25%            1.250000      1.000000                   1.000000
# 50%            3.000000      2.000000                   2.000000
# 75%            4.000000      3.000000                   4.000000
# max            5.000000      4.000000                   5.000000
#
#        control_transcendence  control_sadness  control_joyfulactivation  \
# count                    0.0              0.0                       0.0
# mean                     NaN              NaN                       NaN
# std                      NaN              NaN                       NaN
# min                      NaN              NaN                       NaN
# 25%                      NaN              NaN                       NaN
# 50%                      NaN              NaN                       NaN
# 75%                      NaN              NaN                       NaN
# max                      NaN              NaN                       NaN
#
#        control_peacefulness  song_transcendence  song_sadness  \
# count                   0.0            9.000000      9.000000
# mean                    NaN            3.444444      3.555556
# std                     NaN            0.881917      1.236033
# min                     NaN            2.000000      2.000000
# 25%                     NaN            3.000000      2.000000
# 50%                     NaN            3.000000      4.000000
# 75%                     NaN            4.000000      4.000000
# max                     NaN            5.000000      5.000000
#
#        song_joyfulactivation  song_peacefulness  musicpref_hip_hop  \
# count               9.000000           9.000000         154.000000
# mean                1.444444           3.444444           0.129870
# std                 0.726483           0.726483           0.337257
# min                 1.000000           2.000000           0.000000
# 25%                 1.000000           3.000000           0.000000
# 50%                 1.000000           4.000000           0.000000
# 75%                 2.000000           4.000000           0.000000
# max                 3.000000           4.000000           1.000000
#
#        musicpref_traditional_irish  musicpref_classical  musicpref_hiphop  \
# count                   154.000000           154.000000        154.000000
# mean                      0.116883             0.266234          0.051948
# std                       0.322329             0.443430          0.222646
# min                       0.000000             0.000000          0.000000
# 25%                       0.000000             0.000000          0.000000
# 50%                       0.000000             0.000000          0.000000
# 75%                       0.000000             1.000000          0.000000
# max                       1.000000             1.000000          1.000000
#
#        musicpref_folk  musicpref_jazz  musicpref_dance  musicpref_world  \
# count      154.000000      154.000000       154.000000       154.000000
# mean         0.058442        0.188312         0.220779         0.142857
# std          0.235342        0.392236         0.416125         0.351069
# min          0.000000        0.000000         0.000000         0.000000
# 25%          0.000000        0.000000         0.000000         0.000000
# 50%          0.000000        0.000000         0.000000         0.000000
# 75%          0.000000        0.000000         0.000000         0.000000
# max          1.000000        1.000000         1.000000         1.000000
#
#        musicpref_rock  musicpref_none  musicpref_pop
# count      154.000000      154.000000     154.000000
# mean         0.532468        0.019481       0.616883
# std          0.500573        0.138657       0.487733
# min          0.000000        0.000000       0.000000
# 25%          0.000000        0.000000       0.000000
# 50%          1.000000        0.000000       1.000000
# 75%          1.000000        0.000000       1.000000
# max          1.000000        1.000000       1.000000

# %% [markdown]
# ## `control_activity`

# %%
np.any(all_df.control_activity.isna())
# Out:
# True

# %%
all_df.control_activity.median()
# Out:
# 3.0

# %%
all_df.control_activity.fillna(0, inplace=True)
column_hist(all_df.control_activity)

# %%
np.any(all_df.control_activity.isna())
# Out:
# False

# %%
all_df.loc[:, 'control_activity'] = all_df.loc[:, 'control_activity'].astype('int').astype('category')

# %% [markdown]
# ## `control_tension`

# %%
np.any(all_df.control_tension.isna())
# Out:
# True

# %%
column_hist(all_df.control_tension)

# %%
all_df.control_tension.median()
# Out:
# 4.0

# %%
all_df.control_tension.fillna(0, inplace=True)
column_hist(all_df.control_tension)

# %%
np.any(all_df.control_tension.isna())
# Out:
# False

# %%
all_df.loc[:, 'control_tension'] = all_df.loc[:, 'control_tension'].astype('int').astype('category')

# %% [markdown]
# ## `control_familiarity`

# %% [markdown]
# Drop this column, as it doesn't make any sense.

# %%
all_df = all_df.drop(columns='control_familiarity')
all_df.describe()
# Out:
#               age  personality_trusting  personality_artistic  \
# count  154.000000             61.000000             61.000000
# mean    24.292208              3.655738              2.459016
# std     13.085403              1.123762              1.311154
# min      6.000000              1.000000              1.000000
# 25%     16.000000              3.000000              1.000000
# 50%     21.000000              4.000000              2.000000
# 75%     31.000000              4.000000              3.000000
# max     81.000000              5.000000              5.000000
#
#        personality_imagination  personality_reserved  personality_outgoing  \
# count                61.000000             61.000000             61.000000
# mean                  3.885246              3.278689              3.196721
# std                   1.081640              1.066633              1.301533
# min                   1.000000              1.000000              1.000000
# 25%                   3.000000              3.000000              2.000000
# 50%                   4.000000              4.000000              3.000000
# 75%                   5.000000              4.000000              4.000000
# max                   5.000000              5.000000              5.000000
#
#        personality_lazy  personality_stress  personality_nervous  \
# count         61.000000           61.000000            61.000000
# mean           3.606557            3.163934             3.327869
# std            1.294587            1.128130             1.261234
# min            1.000000            1.000000             1.000000
# 25%            3.000000            2.000000             2.000000
# 50%            4.000000            3.000000             4.000000
# 75%            5.000000            4.000000             4.000000
# max            5.000000            5.000000             5.000000
#
#        personality_fault  personality_thorough  concentration  control_power  \
# count          61.000000             61.000000      61.000000      61.000000
# mean            3.245902              3.016393       4.147541       3.327869
# std             1.220051              1.102902       0.945799       1.193333
# min             1.000000              1.000000       2.000000       1.000000
# 25%             2.000000              2.000000       4.000000       3.000000
# 50%             4.000000              3.000000       4.000000       3.000000
# 75%             4.000000              4.000000       5.000000       4.000000
# max             5.000000              5.000000       5.000000       5.000000
#
#        control_like_dislike  control_engagement  control_positivity  \
# count             61.000000           61.000000           61.000000
# mean               3.377049            3.426230            3.557377
# std                1.451022            1.257763            1.088188
# min                1.000000            1.000000            1.000000
# 25%                2.000000            3.000000            3.000000
# 50%                4.000000            4.000000            4.000000
# 75%                5.000000            4.000000            4.000000
# max                5.000000            5.000000            5.000000
#
#        song_power  song_like_dislike  song_tension  song_engagement  \
# count   70.000000         133.000000    142.000000       133.000000
# mean     3.485714           3.165414      3.809859         3.120301
# std      1.304872           1.472889      1.172577         1.537597
# min      1.000000           1.000000      1.000000         1.000000
# 25%      3.000000           2.000000      3.000000         2.000000
# 50%      4.000000           3.000000      4.000000         3.000000
# 75%      5.000000           5.000000      5.000000         5.000000
# max      5.000000           5.000000      5.000000         5.000000
#
#        song_activity  song_positivity  song_familiarity  visual_impairments  \
# count     133.000000       133.000000        133.000000                 0.0
# mean        3.345865         3.293233          3.263158                 NaN
# std         1.007886         1.301409          1.429636                 NaN
# min         1.000000         1.000000          1.000000                 NaN
# 25%         3.000000         2.000000          2.000000                 NaN
# 50%         3.000000         3.000000          4.000000                 NaN
# 75%         4.000000         4.000000          4.000000                 NaN
# max         5.000000         5.000000          5.000000                 NaN
#
#        control_inspired  control_wonder  control_spirituality  \
# count               0.0             0.0                   0.0
# mean                NaN             NaN                   NaN
# std                 NaN             NaN                   NaN
# min                 NaN             NaN                   NaN
# 25%                 NaN             NaN                   NaN
# 50%                 NaN             NaN                   NaN
# 75%                 NaN             NaN                   NaN
# max                 NaN             NaN                   NaN
#
#        control_thrills  control_chills  control_tenderness  control_nostalgia  \
# count              0.0             0.0                 0.0                0.0
# mean               NaN             NaN                 NaN                NaN
# std                NaN             NaN                 NaN                NaN
# min                NaN             NaN                 NaN                NaN
# 25%                NaN             NaN                 NaN                NaN
# 50%                NaN             NaN                 NaN                NaN
# 75%                NaN             NaN                 NaN                NaN
# max                NaN             NaN                 NaN                NaN
#
#        control_goosebumps  control_overwhelmed  control_shivers  \
# count                 0.0                  0.0              0.0
# mean                  NaN                  NaN              NaN
# std                   NaN                  NaN              NaN
# min                   NaN                  NaN              NaN
# 25%                   NaN                  NaN              NaN
# 50%                   NaN                  NaN              NaN
# 75%                   NaN                  NaN              NaN
# max                   NaN                  NaN              NaN
#
#        song_inspired  song_wonder  song_spirituality  song_thrills  \
# count      22.000000    31.000000          22.000000     22.000000
# mean        2.681818     2.967742           2.863636      2.000000
# std         1.170525     1.353609           1.355604      1.154701
# min         1.000000     1.000000           1.000000      1.000000
# 25%         2.000000     2.000000           2.000000      1.000000
# 50%         3.000000     3.000000           3.000000      2.000000
# 75%         3.750000     4.000000           4.000000      2.750000
# max         5.000000     5.000000           5.000000      4.000000
#
#        song_chills  song_tenderness  song_nostalgia  song_goosebumps  \
# count    22.000000        31.000000       31.000000        22.000000
# mean      2.545455         3.419355        3.548387         2.363636
# std       1.335496         1.310832        1.362319         1.328997
# min       1.000000         1.000000        1.000000         1.000000
# 25%       1.000000         2.500000        2.000000         1.000000
# 50%       2.000000         4.000000        4.000000         2.500000
# 75%       4.000000         4.000000        5.000000         3.000000
# max       4.000000         5.000000        5.000000         5.000000
#
#        song_overwhelmed  song_shivers  song_chillsshiversthrills  \
# count         22.000000     22.000000                  50.000000
# mean           2.727273      2.136364                   2.440000
# std            1.351606      1.082126                   1.430855
# min            1.000000      1.000000                   1.000000
# 25%            1.250000      1.000000                   1.000000
# 50%            3.000000      2.000000                   2.000000
# 75%            4.000000      3.000000                   4.000000
# max            5.000000      4.000000                   5.000000
#
#        control_transcendence  control_sadness  control_joyfulactivation  \
# count                    0.0              0.0                       0.0
# mean                     NaN              NaN                       NaN
# std                      NaN              NaN                       NaN
# min                      NaN              NaN                       NaN
# 25%                      NaN              NaN                       NaN
# 50%                      NaN              NaN                       NaN
# 75%                      NaN              NaN                       NaN
# max                      NaN              NaN                       NaN
#
#        control_peacefulness  song_transcendence  song_sadness  \
# count                   0.0            9.000000      9.000000
# mean                    NaN            3.444444      3.555556
# std                     NaN            0.881917      1.236033
# min                     NaN            2.000000      2.000000
# 25%                     NaN            3.000000      2.000000
# 50%                     NaN            3.000000      4.000000
# 75%                     NaN            4.000000      4.000000
# max                     NaN            5.000000      5.000000
#
#        song_joyfulactivation  song_peacefulness  musicpref_hip_hop  \
# count               9.000000           9.000000         154.000000
# mean                1.444444           3.444444           0.129870
# std                 0.726483           0.726483           0.337257
# min                 1.000000           2.000000           0.000000
# 25%                 1.000000           3.000000           0.000000
# 50%                 1.000000           4.000000           0.000000
# 75%                 2.000000           4.000000           0.000000
# max                 3.000000           4.000000           1.000000
#
#        musicpref_traditional_irish  musicpref_classical  musicpref_hiphop  \
# count                   154.000000           154.000000        154.000000
# mean                      0.116883             0.266234          0.051948
# std                       0.322329             0.443430          0.222646
# min                       0.000000             0.000000          0.000000
# 25%                       0.000000             0.000000          0.000000
# 50%                       0.000000             0.000000          0.000000
# 75%                       0.000000             1.000000          0.000000
# max                       1.000000             1.000000          1.000000
#
#        musicpref_folk  musicpref_jazz  musicpref_dance  musicpref_world  \
# count      154.000000      154.000000       154.000000       154.000000
# mean         0.058442        0.188312         0.220779         0.142857
# std          0.235342        0.392236         0.416125         0.351069
# min          0.000000        0.000000         0.000000         0.000000
# 25%          0.000000        0.000000         0.000000         0.000000
# 50%          0.000000        0.000000         0.000000         0.000000
# 75%          0.000000        0.000000         0.000000         0.000000
# max          1.000000        1.000000         1.000000         1.000000
#
#        musicpref_rock  musicpref_none  musicpref_pop
# count      154.000000      154.000000     154.000000
# mean         0.532468        0.019481       0.616883
# std          0.500573        0.138657       0.487733
# min          0.000000        0.000000       0.000000
# 25%          0.000000        0.000000       0.000000
# 50%          1.000000        0.000000       1.000000
# 75%          1.000000        0.000000       1.000000
# max          1.000000        1.000000       1.000000

# %% [markdown]
# ## `control_engagement`

# %%
np.any(all_df.control_engagement.isna())
# Out:
# True

# %%
column_hist(all_df.control_engagement)

# %%
all_df.control_engagement.fillna(0, inplace=True)
column_hist(all_df.control_engagement)

# %%
all_df.loc[:, 'control_engagement'] = all_df.loc[:, 'control_engagement'].astype('int').astype('category')

# %% [markdown]
# ## Fill other appropriate columns' NA values with 0 and 'categorify'

# %%
cols_to_fill_with_zero = [
    'control_positivity','control_like_dislike','song_chillsshiversthrills','song_activity','song_tension',
    'song_familiarity','song_engagement','song_positivity','song_like_dislike','song_inspired','song_wonder',
    'song_spirituality','song_thrills','song_chills','song_tenderness','song_nostalgia','song_goosebumps',
    'song_overwhelmed','song_shivers','control_power','song_transcendence','song_sadness','song_joyfulactivation',
    'song_peacefulness','song_power','personality_trusting','personality_artistic','personality_imagination',
    'personality_reserved','personality_outgoing','personality_lazy','personality_stress','personality_nervous',
    'personality_fault','personality_thorough','concentration','musicpref_traditional_irish','musicpref_jazz',
    'musicpref_folk','musicpref_hiphop','musicpref_classical','musicpref_none','musicpref_rock','musicpref_hip_hop',
    'musicpref_world','musicpref_pop','musicpref_dance','musical_background','visual_impairments',
    'hearing_impairments'
]

cols_to_drop = [
    'control_inspired','control_wonder','control_spirituality','control_thrills','control_chills',
    'control_tenderness','control_nostalgia','control_goosebumps','control_overwhelmed','control_shivers',
    'control_transcendence','control_sadness','control_joyfulactivation','control_peacefulness','dob'
]

# %%
for c in cols_to_fill_with_zero:
    all_df[c].fillna(0, inplace=True)
    all_df.loc[:, c] = all_df.loc[:, c].astype('int').astype('category')

# %% [markdown]
# ## Drop columns that don't make sense (e.g., familiarity with control stimulus)

# %%
for c in cols_to_drop:
    all_df = all_df.drop(columns=c)

# %% [markdown]
# Also drop `Unnamed: 0` column.

# %%
all_df = all_df.drop(columns='Unnamed: 0')

# %%
all_df.describe()
# Out:
#               age
# count  154.000000
# mean    24.292208
# std     13.085403
# min      6.000000
# 25%     16.000000
# 50%     21.000000
# 75%     31.000000
# max     81.000000

# %% [markdown]
# ## Fill NA values with column mode/'other' as appropriate

# %%
cols_to_fill_with_other = [
    'location', 'sex', 'nationality', 'language'
]

# %%
for c in cols_to_fill_with_other:
    all_df[c].fillna('other', inplace=True)

# %% [markdown]
# # Write out CSV

# %%
all_df.to_csv(Path('data', 'good_reaction_trials_categorified_q90_javier_all_no_bastards.csv'))

# %%
pd.read_csv(Path('data', 'good_reaction_trials_categorified_q90_javier_all_no_bastards.csv')).columns
# Out:
# Index(['_id', 'location', 'language', 'nationality', 'age', 'sex',
#        'hearing_impairments', 'personality_trusting', 'personality_artistic',
#        'personality_imagination', 'personality_reserved',
#        'personality_outgoing', 'personality_lazy', 'personality_stress',
#        'personality_nervous', 'personality_fault', 'personality_thorough',
#        'musical_expertise', 'concentration', 'critical_reaction',
#        'control_power', 'control_like_dislike', 'control_tension',
#        'control_engagement', 'control_activity', 'control_positivity',
#        'song_power', 'song_like_dislike', 'song_tension', 'song_engagement',
#        'song_activity', 'song_positivity', 'song_familiarity',
#        'musical_background', 'visual_impairments', 'song_inspired',
#        'song_wonder', 'song_spirituality', 'song_thrills', 'song_chills',
#        'song_tenderness', 'song_nostalgia', 'song_goosebumps',
#        'song_overwhelmed', 'song_shivers', 'song_chillsshiversthrills',
#        'song_transcendence', 'song_sadness', 'song_joyfulactivation',
#        'song_peacefulness', 'song', 'musicpref_hip_hop',
#        'musicpref_traditional_irish', 'musicpref_classical',
#        'musicpref_hiphop', 'musicpref_folk', 'musicpref_jazz',
#        'musicpref_dance', 'musicpref_world', 'musicpref_rock',
#        'musicpref_none', 'musicpref_pop'],
#       dtype='object')

# %% [markdown]
# # Thoughts
#
# - Might want to look at treating Likert-type items as categorical and using a completely separate category for missing values, instead of filling them with the mean.
# - Data augmentation to balance classes
# - Exclude columns which are all the same for most people (chills, etc.)
# - Take results from working with other songs and break out weighted F-beta scores for comparison with *Hallelujah*-only results
