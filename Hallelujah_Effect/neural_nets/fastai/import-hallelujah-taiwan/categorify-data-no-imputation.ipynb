# %%
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# Read each CSV into a `DataFrame`.

# %%
csv_path = Path('data/good_hallelujah_taiwan_trials_and_signals.csv')
df = pd.read_csv(csv_path, index_col='_id')

# %% [markdown]
# Concatenate all song `DataFrame`s into a master `DataFrame`.

# %%
all_df = df

# %%
pd.set_option('display.max_columns', None)
all_df.describe()
# Out:
#        answers.age  answers.personality.trusting  \
# count    84.000000                     84.000000
# mean     16.928571                      3.738095
# std       8.524643                      1.087930
# min       1.000000                      1.000000
# 25%      11.000000                      3.000000
# 50%      16.000000                      4.000000
# 75%      20.000000                      4.000000
# max      48.000000                      5.000000
#
#        answers.personality.artistic  answers.personality.imagination  \
# count                     84.000000                        84.000000
# mean                       2.416667                         3.940476
# std                        1.300679                         1.079393
# min                        1.000000                         1.000000
# 25%                        1.000000                         3.000000
# 50%                        2.000000                         4.000000
# 75%                        3.000000                         5.000000
# max                        5.000000                         5.000000
#
#        answers.personality.reserved  answers.personality.outgoing  \
# count                     84.000000                     84.000000
# mean                       3.214286                      3.250000
# std                        1.162376                      1.334212
# min                        1.000000                      1.000000
# 25%                        2.000000                      2.000000
# 50%                        4.000000                      3.500000
# 75%                        4.000000                      4.000000
# max                        5.000000                      5.000000
#
#        answers.personality.lazy  answers.personality.stress  \
# count                 84.000000                   84.000000
# mean                   3.630952                    3.190476
# std                    1.268523                    1.135158
# min                    1.000000                    1.000000
# 25%                    3.000000                    2.000000
# 50%                    4.000000                    3.000000
# 75%                    5.000000                    4.000000
# max                    5.000000                    5.000000
#
#        answers.personality.nervous  answers.personality.fault  \
# count                    84.000000                  84.000000
# mean                      3.416667                   3.238095
# std                       1.204493                   1.198584
# min                       1.000000                   1.000000
# 25%                       3.000000                   2.000000
# 50%                       4.000000                   3.500000
# 75%                       4.000000                   4.000000
# max                       5.000000                   5.000000
#
#        answers.personality.thorough  answers.musical_expertise  \
# count                     84.000000                  84.000000
# mean                       3.035714                   2.535714
# std                        1.145409                   1.246165
# min                        1.000000                   1.000000
# 25%                        2.000000                   1.750000
# 50%                        3.000000                   2.500000
# 75%                        4.000000                   3.000000
# max                        5.000000                   5.000000
#
#        answers.concentration  control_power  control_like_dislike  \
# count              84.000000      84.000000             84.000000
# mean                4.154762       3.392857              3.333333
# std                 0.924813       1.212563              1.408523
# min                 2.000000       1.000000              1.000000
# 25%                 4.000000       3.000000              2.000000
# 50%                 4.000000       3.000000              3.000000
# 75%                 5.000000       4.000000              5.000000
# max                 5.000000       5.000000              5.000000
#
#        control_tension  control_engagement  control_activity  \
# count        84.000000           84.000000         84.000000
# mean          3.738095            3.416667          3.083333
# std           1.109858            1.309910          1.184319
# min           1.000000            1.000000          1.000000
# 25%           3.000000            2.750000          2.000000
# 50%           4.000000            4.000000          3.000000
# 75%           5.000000            4.000000          4.000000
# max           5.000000            5.000000          5.000000
#
#        control_positivity  control_familiarity  song_power  song_like_dislike  \
# count           84.000000                 84.0   84.000000          84.000000
# mean             3.547619                 -1.0    3.535714           4.226190
# std              1.112955                  0.0    1.312098           1.056833
# min              1.000000                 -1.0    1.000000           1.000000
# 25%              3.000000                 -1.0    3.000000           4.000000
# 50%              3.500000                 -1.0    4.000000           5.000000
# 75%              4.250000                 -1.0    5.000000           5.000000
# max              5.000000                 -1.0    5.000000           5.000000
#
#        song_tension  song_engagement  song_activity  song_positivity  \
# count     84.000000        84.000000      84.000000        84.000000
# mean       4.273810         4.285714       3.488095         4.178571
# std        0.998206         0.925820       1.124685         0.946276
# min        1.000000         1.000000       1.000000         1.000000
# 25%        4.000000         4.000000       3.000000         4.000000
# 50%        5.000000         4.500000       4.000000         4.000000
# 75%        5.000000         5.000000       4.000000         5.000000
# max        5.000000         5.000000       5.000000         5.000000
#
#        song_familiarity  answers.musicpref.pop  answers.musicpref.hiphop  \
# count         84.000000              84.000000                 84.000000
# mean           2.547619               0.678571                  0.119048
# std            1.616219               0.469830                  0.325790
# min            1.000000               0.000000                  0.000000
# 25%            1.000000               0.000000                  0.000000
# 50%            2.000000               1.000000                  0.000000
# 75%            4.000000               1.000000                  0.000000
# max            5.000000               1.000000                  1.000000
#
#        answers.musicpref.jazz  answers.musicpref.classical  \
# count               84.000000                    84.000000
# mean                 0.166667                     0.309524
# std                  0.374916                     0.465074
# min                  0.000000                     0.000000
# 25%                  0.000000                     0.000000
# 50%                  0.000000                     0.000000
# 75%                  0.000000                     1.000000
# max                  1.000000                     1.000000
#
#        answers.musicpref.folk  answers.musicpref.rock  \
# count               84.000000               84.000000
# mean                 0.154762                0.309524
# std                  0.363850                0.465074
# min                  0.000000                0.000000
# 25%                  0.000000                0.000000
# 50%                  0.000000                0.000000
# 75%                  0.000000                1.000000
# max                  1.000000                1.000000
#
#        answers.musicpref.world  answers.musicpref.dance
# count                84.000000                84.000000
# mean                  0.107143                 0.107143
# std                   0.311152                 0.311152
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max                   1.000000                 1.000000

# %% [markdown]
# # Data Cleanup

# %% [markdown]
# Drop `answers.` and `metadata.` from column names.

# %%
def strip_prefix(prefix=''):
    def strip_fn(s):
        if s.startswith(prefix):
            return s[len(prefix):]
        return s
    return strip_fn

# %%
strip_answers = strip_prefix('answers.')
all_df = all_df.rename(strip_answers, axis='columns')

strip_metadata = strip_prefix('metadata.')
all_df = all_df.rename(strip_metadata, axis='columns')

# %%
for c in all_df.columns:
    new_c = c.replace('.', '_')
    mapper_dict = {}
    mapper_dict[c] = new_c
    all_df = all_df.rename(mapper=mapper_dict, axis='columns')

# %%
all_df.describe()
# Out:
#              age  personality_trusting  personality_artistic  \
# count  84.000000             84.000000             84.000000
# mean   16.928571              3.738095              2.416667
# std     8.524643              1.087930              1.300679
# min     1.000000              1.000000              1.000000
# 25%    11.000000              3.000000              1.000000
# 50%    16.000000              4.000000              2.000000
# 75%    20.000000              4.000000              3.000000
# max    48.000000              5.000000              5.000000
#
#        personality_imagination  personality_reserved  personality_outgoing  \
# count                84.000000             84.000000             84.000000
# mean                  3.940476              3.214286              3.250000
# std                   1.079393              1.162376              1.334212
# min                   1.000000              1.000000              1.000000
# 25%                   3.000000              2.000000              2.000000
# 50%                   4.000000              4.000000              3.500000
# 75%                   5.000000              4.000000              4.000000
# max                   5.000000              5.000000              5.000000
#
#        personality_lazy  personality_stress  personality_nervous  \
# count         84.000000           84.000000            84.000000
# mean           3.630952            3.190476             3.416667
# std            1.268523            1.135158             1.204493
# min            1.000000            1.000000             1.000000
# 25%            3.000000            2.000000             3.000000
# 50%            4.000000            3.000000             4.000000
# 75%            5.000000            4.000000             4.000000
# max            5.000000            5.000000             5.000000
#
#        personality_fault  personality_thorough  musical_expertise  \
# count          84.000000             84.000000          84.000000
# mean            3.238095              3.035714           2.535714
# std             1.198584              1.145409           1.246165
# min             1.000000              1.000000           1.000000
# 25%             2.000000              2.000000           1.750000
# 50%             3.500000              3.000000           2.500000
# 75%             4.000000              4.000000           3.000000
# max             5.000000              5.000000           5.000000
#
#        concentration  control_power  control_like_dislike  control_tension  \
# count      84.000000      84.000000             84.000000        84.000000
# mean        4.154762       3.392857              3.333333         3.738095
# std         0.924813       1.212563              1.408523         1.109858
# min         2.000000       1.000000              1.000000         1.000000
# 25%         4.000000       3.000000              2.000000         3.000000
# 50%         4.000000       3.000000              3.000000         4.000000
# 75%         5.000000       4.000000              5.000000         5.000000
# max         5.000000       5.000000              5.000000         5.000000
#
#        control_engagement  control_activity  control_positivity  \
# count           84.000000         84.000000           84.000000
# mean             3.416667          3.083333            3.547619
# std              1.309910          1.184319            1.112955
# min              1.000000          1.000000            1.000000
# 25%              2.750000          2.000000            3.000000
# 50%              4.000000          3.000000            3.500000
# 75%              4.000000          4.000000            4.250000
# max              5.000000          5.000000            5.000000
#
#        control_familiarity  song_power  song_like_dislike  song_tension  \
# count                 84.0   84.000000          84.000000     84.000000
# mean                  -1.0    3.535714           4.226190      4.273810
# std                    0.0    1.312098           1.056833      0.998206
# min                   -1.0    1.000000           1.000000      1.000000
# 25%                   -1.0    3.000000           4.000000      4.000000
# 50%                   -1.0    4.000000           5.000000      5.000000
# 75%                   -1.0    5.000000           5.000000      5.000000
# max                   -1.0    5.000000           5.000000      5.000000
#
#        song_engagement  song_activity  song_positivity  song_familiarity  \
# count        84.000000      84.000000        84.000000         84.000000
# mean          4.285714       3.488095         4.178571          2.547619
# std           0.925820       1.124685         0.946276          1.616219
# min           1.000000       1.000000         1.000000          1.000000
# 25%           4.000000       3.000000         4.000000          1.000000
# 50%           4.500000       4.000000         4.000000          2.000000
# 75%           5.000000       4.000000         5.000000          4.000000
# max           5.000000       5.000000         5.000000          5.000000
#
#        musicpref_pop  musicpref_hiphop  musicpref_jazz  musicpref_classical  \
# count      84.000000         84.000000       84.000000            84.000000
# mean        0.678571          0.119048        0.166667             0.309524
# std         0.469830          0.325790        0.374916             0.465074
# min         0.000000          0.000000        0.000000             0.000000
# 25%         0.000000          0.000000        0.000000             0.000000
# 50%         1.000000          0.000000        0.000000             0.000000
# 75%         1.000000          0.000000        0.000000             1.000000
# max         1.000000          1.000000        1.000000             1.000000
#
#        musicpref_folk  musicpref_rock  musicpref_world  musicpref_dance
# count       84.000000       84.000000        84.000000        84.000000
# mean         0.154762        0.309524         0.107143         0.107143
# std          0.363850        0.465074         0.311152         0.311152
# min          0.000000        0.000000         0.000000         0.000000
# 25%          0.000000        0.000000         0.000000         0.000000
# 50%          0.000000        0.000000         0.000000         0.000000
# 75%          0.000000        1.000000         0.000000         0.000000
# max          1.000000        1.000000         1.000000         1.000000

# %% [markdown]
# ## `age`

# %% [markdown]
# Check for missing values.

# %%
np.any(all_df.age.isna())
# Out:
# False

# %%
q25, q75 = all_df.age.quantile(q=.25), all_df.age.quantile(q=.75)
q25, q75
# Out:
# (11.0, 20.0)

# %%
iqr = q75 - q25
iqr
# Out:
# 9.0

# %%
low_cut, high_cut = q25 - (2 * iqr), q75 + (2 * iqr)
low_cut, high_cut
# Out:
# (-7.0, 38.0)

# %%
age_outliers = all_df.age[(all_df.age < 6) | (all_df.age > 100)]
age_outliers
# Out:
# _id
# 570eb76d83a73509d0e0359e    1
# 570eb72b83a73509d0e01f7c    5
# 570eb73683a73509d0e02363    5
# Name: age, dtype: int64

# %%
age_outlier_idx = age_outliers.index
age_outlier_idx
# Out:
# Index(['570eb76d83a73509d0e0359e', '570eb72b83a73509d0e01f7c',
#        '570eb73683a73509d0e02363'],
#       dtype='object', name='_id')

# %%
all_df = all_df.drop(index=age_outlier_idx)
age_outliers = all_df.age[(all_df.age < 6) | (all_df.age > 100)]
age_outliers
# Out:
# Series([], Name: age, dtype: int64)

# %% [markdown]
# ## Fill other appropriate columns' NA values with 0 and 'categorify'

# %%
# cols_to_fill_with_zero = [
#     'control_positivity','control_like_dislike','song_chillsshiversthrills','song_activity','song_tension',
#     'song_familiarity','song_engagement','song_positivity','song_like_dislike','song_inspired','song_wonder',
#     'song_spirituality','song_thrills','song_chills','song_tenderness','song_nostalgia','song_goosebumps',
#     'song_overwhelmed','song_shivers','control_power','song_transcendence','song_sadness','song_joyfulactivation',
#     'song_peacefulness','song_power','personality_trusting','personality_artistic','personality_imagination',
#     'personality_reserved','personality_outgoing','personality_lazy','personality_stress','personality_nervous',
#     'personality_fault','personality_thorough','concentration','musicpref_traditional_irish','musicpref_jazz',
#     'musicpref_folk','musicpref_hiphop','musicpref_classical','musicpref_none','musicpref_rock','musicpref_hip_hop',
#     'musicpref_world','musicpref_pop','musicpref_dance','musical_background','visual_impairments',
#     'hearing_impairments'
# ]

# %% [markdown]
# ## Drop columns that don't make sense (e.g., familiarity with control stimulus)

# %%
cols_to_drop = [
    'control_inspired','control_wonder','control_spirituality','control_thrills','control_chills',
    'control_tenderness','control_nostalgia','control_goosebumps','control_overwhelmed','control_shivers',
    'control_transcendence','control_sadness','control_joyfulactivation','control_peacefulness','dob',
    'control_chillsshiversthrills'
]

for c in cols_to_drop:
    try:
        all_df = all_df.drop(columns=c)
    except:
        pass

# %% [markdown]
# Also drop `Unnamed: 0` column.

# %%
all_df = all_df.drop(columns='Unnamed: 0')

# %%
all_df.describe()
# Out:
#              age  personality_trusting  personality_artistic  \
# count  81.000000             81.000000             81.000000
# mean   17.419753              3.703704              2.395062
# std     8.271735              1.089087              1.291114
# min     6.000000              1.000000              1.000000
# 25%    12.000000              3.000000              1.000000
# 50%    16.000000              4.000000              2.000000
# 75%    20.000000              4.000000              3.000000
# max    48.000000              5.000000              5.000000
#
#        personality_imagination  personality_reserved  personality_outgoing  \
# count                 81.00000             81.000000             81.000000
# mean                   3.91358              3.172840              3.259259
# std                    1.08625              1.159635              1.330205
# min                    1.00000              1.000000              1.000000
# 25%                    3.00000              2.000000              2.000000
# 50%                    4.00000              4.000000              4.000000
# 75%                    5.00000              4.000000              4.000000
# max                    5.00000              5.000000              5.000000
#
#        personality_lazy  personality_stress  personality_nervous  \
# count         81.000000           81.000000            81.000000
# mean           3.629630            3.172840             3.407407
# std            1.279106            1.137872             1.201850
# min            1.000000            1.000000             1.000000
# 25%            3.000000            2.000000             3.000000
# 50%            4.000000            3.000000             4.000000
# 75%            5.000000            4.000000             4.000000
# max            5.000000            5.000000             5.000000
#
#        personality_fault  personality_thorough  musical_expertise  \
# count          81.000000             81.000000          81.000000
# mean            3.222222              3.000000           2.543210
# std             1.204159              1.140175           1.215004
# min             1.000000              1.000000           1.000000
# 25%             2.000000              2.000000           2.000000
# 50%             4.000000              3.000000           3.000000
# 75%             4.000000              4.000000           3.000000
# max             5.000000              5.000000           5.000000
#
#        concentration  control_power  control_like_dislike  control_tension  \
# count      81.000000      81.000000             81.000000        81.000000
# mean        4.148148       3.358025              3.296296         3.703704
# std         0.923460       1.207359              1.409295         1.111805
# min         2.000000       1.000000              1.000000         1.000000
# 25%         4.000000       3.000000              2.000000         3.000000
# 50%         4.000000       3.000000              3.000000         4.000000
# 75%         5.000000       4.000000              5.000000         5.000000
# max         5.000000       5.000000              5.000000         5.000000
#
#        control_engagement  control_activity  control_positivity  \
# count           81.000000         81.000000           81.000000
# mean             3.370370          3.074074            3.518519
# std              1.308094          1.201850            1.108051
# min              1.000000          1.000000            1.000000
# 25%              2.000000          2.000000            3.000000
# 50%              4.000000          3.000000            3.000000
# 75%              4.000000          4.000000            4.000000
# max              5.000000          5.000000            5.000000
#
#        control_familiarity  song_power  song_like_dislike  song_tension  \
# count                 81.0   81.000000          81.000000     81.000000
# mean                  -1.0    3.518519           4.197531      4.246914
# std                    0.0    1.304905           1.065596      1.006614
# min                   -1.0    1.000000           1.000000      1.000000
# 25%                   -1.0    3.000000           4.000000      4.000000
# 50%                   -1.0    4.000000           5.000000      5.000000
# 75%                   -1.0    5.000000           5.000000      5.000000
# max                   -1.0    5.000000           5.000000      5.000000
#
#        song_engagement  song_activity  song_positivity  song_familiarity  \
# count        81.000000      81.000000        81.000000         81.000000
# mean          4.259259       3.456790         4.148148          2.506173
# std           0.932440       1.118586         0.950146          1.589996
# min           1.000000       1.000000         1.000000          1.000000
# 25%           4.000000       3.000000         4.000000          1.000000
# 50%           4.000000       4.000000         4.000000          2.000000
# 75%           5.000000       4.000000         5.000000          4.000000
# max           5.000000       5.000000         5.000000          5.000000
#
#        musicpref_pop  musicpref_hiphop  musicpref_jazz  musicpref_classical  \
# count      81.000000         81.000000       81.000000            81.000000
# mean        0.679012          0.123457        0.160494             0.308642
# std         0.469765          0.331010        0.369350             0.464811
# min         0.000000          0.000000        0.000000             0.000000
# 25%         0.000000          0.000000        0.000000             0.000000
# 50%         1.000000          0.000000        0.000000             0.000000
# 75%         1.000000          0.000000        0.000000             1.000000
# max         1.000000          1.000000        1.000000             1.000000
#
#        musicpref_folk  musicpref_rock  musicpref_world  musicpref_dance
# count       81.000000       81.000000        81.000000        81.000000
# mean         0.160494        0.320988         0.111111         0.111111
# std          0.369350        0.469765         0.316228         0.316228
# min          0.000000        0.000000         0.000000         0.000000
# 25%          0.000000        0.000000         0.000000         0.000000
# 50%          0.000000        0.000000         0.000000         0.000000
# 75%          0.000000        1.000000         0.000000         0.000000
# max          1.000000        1.000000         1.000000         1.000000

# %% [markdown]
# # Write out CSV

# %%
all_df.to_csv(Path('data', 'good_reaction_trials_categorified_no_impute.csv'))

# %%
pd.read_csv(Path('data', 'good_reaction_trials_categorified_no_impute.csv')).columns
# Out:
# Index(['_id', 'location', 'language', 'nationality', 'age', 'sex',
#        'hearing_impairments', 'personality_trusting', 'personality_artistic',
#        'personality_imagination', 'personality_reserved',
#        'personality_outgoing', 'personality_lazy', 'personality_stress',
#        'personality_nervous', 'personality_fault', 'personality_thorough',
#        'musical_expertise', 'concentration', 'critical_reaction',
#        'control_power', 'control_like_dislike', 'control_tension',
#        'control_engagement', 'control_activity', 'control_positivity',
#        'control_familiarity', 'song_power', 'song_like_dislike',
#        'song_tension', 'song_engagement', 'song_activity', 'song_positivity',
#        'song_familiarity', 'song', 'musicpref_pop', 'musicpref_hiphop',
#        'musicpref_jazz', 'musicpref_classical', 'musicpref_folk',
#        'musicpref_rock', 'musicpref_world', 'musicpref_dance'],
#       dtype='object')
