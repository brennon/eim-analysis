# %% [markdown]
# # "Hallelujah Effect" Analysis
#
# This notebook models the "Hallelujah Effect" in terms of all basic features available in the dataset for those subjects that listened to the song and had an EDA quality >80%.

# %%
# %bash
pip uninstall -y google-cloud-dataflow
pip install --upgrade --force tensorflow_transform==0.6.0 apache-beam[gcp]

# %% [markdown]
# <b>Restart the kernel</b> after you do a pip install (click on the <b>Reset</b> button in Datalab)

# %%
# %bash
pip freeze | grep -e 'flow\|beam'
# Out:
# apache-airflow==1.9.0
# apache-beam==2.5.0
# tensorflow==1.8.0
# tensorflow-transform==0.6.0
# You are using pip version 9.0.3, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import tensorflow as tf
import tensorflow_transform as tft
import shutil
print(tf.__version__)
# Out:
# /usr/local/envs/py2env/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 1.8.0

# %%
# Set bucket, project, and region
BUCKET = 'eim-muse'
PROJECT = 'eim-muse'
REGION = 'us-central1'

# %%
import os
os.environ['BUCKET'] = BUCKET
os.environ['PROJECT'] = PROJECT
os.environ['REGION'] = REGION

# %%
# %bash
gcloud config set project $PROJECT
gcloud config set compute/region $REGION
# Out:
# Updated property [core/project].
# Updated property [compute/region].

# %% [markdown]
# ## Retrieve and Subset Datasource
#
# Get data from BigQuery but defer filtering, etc. to Beam. Data in BigQuery has been pre-processed with Dataprep.

# %%
import google.datalab.bigquery as bq
def create_query(phase, EVERY_N):
  """
  phase: 1=train 2=valid
  """
  base_query = """
SELECT *
FROM
  `eim-muse.hallelujah_effect.full_hallelujah_trials_cleaned`
  """

  if EVERY_N == None:
    if phase < 2:
      # Training
      query = "{0} WHERE MOD(FARM_FINGERPRINT(id), 10) < 7".format(base_query)
    else:
      # Validation
      query = "{0} WHERE MOD(FARM_FINGERPRINT(id), 10) >= 7".format(base_query)
  else:
      query = "{0} WHERE MOD(FARM_FINGERPRINT(id), {1}) = {2}".format(base_query, EVERY_N, phase)
    
  return query

query = create_query(1, None)

# %%
df_valid = bq.Query(query).execute().result().to_dataframe()
df_valid.head()
df_valid.describe()
# Out:
#               age  concentration  musical_expertise    artistic       fault  \
# count  303.000000     303.000000         303.000000  303.000000  303.000000
# mean    24.726073       3.993500           2.547224    2.344099    3.175612
# std     13.931034       0.795258           1.009324    0.988361    0.891464
# min      1.000000       1.000000           1.000000    1.000000    1.000000
# 25%     16.000000       3.991266           2.000000    2.000000    3.000000
# 50%     21.000000       3.991266           2.529880    2.353712    3.144737
# 75%     31.000000       4.000000           3.000000    2.353712    4.000000
# max    121.000000       5.000000           5.000000    5.000000    5.000000
#
#        imagination        lazy     nervous    outgoing    reserved  \
# count   303.000000  303.000000  303.000000  303.000000  303.000000
# mean      3.852643    3.690403    3.629726    3.213016    3.145503
# std       0.821620    0.905895    0.875898    0.961299    0.891699
# min       1.000000    1.000000    1.000000    1.000000    1.000000
# 25%       3.824561    3.659389    3.596491    3.000000    3.000000
# 50%       3.824561    3.659389    3.596491    3.228070    3.117904
# 75%       4.000000    4.000000    4.000000    4.000000    4.000000
# max       5.000000    5.000000    5.000000    5.000000    5.000000
#
#                    ...               music_pref_none  music_pref_hiphop  \
# count              ...                    303.000000         303.000000
# mean               ...                      0.006601           0.138614
# std                ...                      0.081110           0.346115
# min                ...                      0.000000           0.000000
# 25%                ...                      0.000000           0.000000
# 50%                ...                      0.000000           0.000000
# 75%                ...                      0.000000           0.000000
# max                ...                      1.000000           1.000000
#
#        music_pref_dance  music_pref_world  music_pref_rock  music_pref_pop  \
# count        303.000000        303.000000       303.000000      303.000000
# mean           0.188119          0.132013         0.432343        0.673267
# std            0.391454          0.339065         0.496221        0.469794
# min            0.000000          0.000000         0.000000        0.000000
# 25%            0.000000          0.000000         0.000000        0.000000
# 50%            0.000000          0.000000         0.000000        1.000000
# 75%            0.000000          0.000000         1.000000        1.000000
# max            1.000000          1.000000         1.000000        1.000000
#
#        music_pref_classical  music_pref_jazz  music_pref_folk  \
# count            303.000000       303.000000       303.000000
# mean               0.306931         0.171617         0.089109
# std                0.461983         0.377671         0.285372
# min                0.000000         0.000000         0.000000
# 25%                0.000000         0.000000         0.000000
# 50%                0.000000         0.000000         0.000000
# 75%                1.000000         0.000000         0.000000
# max                1.000000         1.000000         1.000000
#
#        music_pref_traditional_irish
# count                    303.000000
# mean                       0.059406
# std                        0.236774
# min                        0.000000
# 25%                        0.000000
# 50%                        0.000000
# 75%                        0.000000
# max                        1.000000
#
# [8 rows x 29 columns]

# %%
train_query = create_query(1, None)
train_n = len(list(bq.Query(train_query).execute().result()))

eval_query = create_query(2, None)
eval_n = len(list(bq.Query(eval_query).execute().result()))

os.environ['TRAIN_N'] = str(train_n)
os.environ['EVAL_N'] = str(eval_n)

print('{} training examples / {} evaluation examples'.format(train_n, eval_n))
# Out:
# 303 training examples / 61 evaluation examples

# %%
df_valid.columns
# Out:
# Index([u'id', u'age', u'concentration', u'hearing_impairments',
#        u'musical_expertise', u'nationality', u'artistic', u'fault',
#        u'imagination', u'lazy', u'nervous', u'outgoing', u'reserved',
#        u'stress', u'thorough', u'trusting', u'activity', u'engagement',
#        u'familiarity', u'like_dislike', u'positivity', u'tension', u'sex',
#        u'hallelujah_reaction', u'location', u'language', u'music_pref_none',
#        u'music_pref_hiphop', u'music_pref_dance', u'music_pref_world',
#        u'music_pref_rock', u'music_pref_pop', u'music_pref_classical',
#        u'music_pref_jazz', u'music_pref_folk',
#        u'music_pref_traditional_irish'],
#       dtype='object')

# %% [markdown]
# ## Create ML dataset using tf.transform and Dataflow
#
# Let's use Cloud Dataflow to read in the BigQuery data and write it out as CSV files. Along the way, let's use tf.transform to do scaling and transforming. Using tf.transform allows us to save the metadata to ensure that the appropriate transformations get carried out during prediction as well.

# %%
# %writefile requirements.txt
tensorflow-transform==0.6.0
# Out:
# Overwriting requirements.txt

# %%
import datetime
import tensorflow as tf
import apache_beam as beam
import tensorflow_transform as tft
from tensorflow_transform.beam import impl as beam_impl

def is_valid(inputs):
    try:
        return True
    except:
        return False

float_features = [
    'activity',
    'age',
    'artistic',
    'concentration',
    'engagement',
    'familiarity',
    'fault',
    'imagination',
    'lazy',
    'like_dislike',
    'musical_expertise',
    'nervous',
    'outgoing',
    'positivity',
    'reserved',
    'stress',
    'tension',
    'thorough',
    'trusting'
]

boolean_features = [
    'hallelujah_reaction',
    'hearing_impairments',
    'music_pref_classical',
    'music_pref_dance',
    'music_pref_folk',
    'music_pref_hiphop',
    'music_pref_jazz',
    'music_pref_none',
    'music_pref_pop',
    'music_pref_rock',
    'music_pref_traditional_irish',
    'music_pref_world'
]

categorical_features = [
    'language',
    'location',
    'nationality',
    'sex'
]

def preprocess_tft(inputs):
    import datetime
    result = {}
    
    for feature in float_features:
        result[feature] = tft.scale_to_0_1(inputs[feature])
    
    for feature in boolean_features:
        result[feature] = tf.cast(inputs[feature], tf.int64)
    
    for feature in categorical_features:
        result[feature] = tf.identity(inputs[feature])
    
    return result

def preprocess(in_test_mode, EVERY_N=None):
  import os
  import os.path
  import tempfile
  from apache_beam.io import tfrecordio
  from tensorflow_transform.coders import example_proto_coder
  from tensorflow_transform.tf_metadata import dataset_metadata
  from tensorflow_transform.tf_metadata import dataset_schema
  from tensorflow_transform.beam import tft_beam_io
  from tensorflow_transform.beam.tft_beam_io import transform_fn_io

  job_name = 'hallelujah-effect-features' + '-' + datetime.datetime.now().strftime('%y%m%d-%H%M%S')    
  if in_test_mode:
    import shutil
    print 'Launching local job ... hang on'
    OUTPUT_DIR = './preproc_tft'
    shutil.rmtree(OUTPUT_DIR, ignore_errors=True)
    
  else:
    print 'Launching Dataflow job {} ... hang on'.format(job_name)
    OUTPUT_DIR = 'gs://{0}/analysis/hallelujah-effect/preproc_tft/'.format(BUCKET)
    import subprocess
    subprocess.call('gsutil rm -r {}'.format(OUTPUT_DIR).split())
  
  # Configure Beam pipeline options
  options = {
    'staging_location': os.path.join(OUTPUT_DIR, 'tmp', 'staging'),
    'temp_location': os.path.join(OUTPUT_DIR, 'tmp'),
    'job_name': job_name,
    'project': PROJECT,
    'max_num_workers': 24,
    'teardown_policy': 'TEARDOWN_ALWAYS',
    'no_save_main_session': True,
    'requirements_file': 'requirements.txt'
  }
  opts = beam.pipeline.PipelineOptions(flags=[], **options)
  if in_test_mode:
    RUNNER = 'DirectRunner'
  else:
    RUNNER = 'DataflowRunner'

  # Setup metadata
  raw_data_schema = {
    colname : dataset_schema.ColumnSchema(tf.string, [], dataset_schema.FixedColumnRepresentation())
                   for colname in categorical_features
  }
  raw_data_schema.update({
      colname : dataset_schema.ColumnSchema(tf.float32, [], dataset_schema.FixedColumnRepresentation())
                   for colname in float_features
    })
  raw_data_schema.update({
      colname : dataset_schema.ColumnSchema(tf.int64, [], dataset_schema.FixedColumnRepresentation())
                   for colname in boolean_features
    })
  raw_data_metadata = dataset_metadata.DatasetMetadata(dataset_schema.Schema(raw_data_schema))
  
  # run Beam  
  with beam.Pipeline(RUNNER, options=opts) as p:
    with beam_impl.Context(temp_dir=os.path.join(OUTPUT_DIR, 'tmp')):
      
      # Write the raw data metadata to disk
      # Without the overloaded operators: p.apply(tft_beam_io.WriteMetadata(os.path.join(OUTPUT_DIR, 'metadata/rawdata_metadata'), raw_data_metadata)
      _ = (raw_data_metadata
        | 'WriteInputMetadata' >> tft_beam_io.WriteMetadata(
            os.path.join(OUTPUT_DIR, 'metadata/rawdata_metadata'),
            pipeline=p))
           
      # Analyze and transform training data
      this_query = create_query(1, EVERY_N)
      
      # Read in training data from BigQuery table
      raw_data = (p
        # Get raw training data from BigQuery
        | 'train_read' >> beam.io.Read(beam.io.BigQuerySource(query=this_query, use_standard_sql=True))
        # Use our is_valid function to only retain valid examples from training data
        | 'train_filter' >> beam.Filter(is_valid))

      # Package raw training data and its metadata into a 'dataset'
      raw_dataset = (raw_data, raw_data_metadata)
      
      # Using the preprocessing function `preprocess_tft`, preprocess the training data
      # and produce a transformed training dataset and a function to transform other data later
      transformed_dataset, transform_fn = (
          raw_dataset | beam_impl.AnalyzeAndTransformDataset(preprocess_tft))
      
      # Break out the transformed training data and its metadata
      transformed_data, transformed_metadata = transformed_dataset
      
      # Write the transformed training data to files
      _ = transformed_data | 'WriteTrainData' >> tfrecordio.WriteToTFRecord(
          os.path.join(OUTPUT_DIR, 'train'),
          file_name_suffix='.gz',
          coder=example_proto_coder.ExampleProtoCoder(
              transformed_metadata.schema))
      
      # Read in test data from BigQuery table and filter as we did with training data
      raw_test_data = (p 
        | 'eval_read' >> beam.io.Read(beam.io.BigQuerySource(query=create_query(2, EVERY_N), use_standard_sql=True))
        | 'eval_filter' >> beam.Filter(is_valid))
      
      # Package test data and metadata into a dataset
      raw_test_dataset = (raw_test_data, raw_data_metadata)
      
      # Using the same transformation function that was calculated above, transform the test dataset
      transformed_test_dataset = (
          (raw_test_dataset, transform_fn) | beam_impl.TransformDataset())
      
      # Write the transformed test data to files
      transformed_test_data, _ = transformed_test_dataset
      _ = transformed_test_data | 'WriteTestData' >> tfrecordio.WriteToTFRecord(
          os.path.join(OUTPUT_DIR, 'eval'),
          file_name_suffix='.gz',
          coder=example_proto_coder.ExampleProtoCoder(
              transformed_metadata.schema))
      
      # Write the transformation function to a file, as well
      _ = (transform_fn
           | 'WriteTransformFn' >>
           transform_fn_io.WriteTransformFn(os.path.join(OUTPUT_DIR, 'metadata')))

# Preprocess the training/test data
preprocess(in_test_mode=True, EVERY_N=None)
# Out:
# Launching local job ... hang on
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./preproc_tft/tmp/tftransform_tmp/19bb5413bd4b4b0f8e36621e3922af0c/saved_model.pb
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./preproc_tft/tmp/tftransform_tmp/b65580123bf9446cb74310cb4a9f1128/saved_model.pb
# /usr/local/envs/py2env/lib/python2.7/site-packages/apache_beam/runners/direct/direct_runner.py:342: DeprecationWarning: options is deprecated since First stable release.. References to <pipeline>.options will not be supported
#   pipeline.replace_all(_get_transform_overrides(pipeline.options))
# WARNING:root:Dataset eim-muse:temp_dataset_5a0af3dc468743a38e880d08169800c5 does not exist so we will create it as temporary with location=None
# WARNING:root:Dataset eim-muse:temp_dataset_879b26de5073457cb0f8af39f9ec4a87 does not exist so we will create it as temporary with location=None
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./preproc_tft/tmp/tftransform_tmp/9ca1a4d8d57945c898e9ad464331262c/saved_model.pb
# INFO:tensorflow:SavedModel written to: ./preproc_tft/tmp/tftransform_tmp/9ca1a4d8d57945c898e9ad464331262c/saved_model.pb
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-10 01:20:05.224311. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
# %bash
ls -ls preproc_tft
ls -ls preproc_tft/metadata
# gsutil ls -l gs://${BUCKET}/analysis/hallelujah-effect/preproc_tft/
# gsutil ls -l gs://${BUCKET}/analysis/hallelujah-effect/preproc_tft/metadata
# Out:
# total 24
#  4 -rw-r--r-- 1 root root  3071 Jul 11 16:24 eval-00000-of-00001.gz
#  4 drwxr-xr-x 5 root root  4096 Jul 11 16:24 metadata
#  4 drwxr-xr-x 3 root root  4096 Jul 11 16:24 tmp
# 12 -rw-r--r-- 1 root root 11567 Jul 11 16:24 train-00000-of-00001.gz
# total 12
# 4 drwxr-xr-x 3 root root 4096 Jul 11 16:24 rawdata_metadata
# 4 drwxr-xr-x 3 root root 4096 Jul 11 16:24 transformed_metadata
# 4 drwxr-xr-x 3 root root 4096 Jul 11 16:24 transform_fn

# %% [markdown]
# <h2> Train off preprocessed data </h2>

# %% [markdown]
# ### Local Manual Training

# %%
MODEL_NAME = 'basic_dnn_classifier_top_28'
os.environ['MODEL_NAME'] = MODEL_NAME

# %%
# %%bash
#
# OUTPUT_DIR=${PWD}/../models/${MODEL_NAME}
# rm -rf ${OUTPUT_DIR}
# export PYTHONPATH=${PYTHONPATH}:$PWD/trainer
# python -m trainer.task \
#    --train_data_paths="${PWD}/preproc_tft/train*" \
#    --eval_data_paths="${PWD}/preproc_tft/eval*" \
#    --train_steps=2500 \
#    --train_batch_size=${TRAIN_N} \
#    --eval_steps=1 \
#    --output_dir=${OUTPUT_DIR} \
#    --job-dir=/tmp \
#    --metadata_path="${PWD}/preproc_tft/metadata"
# Out:
# /usr/local/envs/py2env/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 60, '_session_config': None, '_keep_checkpoint_max': 10, '_task_type': 'worker', '_train_distribute': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fede0cd7e90>, '_evaluation_master': '', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': '/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28', '_global_id_in_cluster': 0, '_save_summary_steps': 100}
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 60, '_session_config': None, '_keep_checkpoint_max': 10, '_task_type': 'worker', '_train_distribute': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fede0cd7ed0>, '_evaluation_master': '', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': '/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28', '_global_id_in_cluster': 0, '_save_summary_steps': 100}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 5 secs (eval_spec.throttle_secs) or training is finished.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow_transform/saved/input_fn_maker.py:557: read_batch_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:833: read_keyed_batch_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:542: read_keyed_batch_examples (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:550: queue_parsed_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# 2018-07-11 17:25:52.239881: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:loss = 206.42564, step = 1
# INFO:tensorflow:global_step/sec: 108.429
# INFO:tensorflow:loss = 114.865486, step = 101 (0.923 sec)
# INFO:tensorflow:global_step/sec: 133.615
# INFO:tensorflow:loss = 64.92659, step = 201 (0.748 sec)
# INFO:tensorflow:global_step/sec: 134.371
# INFO:tensorflow:loss = 63.222645, step = 301 (0.744 sec)
# INFO:tensorflow:Saving checkpoints for 349 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:Loss for final step: 40.187294.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-17:25:58
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-349
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-11-17:25:59
# INFO:tensorflow:Saving dict for global step 349: accuracy = 0.60655737, accuracy_baseline = 0.6721312, auc = 0.44085366, auc_precision_recall = 0.27787519, average_loss = 2.8048773, f1_score = 0.0, false_negatives = 20.0, false_positives = 4.0, global_step = 349, label/mean = 0.32786885, loss = 171.09752, precision = 0.0, prediction/mean = 0.09716902, recall = 0.0, true_negatives = 37.0, true_positives = 0.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-349
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/export/exporter/temp-1531329960/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-349
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 350 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:loss = 36.920017, step = 350
# INFO:tensorflow:global_step/sec: 117.65
# INFO:tensorflow:loss = 36.474228, step = 450 (0.851 sec)
# INFO:tensorflow:global_step/sec: 144.907
# INFO:tensorflow:loss = 32.986565, step = 550 (0.696 sec)
# INFO:tensorflow:global_step/sec: 132.232
# INFO:tensorflow:loss = 30.249239, step = 650 (0.750 sec)
# INFO:tensorflow:global_step/sec: 142.889
# INFO:tensorflow:loss = 23.499664, step = 750 (0.700 sec)
# INFO:tensorflow:Saving checkpoints for 778 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:Loss for final step: 22.228216.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-17:26:09
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-778
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-11-17:26:10
# INFO:tensorflow:Saving dict for global step 778: accuracy = 0.59016395, accuracy_baseline = 0.6721312, auc = 0.37134147, auc_precision_recall = 0.2366797, average_loss = 4.1585417, f1_score = 0.0, false_negatives = 20.0, false_positives = 5.0, global_step = 778, label/mean = 0.32786885, loss = 253.67104, precision = 0.0, prediction/mean = 0.0891507, recall = 0.0, true_negatives = 36.0, true_positives = 0.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-778
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/export/exporter/temp-1531329970/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-778
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 779 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:loss = 25.819324, step = 779
# INFO:tensorflow:global_step/sec: 113.307
# INFO:tensorflow:loss = 21.834637, step = 879 (0.883 sec)
# INFO:tensorflow:global_step/sec: 146.259
# INFO:tensorflow:loss = 25.484755, step = 979 (0.686 sec)
# INFO:tensorflow:global_step/sec: 141.604
# INFO:tensorflow:loss = 17.04516, step = 1079 (0.706 sec)
# INFO:tensorflow:global_step/sec: 141.25
# INFO:tensorflow:loss = 17.247606, step = 1179 (0.707 sec)
# INFO:tensorflow:Saving checkpoints for 1232 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:Loss for final step: 16.601448.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-17:26:18
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-1232
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-11-17:26:19
# INFO:tensorflow:Saving dict for global step 1232: accuracy = 0.60655737, accuracy_baseline = 0.6721312, auc = 0.36585367, auc_precision_recall = 0.19279131, average_loss = 4.9692264, f1_score = 0.0, false_negatives = 20.0, false_positives = 4.0, global_step = 1232, label/mean = 0.32786885, loss = 303.1228, precision = 0.0, prediction/mean = 0.08082457, recall = 0.0, true_negatives = 37.0, true_positives = 0.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-1232
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/export/exporter/temp-1531329980/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-1232
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1233 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:loss = 13.000499, step = 1233
# INFO:tensorflow:global_step/sec: 87.3246
# INFO:tensorflow:loss = 17.66103, step = 1333 (1.145 sec)
# INFO:tensorflow:global_step/sec: 95.6355
# INFO:tensorflow:loss = 31.646013, step = 1433 (1.046 sec)
# INFO:tensorflow:global_step/sec: 131.896
# INFO:tensorflow:loss = 10.521435, step = 1533 (0.758 sec)
# INFO:tensorflow:Saving checkpoints for 1558 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:Loss for final step: 13.780744.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-17:26:27
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-1558
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-11-17:26:28
# INFO:tensorflow:Saving dict for global step 1558: accuracy = 0.60655737, accuracy_baseline = 0.6721312, auc = 0.3682927, auc_precision_recall = 0.19383298, average_loss = 5.2976756, f1_score = 0.0, false_negatives = 20.0, false_positives = 4.0, global_step = 1558, label/mean = 0.32786885, loss = 323.1582, precision = 0.0, prediction/mean = 0.08033378, recall = 0.0, true_negatives = 37.0, true_positives = 0.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-1558
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/export/exporter/temp-1531329989/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-1558
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1559 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:loss = 9.93323, step = 1559
# INFO:tensorflow:global_step/sec: 114.289
# INFO:tensorflow:loss = 14.706202, step = 1659 (0.876 sec)
# INFO:tensorflow:global_step/sec: 141.47
# INFO:tensorflow:loss = 16.66984, step = 1759 (0.707 sec)
# INFO:tensorflow:global_step/sec: 143.825
# INFO:tensorflow:loss = 9.788587, step = 1859 (0.695 sec)
# INFO:tensorflow:global_step/sec: 143.821
# INFO:tensorflow:loss = 15.738779, step = 1959 (0.695 sec)
# INFO:tensorflow:Saving checkpoints for 2011 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:Loss for final step: 10.423014.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-17:26:37
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-2011
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-11-17:26:38
# INFO:tensorflow:Saving dict for global step 2011: accuracy = 0.60655737, accuracy_baseline = 0.6721312, auc = 0.36707318, auc_precision_recall = 0.19323774, average_loss = 5.5350156, f1_score = 0.0, false_negatives = 20.0, false_positives = 4.0, global_step = 2011, label/mean = 0.32786885, loss = 337.63596, precision = 0.0, prediction/mean = 0.08219353, recall = 0.0, true_negatives = 37.0, true_positives = 0.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-2011
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/export/exporter/temp-1531329998/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-2011
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2012 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:loss = 12.767954, step = 2012
# INFO:tensorflow:global_step/sec: 112.927
# INFO:tensorflow:loss = 15.923145, step = 2112 (0.890 sec)
# INFO:tensorflow:global_step/sec: 143.888
# INFO:tensorflow:loss = 17.138575, step = 2212 (0.690 sec)
# INFO:tensorflow:global_step/sec: 137.198
# INFO:tensorflow:loss = 20.065445, step = 2312 (0.729 sec)
# INFO:tensorflow:global_step/sec: 153.582
# INFO:tensorflow:loss = 11.570865, step = 2412 (0.651 sec)
# INFO:tensorflow:Saving checkpoints for 2468 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:Loss for final step: 8.0457535.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-17:26:46
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-2468
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-11-17:26:47
# INFO:tensorflow:Saving dict for global step 2468: accuracy = 0.60655737, accuracy_baseline = 0.6721312, auc = 0.36707318, auc_precision_recall = 0.19323774, average_loss = 5.727004, f1_score = 0.0, false_negatives = 20.0, false_positives = 4.0, global_step = 2468, label/mean = 0.32786885, loss = 349.34726, precision = 0.0, prediction/mean = 0.08247682, recall = 0.0, true_negatives = 37.0, true_positives = 0.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-2468
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/export/exporter/temp-1531330008/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-2468
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2469 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:loss = 10.657577, step = 2469
# INFO:tensorflow:Saving checkpoints for 2500 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:Loss for final step: 24.569109.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-17:26:53
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-2500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-11-17:26:54
# INFO:tensorflow:Saving dict for global step 2500: accuracy = 0.60655737, accuracy_baseline = 0.6721312, auc = 0.36707318, auc_precision_recall = 0.19323774, average_loss = 5.746234, f1_score = 0.0, false_negatives = 20.0, false_positives = 4.0, global_step = 2500, label/mean = 0.32786885, loss = 350.52026, precision = 0.0, prediction/mean = 0.081900045, recall = 0.0, true_negatives = 37.0, true_positives = 0.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-2500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/export/exporter/temp-1531330015/saved_model.pb

# %% [markdown]
# Results for 2500 batches of 303 cases (2500 training epochs using a `DNNClassifier`):
#
# - accuracy = 0.60655737
# - accuracy baseline = 0.6721312
# - auc = 0.36707318
# - auc precision recall = 0.19323774
# - average loss = 5.746234
# - f1 score = 0.0
# - false negatives = 20.0
# - false positives = 4.0
# - global step = 2500
# - label/mean = 0.32786885
# - loss = 350.52026
# - precision = 0.0
# - prediction/mean = 0.081900045
# - recall = 0.0
# - true negatives = 37.0
# - true positives = 0.0

# %% [markdown]
# ### Local ML Engine Training

# %%
# %%bash
#
# OUTPUT_DIR=${PWD}/../models/${MODEL_NAME}
# rm -rf ${OUTPUT_DIR}
# gcloud ml-engine local train \
#    --module-name=trainer.task \
#    --package-path=${PWD}/trainer/trainer \
#    --job-dir=$OUTPUT_DIR \
#    -- \
#    --train_data_paths="${PWD}/preproc_tft/train*" \
#    --eval_data_paths="${PWD}/preproc_tft/eval*" \
#    --train_steps=2500 \
#    --train_batch_size=${TRAIN_N} \
#    --eval_steps=1 \
#    --output_dir=${OUTPUT_DIR} \
#    --metadata_path="${PWD}/preproc_tft/metadata/"
# Out:
# /usr/local/envs/py2env/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:tensorflow:TF_CONFIG environment variable: {u'environment': u'cloud', u'cluster': {}, u'job': {u'args': [u'--train_data_paths=/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/preproc_tft/train*', u'--eval_data_paths=/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/preproc_tft/eval*', u'--train_steps=2500', u'--train_batch_size=303', u'--eval_steps=1', u'--output_dir=/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28', u'--metadata_path=/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/preproc_tft/metadata/', u'--job-dir', u'/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28'], u'job_name': u'trainer.task'}, u'task': {}}
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 60, '_session_config': None, '_keep_checkpoint_max': 10, '_task_type': 'worker', '_train_distribute': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7efe445c1690>, '_evaluation_master': '', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': '/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28', '_global_id_in_cluster': 0, '_save_summary_steps': 100}
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 60, '_session_config': None, '_keep_checkpoint_max': 10, '_task_type': 'worker', '_train_distribute': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7efe445c16d0>, '_evaluation_master': '', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': '/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28', '_global_id_in_cluster': 0, '_save_summary_steps': 100}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 5 secs (eval_spec.throttle_secs) or training is finished.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow_transform/saved/input_fn_maker.py:557: read_batch_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:833: read_keyed_batch_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:542: read_keyed_batch_examples (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:550: queue_parsed_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# 2018-07-11 17:27:00.696828: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:loss = 213.0317, step = 1
# INFO:tensorflow:global_step/sec: 120.498
# INFO:tensorflow:loss = 119.356834, step = 101 (0.831 sec)
# INFO:tensorflow:global_step/sec: 151.659
# INFO:tensorflow:loss = 67.99141, step = 201 (0.659 sec)
# INFO:tensorflow:global_step/sec: 148.829
# INFO:tensorflow:loss = 19.209124, step = 301 (0.673 sec)
# INFO:tensorflow:global_step/sec: 141.879
# INFO:tensorflow:loss = 16.613308, step = 401 (0.704 sec)
# INFO:tensorflow:Saving checkpoints for 462 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:Loss for final step: 9.540033.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-17:27:07
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-462
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-11-17:27:08
# INFO:tensorflow:Saving dict for global step 462: accuracy = 0.4918033, accuracy_baseline = 0.6721312, auc = 0.3786586, auc_precision_recall = 0.24845831, average_loss = 3.0894065, f1_score = 0.060606062, false_negatives = 19.0, false_positives = 12.0, global_step = 462, label/mean = 0.32786885, loss = 188.4538, precision = 0.07692308, prediction/mean = 0.22727075, recall = 0.05, true_negatives = 29.0, true_positives = 1.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-462
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/export/exporter/temp-1531330029/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-462
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 463 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:loss = 6.8739557, step = 463
# INFO:tensorflow:global_step/sec: 114.879
# INFO:tensorflow:loss = 3.3591228, step = 563 (0.871 sec)
# INFO:tensorflow:global_step/sec: 143.227
# INFO:tensorflow:loss = 4.1342, step = 663 (0.698 sec)
# INFO:tensorflow:global_step/sec: 147.411
# INFO:tensorflow:loss = 3.938574, step = 763 (0.678 sec)
# INFO:tensorflow:global_step/sec: 152.773
# INFO:tensorflow:loss = 3.3374248, step = 863 (0.654 sec)
# INFO:tensorflow:Saving checkpoints for 912 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.6976705.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-17:27:16
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-912
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-11-17:27:17
# INFO:tensorflow:Saving dict for global step 912: accuracy = 0.52459013, accuracy_baseline = 0.6721312, auc = 0.36097565, auc_precision_recall = 0.26163998, average_loss = 4.234659, f1_score = 0.121212125, false_negatives = 18.0, false_positives = 11.0, global_step = 912, label/mean = 0.32786885, loss = 258.3142, precision = 0.15384616, prediction/mean = 0.19967788, recall = 0.1, true_negatives = 30.0, true_positives = 2.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-912
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/export/exporter/temp-1531330038/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-912
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 913 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:loss = 2.6617792, step = 913
# INFO:tensorflow:global_step/sec: 105.373
# INFO:tensorflow:loss = 0.9201779, step = 1013 (0.949 sec)
# INFO:tensorflow:global_step/sec: 140.01
# INFO:tensorflow:loss = 2.0532868, step = 1113 (0.714 sec)
# INFO:tensorflow:global_step/sec: 141.879
# INFO:tensorflow:loss = 2.1817782, step = 1213 (0.705 sec)
# INFO:tensorflow:global_step/sec: 141.816
# INFO:tensorflow:loss = 1.1225964, step = 1313 (0.705 sec)
# INFO:tensorflow:Saving checkpoints for 1349 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.1638615.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-17:27:26
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-1349
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-11-17:27:27
# INFO:tensorflow:Saving dict for global step 1349: accuracy = 0.52459013, accuracy_baseline = 0.6721312, auc = 0.35609758, auc_precision_recall = 0.2563079, average_loss = 4.914309, f1_score = 0.121212125, false_negatives = 18.0, false_positives = 11.0, global_step = 1349, label/mean = 0.32786885, loss = 299.77286, precision = 0.15384616, prediction/mean = 0.21077813, recall = 0.1, true_negatives = 30.0, true_positives = 2.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-1349
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/export/exporter/temp-1531330048/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-1349
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1350 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:loss = 0.89309806, step = 1350
# INFO:tensorflow:global_step/sec: 114.266
# INFO:tensorflow:loss = 0.98343563, step = 1450 (0.876 sec)
# INFO:tensorflow:global_step/sec: 148.468
# INFO:tensorflow:loss = 0.58523875, step = 1550 (0.673 sec)
# INFO:tensorflow:global_step/sec: 137.881
# INFO:tensorflow:loss = 0.58900917, step = 1650 (0.725 sec)
# INFO:tensorflow:global_step/sec: 145.051
# INFO:tensorflow:loss = 0.46569693, step = 1750 (0.689 sec)
# INFO:tensorflow:Saving checkpoints for 1786 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.31294748.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-17:27:37
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-1786
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-11-17:27:38
# INFO:tensorflow:Saving dict for global step 1786: accuracy = 0.4918033, accuracy_baseline = 0.6721312, auc = 0.3640244, auc_precision_recall = 0.25340903, average_loss = 5.346585, f1_score = 0.114285715, false_negatives = 18.0, false_positives = 13.0, global_step = 1786, label/mean = 0.32786885, loss = 326.14166, precision = 0.13333334, prediction/mean = 0.21491979, recall = 0.1, true_negatives = 28.0, true_positives = 2.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-1786
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/export/exporter/temp-1531330059/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-1786
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1787 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:loss = 0.24956419, step = 1787
# INFO:tensorflow:global_step/sec: 113.417
# INFO:tensorflow:loss = 0.20736955, step = 1887 (0.882 sec)
# INFO:tensorflow:global_step/sec: 146.547
# INFO:tensorflow:loss = 0.37137046, step = 1987 (0.682 sec)
# INFO:tensorflow:global_step/sec: 144.535
# INFO:tensorflow:loss = 0.06743652, step = 2087 (0.692 sec)
# INFO:tensorflow:global_step/sec: 110.9
# INFO:tensorflow:loss = 0.13830335, step = 2187 (0.902 sec)
# INFO:tensorflow:Saving checkpoints for 2200 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.11371737.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-17:27:48
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-2200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-11-17:27:50
# INFO:tensorflow:Saving dict for global step 2200: accuracy = 0.5081967, accuracy_baseline = 0.6721312, auc = 0.37439024, auc_precision_recall = 0.25679037, average_loss = 5.634989, f1_score = 0.11764706, false_negatives = 18.0, false_positives = 12.0, global_step = 2200, label/mean = 0.32786885, loss = 343.7343, precision = 0.14285715, prediction/mean = 0.21780387, recall = 0.1, true_negatives = 29.0, true_positives = 2.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-2200
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/export/exporter/temp-1531330071/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-2200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2201 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:loss = 0.14953943, step = 2201
# INFO:tensorflow:Saving checkpoints for 2260 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.1708065.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-17:28:01
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-2260
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-11-17:28:02
# INFO:tensorflow:Saving dict for global step 2260: accuracy = 0.5081967, accuracy_baseline = 0.6721312, auc = 0.37439027, auc_precision_recall = 0.2567794, average_loss = 5.6710267, f1_score = 0.11764706, false_negatives = 18.0, false_positives = 12.0, global_step = 2260, label/mean = 0.32786885, loss = 345.93262, precision = 0.14285715, prediction/mean = 0.21955127, recall = 0.1, true_negatives = 29.0, true_positives = 2.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-2260
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/export/exporter/temp-1531330084/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-2260
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2261 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:loss = 0.12650152, step = 2261
# INFO:tensorflow:global_step/sec: 78.2892
# INFO:tensorflow:loss = 0.115469776, step = 2361 (1.278 sec)
# INFO:tensorflow:Saving checkpoints for 2379 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.14044192.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-17:28:13
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-2379
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-11-17:28:15
# INFO:tensorflow:Saving dict for global step 2379: accuracy = 0.5081967, accuracy_baseline = 0.6721312, auc = 0.375, auc_precision_recall = 0.2569987, average_loss = 5.732381, f1_score = 0.11764706, false_negatives = 18.0, false_positives = 12.0, global_step = 2379, label/mean = 0.32786885, loss = 349.67523, precision = 0.14285715, prediction/mean = 0.22031151, recall = 0.1, true_negatives = 29.0, true_positives = 2.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-2379
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/export/exporter/temp-1531330096/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-2379
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2380 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:loss = 0.1626798, step = 2380
# INFO:tensorflow:global_step/sec: 79.7331
# INFO:tensorflow:loss = 0.09756138, step = 2480 (1.254 sec)
# INFO:tensorflow:Saving checkpoints for 2500 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.09749114.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-17:28:25
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-2500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-11-17:28:28
# INFO:tensorflow:Saving dict for global step 2500: accuracy = 0.5081967, accuracy_baseline = 0.6721312, auc = 0.37560976, auc_precision_recall = 0.25726187, average_loss = 5.7856708, f1_score = 0.11764706, false_negatives = 18.0, false_positives = 12.0, global_step = 2500, label/mean = 0.32786885, loss = 352.9259, precision = 0.14285715, prediction/mean = 0.2217691, recall = 0.1, true_negatives = 29.0, true_positives = 2.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/model.ckpt-2500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_dnn_classifier_top_28/../models/basic_dnn_classifier_top_28/export/exporter/temp-1531330109/saved_model.pb

# %% [markdown]
# Results for 2500 batches of 303 cases (2500 training epochs using a `DNNClassifier`):
#
# - accuracy = 0.5081967
# - accuracy baseline = 0.6721312
# - auc = 0.37560976
# - auc precision recall = 0.25726187
# - average loss = 5.7856708
# - f1 score = 0.11764706
# - false negatives = 18.0
# - false positives = 12.0
# - global step = 2500
# - label/mean = 0.32786885
# - loss = 352.9259
# - precision = 0.14285715
# - prediction/mean = 0.2217691
# - recall = 0.1
# - true negatives = 29.0
# - true positives = 2.0

# %% [markdown]
# ### Cloud ML Engine Training

# %%
# %%bash
#
# OUTPUT_DIR=gs://${BUCKET}/analysis/hallelujah-effect/models/${MODEL_NAME}
# JOBNAME=hallelujah_effect$(date -u +%y%m%d_%H%M%S)
# echo ${OUTPUT_DIR} $REGION $JOBNAME
# gsutil -m rm -rf ${OUTPUT_DIR}
# gcloud ml-engine jobs submit training $JOBNAME \
#    --region=$REGION \
#    --package-path=${PWD}/trainer/trainer \
#    --module-name=trainer.task \
#    --job-dir=${OUTPUT_DIR} \
#    --scale-tier=STANDARD_1 \
#    --runtime-version=1.8 \
#    -- \
#    --train_data_paths="gs://${BUCKET}/analysis/hallelujah-effect/preproc_tft/train*" \
#    --eval_data_paths="gs://${BUCKET}/analysis/hallelujah-effect/preproc_tft/eval*" \
#    --output_dir=$OUTPUT_DIR \
#    --train_steps=25000 \
#    --train_batch_size=${TRAIN_N} \
#    --eval_steps=1 \
#    --metadata_path=gs://${BUCKET}/analysis/hallelujah-effect/preproc_tft/metadata/
# Out:
# gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_28 us-central1 hallelujah_effect180711_172543
# jobId: hallelujah_effect180711_172543
# state: QUEUED
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_dnn_classifier_top_28/packages/3a8eb690a940607c948d1a582328dcf2698f40c1501c4983d8cf7a938059b6c1/trainer-0.1.tar.gz#1531329917342981...
# / [1/1 objects] 100% Done
# Operation completed over 1 objects.
# Job [hallelujah_effect180711_172543] submitted successfully.
# Your job is still active. You may view the status of your job with the command
#
#   $ gcloud ml-engine jobs describe hallelujah_effect180711_172543
#
# or continue streaming the logs with the command
#
#   $ gcloud ml-engine jobs stream-logs hallelujah_effect180711_172543

# %% [markdown]
# Results for 25000 batches of 303 cases (25000 training epochs using a `DNNClassifier`):
#
# - accuracy = 0.59016395
# - accuracy baseline = 0.6721312
# - auc = 0.4390244
# - auc precision recall = 0.26713696
# - average loss = 12.022413
# - f1 score = 0.074074075
# - false negatives = 19.0
# - false positives = 6.0
# - global step = 25007
# - label/mean = 0.32786885
# - loss = 733.3672
# - precision = 0.14285715
# - prediction/mean = 0.12637354
# - recall = 0.05
# - true negatives = 35.0
# - true positives = 1.0

# %% [markdown]
# ## View Results in TensorBoard

# %%
from google.datalab.ml import TensorBoard
TensorBoard().start('gs://eim-muse/analysis/hallelujah-effect/models/')
# Out:
# /usr/local/envs/py2env/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# <p>TensorBoard was started successfully with pid 189. Click <a href="/_proxy/57583/" target="_blank">here</a> to access it.</p>
# 189

# %%
TensorBoard.stop(327)

# %%
TensorBoard().start('gs://eim-muse/analysis/hallelujah-effect/models/')
# Out:
# <p>TensorBoard was started successfully with pid 20606. Click <a href="/_proxy/56999/" target="_blank">here</a> to access it.</p>
# 20606

# %%
TensorBoard.stop(20336)

# %%
# %writefile /tmp/test.json
{"age":"29.0","activity":3.0}

# %%
# %bash
model_dir=$(ls $PWD/hallelujah-effect_trained/export/exporter/)
gcloud ml-engine local predict \
    --model-dir=./hallelujah-effect_trained/export/exporter/${model_dir} \
    --json-instances=/tmp/test.json

# %% [markdown]
# # To Do
#
# - Double-check that Dublin ratings are inverted properly
# - LASSO to identify important features
# - Hyperparameter search
# - More plots and statistics from the dataset with which I'm working here
# - Bring in rows with missing values
# - Feature engineering (physiological signals, MIR, feature crosses, variable-width binning)
# - Include signals with good quality only in reaction range
# - Customize estimator to add additional metrics

# %%
print('gs://{}/analysis/hallelujah-effect/models/{}'.format(BUCKET, MODEL_NAME))
# Out:
# gs://eim-muse/analysis/hallelujah-effect/models/basic_features
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-01 20:34:08.418586. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
# %%bash
#
# tensorboard --inspect --logdir gs://eim-muse/analysis/hallelujah-effect/models/basic_features
# Out:
# ======================================================================
# Processing event files... (this can take a few minutes)
# ======================================================================
#
# Found event files in:
# gs://eim-muse/analysis/hallelujah-effect/models/basic_features
# gs://eim-muse/analysis/hallelujah-effect/models/basic_features/eval/
#
# These tags are in gs://eim-muse/analysis/hallelujah-effect/models/basic_features:
# audio -
# histograms
#    dnn/dnn/hiddenlayer_0/activation
#    dnn/dnn/hiddenlayer_1/activation
#    dnn/dnn/hiddenlayer_2/activation
#    dnn/dnn/logits/activation
# images -
# scalars
#    average_loss
#    dnn/dnn/hiddenlayer_0/fraction_of_zero_values
#    dnn/dnn/hiddenlayer_1/fraction_of_zero_values
#    dnn/dnn/hiddenlayer_2/fraction_of_zero_values
#    dnn/dnn/logits/fraction_of_zero_values
#    loss
#    read_batch_features/file_name_queue/fraction_of_32_full
#    read_batch_features/fraction_over_9970_of_30_full
#    read_batch_features/queue/parsed_features/read_batch_features/fifo_queue/fraction_of_100_full
# tensor -
# ======================================================================
#
# Event statistics for gs://eim-muse/analysis/hallelujah-effect/models/basic_features:
# audio -
# graph
#    first_step           0
#    last_step            0
#    max_step             0
#    min_step             0
#    num_steps            1
#    outoforder_steps     []
# histograms
#    first_step           1
#    last_step            1
#    max_step             1
#    min_step             1
#    num_steps            1
#    outoforder_steps     []
# images -
# scalars
#    first_step           1
#    last_step            1
#    max_step             1
#    min_step             1
#    num_steps            1
#    outoforder_steps     []
# sessionlog:checkpoint
#    first_step           1
#    last_step            8
#    max_step             8
#    min_step             1
#    num_steps            8
#    outoforder_steps     []
# sessionlog:start
#    outoforder_steps     []
#    steps                [1L]
# sessionlog:stop -
# tensor -
# ======================================================================
#
# These tags are in gs://eim-muse/analysis/hallelujah-effect/models/basic_features/eval/:
# audio -
# histograms -
# images -
# scalars
#    accuracy
#    accuracy_baseline
#    auc
#    auc_precision_recall
#    average_loss
#    label/mean
#    loss
#    prediction/mean
# tensor -
# ======================================================================
#
# Event statistics for gs://eim-muse/analysis/hallelujah-effect/models/basic_features/eval/:
# audio -
# graph
#    first_step           0
#    last_step            0
#    max_step             0
#    min_step             0
#    num_steps            1
#    outoforder_steps     []
# histograms -
# images -
# scalars
#    first_step           1
#    last_step            14
#    max_step             14
#    min_step             1
#    num_steps            14
#    outoforder_steps     []
# sessionlog:checkpoint -
# sessionlog:start -
# sessionlog:stop -
# tensor -
# ======================================================================
# /usr/local/envs/py2env/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
ml = """
This is
a
multiline string.
"""

with open('./test.txt', 'w') as file:
  file.write(ml)
# Out:
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-04 00:58:42.778246. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
