# %% [markdown]
# # Exploratory Visualization (_Raining Blood_, Taiwan only)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import pandas as pd
import scipy.stats as sps
import seaborn as sns
import sklearn

from pathlib import Path

# %% [markdown]
# ## Retrieve and Subset Datasource
#
# Retrieve all good trials for IDs that came from Javier's algorithm.

# %%
notebook_song_name = 'slayer_taiwan'

# %%
data_root = Path('../../neural_nets/fastai/import-slayer-taiwan/data')

df_all = pd.read_csv(data_root / 'good_reaction_trials_categorified_no_impute.csv')

# df_all = df_all[df_all.song == 'someone_like_you']

pd.set_option('display.max_columns', None)
df_all.describe()
# Out:
#               age  personality_trusting  personality_artistic  \
# count  189.000000            189.000000             189.00000
# mean    20.095238              3.587302               2.26455
# std     10.812789              0.999493               1.21334
# min      6.000000              1.000000               1.00000
# 25%     12.000000              3.000000               1.00000
# 50%     18.000000              4.000000               2.00000
# 75%     25.000000              4.000000               3.00000
# max     55.000000              5.000000               5.00000
#
#        personality_imagination  personality_reserved  personality_outgoing  \
# count               189.000000            189.000000            189.000000
# mean                  3.719577              3.026455              3.296296
# std                   1.005669              1.131906              1.104650
# min                   1.000000              1.000000              1.000000
# 25%                   3.000000              2.000000              2.000000
# 50%                   4.000000              3.000000              3.000000
# 75%                   5.000000              4.000000              4.000000
# max                   5.000000              5.000000              5.000000
#
#        personality_lazy  personality_stress  personality_nervous  \
# count        189.000000          189.000000           189.000000
# mean           3.550265            3.222222             3.470899
# std            1.112723            1.068571             1.132428
# min            1.000000            1.000000             1.000000
# 25%            3.000000            2.000000             3.000000
# 50%            4.000000            3.000000             4.000000
# 75%            4.000000            4.000000             4.000000
# max            5.000000            5.000000             5.000000
#
#        personality_fault  personality_thorough  musical_expertise  \
# count         189.000000            189.000000         189.000000
# mean            3.190476              3.100529           2.671958
# std             1.099185              1.044463           1.075999
# min             1.000000              1.000000           1.000000
# 25%             2.000000              2.000000           2.000000
# 50%             3.000000              3.000000           3.000000
# 75%             4.000000              4.000000           3.000000
# max             5.000000              5.000000           5.000000
#
#        concentration  control_power  control_like_dislike  control_tension  \
# count     189.000000     189.000000            189.000000       189.000000
# mean        3.846561       3.201058              3.026455         3.560847
# std         1.073249       1.135406              1.306424         1.116964
# min         1.000000       1.000000              1.000000         1.000000
# 25%         3.000000       2.000000              2.000000         3.000000
# 50%         4.000000       3.000000              3.000000         4.000000
# 75%         5.000000       4.000000              4.000000         4.000000
# max         5.000000       5.000000              5.000000         5.000000
#
#        control_engagement  control_activity  control_positivity  \
# count          189.000000        189.000000           189.00000
# mean             3.206349          2.777778             3.21164
# std              1.261020          1.063582             1.08553
# min              1.000000          1.000000             1.00000
# 25%              2.000000          2.000000             2.00000
# 50%              3.000000          3.000000             3.00000
# 75%              4.000000          3.000000             4.00000
# max              5.000000          5.000000             5.00000
#
#        control_familiarity  song_power  song_like_dislike  song_tension  \
# count                189.0   89.000000          89.000000     89.000000
# mean                  -1.0    3.752809           3.382022      3.247191
# std                    0.0    1.047518           1.344227      1.263841
# min                   -1.0    1.000000           1.000000      1.000000
# 25%                   -1.0    3.000000           2.000000      2.000000
# 50%                   -1.0    4.000000           3.000000      3.000000
# 75%                   -1.0    5.000000           5.000000      4.000000
# max                   -1.0    5.000000           5.000000      5.000000
#
#        song_engagement  song_activity  song_positivity  song_familiarity  \
# count        89.000000      89.000000        89.000000         89.000000
# mean          4.067416       4.224719         3.370787          2.078652
# std           1.155990       0.913943         1.218998          1.358682
# min           1.000000       1.000000         1.000000          1.000000
# 25%           4.000000       4.000000         2.000000          1.000000
# 50%           4.000000       4.000000         4.000000          1.000000
# 75%           5.000000       5.000000         4.000000          3.000000
# max           5.000000       5.000000         5.000000          5.000000
#
#        musicpref_world  musicpref_pop  musicpref_dance  musicpref_rock  \
# count       189.000000     189.000000       189.000000      189.000000
# mean          0.095238       0.714286         0.132275        0.232804
# std           0.294323       0.452954         0.339689        0.423741
# min           0.000000       0.000000         0.000000        0.000000
# 25%           0.000000       0.000000         0.000000        0.000000
# 50%           0.000000       1.000000         0.000000        0.000000
# 75%           0.000000       1.000000         0.000000        0.000000
# max           1.000000       1.000000         1.000000        1.000000
#
#        musicpref_jazz  musicpref_folk  musicpref_hiphop  musicpref_classical
# count      189.000000      189.000000        189.000000           189.000000
# mean         0.126984        0.063492          0.100529             0.296296
# std          0.333840        0.244494          0.301503             0.457836
# min          0.000000        0.000000          0.000000             0.000000
# 25%          0.000000        0.000000          0.000000             0.000000
# 50%          0.000000        0.000000          0.000000             0.000000
# 75%          0.000000        0.000000          0.000000             1.000000
# max          1.000000        1.000000          1.000000             1.000000

# %%
print(f"Total N: {df_all.shape[0]}")
# Out:
# Total N: 189

# %%
df_reaction = df_all[df_all['critical_reaction'] == True]
df_no_reaction = df_all[df_all['critical_reaction'] == False]

# %%
print(f"Total reaction N: {df_reaction.shape[0]}")
print(f"Total no-reaction N: {df_no_reaction.shape[0]}")
# Out:
# Total reaction N: 97
# Total no-reaction N: 92

# %%
df_all.columns
# Out:
# Index(['_id', 'location', 'language', 'nationality', 'age', 'sex',
#        'hearing_impairments', 'personality_trusting', 'personality_artistic',
#        'personality_imagination', 'personality_reserved',
#        'personality_outgoing', 'personality_lazy', 'personality_stress',
#        'personality_nervous', 'personality_fault', 'personality_thorough',
#        'musical_expertise', 'concentration', 'critical_reaction',
#        'control_power', 'control_like_dislike', 'control_tension',
#        'control_engagement', 'control_activity', 'control_positivity',
#        'control_familiarity', 'song_power', 'song_like_dislike',
#        'song_tension', 'song_engagement', 'song_activity', 'song_positivity',
#        'song_familiarity', 'song', 'musicpref_world', 'musicpref_pop',
#        'musicpref_dance', 'musicpref_rock', 'musicpref_jazz', 'musicpref_folk',
#        'musicpref_hiphop', 'musicpref_classical'],
#       dtype='object')

# %%
cat_cols = ['location', 'language', 'nationality', 'sex', 
            'hearing_impairments']

personality_cols = ['personality_trusting', 'personality_artistic', 
            'personality_imagination', 'personality_reserved',
            'personality_outgoing', 'personality_lazy', 'personality_stress',
            'personality_nervous', 'personality_fault', 'personality_thorough']

ord_cols = ['musical_expertise', 'concentration', 
            'song_power', 'song_like_dislike',
            'song_tension', 'song_engagement', 'song_activity', 'song_positivity',
            'song_familiarity', 'musicpref_world', 'musicpref_folk',
            'musicpref_classical', 'musicpref_dance', 'musicpref_rock',
            'musicpref_pop', 'musicpref_jazz', 'musicpref_hiphop']

cont_cols = ['age']

# %%
nationality_counts = df_all['nationality'].value_counts()
patches, texts = plt.pie(nationality_counts, 
                                    explode=[0.1] * len(nationality_counts));

labels = ['{}: {}'.format(x.capitalize(), nationality_counts[x]) for x in nationality_counts.index]

plt.legend(patches, labels)
plt.savefig('hallelujah_reaction_pie_nationalities_{}_new_split.pdf'.format(notebook_song_name))

# %%
language_counts = df_all['language'].value_counts()
patches, texts = plt.pie(language_counts, 
                                    explode=[0.1] * len(language_counts));

languages = list(language_counts.index)
for i in range(len(languages)):
    language = languages[i]
    if language == 'en':
        languages[i] = 'English'
    elif language == 'zh_TW':
        languages[i] = 'Taiwanese'

labels = ['{}: {}'.format(languages[i].capitalize(), language_counts[x]) for i, x in enumerate(language_counts.index)]

plt.legend(patches, labels)
plt.savefig('hallelujah_reaction_pie_languages_{}_new_split.pdf'.format(notebook_song_name))

# %%
def mardia(data, unbiased_cov=True):
    """
    data should have observations in rows
    """
    import numpy as np
    import scipy.stats as sps
    
    n = data.shape[0]
    p = data.shape[1]

    S = None
    if unbiased_cov:
        S = ((n - 1.) / n) * np.cov(data, rowvar=False)
    else:
        S = np.cov(data, rowvar=False)

    data_scaled = (data - data.mean(axis=0))

    D = np.matmul(np.matmul(data_scaled, np.linalg.pinv(S, rcond=1e-25)), data_scaled.T)

    product = D * D * D
    skewness = np.sum(product) / n**2
    kurtosis = (D * D).diagonal().sum() / n
    df = p * (p + 1) * (p + 2) / 6
    k = ((p + 1)*(n + 1)*(n + 3))/(n*((n + 1)*(p + 1) - 6))
    
    skew, kurt, skew_p, kurt_p = None, None, None, None
    if n < 20:
        skew = n * k * skewness / 6.
    else:
        skew = n * skewness / 6.
    
    chi2_test_skew = sps.chi2(df)
    skew_p = 1. - chi2_test_skew.cdf(skew)
    
    skew_result = False
    if skew_p > 0.05:
        skew_result = True
    
    kurt = (kurtosis - p * (p + 2)) * np.sqrt(n / (8 * p * (p + 2)))
    
    normal_test_kurt = sps.norm()
    kurt_p = 2. * (1. - normal_test_kurt.cdf(np.abs(kurt)))
    
    kurt_result = False
    if kurt_p  > 0.05:
        kurt_result = True
    
    result_skewness = {
        'test': 'Mardia Skewness',
        'statistic': skew,
        'p-value': skew_p,
        'result': skew_result
    }
    
    result_kurtosis = {
        'test': 'Mardia Kurtosis',
        'statistic': kurt,
        'p-value': kurt_p,
        'result': kurt_result
    }
    
    result = {
        'test': 'MVN',
        'statistic': None,
        'p-value': None,
        'result': skew_result and kurt_result
    }
    
    return result_skewness, result_kurtosis, result

# %%
def run_tests(x_label, dist_var, bins=None, normed=False, kde=True, bw='normal_reference', x_lim=None, plots=False, print_output=False):
    
    if plots:
        f = plt.figure(figsize=(8, 4))
        sns.distplot(df_all[dist_var].dropna(), bins=bins, norm_hist=normed, kde=kde, rug=True, kde_kws={'bw': bw})
        plt.xlabel('')
        if x_lim is not None:
            plt.xlim([0.5, 5.5])

        g = sns.FacetGrid(df_all, hue='critical_reaction', height=4, aspect=2)
        g.map(sns.distplot, dist_var, bins=bins, norm_hist=normed, kde=kde, kde_kws={'bw': bw})
        g.set_xlabels(x_label)
        if x_lim is not None:
            g.axes[0,0].set_xlim([0.5, 5.5])
        g.fig.suptitle('Distribution of {} by reaction group'.format(dist_var), y=1.0)
        g.add_legend(title='Hallelujah Reaction');

        fig_file = 'hallelujah_reaction_distribution_hallelujah_{}_new_split.pdf'.format(dist_var)
        g.savefig(fig_file, orientation='landscape')
        
    mean_true = df_all[df_all['critical_reaction'] == True][dist_var].dropna()
    mean_false = df_all[df_all['critical_reaction'] == False][dist_var].dropna()
    
    all_normtest = sps.normaltest(df_all[dist_var])
    true_normtest = sps.normaltest(df_all[df_all['critical_reaction'] == True][dist_var])
    false_normtest = sps.normaltest(df_all[df_all['critical_reaction'] == False][dist_var])
    if print_output:
        print(f'All normal test results: {all_normtest}')
        print(f'Reaction normal test results: {true_normtest}')
        print(f'No-reaction normal test results: {false_normtest}')
    
    alpha = 0.05
    _, equal_variance_p = sps.levene(mean_true, mean_false)
    
    equal_var = None
    if equal_variance_p >= alpha:
        equal_var = True
    else:
        equal_var = False
    
    t_stat, t_p = sps.ttest_ind(mean_true, mean_false, equal_var=equal_var)
    u_stat, u_p = sps.mannwhitneyu(mean_true, mean_false, alternative='two-sided')

    if print_output:
        print('Student\'s t-test for difference in mean {} between Hallelujah Reaction groups'.format(x_label.capitalize()))

        print('T test statistic: {:.4f}'.format(t_stat))
        print('T test p-value: {:.4f}'.format(t_p))

        print('Mann-Whitney U test statistic: {:.4f}'.format(u_stat))
        print('Mann-Whitney U test p-value: {:.4f}'.format(u_p))

        if t_p <= alpha or u_p <= alpha:
            print('**** Significant Result ****')
    
    return {
        'mean_true': mean_true.mean(),
        'mean_false': mean_false.mean(),
        'median_true': mean_true.median(),
        'median_false': mean_false.median(),
        't_stat': t_stat,
        't_p': t_p,
        'u_stat': u_stat,
        'u_p': u_p
    }

# %%
run_tests('Age [years]', 'age', bins=None, normed=False, kde=True, bw='normal_reference', x_lim=None, plots=True, print_output=True)
# Out:
# /home/paperspace/anaconda3/envs/fastai/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# All normal test results: NormaltestResult(statistic=30.83363985220977, pvalue=2.016323341210107e-07)
# Reaction normal test results: NormaltestResult(statistic=24.052739129203072, pvalue=5.984309696114051e-06)
# No-reaction normal test results: NormaltestResult(statistic=12.305338762338142, pvalue=0.0021277942883816538)
# Student's t-test for difference in mean Age [years] between Hallelujah Reaction groups
# T test statistic: -1.7352
# T test p-value: 0.0844
# Mann-Whitney U test statistic: 3743.0000
# Mann-Whitney U test p-value: 0.0557
# {'mean_true': 18.77319587628866,
#  'mean_false': 21.48913043478261,
#  'median_true': 16.0,
#  'median_false': 19.0,
#  't_stat': -1.7351644916948983,
#  't_p': 0.08435917145993001,
#  'u_stat': 3743.0,
#  'u_p': 0.055743977236319645}

# %%
df_results = pd.DataFrame({})

for c in personality_cols:
    try:
        result = run_tests(c, c)
        df_results = pd.concat([df_results, pd.DataFrame(result, index=[c])])
    except:
        print(f'Could not run tests for {c}')

# %%
df_results = df_results.sort_values(by='u_p')

i = np.arange(1, df_results.shape[0] + 1)
m = len(i)
Q = 0.25
benjamini_hochberg = ((i * 1.) / m) * Q
df_results['bh_threshold'] = benjamini_hochberg
df_results['significant'] = df_results.u_p < df_results.bh_threshold

df_results
# Out:
#                          mean_true  mean_false  median_true  median_false  \
# personality_imagination   3.639175    3.804348          4.0           4.0
# personality_lazy          3.608247    3.489130          4.0           4.0
# personality_artistic      2.329897    2.195652          2.0           2.0
# personality_trusting      3.628866    3.543478          4.0           4.0
# personality_thorough      3.123711    3.076087          3.0           3.0
# personality_outgoing      3.319588    3.271739          3.0           3.0
# personality_stress        3.195876    3.250000          3.0           3.0
# personality_reserved      3.041237    3.010870          3.0           3.0
# personality_fault         3.175258    3.206522          3.0           3.0
# personality_nervous       3.474227    3.467391          4.0           4.0
#
#                            t_stat       t_p  u_stat       u_p  bh_threshold  \
# personality_imagination -1.129405  0.260174  4049.5  0.253390         0.025
# personality_lazy         0.734689  0.463449  4776.0  0.379347         0.050
# personality_artistic     0.759406  0.448566  4780.5  0.379706         0.075
# personality_trusting     0.586010  0.558576  4731.5  0.443811         0.100
# personality_thorough     0.312565  0.754959  4584.5  0.735964         0.125
# personality_outgoing     0.296918  0.766859  4584.0  0.738232         0.150
# personality_stress      -0.347228  0.728810  4350.0  0.758488         0.175
# personality_reserved     0.183878  0.854309  4548.5  0.812833         0.200
# personality_fault       -0.194944  0.845649  4412.0  0.890840         0.225
# personality_nervous      0.041367  0.967048  4466.0  0.992175         0.250
#
#                          significant
# personality_imagination        False
# personality_lazy               False
# personality_artistic           False
# personality_trusting           False
# personality_thorough           False
# personality_outgoing           False
# personality_stress             False
# personality_reserved           False
# personality_fault              False
# personality_nervous            False

# %%
sns.countplot(x='sex', hue='critical_reaction', data=df_all)
plt.xticks(ticks=[0,1], labels=['Male', 'Female'])
plt.xlabel('Sex')
plt.ylabel('Count')
plt.legend(title='Significant Reaction')
plt.tight_layout()
plt.savefig(f'hallelujah_reaction_bar_sex_by_reaction_{notebook_song_name}_new_split.pdf')

# %%
# Chi-squared test of male/female proportions

cross = pd.crosstab(df_all['sex'], df_all['critical_reaction'])
display(cross)
chi2, p, dof, table = sps.chi2_contingency(cross)
print('Chi-squared test of sex vs hallelujah reaction proportions')
print('Test statistic: {:.4f}'.format(chi2))
print('p-value: {:.4f}'.format(p))
print('Degrees of freedom: {}'.format(dof))
# Out:
# critical_reaction  False  True
# sex
# female                54     55
# male                  38     42
# Chi-squared test of sex vs hallelujah reaction proportions
# Test statistic: 0.0169
# p-value: 0.8965
# Degrees of freedom: 1

# %%
sns.countplot(x='location', hue='critical_reaction', data=df_all)

# %%
# Chi-squared test of location proportions

cross = pd.crosstab(df_all['location'], df_all['critical_reaction'])
display(cross)
chi2, p, dof, table = sps.chi2_contingency(cross)
print('Chi-squared test of location vs hallelujah reaction proportions')
print('Test statistic: {:.4f}'.format(chi2))
print('p-value: {:.4f}'.format(p))
print('Degrees of freedom: {}'.format(dof))
# Out:
# critical_reaction  False  True
# location
# taichung_city         17     35
# taipei_city           75     62
# Chi-squared test of location vs hallelujah reaction proportions
# Test statistic: 6.4810
# p-value: 0.0109
# Degrees of freedom: 1

# %%
sns.countplot(x='language', hue='critical_reaction', data=df_all)

# %%
# Chi-squared test of language proportions

cross = pd.crosstab(df_all['language'], df_all['critical_reaction'])
display(cross)
chi2, p, dof, table = sps.chi2_contingency(cross)
print('Chi-squared test of language vs hallelujah reaction proportions (for Taiwanese, English, and NA)')
print('Test statistic: {:.4f}'.format(chi2))
print('p-value: {:.4f}'.format(p))
print('Degrees of freedom: {}'.format(dof))
# Out:
# critical_reaction  False  True
# language
# en                    77     70
# zh_TW                 15     27
# Chi-squared test of language vs hallelujah reaction proportions (for Taiwanese, English, and NA)
# Test statistic: 2.9957
# p-value: 0.0835
# Degrees of freedom: 1

# %% [markdown]
# Sources for Hotelling's $T^2$:
# - https://ncss-wpengine.netdna-ssl.com/wp-content/themes/ncss/pdf/Procedures/NCSS/Hotellings_Two-Sample_T2.pdf
# - https://onlinecourses.science.psu.edu/stat505/node/100/

# %%
def hotelling_t2(X_1, X_2, alpha):
    
    import scipy.stats as sps
    
    n_1 = len(X_1)
    n_2 = len(X_2)

    y_1 = X_1.mean().as_matrix()
    y_1 = y_1.reshape(len(y_1), -1)
    y_2 = X_2.mean().as_matrix()
    y_2 = y_2.reshape(len(y_2), -1)

    # Covariance matrices
    S_1 = np.cov(X_1.astype(np.float64).T)
    S_2 = np.cov(X_2.astype(np.float64).T)

    # Pooled variance
    S_pooled_num = ((n_1 - 1) * S_1) + ((n_2 - 1) * S_2)
    S_pooled_denom = n_1 + n_2 - 2
    S_pooled = S_pooled_num / S_pooled_denom
    
    T_2 = (n_1 * n_2) / (n_1 + n_2)
    T_2 = T_2 * np.matmul((y_1 - y_2).T, np.linalg.pinv(S_pooled))
    T_2 = np.matmul(T_2, (y_1 - y_2))
    T_2 = T_2.squeeze()
    
    p = len(X_1.columns)
    F_num = n_1 + n_2 - p - 1
    F_denom = p * (n_1 + n_2 - 2)
    F = (F_num / F_denom) * T_2
    F = F.squeeze()
    
    df_1 = p
    df_2 = n_1 + n_2 - p - 1
    F_dist = sps.f(df_1, df_2)
    p_value = F_dist.cdf(F)
    
    # Calculate effect size
    D_2 = ((n_1 + n_2) * T_2) / (n_1 * n_2)
    
    return({
        'T2': T_2,
        'F': F,
        'df': (df_1, df_2),
        'p': p_value,
        'D2': D_2
    })

# %% [markdown]
# # Pairwise Hotelling's $T^2$

# %%
import itertools

plot_vars = ['song_activity', 
             'song_engagement', 
             'song_familiarity', 
             'song_like_dislike', 
             'song_positivity', 
             'song_tension', 
             'age', 
             'musical_expertise', 
             'concentration', 
             'personality_artistic', 
             'personality_fault', 
             'personality_imagination', 
             'personality_lazy', 
             'personality_nervous', 
             'personality_outgoing', 
             'personality_reserved', 
             'personality_stress', 
             'personality_thorough', 
             'personality_trusting']

pairs = list(itertools.combinations(plot_vars, 2))

results = pd.DataFrame(columns=['p', 'adjustedP', 'F', 'T2', 'df1', 'df2', 'D2'])

for pair in pairs:
    
    test_vars = list(pair)
    test_vars.append('critical_reaction')
    df_pair = df_all[test_vars].dropna()
    df_pair_1 = df_pair[df_pair['critical_reaction'] == False].drop(['critical_reaction'], axis=1)
    df_pair_2 = df_pair[df_pair['critical_reaction'] == True].drop(['critical_reaction'], axis=1)
    
    mardia_result = mardia(df_pair.drop(['critical_reaction'], axis=1), unbiased_cov=True)
    if mardia_result[2]['result']:
        pass

    t2_results = hotelling_t2(df_pair_1, df_pair_2, 0.05)
    p = t2_results['p']
    adjusted_p = p * len(pairs)
    if adjusted_p > 1:
        adjusted_p = 1
        
    row = pd.DataFrame(
        {
            'p': t2_results['p'], 
            'adjustedP': adjusted_p,
            'F': t2_results['F'], 
            'T2': t2_results['T2'], 
            'df1': t2_results['df'][0], 
            'df2': t2_results['df'][1],
            'D2': t2_results['D2']
        }, 
        index=[pair])

    results = pd.concat([results, row])
    
alpha = 0.5
    
with pd.option_context('display.max_rows', None, 'display.float_format', lambda x: '%.5f' % x):
    display('Tests for difference between combined means of {} and {} between hallelujah reaction groups:'.format(pair[0], pair[1]))
    display(results.sort_values(by='p'))

results.to_csv('hotelling_comparisons_{}.csv'.format(notebook_song_name))
# Out:
# /home/paperspace/anaconda3/envs/fastai/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# /home/paperspace/anaconda3/envs/fastai/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.
# 'Tests for difference between combined means of personality_thorough and personality_trusting between hallelujah reaction groups:'
#                                                       p adjustedP       F  \
# (personality_nervous, personality_reserved)     0.01735         1 0.01750
# (personality_fault, personality_nervous)        0.02414         1 0.02444
# (song_familiarity, age)                         0.03164         1 0.03217
# (song_familiarity, personality_artistic)        0.03346         1 0.03404
# (song_familiarity, personality_stress)          0.03571         1 0.03638
# (personality_fault, personality_reserved)       0.03920         1 0.04000
# (personality_nervous, personality_outgoing)     0.04671         1 0.04785
# (personality_nervous, personality_thorough)     0.05113         1 0.05250
# (song_familiarity, personality_trusting)        0.05883         1 0.06068
# (personality_fault, personality_outgoing)       0.05906         1 0.06090
# (personality_nervous, personality_stress)       0.06289         1 0.06497
# (personality_reserved, personality_thorough)    0.06318         1 0.06529
# (personality_reserved, personality_stress)      0.06445         1 0.06665
# (personality_fault, personality_thorough)       0.06755         1 0.06997
# (song_activity, age)                            0.07030         1 0.07296
# (song_activity, personality_artistic)           0.07053         1 0.07320
# (song_activity, personality_stress)             0.07058         1 0.07326
# (song_activity, personality_trusting)           0.07781         1 0.08108
# (song_familiarity, concentration)               0.07955         1 0.08297
# (song_familiarity, personality_nervous)         0.08273         1 0.08644
# (personality_outgoing, personality_thorough)    0.08515         1 0.08904
# (personality_outgoing, personality_reserved)    0.08743         1 0.09154
# (personality_fault, personality_stress)         0.08899         1 0.09325
# (song_activity, concentration)                  0.09328         1 0.09803
# (song_familiarity, personality_thorough)        0.10982         1 0.11649
# (personality_stress, personality_thorough)      0.12001         1 0.12793
# (song_activity, song_familiarity)               0.12115         1 0.12934
# (personality_outgoing, personality_stress)      0.12692         1 0.13582
# (song_activity, personality_nervous)            0.12932         1 0.13871
# (song_engagement, age)                          0.12974         1 0.13918
# (song_engagement, personality_stress)           0.13067         1 0.14027
# (song_engagement, concentration)                0.13092         1 0.14055
# (song_activity, song_engagement)                0.13235         1 0.14220
# (song_engagement, personality_artistic)         0.13297         1 0.14292
# (song_engagement, personality_trusting)         0.14217         1 0.15362
# (personality_nervous, personality_trusting)     0.15735         1 0.17136
# (song_activity, personality_thorough)           0.15959         1 0.17422
# (song_engagement, personality_nervous)          0.16568         1 0.18152
# (personality_fault, personality_trusting)       0.16587         1 0.18155
# (personality_outgoing, personality_trusting)    0.16723         1 0.18317
# (personality_reserved, personality_trusting)    0.16779         1 0.18385
# (song_engagement, song_familiarity)             0.19153         1 0.21314
# (personality_thorough, personality_trusting)    0.19269         1 0.21430
# (concentration, personality_nervous)            0.20053         1 0.22408
# (concentration, personality_fault)              0.20670         1 0.23184
# (song_engagement, personality_thorough)         0.20857         1 0.23456
# (concentration, personality_reserved)           0.21188         1 0.23841
# (concentration, personality_outgoing)           0.21433         1 0.24154
# (song_positivity, personality_artistic)         0.21850         1 0.24725
# (song_familiarity, song_positivity)             0.22031         1 0.24958
# (song_positivity, age)                          0.22484         1 0.25544
# (song_familiarity, song_like_dislike)           0.22555         1 0.25636
# (song_like_dislike, personality_artistic)       0.22573         1 0.25659
# (song_like_dislike, age)                        0.22792         1 0.25945
# (song_positivity, personality_trusting)         0.23292         1 0.26598
# (personality_stress, personality_trusting)      0.23688         1 0.27073
# (personality_lazy, personality_reserved)        0.23807         1 0.27230
# (song_positivity, personality_stress)           0.24355         1 0.28003
# (concentration, personality_thorough)           0.24401         1 0.28015
# (personality_lazy, personality_nervous)         0.24479         1 0.28118
# (song_like_dislike, personality_trusting)       0.24588         1 0.28314
# (song_like_dislike, personality_stress)         0.24899         1 0.28729
# (personality_artistic, personality_nervous)     0.24989         1 0.28798
# (song_like_dislike, song_positivity)            0.25171         1 0.29095
# (personality_artistic, personality_reserved)    0.25235         1 0.29127
# (song_positivity, personality_nervous)          0.25628         1 0.29711
# (song_familiarity, musical_expertise)           0.25672         1 0.29771
# (song_like_dislike, personality_nervous)        0.25688         1 0.29792
# (personality_lazy, personality_stress)          0.26174         1 0.30395
# (personality_artistic, personality_fault)       0.26466         1 0.30793
# (song_positivity, personality_thorough)         0.26642         1 0.31094
# (concentration, personality_stress)             0.27084         1 0.31640
# (personality_artistic, personality_thorough)    0.28062         1 0.32995
# (personality_artistic, personality_stress)      0.28149         1 0.33116
# (personality_lazy, personality_outgoing)        0.28245         1 0.33251
# (personality_fault, personality_lazy)           0.28402         1 0.33470
# (personality_artistic, personality_outgoing)    0.28938         1 0.34225
# (song_activity, musical_expertise)              0.29226         1 0.34708
# (concentration, personality_trusting)           0.29766         1 0.35402
# (song_like_dislike, concentration)              0.30147         1 0.36027
# (song_positivity, concentration)                0.30743         1 0.36892
# (song_like_dislike, personality_thorough)       0.31438         1 0.37909
# (personality_lazy, personality_trusting)        0.32108         1 0.38805
# (song_positivity, musical_expertise)            0.34166         1 0.42007
# (song_engagement, personality_reserved)         0.34268         1 0.42163
# (song_familiarity, personality_reserved)        0.34543         1 0.42588
# (song_activity, personality_reserved)           0.34556         1 0.42607
# (personality_lazy, personality_thorough)        0.34841         1 0.42933
# (song_familiarity, personality_fault)           0.35806         1 0.44555
# (song_engagement, personality_fault)            0.36257         1 0.45267
# (song_engagement, musical_expertise)            0.36267         1 0.45283
# (song_activity, personality_fault)              0.36538         1 0.45714
# (personality_artistic, personality_trusting)    0.37134         1 0.46533
# (song_like_dislike, musical_expertise)          0.38649         1 0.49135
# (personality_artistic, personality_lazy)        0.40060         1 0.51323
# (concentration, personality_lazy)               0.40588         1 0.52213
# (song_activity, personality_lazy)               0.40830         1 0.52797
# (song_engagement, personality_lazy)             0.42038         1 0.54886
# (song_activity, song_positivity)                0.42585         1 0.55845
# (song_activity, song_like_dislike)              0.43164         1 0.56873
# (song_familiarity, personality_lazy)            0.43475         1 0.57429
# (song_like_dislike, personality_fault)          0.44894         1 0.60006
# (song_like_dislike, personality_reserved)       0.45389         1 0.60922
# (song_positivity, personality_fault)            0.45509         1 0.61144
# (song_positivity, personality_reserved)         0.45823         1 0.61730
# (personality_imagination, personality_reserved) 0.46869         1 0.63456
# (personality_imagination, personality_stress)   0.47043         1 0.63787
# (personality_imagination, personality_nervous)  0.47226         1 0.64136
# (concentration, personality_artistic)           0.48017         1 0.65657
# (personality_fault, personality_imagination)    0.48087         1 0.65792
# (song_familiarity, personality_outgoing)        0.48429         1 0.66734
# (personality_artistic, personality_imagination) 0.51967         1 0.73619
# (personality_imagination, personality_thorough) 0.52353         1 0.74431
# (song_positivity, personality_outgoing)         0.52703         1 0.75528
# (song_positivity, personality_lazy)             0.53129         1 0.76448
# (song_like_dislike, personality_outgoing)       0.53751         1 0.77808
# (song_activity, personality_outgoing)           0.54093         1 0.78564
# (song_engagement, song_positivity)              0.55493         1 0.81718
# (song_engagement, personality_outgoing)         0.56120         1 0.83164
# (personality_imagination, personality_lazy)     0.58359         1 0.88022
# (song_like_dislike, personality_lazy)           0.58763         1 0.89503
# (personality_imagination, personality_outgoing) 0.60110         1 0.92360
# (concentration, personality_imagination)        0.60844         1 0.94235
# (personality_imagination, personality_trusting) 0.62375         1 0.98265
# (song_engagement, song_like_dislike)            0.64174         1 1.03884
# (musical_expertise, personality_nervous)        0.68064         1 1.14845
# (musical_expertise, personality_fault)          0.68098         1 1.14954
# (musical_expertise, personality_reserved)       0.68277         1 1.15525
# (musical_expertise, personality_stress)         0.68303         1 1.15608
# (musical_expertise, personality_artistic)       0.69513         1 1.19550
# (musical_expertise, personality_thorough)       0.70187         1 1.21813
# (musical_expertise, personality_outgoing)       0.70881         1 1.24201
# (musical_expertise, personality_trusting)       0.72968         1 1.31738
# (musical_expertise, personality_lazy)           0.76835         1 1.47410
# (age, personality_fault)                        0.77370         1 1.49783
# (age, personality_outgoing)                     0.77597         1 1.50809
# (song_familiarity, personality_imagination)     0.78461         1 1.56307
# (age, personality_nervous)                      0.78661         1 1.55752
# (musical_expertise, personality_imagination)    0.78879         1 1.56796
# (musical_expertise, concentration)              0.79382         1 1.59251
# (age, concentration)                            0.79428         1 1.59475
# (age, personality_stress)                       0.80740         1 1.66181
# (age, personality_thorough)                     0.80829         1 1.66655
# (age, personality_lazy)                         0.81224         1 1.68771
# (age, personality_reserved)                     0.81334         1 1.69369
# (song_positivity, personality_imagination)      0.81374         1 1.71390
# (age, personality_trusting)                     0.81902         1 1.72519
# (song_like_dislike, personality_imagination)    0.82173         1 1.75950
# (song_activity, personality_imagination)        0.84311         1 1.89266
# (age, personality_artistic)                     0.84495         1 1.88283
# (song_engagement, personality_imagination)      0.85288         1 1.95985
# (song_familiarity, song_tension)                0.88493         1 2.21749
# (song_tension, age)                             0.88500         1 2.21812
# (song_tension, personality_trusting)            0.88515         1 2.21949
# (song_tension, personality_nervous)             0.88517         1 2.21968
# (song_tension, personality_artistic)            0.88543         1 2.22212
# (song_tension, personality_thorough)            0.89250         1 2.28909
# (song_tension, musical_expertise)               0.89360         1 2.29998
# (song_tension, concentration)                   0.89482         1 2.31212
# (song_tension, personality_stress)              0.89574         1 2.32140
# (song_tension, personality_fault)               0.91191         1 2.49939
# (song_tension, personality_reserved)            0.91514         1 2.53889
# (song_activity, song_tension)                   0.92104         1 2.61522
# (song_tension, personality_outgoing)            0.92360         1 2.65019
# (age, personality_imagination)                  0.92757         1 2.66255
# (song_like_dislike, song_tension)               0.92884         1 2.72569
# (song_positivity, song_tension)                 0.92997         1 2.74271
# (song_tension, personality_lazy)                0.94358         1 2.97319
# (song_engagement, song_tension)                 0.94871         1 3.07517
# (age, musical_expertise)                        0.96517         1 3.41853
# (song_tension, personality_imagination)         0.97528         1 3.86380
#
#                                                      T2 df1  df2      D2
# (personality_nervous, personality_reserved)     0.03519   2  186 0.00075
# (personality_fault, personality_nervous)        0.04914   2  186 0.00104
# (song_familiarity, age)                         0.06508   2   86 0.00293
# (song_familiarity, personality_artistic)        0.06888   2   86 0.00310
# (song_familiarity, personality_stress)          0.07360   2   86 0.00331
# (personality_fault, personality_reserved)       0.08043   2  186 0.00170
# (personality_nervous, personality_outgoing)     0.09621   2  186 0.00204
# (personality_nervous, personality_thorough)     0.10556   2  186 0.00224
# (song_familiarity, personality_trusting)        0.12276   2   86 0.00552
# (personality_fault, personality_outgoing)       0.12245   2  186 0.00259
# (personality_nervous, personality_stress)       0.13065   2  186 0.00277
# (personality_reserved, personality_thorough)    0.13129   2  186 0.00278
# (personality_reserved, personality_stress)      0.13401   2  186 0.00284
# (personality_fault, personality_thorough)       0.14069   2  186 0.00298
# (song_activity, age)                            0.14762   2   86 0.00664
# (song_activity, personality_artistic)           0.14811   2   86 0.00666
# (song_activity, personality_stress)             0.14821   2   86 0.00667
# (song_activity, personality_trusting)           0.16405   2   86 0.00738
# (song_familiarity, concentration)               0.16787   2   86 0.00755
# (song_familiarity, personality_nervous)         0.17488   2   86 0.00787
# (personality_outgoing, personality_thorough)    0.17904   2  186 0.00379
# (personality_outgoing, personality_reserved)    0.18406   2  186 0.00390
# (personality_fault, personality_stress)         0.18751   2  186 0.00397
# (song_activity, concentration)                  0.19835   2   86 0.00892
# (song_familiarity, personality_thorough)        0.23569   2   86 0.01060
# (personality_stress, personality_thorough)      0.25724   2  186 0.00545
# (song_activity, song_familiarity)               0.26169   2   86 0.01177
# (personality_outgoing, personality_stress)      0.27311   2  186 0.00578
# (song_activity, personality_nervous)            0.28064   2   86 0.01263
# (song_engagement, age)                          0.28160   2   86 0.01267
# (song_engagement, personality_stress)           0.28379   2   86 0.01277
# (song_engagement, concentration)                0.28438   2   86 0.01280
# (song_activity, song_engagement)                0.28772   2   86 0.01295
# (song_engagement, personality_artistic)         0.28916   2   86 0.01301
# (song_engagement, personality_trusting)         0.31082   2   86 0.01399
# (personality_nervous, personality_trusting)     0.34456   2  186 0.00730
# (song_activity, personality_thorough)           0.35249   2   86 0.01586
# (song_engagement, personality_nervous)          0.36726   2   86 0.01652
# (personality_fault, personality_trusting)       0.36505   2  186 0.00773
# (personality_outgoing, personality_trusting)    0.36832   2  186 0.00780
# (personality_reserved, personality_trusting)    0.36968   2  186 0.00783
# (song_engagement, song_familiarity)             0.43124   2   86 0.01940
# (personality_thorough, personality_trusting)    0.43090   2  186 0.00913
# (concentration, personality_nervous)            0.45056   2  186 0.00954
# (concentration, personality_fault)              0.46617   2  186 0.00987
# (song_engagement, personality_thorough)         0.47457   2   86 0.02135
# (concentration, personality_reserved)           0.47938   2  186 0.01015
# (concentration, personality_outgoing)           0.48567   2  186 0.01029
# (song_positivity, personality_artistic)         0.50024   2   86 0.02251
# (song_familiarity, song_positivity)             0.50496   2   86 0.02272
# (song_positivity, age)                          0.51682   2   86 0.02325
# (song_familiarity, song_like_dislike)           0.51868   2   86 0.02334
# (song_like_dislike, personality_artistic)       0.51915   2   86 0.02336
# (song_like_dislike, age)                        0.52493   2   86 0.02362
# (song_positivity, personality_trusting)         0.53814   2   86 0.02421
# (personality_stress, personality_trusting)      0.54437   2  186 0.01153
# (personality_lazy, personality_reserved)        0.54752   2  186 0.01160
# (song_positivity, personality_stress)           0.56657   2   86 0.02549
# (concentration, personality_thorough)           0.56331   2  186 0.01193
# (personality_lazy, personality_nervous)         0.56538   2  186 0.01197
# (song_like_dislike, personality_trusting)       0.57286   2   86 0.02578
# (song_like_dislike, personality_stress)         0.58126   2   86 0.02615
# (personality_artistic, personality_nervous)     0.57905   2  186 0.01226
# (song_like_dislike, song_positivity)            0.58866   2   86 0.02649
# (personality_artistic, personality_reserved)    0.58567   2  186 0.01240
# (song_positivity, personality_nervous)          0.60113   2   86 0.02705
# (song_familiarity, musical_expertise)           0.60234   2   86 0.02710
# (song_like_dislike, personality_nervous)        0.60277   2   86 0.02712
# (personality_lazy, personality_stress)          0.61117   2  186 0.01294
# (personality_artistic, personality_fault)       0.61918   2  186 0.01311
# (song_positivity, personality_thorough)         0.62910   2   86 0.02831
# (concentration, personality_stress)             0.63621   2  186 0.01347
# (personality_artistic, personality_thorough)    0.66345   2  186 0.01405
# (personality_artistic, personality_stress)      0.66588   2  186 0.01410
# (personality_lazy, personality_outgoing)        0.66859   2  186 0.01416
# (personality_fault, personality_lazy)           0.67300   2  186 0.01425
# (personality_artistic, personality_outgoing)    0.68818   2  186 0.01457
# (song_activity, musical_expertise)              0.70223   2   86 0.03160
# (concentration, personality_trusting)           0.71184   2  186 0.01508
# (song_like_dislike, concentration)              0.72892   2   86 0.03280
# (song_positivity, concentration)                0.74642   2   86 0.03359
# (song_like_dislike, personality_thorough)       0.76699   2   86 0.03451
# (personality_lazy, personality_trusting)        0.78028   2  186 0.01653
# (song_positivity, musical_expertise)            0.84991   2   86 0.03824
# (song_engagement, personality_reserved)         0.85307   2   86 0.03838
# (song_familiarity, personality_reserved)        0.86166   2   86 0.03877
# (song_activity, personality_reserved)           0.86205   2   86 0.03879
# (personality_lazy, personality_thorough)        0.86328   2  186 0.01828
# (song_familiarity, personality_fault)           0.90147   2   86 0.04056
# (song_engagement, personality_fault)            0.91587   2   86 0.04121
# (song_engagement, musical_expertise)            0.91619   2   86 0.04122
# (song_activity, personality_fault)              0.92491   2   86 0.04162
# (personality_artistic, personality_trusting)    0.93567   2  186 0.01982
# (song_like_dislike, musical_expertise)          0.99413   2   86 0.04473
# (personality_artistic, personality_lazy)        1.03198   2  186 0.02186
# (concentration, personality_lazy)               1.04987   2  186 0.02223
# (song_activity, personality_lazy)               1.06821   2   86 0.04806
# (song_engagement, personality_lazy)             1.11048   2   86 0.04997
# (song_activity, song_positivity)                1.12990   2   86 0.05084
# (song_activity, song_like_dislike)              1.15068   2   86 0.05177
# (song_familiarity, personality_lazy)            1.16193   2   86 0.05228
# (song_like_dislike, personality_fault)          1.21408   2   86 0.05463
# (song_like_dislike, personality_reserved)       1.23261   2   86 0.05546
# (song_positivity, personality_fault)            1.23710   2   86 0.05566
# (song_positivity, personality_reserved)         1.24895   2   86 0.05620
# (personality_imagination, personality_reserved) 1.27594   2  186 0.02702
# (personality_imagination, personality_stress)   1.28259   2  186 0.02716
# (personality_imagination, personality_nervous)  1.28961   2  186 0.02731
# (concentration, personality_artistic)           1.32019   2  186 0.02796
# (personality_fault, personality_imagination)    1.32291   2  186 0.02802
# (song_familiarity, personality_outgoing)        1.35020   2   86 0.06075
# (personality_artistic, personality_imagination) 1.48030   2  186 0.03135
# (personality_imagination, personality_thorough) 1.49662   2  186 0.03170
# (song_positivity, personality_outgoing)         1.52812   2   86 0.06876
# (song_positivity, personality_lazy)             1.54674   2   86 0.06960
# (song_like_dislike, personality_outgoing)       1.57426   2   86 0.07083
# (song_activity, personality_outgoing)           1.58956   2   86 0.07152
# (song_engagement, song_positivity)              1.65337   2   86 0.07439
# (song_engagement, personality_outgoing)         1.68262   2   86 0.07571
# (personality_imagination, personality_lazy)     1.76991   2  186 0.03748
# (song_like_dislike, personality_lazy)           1.81087   2   86 0.08148
# (personality_imagination, personality_outgoing) 1.85713   2  186 0.03933
# (concentration, personality_imagination)        1.89484   2  186 0.04013
# (personality_imagination, personality_trusting) 1.97586   2  186 0.04185
# (song_engagement, song_like_dislike)            2.10183   2   86 0.09457
# (musical_expertise, personality_nervous)        2.30926   2  186 0.04891
# (musical_expertise, personality_fault)          2.31144   2  186 0.04895
# (musical_expertise, personality_reserved)       2.32292   2  186 0.04920
# (musical_expertise, personality_stress)         2.32459   2  186 0.04923
# (musical_expertise, personality_artistic)       2.40385   2  186 0.05091
# (musical_expertise, personality_thorough)       2.44936   2  186 0.05187
# (musical_expertise, personality_outgoing)       2.49738   2  186 0.05289
# (musical_expertise, personality_trusting)       2.64892   2  186 0.05610
# (musical_expertise, personality_lazy)           2.96405   2  186 0.06278
# (age, personality_fault)                        3.01176   2  186 0.06379
# (age, personality_outgoing)                     3.03239   2  186 0.06422
# (song_familiarity, personality_imagination)     3.16248   2   86 0.14230
# (age, personality_nervous)                      3.13179   2  186 0.06633
# (musical_expertise, personality_imagination)    3.15277   2  186 0.06677
# (musical_expertise, concentration)              3.20214   2  186 0.06782
# (age, concentration)                            3.20664   2  186 0.06791
# (age, personality_stress)                       3.34150   2  186 0.07077
# (age, personality_thorough)                     3.35101   2  186 0.07097
# (age, personality_lazy)                         3.39357   2  186 0.07187
# (age, personality_reserved)                     3.40559   2  186 0.07213
# (song_positivity, personality_imagination)      3.46765   2   86 0.15603
# (age, personality_trusting)                     3.46893   2  186 0.07347
# (song_like_dislike, personality_imagination)    3.55993   2   86 0.16018
# (song_activity, personality_imagination)        3.82934   2   86 0.17230
# (age, personality_artistic)                     3.78591   2  186 0.08018
# (song_engagement, personality_imagination)      3.96527   2   86 0.17842
# (song_familiarity, song_tension)                4.48656   2   86 0.20187
# (song_tension, age)                             4.48782   2   86 0.20193
# (song_tension, personality_trusting)            4.49060   2   86 0.20205
# (song_tension, personality_nervous)             4.49097   2   86 0.20207
# (song_tension, personality_artistic)            4.49592   2   86 0.20229
# (song_tension, personality_thorough)            4.63141   2   86 0.20839
# (song_tension, musical_expertise)               4.65344   2   86 0.20938
# (song_tension, concentration)                   4.67800   2   86 0.21049
# (song_tension, personality_stress)              4.69678   2   86 0.21133
# (song_tension, personality_fault)               5.05690   2   86 0.22753
# (song_tension, personality_reserved)            5.13682   2   86 0.23113
# (song_activity, song_tension)                   5.29126   2   86 0.23808
# (song_tension, personality_outgoing)            5.36201   2   86 0.24126
# (age, personality_imagination)                  5.35373   2  186 0.11339
# (song_like_dislike, song_tension)               5.51478   2   86 0.24814
# (song_positivity, song_tension)                 5.54921   2   86 0.24969
# (song_tension, personality_lazy)                6.01553   2   86 0.27067
# (song_engagement, song_tension)                 6.22185   2   86 0.27995
# (age, musical_expertise)                        6.87381   2  186 0.14558
# (song_tension, personality_imagination)         7.81746   2   86 0.35175

# %%
if results[results.adjustedP <= alpha].shape[0] > 0:
    for pair in results.index.values[0:3]:
        g = sns.FacetGrid(df_all[[pair[0], pair[1], 'critical_reaction']], col='critical_reaction', height=6, aspect=1, margin_titles=True)
        g.map(sns.kdeplot, pair[0], pair[1], cmap='Reds', shade=True, shade_lowest=False, alpha=0.65)
        g.savefig('hallelujah_reaction_distributions_{}_{}_{}_by_reaction.pdf'.format(notebook_song_name, pair[0], pair[1]))
else:
    print('No significant results to plot')
# Out:
# No significant results to plot
