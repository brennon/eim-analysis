# %% [markdown]
# # Exploratory Visualization

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import pandas as pd
import scipy.stats as sps
import seaborn as sns
import sklearn

from pathlib import Path

# %% [markdown]
# ## Retrieve and Subset Datasource
#
# Retrieve all good trials for IDs that came from Javier's algorithm.

# %%
notebook_song_name = 'hallelujah'

# %%
data_root = Path('../../neural_nets/fastai/data')

df_all = pd.read_csv(data_root / 'good_reaction_trials_categorified_q90_javier_all_no_bastards_no_impute.csv')

df_all = df_all[df_all.song == 'hallelujah']

pd.set_option('display.max_columns', None)
df_all.describe()
# Out:
#               age  personality_trusting  personality_artistic  \
# count  154.000000             61.000000             61.000000
# mean    24.292208              3.655738              2.459016
# std     13.085403              1.123762              1.311154
# min      6.000000              1.000000              1.000000
# 25%     16.000000              3.000000              1.000000
# 50%     21.000000              4.000000              2.000000
# 75%     31.000000              4.000000              3.000000
# max     81.000000              5.000000              5.000000
#
#        personality_imagination  personality_reserved  personality_outgoing  \
# count                61.000000             61.000000             61.000000
# mean                  3.885246              3.278689              3.196721
# std                   1.081640              1.066633              1.301533
# min                   1.000000              1.000000              1.000000
# 25%                   3.000000              3.000000              2.000000
# 50%                   4.000000              4.000000              3.000000
# 75%                   5.000000              4.000000              4.000000
# max                   5.000000              5.000000              5.000000
#
#        personality_lazy  personality_stress  personality_nervous  \
# count         61.000000           61.000000            61.000000
# mean           3.606557            3.163934             3.327869
# std            1.294587            1.128130             1.261234
# min            1.000000            1.000000             1.000000
# 25%            3.000000            2.000000             2.000000
# 50%            4.000000            3.000000             4.000000
# 75%            5.000000            4.000000             4.000000
# max            5.000000            5.000000             5.000000
#
#        personality_fault  personality_thorough  musical_expertise  \
# count          61.000000             61.000000          97.000000
# mean            3.245902              3.016393           2.608247
# std             1.220051              1.102902           1.177539
# min             1.000000              1.000000           1.000000
# 25%             2.000000              2.000000           2.000000
# 50%             4.000000              3.000000           3.000000
# 75%             4.000000              4.000000           3.000000
# max             5.000000              5.000000           5.000000
#
#        concentration  control_power  control_like_dislike  control_tension  \
# count      61.000000      61.000000             61.000000        61.000000
# mean        4.147541       3.327869              3.377049         3.721311
# std         0.945799       1.193333              1.451022         1.097439
# min         2.000000       1.000000              1.000000         1.000000
# 25%         4.000000       3.000000              2.000000         3.000000
# 50%         4.000000       3.000000              4.000000         4.000000
# 75%         5.000000       4.000000              5.000000         5.000000
# max         5.000000       5.000000              5.000000         5.000000
#
#        control_engagement  control_activity  control_positivity  \
# count           61.000000         61.000000           61.000000
# mean             3.426230          3.213115            3.557377
# std              1.257763          1.170680            1.088188
# min              1.000000          1.000000            1.000000
# 25%              3.000000          2.000000            3.000000
# 50%              4.000000          3.000000            4.000000
# 75%              4.000000          4.000000            4.000000
# max              5.000000          5.000000            5.000000
#
#        control_familiarity  song_power  song_like_dislike  song_tension  \
# count                 61.0   70.000000         133.000000    142.000000
# mean                  -1.0    3.485714           3.165414      3.809859
# std                    0.0    1.304872           1.472889      1.172577
# min                   -1.0    1.000000           1.000000      1.000000
# 25%                   -1.0    3.000000           2.000000      3.000000
# 50%                   -1.0    4.000000           3.000000      4.000000
# 75%                   -1.0    5.000000           5.000000      5.000000
# max                   -1.0    5.000000           5.000000      5.000000
#
#        song_engagement  song_activity  song_positivity  song_familiarity  \
# count       133.000000     133.000000       133.000000        133.000000
# mean          3.120301       3.345865         3.293233          3.263158
# std           1.537597       1.007886         1.301409          1.429636
# min           1.000000       1.000000         1.000000          1.000000
# 25%           2.000000       3.000000         2.000000          2.000000
# 50%           3.000000       3.000000         3.000000          4.000000
# 75%           5.000000       4.000000         4.000000          4.000000
# max           5.000000       5.000000         5.000000          5.000000
#
#        visual_impairments  song_inspired  song_wonder  song_spirituality  \
# count                 0.0      22.000000    31.000000          22.000000
# mean                  NaN       2.681818     2.967742           2.863636
# std                   NaN       1.170525     1.353609           1.355604
# min                   NaN       1.000000     1.000000           1.000000
# 25%                   NaN       2.000000     2.000000           2.000000
# 50%                   NaN       3.000000     3.000000           3.000000
# 75%                   NaN       3.750000     4.000000           4.000000
# max                   NaN       5.000000     5.000000           5.000000
#
#        song_thrills  song_chills  song_tenderness  song_nostalgia  \
# count     22.000000    22.000000        31.000000       31.000000
# mean       2.000000     2.545455         3.419355        3.548387
# std        1.154701     1.335496         1.310832        1.362319
# min        1.000000     1.000000         1.000000        1.000000
# 25%        1.000000     1.000000         2.500000        2.000000
# 50%        2.000000     2.000000         4.000000        4.000000
# 75%        2.750000     4.000000         4.000000        5.000000
# max        4.000000     4.000000         5.000000        5.000000
#
#        song_goosebumps  song_overwhelmed  song_shivers  \
# count        22.000000         22.000000     22.000000
# mean          2.363636          2.727273      2.136364
# std           1.328997          1.351606      1.082126
# min           1.000000          1.000000      1.000000
# 25%           1.000000          1.250000      1.000000
# 50%           2.500000          3.000000      2.000000
# 75%           3.000000          4.000000      3.000000
# max           5.000000          5.000000      4.000000
#
#        song_chillsshiversthrills  song_transcendence  song_sadness  \
# count                  50.000000            9.000000      9.000000
# mean                    2.440000            3.444444      3.555556
# std                     1.430855            0.881917      1.236033
# min                     1.000000            2.000000      2.000000
# 25%                     1.000000            3.000000      2.000000
# 50%                     2.000000            3.000000      4.000000
# 75%                     4.000000            4.000000      4.000000
# max                     5.000000            5.000000      5.000000
#
#        song_joyfulactivation  song_peacefulness  musicpref_hip_hop  \
# count               9.000000           9.000000         154.000000
# mean                1.444444           3.444444           0.129870
# std                 0.726483           0.726483           0.337257
# min                 1.000000           2.000000           0.000000
# 25%                 1.000000           3.000000           0.000000
# 50%                 1.000000           4.000000           0.000000
# 75%                 2.000000           4.000000           0.000000
# max                 3.000000           4.000000           1.000000
#
#        musicpref_traditional_irish  musicpref_classical  musicpref_hiphop  \
# count                   154.000000           154.000000        154.000000
# mean                      0.116883             0.266234          0.051948
# std                       0.322329             0.443430          0.222646
# min                       0.000000             0.000000          0.000000
# 25%                       0.000000             0.000000          0.000000
# 50%                       0.000000             0.000000          0.000000
# 75%                       0.000000             1.000000          0.000000
# max                       1.000000             1.000000          1.000000
#
#        musicpref_folk  musicpref_jazz  musicpref_dance  musicpref_world  \
# count      154.000000      154.000000       154.000000       154.000000
# mean         0.058442        0.188312         0.220779         0.142857
# std          0.235342        0.392236         0.416125         0.351069
# min          0.000000        0.000000         0.000000         0.000000
# 25%          0.000000        0.000000         0.000000         0.000000
# 50%          0.000000        0.000000         0.000000         0.000000
# 75%          0.000000        0.000000         0.000000         0.000000
# max          1.000000        1.000000         1.000000         1.000000
#
#        musicpref_rock  musicpref_none  musicpref_pop
# count      154.000000      154.000000     154.000000
# mean         0.532468        0.019481       0.616883
# std          0.500573        0.138657       0.487733
# min          0.000000        0.000000       0.000000
# 25%          0.000000        0.000000       0.000000
# 50%          1.000000        0.000000       1.000000
# 75%          1.000000        0.000000       1.000000
# max          1.000000        1.000000       1.000000

# %%
print(f"Total N: {df_all.shape[0]}")
# Out:
# Total N: 154

# %%
df_reaction = df_all[df_all['critical_reaction'] == True]
df_no_reaction = df_all[df_all['critical_reaction'] == False]

# %%
print(f"Total reaction N: {df_reaction.shape[0]}")
print(f"Total no-reaction N: {df_no_reaction.shape[0]}")
# Out:
# Total reaction N: 78
# Total no-reaction N: 76

# %%
df_all.columns
# Out:
# Index(['_id', 'location', 'language', 'nationality', 'age', 'sex',
#        'hearing_impairments', 'personality_trusting', 'personality_artistic',
#        'personality_imagination', 'personality_reserved',
#        'personality_outgoing', 'personality_lazy', 'personality_stress',
#        'personality_nervous', 'personality_fault', 'personality_thorough',
#        'musical_expertise', 'concentration', 'critical_reaction',
#        'control_power', 'control_like_dislike', 'control_tension',
#        'control_engagement', 'control_activity', 'control_positivity',
#        'control_familiarity', 'song_power', 'song_like_dislike',
#        'song_tension', 'song_engagement', 'song_activity', 'song_positivity',
#        'song_familiarity', 'musical_background', 'visual_impairments',
#        'song_inspired', 'song_wonder', 'song_spirituality', 'song_thrills',
#        'song_chills', 'song_tenderness', 'song_nostalgia', 'song_goosebumps',
#        'song_overwhelmed', 'song_shivers', 'song_chillsshiversthrills',
#        'song_transcendence', 'song_sadness', 'song_joyfulactivation',
#        'song_peacefulness', 'song', 'musicpref_hip_hop',
#        'musicpref_traditional_irish', 'musicpref_classical',
#        'musicpref_hiphop', 'musicpref_folk', 'musicpref_jazz',
#        'musicpref_dance', 'musicpref_world', 'musicpref_rock',
#        'musicpref_none', 'musicpref_pop'],
#       dtype='object')

# %%
cat_cols = ['location', 'language', 'nationality', 'sex', 'hearing_impairments']

ord_cols = ['personality_trusting', 'personality_artistic', 'personality_imagination', 'personality_reserved', 
            'personality_outgoing', 'personality_lazy', 'personality_stress', 'personality_nervous', 
            'personality_fault', 'personality_thorough', 'musical_expertise', 'concentration', 'song_power', 
            'song_like_dislike', 'song_tension', 'song_engagement', 'song_activity', 'song_positivity', 
            'song_familiarity', 'musical_background', 'song_chillsshiversthrills', 'musicpref_rock', 
            'musicpref_traditional_irish', 'musicpref_hip_hop', 'musicpref_jazz', 'musicpref_pop', 
            'musicpref_hiphop', 'musicpref_world', 'musicpref_none', 'musicpref_classical', 'musicpref_folk', 
            'musicpref_dance']

cont_cols = ['age']

# %%
nationality_counts = df_all['nationality'].value_counts()
patches, texts = plt.pie(nationality_counts, 
                                    explode=[0.1] * len(nationality_counts));

labels = ['{}: {}'.format(x.capitalize(), nationality_counts[x]) for x in nationality_counts.index]

plt.legend(patches, labels)
plt.savefig('hallelujah_reaction_pie_nationalities_redux_{}.pdf'.format(notebook_song_name))

# %%
language_counts = df_all['language'].value_counts()
patches, texts = plt.pie(language_counts, 
                                    explode=[0.1] * len(language_counts));

languages = list(language_counts.index)
for i in range(len(languages)):
    language = languages[i]
    if language == 'en':
        languages[i] = 'English'
    elif language == 'zh_TW':
        languages[i] = 'Taiwanese'

labels = ['{}: {}'.format(languages[i].capitalize(), language_counts[x]) for i, x in enumerate(language_counts.index)]

plt.legend(patches, labels)
plt.savefig('hallelujah_reaction_pie_languages_redux_{}.pdf'.format(notebook_song_name))

# %%
def mardia(data, unbiased_cov=True):
    """
    data should have observations in rows
    """
    import numpy as np
    import scipy.stats as sps
    
    n = data.shape[0]
    p = data.shape[1]

    S = None
    if unbiased_cov:
        S = ((n - 1.) / n) * np.cov(data, rowvar=False)
    else:
        S = np.cov(data, rowvar=False)

    data_scaled = (data - data.mean(axis=0))

    D = np.matmul(np.matmul(data_scaled, np.linalg.pinv(S, rcond=1e-25)), data_scaled.T)

    product = D * D * D
    skewness = np.sum(product) / n**2
    kurtosis = (D * D).diagonal().sum() / n
    df = p * (p + 1) * (p + 2) / 6
    k = ((p + 1)*(n + 1)*(n + 3))/(n*((n + 1)*(p + 1) - 6))
    
    skew, kurt, skew_p, kurt_p = None, None, None, None
    if n < 20:
        skew = n * k * skewness / 6.
    else:
        skew = n * skewness / 6.
    
    chi2_test_skew = sps.chi2(df)
    skew_p = 1. - chi2_test_skew.cdf(skew)
    
    skew_result = False
    if skew_p > 0.05:
        skew_result = True
    
    kurt = (kurtosis - p * (p + 2)) * np.sqrt(n / (8 * p * (p + 2)))
    
    normal_test_kurt = sps.norm()
    kurt_p = 2. * (1. - normal_test_kurt.cdf(np.abs(kurt)))
    
    kurt_result = False
    if kurt_p  > 0.05:
        kurt_result = True
    
    result_skewness = {
        'test': 'Mardia Skewness',
        'statistic': skew,
        'p-value': skew_p,
        'result': skew_result
    }
    
    result_kurtosis = {
        'test': 'Mardia Kurtosis',
        'statistic': kurt,
        'p-value': kurt_p,
        'result': kurt_result
    }
    
    result = {
        'test': 'MVN',
        'statistic': None,
        'p-value': None,
        'result': skew_result and kurt_result
    }
    
    return result_skewness, result_kurtosis, result

# %%
def run_tests(x_label, dist_var, bins=None, normed=False, kde=True, bw='normal_reference', x_lim=None, plots=False, print_output=False):
    
    if plots:
        f = plt.figure(figsize=(8, 4))
        sns.distplot(df_all[dist_var].dropna(), bins=bins, norm_hist=normed, kde=kde, rug=True, kde_kws={'bw': bw})
        plt.xlabel('')
        if x_lim is not None:
            plt.xlim([0.5, 5.5])

        g = sns.FacetGrid(df_all, hue='critical_reaction', height=4, aspect=2)
        g.map(sns.distplot, dist_var, bins=bins, norm_hist=normed, kde=kde, kde_kws={'bw': bw})
        g.set_xlabels(x_label)
        if x_lim is not None:
            g.axes[0,0].set_xlim([0.5, 5.5])
        g.fig.suptitle('Distribution of {} by reaction group'.format(dist_var), y=1.0)
        g.add_legend(title='Hallelujah Reaction');

        fig_file = 'hallelujah_reaction_distribution_all_stimuli_{}.pdf'.format(dist_var)
        g.savefig(fig_file, orientation='landscape')
        
    mean_true = df_all[df_all['critical_reaction'] == True][dist_var].dropna()
    mean_false = df_all[df_all['critical_reaction'] == False][dist_var].dropna()
    
    all_normtest = sps.normaltest(df_all[dist_var])
    true_normtest = sps.normaltest(df_all[df_all['critical_reaction'] == True][dist_var])
    false_normtest = sps.normaltest(df_all[df_all['critical_reaction'] == False][dist_var])
    if print_output:
        print(f'All normal test results: {all_normtest}')
        print(f'Reaction normal test results: {true_normtest}')
        print(f'No-reaction normal test results: {false_normtest}')
    
    alpha = 0.05
    _, equal_variance_p = sps.levene(mean_true, mean_false)
    
    equal_var = None
    if equal_variance_p >= alpha:
        equal_var = True
    else:
        equal_var = False
    
    t_stat, t_p = sps.ttest_ind(mean_true, mean_false, equal_var=equal_var)
    u_stat, u_p = sps.mannwhitneyu(mean_true, mean_false, alternative='two-sided')

    if print_output:
        print('Student\'s t-test for difference in mean {} between Hallelujah Reaction groups'.format(x_label.capitalize()))

        print('T test statistic: {:.4f}'.format(t_stat))
        print('T test p-value: {:.4f}'.format(t_p))

        print('Mann-Whitney U test statistic: {:.4f}'.format(u_stat))
        print('Mann-Whitney U test p-value: {:.4f}'.format(u_p))

        if t_p <= alpha or u_p <= alpha:
            print('**** Significant Result ****')
    
    return {
        'mean_true': mean_true.mean(),
        'mean_false': mean_false.mean(),
        'median_true': mean_true.median(),
        'median_false': mean_false.median(),
        't_stat': t_stat,
        't_p': t_p,
        'u_stat': u_stat,
        'u_p': u_p
    }

# %%
run_tests('Age [years]', 'age', bins=None, normed=False, kde=True, bw='normal_reference', x_lim=None, plots=True, print_output=True)
# Out:
# /home/paperspace/anaconda3/envs/fastai/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# All normal test results: NormaltestResult(statistic=46.47971757268405, pvalue=8.073420421944794e-11)
# Reaction normal test results: NormaltestResult(statistic=23.000823244917108, pvalue=1.0125924682666839e-05)
# No-reaction normal test results: NormaltestResult(statistic=29.488611145114604, pvalue=3.9502942839394163e-07)
# Student's t-test for difference in mean Age [years] between Hallelujah Reaction groups
# T test statistic: -1.0571
# T test p-value: 0.2921
# Mann-Whitney U test statistic: 2694.5000
# Mann-Whitney U test p-value: 0.3305
# {'mean_true': 23.192307692307693,
#  'mean_false': 25.42105263157895,
#  'median_true': 21.0,
#  'median_false': 21.0,
#  't_stat': -1.057143062107587,
#  't_p': 0.2921235239259984,
#  'u_stat': 2694.5,
#  'u_p': 0.33045494847184675}

# %%
df_results = pd.DataFrame({})

for c in ord_cols:
    result = run_tests(c, c)
    df_results = pd.concat([df_results, pd.DataFrame(result, index=[c])])

# %%
df_results = df_results.sort_values(by='u_p')

i = np.arange(1, len(ord_cols) + len(cont_cols))
m = len(i)
Q = 0.25
benjamini_hochberg = ((i * 1.) / m) * Q
df_results['bh_threshold'] = benjamini_hochberg
df_results['significant'] = df_results.u_p < df_results.bh_threshold

df_results
# Out:
#                              mean_true  mean_false  median_true  median_false  \
# song_like_dislike             2.835821    3.500000          3.0           4.0
# musicpref_classical           0.192308    0.342105          0.0           0.0
# song_activity                 3.194030    3.500000          3.0           4.0
# song_chillsshiversthrills     2.840000    2.040000          2.0           2.0
# song_engagement               2.910448    3.333333          3.0           4.0
# song_tension                  3.694444    3.928571          4.0           4.0
# musicpref_hiphop              0.025641    0.078947          0.0           0.0
# personality_stress            3.400000    3.000000          4.0           3.0
# personality_thorough          2.760000    3.194444          3.0           3.0
# musicpref_jazz                0.153846    0.223684          0.0           0.0
# personality_fault             3.440000    3.111111          4.0           3.0
# musicpref_folk                0.038462    0.078947          0.0           0.0
# personality_lazy              3.440000    3.722222          4.0           4.0
# personality_artistic          2.680000    2.305556          3.0           2.0
# musicpref_world               0.166667    0.118421          0.0           0.0
# song_familiarity              3.388060    3.136364          4.0           4.0
# concentration                 4.000000    4.250000          4.0           4.0
# musicpref_traditional_irish   0.102564    0.131579          0.0           0.0
# musicpref_none                0.025641    0.013158          0.0           0.0
# musicpref_rock                0.512821    0.552632          1.0           1.0
# personality_outgoing          3.280000    3.138889          3.0           3.5
# personality_trusting          3.560000    3.722222          4.0           4.0
# song_power                    3.566667    3.425000          4.0           4.0
# musicpref_hip_hop             0.141026    0.118421          0.0           0.0
# personality_reserved          3.240000    3.305556          3.0           4.0
# personality_nervous           3.280000    3.361111          3.0           4.0
# musical_background            0.500000    0.437500          0.5           0.0
# personality_imagination       3.840000    3.916667          4.0           4.0
# musical_expertise             2.577778    2.634615          3.0           3.0
# song_positivity               3.283582    3.303030          3.0           4.0
# musicpref_dance               0.217949    0.223684          0.0           0.0
# musicpref_pop                 0.615385    0.618421          1.0           1.0
#
#                                t_stat       t_p  u_stat       u_p  \
# song_like_dislike           -2.659282  0.008808  1659.0  0.011148
# musicpref_classical         -2.114626  0.036165  2520.0  0.036300
# song_activity               -1.764411  0.079994  1814.5  0.060736
# song_chillsshiversthrills    2.039472  0.046928   402.5  0.072104
# song_engagement             -1.595106  0.113098  1873.5  0.120060
# song_tension                -1.191313  0.235547  2172.5  0.135271
# musicpref_hiphop            -1.491378  0.137935  2806.0  0.138674
# personality_stress           1.371913  0.175285   545.5  0.149988
# personality_thorough        -1.529859  0.131396   355.5  0.152366
# musicpref_jazz              -1.105485  0.270696  2757.0  0.270455
# personality_fault            1.036080  0.304393   520.0  0.286842
# musicpref_folk              -1.067816  0.287296  2844.0  0.287836
# personality_lazy            -0.835255  0.406944   384.0  0.316692
# personality_artistic         1.098853  0.276296   511.0  0.360678
# musicpref_world              0.851863  0.395630  3107.0  0.395522
# song_familiarity             1.015278  0.311845  2394.0  0.396370
# concentration               -1.015573  0.313979   402.0  0.455616
# musicpref_traditional_irish -0.557229  0.578191  2878.0  0.578729
# musicpref_none               0.557306  0.578138  3001.0  0.581622
# musicpref_rock              -0.492212  0.623280  2846.0  0.623183
# personality_outgoing         0.413563  0.680694   482.5  0.628250
# personality_trusting        -0.551262  0.583536   423.5  0.678022
# song_power                   0.446898  0.656369   634.5  0.678097
# musicpref_hip_hop            0.414716  0.678935  3031.0  0.679798
# personality_reserved        -0.234209  0.815634   424.5  0.696687
# personality_nervous         -0.245083  0.807243   424.0  0.700616
# musical_background           0.363442  0.718525   170.0  0.726615
# personality_imagination     -0.270146  0.787990   432.0  0.787962
# musical_expertise           -0.235904  0.814015  1140.0  0.825283
# song_positivity             -0.085844  0.931721  2173.0  0.862506
# musicpref_dance             -0.085237  0.932185  2947.0  0.933852
# musicpref_pop               -0.038499  0.969340  2955.0  0.970900
#
#                              bh_threshold  significant
# song_like_dislike                0.007812        False
# musicpref_classical              0.015625        False
# song_activity                    0.023438        False
# song_chillsshiversthrills        0.031250        False
# song_engagement                  0.039062        False
# song_tension                     0.046875        False
# musicpref_hiphop                 0.054688        False
# personality_stress               0.062500        False
# personality_thorough             0.070312        False
# musicpref_jazz                   0.078125        False
# personality_fault                0.085938        False
# musicpref_folk                   0.093750        False
# personality_lazy                 0.101562        False
# personality_artistic             0.109375        False
# musicpref_world                  0.117188        False
# song_familiarity                 0.125000        False
# concentration                    0.132812        False
# musicpref_traditional_irish      0.140625        False
# musicpref_none                   0.148438        False
# musicpref_rock                   0.156250        False
# personality_outgoing             0.164062        False
# personality_trusting             0.171875        False
# song_power                       0.179688        False
# musicpref_hip_hop                0.187500        False
# personality_reserved             0.195312        False
# personality_nervous              0.203125        False
# musical_background               0.210938        False
# personality_imagination          0.218750        False
# musical_expertise                0.226562        False
# song_positivity                  0.234375        False
# musicpref_dance                  0.242188        False
# musicpref_pop                    0.250000        False

# %%
sns.countplot(x='sex', hue='critical_reaction', data=df_all)

# %%
# Chi-squared test of male/female proportions

cross = pd.crosstab(df_all['sex'], df_all['critical_reaction'])
display(cross)
chi2, p, dof, table = sps.chi2_contingency(cross)
print('Chi-squared test of sex vs hallelujah reaction proportions')
print('Test statistic: {:.4f}'.format(chi2))
print('p-value: {:.4f}'.format(p))
print('Degrees of freedom: {}'.format(dof))
# Out:
# critical_reaction  False  True
# sex
# female                33     41
# male                  43     37
# Chi-squared test of sex vs hallelujah reaction proportions
# Test statistic: 0.9488
# p-value: 0.3300
# Degrees of freedom: 1

# %%
sns.countplot(x='location', hue='critical_reaction', data=df_all)

# %%
# Chi-squared test of location proportions

cross = pd.crosstab(df_all['location'], df_all['critical_reaction'])
display(cross)
chi2, p, dof, table = sps.chi2_contingency(cross)
print('Chi-squared test of location vs hallelujah reaction proportions')
print('Test statistic: {:.4f}'.format(chi2))
print('p-value: {:.4f}'.format(p))
print('Degrees of freedom: {}'.format(dof))
# Out:
# critical_reaction  False  True
# location
# dublin                40     53
# taichung_city          9      5
# taipei_city           27     20
# Chi-squared test of location vs hallelujah reaction proportions
# Test statistic: 3.9773
# p-value: 0.1369
# Degrees of freedom: 2

# %%
sns.countplot(x='language', hue='critical_reaction', data=df_all)

# %%
# Chi-squared test of language proportions

cross = pd.crosstab(df_all['language'], df_all['critical_reaction'])
display(cross)
chi2, p, dof, table = sps.chi2_contingency(cross)
print('Chi-squared test of language vs hallelujah reaction proportions (for Taiwanese, English, and NA)')
print('Test statistic: {:.4f}'.format(chi2))
print('p-value: {:.4f}'.format(p))
print('Degrees of freedom: {}'.format(dof))
# Out:
# critical_reaction  False  True
# language
# en                    31     18
# zh_TW                  5      7
# Chi-squared test of language vs hallelujah reaction proportions (for Taiwanese, English, and NA)
# Test statistic: 1.0734
# p-value: 0.3002
# Degrees of freedom: 1

# %% [markdown]
# Sources for Hotelling's $T^2$:
# - https://ncss-wpengine.netdna-ssl.com/wp-content/themes/ncss/pdf/Procedures/NCSS/Hotellings_Two-Sample_T2.pdf
# - https://onlinecourses.science.psu.edu/stat505/node/100/

# %%
def hotelling_t2(X_1, X_2, alpha):
    
    import scipy.stats as sps
    
    n_1 = len(X_1)
    n_2 = len(X_2)

    y_1 = X_1.mean().as_matrix()
    y_1 = y_1.reshape(len(y_1), -1)
    y_2 = X_2.mean().as_matrix()
    y_2 = y_2.reshape(len(y_2), -1)

    # Covariance matrices
    S_1 = np.cov(X_1.astype(np.float64).T)
    S_2 = np.cov(X_2.astype(np.float64).T)

    # Pooled variance
    S_pooled_num = ((n_1 - 1) * S_1) + ((n_2 - 1) * S_2)
    S_pooled_denom = n_1 + n_2 - 2
    S_pooled = S_pooled_num / S_pooled_denom
    
    T_2 = (n_1 * n_2) / (n_1 + n_2)
    T_2 = T_2 * np.matmul((y_1 - y_2).T, np.linalg.pinv(S_pooled))
    T_2 = np.matmul(T_2, (y_1 - y_2))
    T_2 = T_2.squeeze()
    
    p = len(X_1.columns)
    F_num = n_1 + n_2 - p - 1
    F_denom = p * (n_1 + n_2 - 2)
    F = (F_num / F_denom) * T_2
    F = F.squeeze()
    
    df_1 = p
    df_2 = n_1 + n_2 - p - 1
    F_dist = sps.f(df_1, df_2)
    p_value = F_dist.cdf(F)
    
    # Calculate effect size
    D_2 = ((n_1 + n_2) * T_2) / (n_1 * n_2)
    
    return({
        'T2': T_2,
        'F': F,
        'df': (df_1, df_2),
        'p': p_value,
        'D2': D_2
    })

# %% [markdown]
# # Pairwise Hotelling's $T^2$

# %%
import itertools

plot_vars = ['song_activity', 
             'song_engagement', 
             'song_familiarity', 
             'song_like_dislike', 
             'song_positivity', 
             'song_tension', 
             'age', 
             'musical_expertise', 
             'concentration', 
             'personality_artistic', 
             'personality_fault', 
             'personality_imagination', 
             'personality_lazy', 
             'personality_nervous', 
             'personality_outgoing', 
             'personality_reserved', 
             'personality_stress', 
             'personality_thorough', 
             'personality_trusting']

pairs = list(itertools.combinations(plot_vars, 2))

results = pd.DataFrame(columns=['p', 'adjustedP', 'F', 'T2', 'df1', 'df2', 'D2'])

for pair in pairs:
    
    test_vars = list(pair)
    test_vars.append('critical_reaction')
    df_pair = df_all[test_vars].dropna()
    df_pair_1 = df_pair[df_pair['critical_reaction'] == False].drop(['critical_reaction'], axis=1)
    df_pair_2 = df_pair[df_pair['critical_reaction'] == True].drop(['critical_reaction'], axis=1)
    
    mardia_result = mardia(df_pair.drop(['critical_reaction'], axis=1), unbiased_cov=True)
    if mardia_result[2]['result']:
        pass

    t2_results = hotelling_t2(df_pair_1, df_pair_2, 0.05)
    p = t2_results['p']
    adjusted_p = p * len(pairs)
    if adjusted_p > 1:
        adjusted_p = 1
        
    row = pd.DataFrame(
        {
            'p': t2_results['p'], 
            'adjustedP': adjusted_p,
            'F': t2_results['F'], 
            'T2': t2_results['T2'], 
            'df1': t2_results['df'][0], 
            'df2': t2_results['df'][1],
            'D2': t2_results['D2']
        }, 
        index=[pair])

    results = pd.concat([results, row])
    
alpha = 0.5
    
with pd.option_context('display.max_rows', None, 'display.float_format', lambda x: '%.5f' % x):
    display('Tests for difference between combined means of {} and {} between hallelujah reaction groups:'.format(pair[0], pair[1]))
    display(results.sort_values(by='p'))

results.to_csv('hotelling_comparisons_{}.csv'.format(notebook_song_name))
# Out:
# /home/paperspace/anaconda3/envs/fastai/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# /home/paperspace/anaconda3/envs/fastai/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.
# 'Tests for difference between combined means of personality_thorough and personality_trusting between hallelujah reaction groups:'
#                                                       p adjustedP       F  \
# (song_tension, personality_reserved)            0.02989         1 0.03037
# (song_tension, personality_nervous)             0.03036         1 0.03085
# (song_tension, personality_imagination)         0.03642         1 0.03712
# (personality_nervous, personality_reserved)     0.04205         1 0.04300
# (personality_imagination, personality_nervous)  0.05530         1 0.05695
# (age, musical_expertise)                        0.05637         1 0.05806
# (personality_imagination, personality_reserved) 0.06268         1 0.06480
# (personality_outgoing, personality_reserved)    0.08687         1 0.09102
# (song_tension, personality_outgoing)            0.08716         1 0.09134
# (song_familiarity, personality_imagination)     0.08869         1 0.09302
# (song_familiarity, personality_reserved)        0.09635         1 0.10149
# (song_familiarity, personality_nervous)         0.09698         1 0.10219
# (personality_nervous, personality_outgoing)     0.09715         1 0.10238
# (song_like_dislike, personality_nervous)        0.10608         1 0.11235
# (song_like_dislike, personality_reserved)       0.11124         1 0.11817
# (song_positivity, personality_reserved)         0.11469         1 0.12208
# (song_like_dislike, personality_imagination)    0.11974         1 0.12782
# (song_positivity, personality_imagination)      0.12422         1 0.13295
# (song_tension, personality_trusting)            0.13844         1 0.14939
# (song_positivity, personality_nervous)          0.13928         1 0.15038
# (personality_nervous, personality_trusting)     0.14584         1 0.15806
# (song_positivity, personality_outgoing)         0.14908         1 0.16189
# (personality_reserved, personality_trusting)    0.15138         1 0.16461
# (song_positivity, musical_expertise)            0.15902         1 0.17359
# (song_familiarity, personality_outgoing)        0.16068         1 0.17569
# (personality_imagination, personality_trusting) 0.16325         1 0.17877
# (song_like_dislike, personality_outgoing)       0.18034         1 0.19955
# (personality_imagination, personality_outgoing) 0.19291         1 0.21511
# (song_activity, personality_nervous)            0.19457         1 0.21719
# (song_activity, personality_reserved)           0.19620         1 0.21923
# (song_engagement, personality_reserved)         0.19633         1 0.21939
# (song_activity, personality_imagination)        0.20247         1 0.22712
# (song_like_dislike, personality_trusting)       0.20371         1 0.22869
# (song_familiarity, musical_expertise)           0.21423         1 0.24188
# (song_positivity, personality_trusting)         0.21498         1 0.24305
# (song_engagement, personality_outgoing)         0.21517         1 0.24330
# (song_familiarity, personality_trusting)        0.21542         1 0.24363
# (song_engagement, personality_nervous)          0.23382         1 0.26756
# (song_engagement, personality_imagination)      0.24310         1 0.27986
# (personality_outgoing, personality_trusting)    0.24754         1 0.28581
# (song_activity, personality_outgoing)           0.26711         1 0.31243
# (personality_lazy, personality_nervous)         0.28912         1 0.34327
# (personality_imagination, personality_lazy)     0.29023         1 0.34485
# (song_tension, personality_lazy)                0.29576         1 0.35276
# (song_engagement, personality_trusting)         0.30028         1 0.35928
# (personality_lazy, personality_reserved)        0.30391         1 0.36455
# (song_familiarity, personality_lazy)            0.30929         1 0.37240
# (song_activity, personality_trusting)           0.31209         1 0.37652
# (personality_lazy, personality_outgoing)        0.32472         1 0.39529
# (song_like_dislike, personality_lazy)           0.33416         1 0.40958
# (song_tension, musical_expertise)               0.34139         1 0.41976
# (personality_lazy, personality_trusting)        0.36821         1 0.46285
# (song_positivity, personality_lazy)             0.37384         1 0.47195
# (song_tension, concentration)                   0.39511         1 0.50708
# (concentration, personality_imagination)        0.39603         1 0.50864
# (song_familiarity, concentration)               0.40030         1 0.51586
# (song_familiarity, song_positivity)             0.41147         1 0.53229
# (concentration, personality_reserved)           0.41504         1 0.54120
# (song_tension, personality_fault)               0.41721         1 0.54498
# (song_like_dislike, concentration)              0.41823         1 0.54678
# (song_positivity, personality_fault)            0.42135         1 0.55226
# (concentration, personality_nervous)            0.42990         1 0.56742
# (song_activity, personality_lazy)               0.43472         1 0.57609
# (concentration, personality_trusting)           0.44397         1 0.59291
# (personality_fault, personality_imagination)    0.44688         1 0.59827
# (song_engagement, personality_lazy)             0.45294         1 0.60952
# (personality_artistic, personality_nervous)     0.45301         1 0.60965
# (personality_artistic, personality_outgoing)    0.45309         1 0.60980
# (personality_fault, personality_trusting)       0.46253         1 0.62758
# (musical_expertise, personality_imagination)    0.46381         1 0.63002
# (musical_expertise, personality_reserved)       0.46424         1 0.63084
# (personality_fault, personality_outgoing)       0.46587         1 0.63394
# (personality_fault, personality_reserved)       0.46841         1 0.63882
# (personality_artistic, personality_imagination) 0.46858         1 0.63914
# (musical_expertise, personality_nervous)        0.46877         1 0.63950
# (song_positivity, personality_artistic)         0.46888         1 0.63972
# (song_engagement, personality_fault)            0.46945         1 0.64081
# (personality_artistic, personality_reserved)    0.47134         1 0.64448
# (song_familiarity, personality_artistic)        0.47449         1 0.65057
# (song_tension, personality_artistic)            0.47516         1 0.65188
# (song_activity, concentration)                  0.47980         1 0.66096
# (song_engagement, personality_artistic)         0.49357         1 0.68841
# (song_activity, personality_fault)              0.49543         1 0.69219
# (song_positivity, concentration)                0.50423         1 0.71020
# (personality_fault, personality_nervous)        0.50911         1 0.72034
# (musical_expertise, personality_trusting)       0.51126         1 0.72484
# (song_like_dislike, personality_fault)          0.52273         1 0.74920
# (song_familiarity, personality_fault)           0.53129         1 0.76777
# (personality_artistic, personality_trusting)    0.53500         1 0.77591
# (song_like_dislike, personality_artistic)       0.56608         1 0.84704
# (song_positivity, song_tension)                 0.56823         1 0.84531
# (concentration, personality_outgoing)           0.57016         1 0.85675
# (musical_expertise, personality_outgoing)       0.57910         1 0.87840
# (musical_expertise, personality_lazy)           0.58857         1 0.90184
# (song_engagement, concentration)                0.59553         1 0.91945
# (personality_artistic, personality_fault)       0.59998         1 0.93086
# (personality_outgoing, personality_stress)      0.60057         1 0.93240
# (song_positivity, personality_stress)           0.60273         1 0.93799
# (concentration, personality_fault)              0.60761         1 0.95075
# (personality_nervous, personality_stress)       0.60793         1 0.95158
# (song_activity, personality_artistic)           0.60892         1 0.95421
# (song_engagement, personality_stress)           0.61312         1 0.96536
# (song_tension, personality_stress)              0.62656         1 1.00191
# (concentration, personality_lazy)               0.62865         1 1.00773
# (musical_expertise, concentration)              0.63259         1 1.01875
# (personality_artistic, personality_lazy)        0.63727         1 1.03204
# (personality_reserved, personality_stress)      0.64388         1 1.05108
# (song_activity, musical_expertise)              0.64630         1 1.05423
# (song_engagement, musical_expertise)            0.66063         1 1.09682
# (song_familiarity, personality_stress)          0.66819         1 1.12445
# (personality_imagination, personality_stress)   0.67010         1 1.13046
# (musical_expertise, personality_artistic)       0.67345         1 1.14106
# (musical_expertise, personality_fault)          0.67722         1 1.15313
# (personality_imagination, personality_thorough) 0.67742         1 1.15376
# (personality_reserved, personality_thorough)    0.67811         1 1.15600
# (song_tension, personality_thorough)            0.67833         1 1.15671
# (song_like_dislike, personality_stress)         0.68164         1 1.16745
# (personality_nervous, personality_thorough)     0.68164         1 1.16746
# (song_activity, personality_thorough)           0.68242         1 1.17001
# (song_like_dislike, personality_thorough)       0.69091         1 1.19821
# (personality_lazy, personality_stress)          0.69884         1 1.22530
# (song_activity, personality_stress)             0.70197         1 1.23617
# (personality_stress, personality_trusting)      0.71005         1 1.26485
# (song_familiarity, personality_thorough)        0.71495         1 1.28265
# (personality_artistic, personality_stress)      0.72582         1 1.32326
# (personality_fault, personality_lazy)           0.73131         1 1.34442
# (song_positivity, personality_thorough)         0.73791         1 1.37047
# (song_engagement, personality_thorough)         0.73793         1 1.37053
# (personality_outgoing, personality_thorough)    0.73824         1 1.37178
# (song_like_dislike, musical_expertise)          0.74282         1 1.38355
# (song_engagement, song_familiarity)             0.74523         1 1.38189
# (personality_thorough, personality_trusting)    0.75374         1 1.43577
# (song_familiarity, song_tension)                0.75786         1 1.43381
# (personality_fault, personality_stress)         0.75929         1 1.45973
# (concentration, personality_thorough)           0.76332         1 1.47744
# (concentration, personality_artistic)           0.76690         1 1.49347
# (musical_expertise, personality_thorough)       0.77118         1 1.51295
# (song_engagement, song_tension)                 0.80899         1 1.67671
# (song_activity, song_positivity)                0.81216         1 1.69384
# (song_positivity, age)                          0.81513         1 1.71020
# (song_activity, song_familiarity)               0.84386         1 1.88378
# (song_activity, song_tension)                   0.85893         1 1.98832
# (personality_lazy, personality_thorough)        0.86841         1 2.10069
# (song_activity, song_engagement)                0.86960         1 2.06939
# (musical_expertise, personality_stress)         0.87647         1 2.16850
# (personality_artistic, personality_thorough)    0.87953         1 2.19548
# (song_engagement, song_positivity)              0.88127         1 2.16624
# (personality_fault, personality_thorough)       0.88162         1 2.21431
# (song_tension, age)                             0.88466         1 2.19376
# (concentration, personality_stress)             0.89038         1 2.29718
# (personality_stress, personality_thorough)      0.90600         1 2.46350
# (song_familiarity, age)                         0.92180         1 2.59914
# (age, personality_lazy)                         0.92654         1 2.73215
# (age, personality_nervous)                      0.92709         1 2.74034
# (age, personality_reserved)                     0.92776         1 2.75053
# (age, personality_outgoing)                     0.92794         1 2.75317
# (age, personality_imagination)                  0.92855         1 2.76248
# (age, personality_trusting)                     0.92931         1 2.77426
# (age, personality_artistic)                     0.93938         1 2.94303
# (age, personality_stress)                       0.95782         1 3.34508
# (age, concentration)                            0.96465         1 3.54282
# (song_familiarity, song_like_dislike)           0.96722         1 3.50932
# (age, personality_fault)                        0.97068         1 3.75320
# (song_like_dislike, song_tension)               0.97266         1 3.70080
# (song_activity, age)                            0.97437         1 3.76909
# (age, personality_thorough)                     0.97673         1 4.01553
# (song_activity, song_like_dislike)              0.97748         1 3.90643
# (song_engagement, song_like_dislike)            0.98018         1 4.04170
# (song_engagement, age)                          0.99197         1 5.00800
# (song_like_dislike, song_positivity)            0.99899         1 7.27561
# (song_like_dislike, age)                        0.99957         1 8.24516
#
#                                                       T2 df1  df2      D2
# (song_tension, personality_reserved)             0.06178   2   58 0.00419
# (song_tension, personality_nervous)              0.06277   2   58 0.00425
# (song_tension, personality_imagination)          0.07552   2   58 0.00512
# (personality_nervous, personality_reserved)      0.08748   2   58 0.00593
# (personality_imagination, personality_nervous)   0.11586   2   58 0.00785
# (age, musical_expertise)                         0.11735   2   94 0.00486
# (personality_imagination, personality_reserved)  0.13184   2   58 0.00894
# (personality_outgoing, personality_reserved)     0.18518   2   58 0.01255
# (song_tension, personality_outgoing)             0.18582   2   58 0.01259
# (song_familiarity, personality_imagination)      0.18924   2   58 0.01283
# (song_familiarity, personality_reserved)         0.20648   2   58 0.01399
# (song_familiarity, personality_nervous)          0.20791   2   58 0.01409
# (personality_nervous, personality_outgoing)      0.20829   2   58 0.01412
# (song_like_dislike, personality_nervous)         0.22858   2   58 0.01549
# (song_like_dislike, personality_reserved)        0.24041   2   58 0.01629
# (song_positivity, personality_reserved)          0.24837   2   58 0.01683
# (song_like_dislike, personality_imagination)     0.26005   2   58 0.01763
# (song_positivity, personality_imagination)       0.27048   2   58 0.01833
# (song_tension, personality_trusting)             0.30393   2   58 0.02060
# (song_positivity, personality_nervous)           0.30594   2   58 0.02074
# (personality_nervous, personality_trusting)      0.32157   2   58 0.02180
# (song_positivity, personality_outgoing)          0.32936   2   58 0.02232
# (personality_reserved, personality_trusting)     0.33489   2   58 0.02270
# (song_positivity, musical_expertise)             0.35194   2   73 0.01873
# (song_familiarity, personality_outgoing)         0.35743   2   58 0.02423
# (personality_imagination, personality_trusting)  0.36371   2   58 0.02465
# (song_like_dislike, personality_outgoing)        0.40598   2   58 0.02752
# (personality_imagination, personality_outgoing)  0.43764   2   58 0.02966
# (song_activity, personality_nervous)             0.44187   2   58 0.02995
# (song_activity, personality_reserved)            0.44602   2   58 0.03023
# (song_engagement, personality_reserved)          0.44635   2   58 0.03025
# (song_activity, personality_imagination)         0.46206   2   58 0.03132
# (song_like_dislike, personality_trusting)        0.46527   2   58 0.03154
# (song_familiarity, musical_expertise)            0.49040   2   73 0.02610
# (song_positivity, personality_trusting)          0.49449   2   58 0.03352
# (song_engagement, personality_outgoing)          0.49498   2   58 0.03355
# (song_familiarity, personality_trusting)         0.49566   2   58 0.03359
# (song_engagement, personality_nervous)           0.54435   2   58 0.03689
# (song_engagement, personality_imagination)       0.56937   2   58 0.03859
# (personality_outgoing, personality_trusting)     0.58148   2   58 0.03941
# (song_activity, personality_outgoing)            0.63563   2   58 0.04308
# (personality_lazy, personality_nervous)          0.69838   2   58 0.04733
# (personality_imagination, personality_lazy)      0.70159   2   58 0.04755
# (song_tension, personality_lazy)                 0.71769   2   58 0.04864
# (song_engagement, personality_trusting)          0.73096   2   58 0.04954
# (personality_lazy, personality_reserved)         0.74166   2   58 0.05027
# (song_familiarity, personality_lazy)             0.75764   2   58 0.05135
# (song_activity, personality_trusting)            0.76602   2   58 0.05192
# (personality_lazy, personality_outgoing)         0.80422   2   58 0.05451
# (song_like_dislike, personality_lazy)            0.83328   2   58 0.05648
# (song_tension, musical_expertise)                0.84975   2   82 0.04026
# (personality_lazy, personality_trusting)         0.94166   2   58 0.06382
# (song_positivity, personality_lazy)              0.96017   2   58 0.06508
# (song_tension, concentration)                    1.03166   2   58 0.06992
# (concentration, personality_imagination)         1.03481   2   58 0.07014
# (song_familiarity, concentration)                1.04951   2   58 0.07113
# (song_familiarity, song_positivity)              1.07277   2  130 0.03227
# (concentration, personality_reserved)            1.10106   2   58 0.07463
# (song_tension, personality_fault)                1.10875   2   58 0.07515
# (song_like_dislike, concentration)               1.11241   2   58 0.07540
# (song_positivity, personality_fault)             1.12356   2   58 0.07615
# (concentration, personality_nervous)             1.15441   2   58 0.07824
# (song_activity, personality_lazy)                1.17204   2   58 0.07944
# (concentration, personality_trusting)            1.20627   2   58 0.08176
# (personality_fault, personality_imagination)     1.21718   2   58 0.08250
# (song_engagement, personality_lazy)              1.24006   2   58 0.08405
# (personality_artistic, personality_nervous)      1.24032   2   58 0.08407
# (personality_artistic, personality_outgoing)     1.24063   2   58 0.08409
# (personality_fault, personality_trusting)        1.27679   2   58 0.08654
# (musical_expertise, personality_imagination)     1.28176   2   58 0.08688
# (musical_expertise, personality_reserved)        1.28343   2   58 0.08699
# (personality_fault, personality_outgoing)        1.28975   2   58 0.08742
# (personality_fault, personality_reserved)        1.29966   2   58 0.08809
# (personality_artistic, personality_imagination)  1.30033   2   58 0.08813
# (musical_expertise, personality_nervous)         1.30105   2   58 0.08818
# (song_positivity, personality_artistic)          1.30150   2   58 0.08821
# (song_engagement, personality_fault)             1.30373   2   58 0.08836
# (personality_artistic, personality_reserved)     1.31118   2   58 0.08887
# (song_familiarity, personality_artistic)         1.32357   2   58 0.08971
# (song_tension, personality_artistic)             1.32624   2   58 0.08989
# (song_activity, concentration)                   1.34471   2   58 0.09114
# (song_engagement, personality_artistic)          1.40055   2   58 0.09493
# (song_activity, personality_fault)               1.40825   2   58 0.09545
# (song_positivity, concentration)                 1.44490   2   58 0.09793
# (personality_fault, personality_nervous)         1.46551   2   58 0.09933
# (musical_expertise, personality_trusting)        1.47468   2   58 0.09995
# (song_like_dislike, personality_fault)           1.52422   2   58 0.10331
# (song_familiarity, personality_fault)            1.56201   2   58 0.10587
# (personality_artistic, personality_trusting)     1.57858   2   58 0.10699
# (song_like_dislike, personality_artistic)        1.72328   2   58 0.11680
# (song_positivity, song_tension)                  1.70362   2  130 0.05124
# (concentration, personality_outgoing)            1.74305   2   58 0.11814
# (musical_expertise, personality_outgoing)        1.78708   2   58 0.12112
# (musical_expertise, personality_lazy)            1.83479   2   58 0.12436
# (song_engagement, concentration)                 1.87061   2   58 0.12679
# (personality_artistic, personality_fault)        1.89382   2   58 0.12836
# (personality_outgoing, personality_stress)       1.89695   2   58 0.12857
# (song_positivity, personality_stress)            1.90833   2   58 0.12934
# (concentration, personality_fault)               1.93427   2   58 0.13110
# (personality_nervous, personality_stress)        1.93598   2   58 0.13122
# (song_activity, personality_artistic)            1.94132   2   58 0.13158
# (song_engagement, personality_stress)            1.96401   2   58 0.13312
# (song_tension, personality_stress)               2.03838   2   58 0.13816
# (concentration, personality_lazy)                2.05022   2   58 0.13896
# (musical_expertise, concentration)               2.07263   2   58 0.14048
# (personality_artistic, personality_lazy)         2.09967   2   58 0.14231
# (personality_reserved, personality_stress)       2.13839   2   58 0.14494
# (song_activity, musical_expertise)               2.13735   2   73 0.11375
# (song_engagement, musical_expertise)             2.22369   2   73 0.11835
# (song_familiarity, personality_stress)           2.28768   2   58 0.15505
# (personality_imagination, personality_stress)    2.29990   2   58 0.15588
# (musical_expertise, personality_artistic)        2.32146   2   58 0.15734
# (musical_expertise, personality_fault)           2.34601   2   58 0.15901
# (personality_imagination, personality_thorough)  2.34731   2   58 0.15910
# (personality_reserved, personality_thorough)     2.35186   2   58 0.15940
# (song_tension, personality_thorough)             2.35331   2   58 0.15950
# (song_like_dislike, personality_stress)          2.37516   2   58 0.16098
# (personality_nervous, personality_thorough)      2.37517   2   58 0.16098
# (song_activity, personality_thorough)            2.38037   2   58 0.16134
# (song_like_dislike, personality_thorough)        2.43773   2   58 0.16522
# (personality_lazy, personality_stress)           2.49285   2   58 0.16896
# (song_activity, personality_stress)              2.51497   2   58 0.17046
# (personality_stress, personality_trusting)       2.57332   2   58 0.17441
# (song_familiarity, personality_thorough)         2.60953   2   58 0.17687
# (personality_artistic, personality_stress)       2.69216   2   58 0.18247
# (personality_fault, personality_lazy)            2.73520   2   58 0.18539
# (song_positivity, personality_thorough)          2.78820   2   58 0.18898
# (song_engagement, personality_thorough)          2.78831   2   58 0.18899
# (personality_outgoing, personality_thorough)     2.79086   2   58 0.18916
# (song_like_dislike, musical_expertise)           2.80501   2   73 0.14929
# (song_engagement, song_familiarity)              2.78504   2  130 0.08377
# (personality_thorough, personality_trusting)     2.92106   2   58 0.19798
# (song_familiarity, song_tension)                 2.88969   2  130 0.08691
# (personality_fault, personality_stress)          2.96979   2   58 0.20129
# (concentration, personality_thorough)            3.00583   2   58 0.20373
# (concentration, personality_artistic)            3.03843   2   58 0.20594
# (musical_expertise, personality_thorough)        3.07808   2   58 0.20863
# (song_engagement, song_tension)                  3.37921   2  130 0.10164
# (song_activity, song_positivity)                 3.41374   2  130 0.10267
# (song_positivity, age)                           3.44671   2  130 0.10367
# (song_activity, song_familiarity)                3.79654   2  130 0.11419
# (song_activity, song_tension)                    4.00722   2  130 0.12052
# (personality_lazy, personality_thorough)         4.27382   2   58 0.28967
# (song_activity, song_engagement)                 4.17062   2  130 0.12544
# (musical_expertise, personality_stress)          4.41178   2   58 0.29902
# (personality_artistic, personality_thorough)     4.46667   2   58 0.30274
# (song_engagement, song_positivity)               4.36580   2  130 0.13131
# (personality_fault, personality_thorough)        4.50498   2   58 0.30534
# (song_tension, age)                              4.41908   2  139 0.12451
# (concentration, personality_stress)              4.67358   2   58 0.31676
# (personality_stress, personality_thorough)       5.01195   2   58 0.33970
# (song_familiarity, age)                          5.23827   2  130 0.15755
# (age, personality_lazy)                          5.55852   2   58 0.37674
# (age, personality_nervous)                       5.57518   2   58 0.37787
# (age, personality_reserved)                      5.59591   2   58 0.37928
# (age, personality_outgoing)                      5.60127   2   58 0.37964
# (age, personality_imagination)                   5.62022   2   58 0.38093
# (age, personality_trusting)                      5.64418   2   58 0.38255
# (age, personality_artistic)                      5.98755   2   58 0.40582
# (age, personality_stress)                        6.80551   2   58 0.46126
# (age, concentration)                             7.20780   2   58 0.48853
# (song_familiarity, song_like_dislike)            7.07262   2  130 0.21272
# (age, personality_fault)                         7.63583   2   58 0.51754
# (song_like_dislike, song_tension)                7.45853   2  130 0.22433
# (song_activity, age)                             7.59616   2  130 0.22847
# (age, personality_thorough)                      8.16952   2   58 0.55371
# (song_activity, song_like_dislike)               7.87297   2  130 0.23679
# (song_engagement, song_like_dislike)             8.14558   2  130 0.24499
# (song_engagement, age)                          10.09305   2  130 0.30357
# (song_like_dislike, song_positivity)            14.66315   2  130 0.44102
# (song_like_dislike, age)                        16.61718   2  130 0.49979

# %%
if results[results.adjustedP <= alpha].shape[0] > 0:
    for pair in results.index.values[0:3]:
        g = sns.FacetGrid(df_all[[pair[0], pair[1], 'critical_reaction']], col='critical_reaction', height=6, aspect=1, margin_titles=True)
        g.map(sns.kdeplot, pair[0], pair[1], cmap='Reds', shade=True, shade_lowest=False, alpha=0.65)
        g.savefig('hallelujah_reaction_distributions_{}_{}_{}_by_reaction.pdf'.format(notebook_song_name, pair[0], pair[1]))
else:
    print('No significant results to plot')
# Out:
# No significant results to plot
