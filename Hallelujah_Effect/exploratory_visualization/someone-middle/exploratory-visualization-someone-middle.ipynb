# %% [markdown]
# # Exploratory Visualization (_Someone Like You_, middle section)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import pandas as pd
import scipy.stats as sps
import seaborn as sns
import sklearn

from pathlib import Path

# %% [markdown]
# ## Retrieve and Subset Datasource
#
# Retrieve all good trials for IDs that came from Javier's algorithm.

# %%
notebook_song_name = 'someone_middle'

# %%
data_root = Path('../../neural_nets/fastai/import-someone-middle/data')

df_all = pd.read_csv(data_root / 'good_reaction_trials_categorified_no_impute.csv')

# df_all = df_all[df_all.song == 'someone_like_you']

pd.set_option('display.max_columns', None)
df_all.describe()
# Out:
#              age  personality_trusting  personality_artistic  \
# count  87.000000             87.000000             87.000000
# mean   21.356322              3.781609              2.229885
# std    11.026371              1.039066              1.053247
# min     7.000000              1.000000              1.000000
# 25%    13.000000              3.000000              1.000000
# 50%    18.000000              4.000000              2.000000
# 75%    26.000000              4.500000              3.000000
# max    75.000000              5.000000              5.000000
#
#        personality_imagination  personality_reserved  personality_outgoing  \
# count                87.000000             87.000000             87.000000
# mean                  3.919540              3.126437              3.045977
# std                   0.979064              1.086969              1.209536
# min                   1.000000              1.000000              1.000000
# 25%                   3.000000              2.000000              2.000000
# 50%                   4.000000              3.000000              3.000000
# 75%                   5.000000              4.000000              4.000000
# max                   5.000000              5.000000              5.000000
#
#        personality_lazy  personality_stress  personality_nervous  \
# count         87.000000           87.000000            87.000000
# mean           3.586207            3.172414             3.505747
# std            1.126341            1.133085             1.218783
# min            1.000000            1.000000             1.000000
# 25%            3.000000            2.000000             2.000000
# 50%            4.000000            3.000000             4.000000
# 75%            4.000000            4.000000             4.000000
# max            5.000000            5.000000             5.000000
#
#        personality_fault  personality_thorough  musical_expertise  \
# count          87.000000             87.000000          87.000000
# mean            3.149425              3.275862           2.482759
# std             1.146570              1.030801           1.179890
# min             1.000000              1.000000           1.000000
# 25%             2.000000              2.000000           1.000000
# 50%             3.000000              3.000000           3.000000
# 75%             4.000000              4.000000           3.000000
# max             5.000000              5.000000           5.000000
#
#        concentration  control_power  control_like_dislike  control_tension  \
# count      87.000000      87.000000             87.000000        87.000000
# mean        4.068966       3.172414              3.045977         3.436782
# std         0.937502       1.259447              1.140257         0.996519
# min         1.000000       1.000000              1.000000         1.000000
# 25%         4.000000       2.000000              2.500000         3.000000
# 50%         4.000000       3.000000              3.000000         3.000000
# 75%         5.000000       4.000000              4.000000         4.000000
# max         5.000000       5.000000              5.000000         5.000000
#
#        control_engagement  control_activity  control_positivity  \
# count           87.000000         87.000000           87.000000
# mean             3.080460          2.942529            3.275862
# std              1.304896          1.113932            1.042020
# min              1.000000          1.000000            1.000000
# 25%              2.000000          2.000000            3.000000
# 50%              3.000000          3.000000            3.000000
# 75%              4.000000          4.000000            4.000000
# max              5.000000          5.000000            5.000000
#
#        control_familiarity  song_power  song_like_dislike  song_tension  \
# count                 87.0   87.000000          87.000000     87.000000
# mean                  -1.0    3.344828           4.471264      4.356322
# std                    0.0    1.265165           0.818948      0.792068
# min                   -1.0    1.000000           2.000000      1.000000
# 25%                   -1.0    2.000000           4.000000      4.000000
# 50%                   -1.0    4.000000           5.000000      5.000000
# 75%                   -1.0    4.000000           5.000000      5.000000
# max                   -1.0    5.000000           5.000000      5.000000
#
#        song_engagement  song_activity  song_positivity  song_familiarity  \
# count        87.000000      87.000000        87.000000         87.000000
# mean          4.413793       3.896552         4.091954          3.287356
# std           0.856599       0.849548         1.041379          1.598750
# min           1.000000       2.000000         1.000000          1.000000
# 25%           4.000000       3.000000         4.000000          1.000000
# 50%           5.000000       4.000000         4.000000          4.000000
# 75%           5.000000       5.000000         5.000000          5.000000
# max           5.000000       5.000000         5.000000          5.000000
#
#        musicpref_hiphop  musicpref_jazz  musicpref_classical  musicpref_dance  \
# count         87.000000       87.000000            87.000000        87.000000
# mean           0.080460        0.103448             0.333333         0.091954
# std            0.273581        0.306309             0.474137         0.290636
# min            0.000000        0.000000             0.000000         0.000000
# 25%            0.000000        0.000000             0.000000         0.000000
# 50%            0.000000        0.000000             0.000000         0.000000
# 75%            0.000000        0.000000             1.000000         0.000000
# max            1.000000        1.000000             1.000000         1.000000
#
#        musicpref_rock  musicpref_folk  musicpref_world  musicpref_pop
# count       87.000000       87.000000        87.000000      87.000000
# mean         0.241379        0.103448         0.068966       0.747126
# std          0.430400        0.306309         0.254864       0.437179
# min          0.000000        0.000000         0.000000       0.000000
# 25%          0.000000        0.000000         0.000000       0.500000
# 50%          0.000000        0.000000         0.000000       1.000000
# 75%          0.000000        0.000000         0.000000       1.000000
# max          1.000000        1.000000         1.000000       1.000000

# %%
print(f"Total N: {df_all.shape[0]}")
# Out:
# Total N: 87

# %%
df_reaction = df_all[df_all['critical_reaction'] == True]
df_no_reaction = df_all[df_all['critical_reaction'] == False]

# %%
print(f"Total reaction N: {df_reaction.shape[0]}")
print(f"Total no-reaction N: {df_no_reaction.shape[0]}")
# Out:
# Total reaction N: 34
# Total no-reaction N: 53

# %%
df_all.columns
# Out:
# Index(['_id', 'location', 'language', 'nationality', 'age', 'sex',
#        'hearing_impairments', 'personality_trusting', 'personality_artistic',
#        'personality_imagination', 'personality_reserved',
#        'personality_outgoing', 'personality_lazy', 'personality_stress',
#        'personality_nervous', 'personality_fault', 'personality_thorough',
#        'musical_expertise', 'concentration', 'critical_reaction',
#        'control_power', 'control_like_dislike', 'control_tension',
#        'control_engagement', 'control_activity', 'control_positivity',
#        'control_familiarity', 'song_power', 'song_like_dislike',
#        'song_tension', 'song_engagement', 'song_activity', 'song_positivity',
#        'song_familiarity', 'song', 'musicpref_hiphop', 'musicpref_jazz',
#        'musicpref_classical', 'musicpref_dance', 'musicpref_rock',
#        'musicpref_folk', 'musicpref_world', 'musicpref_pop'],
#       dtype='object')

# %%
cat_cols = ['location', 'language', 'nationality', 'sex', 
            'hearing_impairments']

personality_cols = ['personality_trusting', 'personality_artistic', 
            'personality_imagination', 'personality_reserved',
            'personality_outgoing', 'personality_lazy', 'personality_stress',
            'personality_nervous', 'personality_fault', 'personality_thorough']

ord_cols = ['musical_expertise', 'concentration', 
            'song_power', 'song_like_dislike',
            'song_tension', 'song_engagement', 'song_activity', 'song_positivity',
            'song_familiarity', 'musicpref_world', 'musicpref_folk',
            'musicpref_classical', 'musicpref_dance', 'musicpref_rock',
            'musicpref_pop', 'musicpref_jazz', 'musicpref_hiphop']

cont_cols = ['age']

# %%
nationality_counts = df_all['nationality'].value_counts()
patches, texts = plt.pie(nationality_counts, 
                                    explode=[0.1] * len(nationality_counts));

labels = ['{}: {}'.format(x.capitalize(), nationality_counts[x]) for x in nationality_counts.index]

plt.legend(patches, labels)
plt.savefig('hallelujah_reaction_pie_nationalities_{}_new_split.pdf'.format(notebook_song_name))

# %%
language_counts = df_all['language'].value_counts()
patches, texts = plt.pie(language_counts, 
                                    explode=[0.1] * len(language_counts));

languages = list(language_counts.index)
for i in range(len(languages)):
    language = languages[i]
    if language == 'en':
        languages[i] = 'English'
    elif language == 'zh_TW':
        languages[i] = 'Taiwanese'

labels = ['{}: {}'.format(languages[i].capitalize(), language_counts[x]) for i, x in enumerate(language_counts.index)]

plt.legend(patches, labels)
plt.savefig('hallelujah_reaction_pie_languages_{}_new_split.pdf'.format(notebook_song_name))

# %%
def mardia(data, unbiased_cov=True):
    """
    data should have observations in rows
    """
    import numpy as np
    import scipy.stats as sps
    
    n = data.shape[0]
    p = data.shape[1]

    S = None
    if unbiased_cov:
        S = ((n - 1.) / n) * np.cov(data, rowvar=False)
    else:
        S = np.cov(data, rowvar=False)

    data_scaled = (data - data.mean(axis=0))

    D = np.matmul(np.matmul(data_scaled, np.linalg.pinv(S, rcond=1e-25)), data_scaled.T)

    product = D * D * D
    skewness = np.sum(product) / n**2
    kurtosis = (D * D).diagonal().sum() / n
    df = p * (p + 1) * (p + 2) / 6
    k = ((p + 1)*(n + 1)*(n + 3))/(n*((n + 1)*(p + 1) - 6))
    
    skew, kurt, skew_p, kurt_p = None, None, None, None
    if n < 20:
        skew = n * k * skewness / 6.
    else:
        skew = n * skewness / 6.
    
    chi2_test_skew = sps.chi2(df)
    skew_p = 1. - chi2_test_skew.cdf(skew)
    
    skew_result = False
    if skew_p > 0.05:
        skew_result = True
    
    kurt = (kurtosis - p * (p + 2)) * np.sqrt(n / (8 * p * (p + 2)))
    
    normal_test_kurt = sps.norm()
    kurt_p = 2. * (1. - normal_test_kurt.cdf(np.abs(kurt)))
    
    kurt_result = False
    if kurt_p  > 0.05:
        kurt_result = True
    
    result_skewness = {
        'test': 'Mardia Skewness',
        'statistic': skew,
        'p-value': skew_p,
        'result': skew_result
    }
    
    result_kurtosis = {
        'test': 'Mardia Kurtosis',
        'statistic': kurt,
        'p-value': kurt_p,
        'result': kurt_result
    }
    
    result = {
        'test': 'MVN',
        'statistic': None,
        'p-value': None,
        'result': skew_result and kurt_result
    }
    
    return result_skewness, result_kurtosis, result

# %%
def run_tests(x_label, dist_var, bins=None, normed=False, kde=True, bw='normal_reference', x_lim=None, plots=False, print_output=False):
    
    if plots:
        f = plt.figure(figsize=(8, 4))
        sns.distplot(df_all[dist_var].dropna(), bins=bins, norm_hist=normed, kde=kde, rug=True, kde_kws={'bw': bw})
        plt.xlabel('')
        if x_lim is not None:
            plt.xlim([0.5, 5.5])

        g = sns.FacetGrid(df_all, hue='critical_reaction', height=4, aspect=2)
        g.map(sns.distplot, dist_var, bins=bins, norm_hist=normed, kde=kde, kde_kws={'bw': bw})
        g.set_xlabels(x_label)
        if x_lim is not None:
            g.axes[0,0].set_xlim([0.5, 5.5])
        g.fig.suptitle('Distribution of {} by reaction group'.format(dist_var), y=1.0)
        g.add_legend(title='Hallelujah Reaction');

        fig_file = 'hallelujah_reaction_distribution_hallelujah_{}_new_split.pdf'.format(dist_var)
        g.savefig(fig_file, orientation='landscape')
        
    mean_true = df_all[df_all['critical_reaction'] == True][dist_var].dropna()
    mean_false = df_all[df_all['critical_reaction'] == False][dist_var].dropna()
    
    all_normtest = sps.normaltest(df_all[dist_var])
    true_normtest = sps.normaltest(df_all[df_all['critical_reaction'] == True][dist_var])
    false_normtest = sps.normaltest(df_all[df_all['critical_reaction'] == False][dist_var])
    if print_output:
        print(f'All normal test results: {all_normtest}')
        print(f'Reaction normal test results: {true_normtest}')
        print(f'No-reaction normal test results: {false_normtest}')
    
    alpha = 0.05
    _, equal_variance_p = sps.levene(mean_true, mean_false)
    
    equal_var = None
    if equal_variance_p >= alpha:
        equal_var = True
    else:
        equal_var = False
    
    t_stat, t_p = sps.ttest_ind(mean_true, mean_false, equal_var=equal_var)
    u_stat, u_p = sps.mannwhitneyu(mean_true, mean_false, alternative='two-sided')

    if print_output:
        print('Student\'s t-test for difference in mean {} between Hallelujah Reaction groups'.format(x_label.capitalize()))

        print('T test statistic: {:.4f}'.format(t_stat))
        print('T test p-value: {:.4f}'.format(t_p))

        print('Mann-Whitney U test statistic: {:.4f}'.format(u_stat))
        print('Mann-Whitney U test p-value: {:.4f}'.format(u_p))

        if t_p <= alpha or u_p <= alpha:
            print('**** Significant Result ****')
    
    return {
        'mean_true': mean_true.mean(),
        'mean_false': mean_false.mean(),
        'median_true': mean_true.median(),
        'median_false': mean_false.median(),
        't_stat': t_stat,
        't_p': t_p,
        'u_stat': u_stat,
        'u_p': u_p
    }

# %%
run_tests('Age [years]', 'age', bins=None, normed=False, kde=True, bw='normal_reference', x_lim=None, plots=True, print_output=True)
# Out:
# /home/paperspace/anaconda3/envs/fastai/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# All normal test results: NormaltestResult(statistic=44.0394634922056, pvalue=2.7349664908860284e-10)
# Reaction normal test results: NormaltestResult(statistic=4.564282869860009, pvalue=0.10206540609974332)
# No-reaction normal test results: NormaltestResult(statistic=49.99584870084333, pvalue=1.391680030736226e-11)
# Student's t-test for difference in mean Age [years] between Hallelujah Reaction groups
# T test statistic: 1.3185
# T test p-value: 0.1909
# Mann-Whitney U test statistic: 1078.0000
# Mann-Whitney U test p-value: 0.1242
# {'mean_true': 23.294117647058822,
#  'mean_false': 20.11320754716981,
#  'median_true': 22.0,
#  'median_false': 18.0,
#  't_stat': 1.3185402897873588,
#  't_p': 0.1908646201145165,
#  'u_stat': 1078.0,
#  'u_p': 0.12415036999035409}

# %%
df_results = pd.DataFrame({})

for c in personality_cols:
    try:
        result = run_tests(c, c)
        df_results = pd.concat([df_results, pd.DataFrame(result, index=[c])])
    except:
        print(f'Could not run tests for {c}')

# %%
df_results = df_results.sort_values(by='u_p')

i = np.arange(1, df_results.shape[0] + 1)
m = len(i)
Q = 0.25
benjamini_hochberg = ((i * 1.) / m) * Q
df_results['bh_threshold'] = benjamini_hochberg
df_results['significant'] = df_results.u_p < df_results.bh_threshold

df_results
# Out:
#                          mean_true  mean_false  median_true  median_false  \
# personality_nervous       3.852941    3.283019          4.0           4.0
# personality_reserved      3.382353    2.962264          4.0           3.0
# personality_artistic      2.352941    2.150943          2.0           2.0
# personality_stress        3.058824    3.245283          3.0           3.0
# personality_fault         3.205882    3.113208          3.0           3.0
# personality_trusting      3.764706    3.792453          4.0           4.0
# personality_imagination   3.882353    3.943396          4.0           4.0
# personality_outgoing      3.000000    3.075472          3.0           3.0
# personality_thorough      3.264706    3.283019          3.5           3.0
# personality_lazy          3.558824    3.603774          4.0           4.0
#
#                            t_stat       t_p  u_stat       u_p  bh_threshold  \
# personality_nervous      2.173779  0.032503  1131.5  0.037656         0.025
# personality_reserved     1.780973  0.078489  1082.5  0.097220         0.050
# personality_artistic     0.871619  0.385872  1001.0  0.363590         0.075
# personality_stress      -0.747001  0.457125   823.5  0.486583         0.100
# personality_fault        0.366000  0.715274   946.5  0.686309         0.125
# personality_trusting    -0.120834  0.904108   872.5  0.796662         0.150
# personality_imagination -0.282233  0.778451   874.0  0.807596         0.175
# personality_outgoing    -0.282454  0.778282   888.0  0.910944         0.200
# personality_thorough    -0.080386  0.936119   895.5  0.963659         0.225
# personality_lazy        -0.180602  0.857110   897.5  0.978225         0.250
#
#                          significant
# personality_nervous            False
# personality_reserved           False
# personality_artistic           False
# personality_stress             False
# personality_fault              False
# personality_trusting           False
# personality_imagination        False
# personality_outgoing           False
# personality_thorough           False
# personality_lazy               False

# %%
sns.countplot(x='sex', hue='critical_reaction', data=df_all)
plt.xticks(ticks=[0,1], labels=['Male', 'Female'])
plt.xlabel('Sex')
plt.ylabel('Count')
plt.legend(title='Significant Reaction')
plt.tight_layout()
plt.savefig(f'hallelujah_reaction_bar_sex_by_reaction_{notebook_song_name}_new_split.pdf')

# %%
# Chi-squared test of male/female proportions

cross = pd.crosstab(df_all['sex'], df_all['critical_reaction'])
display(cross)
chi2, p, dof, table = sps.chi2_contingency(cross)
print('Chi-squared test of sex vs hallelujah reaction proportions')
print('Test statistic: {:.4f}'.format(chi2))
print('p-value: {:.4f}'.format(p))
print('Degrees of freedom: {}'.format(dof))
# Out:
# critical_reaction  False  True
# sex
# female                29     17
# male                  24     17
# Chi-squared test of sex vs hallelujah reaction proportions
# Test statistic: 0.0441
# p-value: 0.8337
# Degrees of freedom: 1

# %%
sns.countplot(x='location', hue='critical_reaction', data=df_all)

# %%
# Chi-squared test of location proportions

cross = pd.crosstab(df_all['location'], df_all['critical_reaction'])
display(cross)
chi2, p, dof, table = sps.chi2_contingency(cross)
print('Chi-squared test of location vs hallelujah reaction proportions')
print('Test statistic: {:.4f}'.format(chi2))
print('p-value: {:.4f}'.format(p))
print('Degrees of freedom: {}'.format(dof))
# Out:
# critical_reaction  False  True
# location
# taichung_city         18      6
# taipei_city           35     28
# Chi-squared test of location vs hallelujah reaction proportions
# Test statistic: 2.0037
# p-value: 0.1569
# Degrees of freedom: 1

# %%
sns.countplot(x='language', hue='critical_reaction', data=df_all)

# %%
# Chi-squared test of language proportions

cross = pd.crosstab(df_all['language'], df_all['critical_reaction'])
display(cross)
chi2, p, dof, table = sps.chi2_contingency(cross)
print('Chi-squared test of language vs hallelujah reaction proportions (for Taiwanese, English, and NA)')
print('Test statistic: {:.4f}'.format(chi2))
print('p-value: {:.4f}'.format(p))
print('Degrees of freedom: {}'.format(dof))
# Out:
# critical_reaction  False  True
# language
# en                    38     25
# zh_TW                 15      9
# Chi-squared test of language vs hallelujah reaction proportions (for Taiwanese, English, and NA)
# Test statistic: 0.0035
# p-value: 0.9527
# Degrees of freedom: 1

# %% [markdown]
# Sources for Hotelling's $T^2$:
# - https://ncss-wpengine.netdna-ssl.com/wp-content/themes/ncss/pdf/Procedures/NCSS/Hotellings_Two-Sample_T2.pdf
# - https://onlinecourses.science.psu.edu/stat505/node/100/

# %%
def hotelling_t2(X_1, X_2, alpha):
    
    import scipy.stats as sps
    
    n_1 = len(X_1)
    n_2 = len(X_2)

    y_1 = X_1.mean().as_matrix()
    y_1 = y_1.reshape(len(y_1), -1)
    y_2 = X_2.mean().as_matrix()
    y_2 = y_2.reshape(len(y_2), -1)

    # Covariance matrices
    S_1 = np.cov(X_1.astype(np.float64).T)
    S_2 = np.cov(X_2.astype(np.float64).T)

    # Pooled variance
    S_pooled_num = ((n_1 - 1) * S_1) + ((n_2 - 1) * S_2)
    S_pooled_denom = n_1 + n_2 - 2
    S_pooled = S_pooled_num / S_pooled_denom
    
    T_2 = (n_1 * n_2) / (n_1 + n_2)
    T_2 = T_2 * np.matmul((y_1 - y_2).T, np.linalg.pinv(S_pooled))
    T_2 = np.matmul(T_2, (y_1 - y_2))
    T_2 = T_2.squeeze()
    
    p = len(X_1.columns)
    F_num = n_1 + n_2 - p - 1
    F_denom = p * (n_1 + n_2 - 2)
    F = (F_num / F_denom) * T_2
    F = F.squeeze()
    
    df_1 = p
    df_2 = n_1 + n_2 - p - 1
    F_dist = sps.f(df_1, df_2)
    p_value = F_dist.cdf(F)
    
    # Calculate effect size
    D_2 = ((n_1 + n_2) * T_2) / (n_1 * n_2)
    
    return({
        'T2': T_2,
        'F': F,
        'df': (df_1, df_2),
        'p': p_value,
        'D2': D_2
    })

# %% [markdown]
# # Pairwise Hotelling's $T^2$

# %%
import itertools

plot_vars = ['song_activity', 
             'song_engagement', 
             'song_familiarity', 
             'song_like_dislike', 
             'song_positivity', 
             'song_tension', 
             'age', 
             'musical_expertise', 
             'concentration', 
             'personality_artistic', 
             'personality_fault', 
             'personality_imagination', 
             'personality_lazy', 
             'personality_nervous', 
             'personality_outgoing', 
             'personality_reserved', 
             'personality_stress', 
             'personality_thorough', 
             'personality_trusting']

pairs = list(itertools.combinations(plot_vars, 2))

results = pd.DataFrame(columns=['p', 'adjustedP', 'F', 'T2', 'df1', 'df2', 'D2'])

for pair in pairs:
    
    test_vars = list(pair)
    test_vars.append('critical_reaction')
    df_pair = df_all[test_vars].dropna()
    df_pair_1 = df_pair[df_pair['critical_reaction'] == False].drop(['critical_reaction'], axis=1)
    df_pair_2 = df_pair[df_pair['critical_reaction'] == True].drop(['critical_reaction'], axis=1)
    
    mardia_result = mardia(df_pair.drop(['critical_reaction'], axis=1), unbiased_cov=True)
    if mardia_result[2]['result']:
        pass

    t2_results = hotelling_t2(df_pair_1, df_pair_2, 0.05)
    p = t2_results['p']
    adjusted_p = p * len(pairs)
    if adjusted_p > 1:
        adjusted_p = 1
        
    row = pd.DataFrame(
        {
            'p': t2_results['p'], 
            'adjustedP': adjusted_p,
            'F': t2_results['F'], 
            'T2': t2_results['T2'], 
            'df1': t2_results['df'][0], 
            'df2': t2_results['df'][1],
            'D2': t2_results['D2']
        }, 
        index=[pair])

    results = pd.concat([results, row])
    
alpha = 0.5
    
with pd.option_context('display.max_rows', None, 'display.float_format', lambda x: '%.5f' % x):
    display('Tests for difference between combined means of {} and {} between hallelujah reaction groups:'.format(pair[0], pair[1]))
    display(results.sort_values(by='p'))

results.to_csv('hotelling_comparisons_{}.csv'.format(notebook_song_name))
# Out:
# /home/paperspace/anaconda3/envs/fastai/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# /home/paperspace/anaconda3/envs/fastai/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.
# 'Tests for difference between combined means of personality_thorough and personality_trusting between hallelujah reaction groups:'
#                                                       p adjustedP       F  \
# (song_like_dislike, personality_thorough)       0.00319   0.54517 0.00319
# (song_like_dislike, personality_trusting)       0.00757         1 0.00760
# (personality_thorough, personality_trusting)    0.00949         1 0.00954
# (song_like_dislike, personality_lazy)           0.01600         1 0.01614
# (personality_lazy, personality_thorough)        0.02075         1 0.02097
# (personality_lazy, personality_trusting)        0.02536         1 0.02570
# (personality_imagination, personality_thorough) 0.03860         1 0.03939
# (personality_outgoing, personality_thorough)    0.03895         1 0.03975
# (song_like_dislike, personality_outgoing)       0.03909         1 0.03990
# (personality_imagination, personality_trusting) 0.03935         1 0.04017
# (song_like_dislike, personality_imagination)    0.03994         1 0.04078
# (personality_outgoing, personality_trusting)    0.04097         1 0.04185
# (personality_imagination, personality_lazy)     0.04982         1 0.05113
# (personality_lazy, personality_outgoing)        0.05499         1 0.05660
# (personality_imagination, personality_outgoing) 0.05804         1 0.05983
# (song_like_dislike, personality_fault)          0.06405         1 0.06624
# (personality_fault, personality_trusting)       0.06419         1 0.06640
# (personality_fault, personality_thorough)       0.07479         1 0.07780
# (personality_fault, personality_lazy)           0.09048         1 0.09494
# (song_familiarity, song_like_dislike)           0.09408         1 0.09892
# (song_like_dislike, musical_expertise)          0.09408         1 0.09893
# (musical_expertise, personality_thorough)       0.09555         1 0.10054
# (song_familiarity, personality_thorough)        0.09629         1 0.10137
# (personality_fault, personality_imagination)    0.09926         1 0.10467
# (personality_fault, personality_outgoing)       0.09976         1 0.10522
# (song_familiarity, personality_trusting)        0.10239         1 0.10816
# (musical_expertise, personality_trusting)       0.10412         1 0.11010
# (musical_expertise, personality_imagination)    0.11312         1 0.12022
# (musical_expertise, personality_outgoing)       0.11599         1 0.12347
# (musical_expertise, personality_lazy)           0.11863         1 0.12647
# (song_familiarity, personality_lazy)            0.12163         1 0.12989
# (song_familiarity, personality_imagination)     0.12238         1 0.13075
# (song_familiarity, personality_fault)           0.13182         1 0.14159
# (song_familiarity, personality_outgoing)        0.13531         1 0.14563
# (concentration, personality_trusting)           0.14157         1 0.15293
# (song_like_dislike, concentration)              0.14694         1 0.15922
# (concentration, personality_lazy)               0.15262         1 0.16594
# (concentration, personality_thorough)           0.15328         1 0.16672
# (musical_expertise, personality_fault)          0.15799         1 0.17231
# (concentration, personality_outgoing)           0.16272         1 0.17797
# (concentration, personality_imagination)        0.16543         1 0.18123
# (concentration, personality_fault)              0.17727         1 0.19558
# (song_familiarity, musical_expertise)           0.18146         1 0.20071
# (song_familiarity, concentration)               0.19393         1 0.21614
# (musical_expertise, concentration)              0.21278         1 0.23993
# (personality_outgoing, personality_stress)      0.24033         1 0.27577
# (personality_imagination, personality_stress)   0.24039         1 0.27585
# (song_like_dislike, personality_stress)         0.24090         1 0.27652
# (personality_lazy, personality_stress)          0.24187         1 0.27781
# (personality_stress, personality_thorough)      0.24678         1 0.28435
# (personality_stress, personality_trusting)      0.24761         1 0.28546
# (personality_fault, personality_stress)         0.26195         1 0.30484
# (musical_expertise, personality_stress)         0.27346         1 0.32068
# (song_familiarity, personality_stress)          0.30442         1 0.36459
# (song_like_dislike, personality_artistic)       0.31306         1 0.37719
# (personality_artistic, personality_thorough)    0.31430         1 0.37901
# (musical_expertise, personality_artistic)       0.31534         1 0.38055
# (personality_artistic, personality_imagination) 0.32428         1 0.39380
# (personality_artistic, personality_lazy)        0.32910         1 0.40104
# (song_activity, personality_trusting)           0.32971         1 0.40195
# (song_activity, song_like_dislike)              0.33311         1 0.40709
# (song_activity, personality_thorough)           0.33558         1 0.41083
# (song_activity, personality_outgoing)           0.33575         1 0.41109
# (personality_artistic, personality_outgoing)    0.34182         1 0.42036
# (song_activity, concentration)                  0.34203         1 0.42069
# (song_activity, personality_imagination)        0.34228         1 0.42107
# (song_activity, song_familiarity)               0.34280         1 0.42187
# (personality_artistic, personality_trusting)    0.34529         1 0.42571
# (concentration, personality_stress)             0.35132         1 0.43505
# (song_activity, musical_expertise)              0.35834         1 0.44604
# (song_activity, personality_fault)              0.36555         1 0.45748
# (song_activity, personality_lazy)               0.37572         1 0.47381
# (personality_artistic, personality_fault)       0.38084         1 0.48214
# (song_engagement, personality_trusting)         0.41506         1 0.53968
# (song_engagement, concentration)                0.41583         1 0.54102
# (song_engagement, personality_thorough)         0.41584         1 0.54104
# (song_engagement, personality_lazy)             0.41720         1 0.54339
# (concentration, personality_artistic)           0.42320         1 0.55389
# (song_engagement, personality_outgoing)         0.42343         1 0.55428
# (song_familiarity, personality_artistic)        0.42456         1 0.55628
# (song_engagement, personality_imagination)      0.42595         1 0.55871
# (song_positivity, personality_thorough)         0.43764         1 0.57957
# (song_positivity, concentration)                0.43850         1 0.58114
# (song_familiarity, song_positivity)             0.43908         1 0.58218
# (song_positivity, personality_outgoing)         0.43922         1 0.58243
# (song_positivity, personality_trusting)         0.44165         1 0.58683
# (song_positivity, personality_imagination)      0.44209         1 0.58764
# (song_positivity, personality_fault)            0.44633         1 0.59536
# (song_like_dislike, song_positivity)            0.44765         1 0.59780
# (song_activity, personality_stress)             0.44783         1 0.59812
# (song_positivity, musical_expertise)            0.44827         1 0.59893
# (song_engagement, personality_fault)            0.46480         1 0.62978
# (song_engagement, song_familiarity)             0.46626         1 0.63255
# (personality_artistic, personality_stress)      0.46738         1 0.63469
# (song_engagement, musical_expertise)            0.46858         1 0.63698
# (song_tension, personality_thorough)            0.47352         1 0.64646
# (song_tension, personality_outgoing)            0.47480         1 0.64893
# (song_tension, personality_imagination)         0.47540         1 0.65010
# (song_tension, personality_fault)               0.48372         1 0.66634
# (song_activity, song_positivity)                0.48977         1 0.67831
# (song_tension, concentration)                   0.49038         1 0.67953
# (song_tension, personality_trusting)            0.49067         1 0.68011
# (song_positivity, personality_lazy)             0.49645         1 0.69171
# (song_tension, personality_lazy)                0.50205         1 0.70307
# (song_tension, musical_expertise)               0.50224         1 0.70346
# (song_familiarity, song_tension)                0.50472         1 0.70855
# (song_activity, song_engagement)                0.51100         1 0.72151
# (song_tension, personality_stress)              0.51737         1 0.73486
# (song_engagement, song_tension)                 0.53408         1 0.77073
# (song_activity, personality_artistic)           0.53518         1 0.77312
# (song_engagement, personality_stress)           0.54952         1 0.80505
# (song_positivity, personality_stress)           0.54972         1 0.80550
# (song_engagement, song_like_dislike)            0.55287         1 0.81267
# (song_activity, song_tension)                   0.55648         1 0.82094
# (song_positivity, song_tension)                 0.56848         1 0.84892
# (age, personality_thorough)                     0.57569         1 0.86610
# (age, personality_trusting)                     0.57689         1 0.86900
# (song_engagement, song_positivity)              0.57706         1 0.86941
# (age, personality_imagination)                  0.58395         1 0.88618
# (age, musical_expertise)                        0.58752         1 0.89497
# (song_like_dislike, age)                        0.58793         1 0.89600
# (age, personality_outgoing)                     0.58953         1 0.89996
# (age, personality_lazy)                         0.59479         1 0.91314
# (age, personality_fault)                        0.60021         1 0.92691
# (song_familiarity, age)                         0.60578         1 0.94123
# (song_like_dislike, song_tension)               0.60780         1 0.94648
# (song_engagement, personality_artistic)         0.62713         1 0.99821
# (age, concentration)                            0.62783         1 1.00012
# (age, personality_stress)                       0.65543         1 1.07910
# (song_positivity, personality_artistic)         0.65648         1 1.08221
# (song_tension, personality_artistic)            0.71078         1 1.25908
# (song_activity, age)                            0.71888         1 1.28833
# (age, personality_artistic)                     0.71992         1 1.29217
# (song_positivity, age)                          0.74522         1 1.38988
# (song_tension, age)                             0.76814         1 1.48735
# (song_engagement, age)                          0.77685         1 1.52703
# (song_like_dislike, personality_reserved)       0.78540         1 1.56751
# (personality_reserved, personality_thorough)    0.78683         1 1.57444
# (personality_fault, personality_reserved)       0.78683         1 1.57448
# (personality_imagination, personality_reserved) 0.78713         1 1.57593
# (musical_expertise, personality_reserved)       0.78811         1 1.58069
# (personality_reserved, personality_trusting)    0.79340         1 1.60697
# (personality_outgoing, personality_reserved)    0.79604         1 1.62030
# (concentration, personality_reserved)           0.79870         1 1.63395
# (personality_lazy, personality_reserved)        0.80161         1 1.64905
# (song_familiarity, personality_reserved)        0.80593         1 1.67196
# (song_activity, personality_reserved)           0.81925         1 1.74594
# (personality_reserved, personality_stress)      0.82336         1 1.76990
# (personality_artistic, personality_reserved)    0.83983         1 1.87202
# (song_positivity, personality_reserved)         0.84115         1 1.88068
# (song_tension, personality_reserved)            0.84824         1 1.92841
# (song_engagement, personality_reserved)         0.86103         1 2.02061
# (age, personality_reserved)                     0.89334         1 2.29885
# (personality_nervous, personality_outgoing)     0.89693         1 2.33499
# (personality_nervous, personality_stress)       0.89702         1 2.33582
# (personality_fault, personality_nervous)        0.89702         1 2.33582
# (song_familiarity, personality_nervous)         0.89773         1 2.34314
# (song_like_dislike, personality_nervous)        0.89791         1 2.34507
# (personality_imagination, personality_nervous)  0.89801         1 2.34606
# (personality_nervous, personality_thorough)     0.89993         1 2.36615
# (personality_artistic, personality_nervous)     0.90072         1 2.37447
# (concentration, personality_nervous)            0.90133         1 2.38103
# (musical_expertise, personality_nervous)        0.90145         1 2.38232
# (personality_nervous, personality_trusting)     0.90552         1 2.42685
# (song_positivity, personality_nervous)          0.91200         1 2.50216
# (song_activity, personality_nervous)            0.91368         1 2.52258
# (personality_lazy, personality_nervous)         0.92180         1 2.62744
# (song_tension, personality_nervous)             0.92314         1 2.64572
# (age, personality_nervous)                      0.94207         1 2.94738
# (personality_nervous, personality_reserved)     0.94640         1 3.03054
# (song_engagement, personality_nervous)          0.95176         1 3.14374
#
#                                                      T2 df1 df2      D2
# (song_like_dislike, personality_thorough)       0.00646   2  84 0.00031
# (song_like_dislike, personality_trusting)       0.01538   2  84 0.00074
# (personality_thorough, personality_trusting)    0.01931   2  84 0.00093
# (song_like_dislike, personality_lazy)           0.03266   2  84 0.00158
# (personality_lazy, personality_thorough)        0.04245   2  84 0.00205
# (personality_lazy, personality_trusting)        0.05201   2  84 0.00251
# (personality_imagination, personality_thorough) 0.07971   2  84 0.00385
# (personality_outgoing, personality_thorough)    0.08045   2  84 0.00388
# (song_like_dislike, personality_outgoing)       0.08074   2  84 0.00390
# (personality_imagination, personality_trusting) 0.08129   2  84 0.00392
# (song_like_dislike, personality_imagination)    0.08253   2  84 0.00398
# (personality_outgoing, personality_trusting)    0.08470   2  84 0.00409
# (personality_imagination, personality_lazy)     0.10348   2  84 0.00500
# (personality_lazy, personality_outgoing)        0.11455   2  84 0.00553
# (personality_imagination, personality_outgoing) 0.12108   2  84 0.00585
# (song_like_dislike, personality_fault)          0.13406   2  84 0.00647
# (personality_fault, personality_trusting)       0.13438   2  84 0.00649
# (personality_fault, personality_thorough)       0.15746   2  84 0.00760
# (personality_fault, personality_lazy)           0.19214   2  84 0.00928
# (song_familiarity, song_like_dislike)           0.20019   2  84 0.00967
# (song_like_dislike, musical_expertise)          0.20021   2  84 0.00967
# (musical_expertise, personality_thorough)       0.20348   2  84 0.00982
# (song_familiarity, personality_thorough)        0.20515   2  84 0.00990
# (personality_fault, personality_imagination)    0.21183   2  84 0.01023
# (personality_fault, personality_outgoing)       0.21295   2  84 0.01028
# (song_familiarity, personality_trusting)        0.21890   2  84 0.01057
# (musical_expertise, personality_trusting)       0.22282   2  84 0.01076
# (musical_expertise, personality_imagination)    0.24330   2  84 0.01175
# (musical_expertise, personality_outgoing)       0.24987   2  84 0.01206
# (musical_expertise, personality_lazy)           0.25594   2  84 0.01236
# (song_familiarity, personality_lazy)            0.26287   2  84 0.01269
# (song_familiarity, personality_imagination)     0.26461   2  84 0.01278
# (song_familiarity, personality_fault)           0.28655   2  84 0.01383
# (song_familiarity, personality_outgoing)        0.29473   2  84 0.01423
# (concentration, personality_trusting)           0.30950   2  84 0.01494
# (song_like_dislike, concentration)              0.32224   2  84 0.01556
# (concentration, personality_lazy)               0.33583   2  84 0.01621
# (concentration, personality_thorough)           0.33741   2  84 0.01629
# (musical_expertise, personality_fault)          0.34873   2  84 0.01684
# (concentration, personality_outgoing)           0.36017   2  84 0.01739
# (concentration, personality_imagination)        0.36678   2  84 0.01771
# (concentration, personality_fault)              0.39583   2  84 0.01911
# (song_familiarity, musical_expertise)           0.40620   2  84 0.01961
# (song_familiarity, concentration)               0.43743   2  84 0.02112
# (musical_expertise, concentration)              0.48556   2  84 0.02344
# (personality_outgoing, personality_stress)      0.55810   2  84 0.02694
# (personality_imagination, personality_stress)   0.55828   2  84 0.02695
# (song_like_dislike, personality_stress)         0.55963   2  84 0.02702
# (personality_lazy, personality_stress)          0.56224   2  84 0.02714
# (personality_stress, personality_thorough)      0.57548   2  84 0.02778
# (personality_stress, personality_trusting)      0.57772   2  84 0.02789
# (personality_fault, personality_stress)         0.61694   2  84 0.02979
# (musical_expertise, personality_stress)         0.64899   2  84 0.03133
# (song_familiarity, personality_stress)          0.73786   2  84 0.03562
# (song_like_dislike, personality_artistic)       0.76336   2  84 0.03685
# (personality_artistic, personality_thorough)    0.76705   2  84 0.03703
# (musical_expertise, personality_artistic)       0.77016   2  84 0.03718
# (personality_artistic, personality_imagination) 0.79698   2  84 0.03848
# (personality_artistic, personality_lazy)        0.81163   2  84 0.03919
# (song_activity, personality_trusting)           0.81347   2  84 0.03927
# (song_activity, song_like_dislike)              0.82388   2  84 0.03978
# (song_activity, personality_thorough)           0.83145   2  84 0.04014
# (song_activity, personality_outgoing)           0.83196   2  84 0.04017
# (personality_artistic, personality_outgoing)    0.85073   2  84 0.04107
# (song_activity, concentration)                  0.85139   2  84 0.04110
# (song_activity, personality_imagination)        0.85217   2  84 0.04114
# (song_activity, song_familiarity)               0.85378   2  84 0.04122
# (personality_artistic, personality_trusting)    0.86155   2  84 0.04160
# (concentration, personality_stress)             0.88046   2  84 0.04251
# (song_activity, musical_expertise)              0.90270   2  84 0.04358
# (song_activity, personality_fault)              0.92585   2  84 0.04470
# (song_activity, personality_lazy)               0.95891   2  84 0.04630
# (personality_artistic, personality_fault)       0.97576   2  84 0.04711
# (song_engagement, personality_trusting)         1.09220   2  84 0.05273
# (song_engagement, concentration)                1.09493   2  84 0.05286
# (song_engagement, personality_thorough)         1.09496   2  84 0.05286
# (song_engagement, personality_lazy)             1.09971   2  84 0.05309
# (concentration, personality_artistic)           1.12096   2  84 0.05412
# (song_engagement, personality_outgoing)         1.12176   2  84 0.05416
# (song_familiarity, personality_artistic)        1.12580   2  84 0.05435
# (song_engagement, personality_imagination)      1.13073   2  84 0.05459
# (song_positivity, personality_thorough)         1.17295   2  84 0.05663
# (song_positivity, concentration)                1.17611   2  84 0.05678
# (song_familiarity, song_positivity)             1.17821   2  84 0.05688
# (song_positivity, personality_outgoing)         1.17873   2  84 0.05691
# (song_positivity, personality_trusting)         1.18762   2  84 0.05734
# (song_positivity, personality_imagination)      1.18927   2  84 0.05742
# (song_positivity, personality_fault)            1.20489   2  84 0.05817
# (song_like_dislike, song_positivity)            1.20982   2  84 0.05841
# (song_activity, personality_stress)             1.21049   2  84 0.05844
# (song_positivity, musical_expertise)            1.21212   2  84 0.05852
# (song_engagement, personality_fault)            1.27456   2  84 0.06154
# (song_engagement, song_familiarity)             1.28017   2  84 0.06181
# (personality_artistic, personality_stress)      1.28450   2  84 0.06202
# (song_engagement, musical_expertise)            1.28912   2  84 0.06224
# (song_tension, personality_thorough)            1.30832   2  84 0.06317
# (song_tension, personality_outgoing)            1.31331   2  84 0.06341
# (song_tension, personality_imagination)         1.31568   2  84 0.06352
# (song_tension, personality_fault)               1.34854   2  84 0.06511
# (song_activity, song_positivity)                1.37278   2  84 0.06628
# (song_tension, concentration)                   1.37524   2  84 0.06640
# (song_tension, personality_trusting)            1.37640   2  84 0.06645
# (song_positivity, personality_lazy)             1.39988   2  84 0.06759
# (song_tension, personality_lazy)                1.42288   2  84 0.06870
# (song_tension, musical_expertise)               1.42367   2  84 0.06873
# (song_familiarity, song_tension)                1.43397   2  84 0.06923
# (song_activity, song_engagement)                1.46020   2  84 0.07050
# (song_tension, personality_stress)              1.48722   2  84 0.07180
# (song_engagement, song_tension)                 1.55981   2  84 0.07531
# (song_activity, personality_artistic)           1.56466   2  84 0.07554
# (song_engagement, personality_stress)           1.62927   2  84 0.07866
# (song_positivity, personality_stress)           1.63019   2  84 0.07870
# (song_engagement, song_like_dislike)            1.64469   2  84 0.07940
# (song_activity, song_tension)                   1.66143   2  84 0.08021
# (song_positivity, song_tension)                 1.71805   2  84 0.08295
# (age, personality_thorough)                     1.75283   2  84 0.08463
# (age, personality_trusting)                     1.75870   2  84 0.08491
# (song_engagement, song_positivity)              1.75952   2  84 0.08495
# (age, personality_imagination)                  1.79346   2  84 0.08659
# (age, musical_expertise)                        1.81125   2  84 0.08745
# (song_like_dislike, age)                        1.81332   2  84 0.08755
# (age, personality_outgoing)                     1.82134   2  84 0.08793
# (age, personality_lazy)                         1.84802   2  84 0.08922
# (age, personality_fault)                        1.87588   2  84 0.09057
# (song_familiarity, age)                         1.90486   2  84 0.09197
# (song_like_dislike, song_tension)               1.91550   2  84 0.09248
# (song_engagement, personality_artistic)         2.02019   2  84 0.09753
# (age, concentration)                            2.02405   2  84 0.09772
# (age, personality_stress)                       2.18390   2  84 0.10544
# (song_positivity, personality_artistic)         2.19019   2  84 0.10574
# (song_tension, personality_artistic)            2.54813   2  84 0.12302
# (song_activity, age)                            2.60734   2  84 0.12588
# (age, personality_artistic)                     2.61511   2  84 0.12626
# (song_positivity, age)                          2.81284   2  84 0.13580
# (song_tension, age)                             3.01012   2  84 0.14533
# (song_engagement, age)                          3.09041   2  84 0.14920
# (song_like_dislike, personality_reserved)       3.17234   2  84 0.15316
# (personality_reserved, personality_thorough)    3.18637   2  84 0.15384
# (personality_fault, personality_reserved)       3.18644   2  84 0.15384
# (personality_imagination, personality_reserved) 3.18938   2  84 0.15398
# (musical_expertise, personality_reserved)       3.19901   2  84 0.15445
# (personality_reserved, personality_trusting)    3.25220   2  84 0.15702
# (personality_outgoing, personality_reserved)    3.27917   2  84 0.15832
# (concentration, personality_reserved)           3.30680   2  84 0.15965
# (personality_lazy, personality_reserved)        3.33737   2  84 0.16113
# (song_familiarity, personality_reserved)        3.38373   2  84 0.16337
# (song_activity, personality_reserved)           3.53344   2  84 0.17059
# (personality_reserved, personality_stress)      3.58195   2  84 0.17294
# (personality_artistic, personality_reserved)    3.78861   2  84 0.18291
# (song_positivity, personality_reserved)         3.80614   2  84 0.18376
# (song_tension, personality_reserved)            3.90274   2  84 0.18842
# (song_engagement, personality_reserved)         4.08933   2  84 0.19743
# (age, personality_reserved)                     4.65243   2  84 0.22462
# (personality_nervous, personality_outgoing)     4.72557   2  84 0.22815
# (personality_nervous, personality_stress)       4.72725   2  84 0.22823
# (personality_fault, personality_nervous)        4.72726   2  84 0.22823
# (song_familiarity, personality_nervous)         4.74206   2  84 0.22895
# (song_like_dislike, personality_nervous)        4.74597   2  84 0.22913
# (personality_imagination, personality_nervous)  4.74797   2  84 0.22923
# (personality_nervous, personality_thorough)     4.78864   2  84 0.23119
# (personality_artistic, personality_nervous)     4.80547   2  84 0.23201
# (concentration, personality_nervous)            4.81875   2  84 0.23265
# (musical_expertise, personality_nervous)        4.82135   2  84 0.23277
# (personality_nervous, personality_trusting)     4.91148   2  84 0.23712
# (song_positivity, personality_nervous)          5.06389   2  84 0.24448
# (song_activity, personality_nervous)            5.10522   2  84 0.24648
# (personality_lazy, personality_nervous)         5.31745   2  84 0.25672
# (song_tension, personality_nervous)             5.35444   2  84 0.25851
# (age, personality_nervous)                      5.96494   2  84 0.28799
# (personality_nervous, personality_reserved)     6.13325   2  84 0.29611
# (song_engagement, personality_nervous)          6.36232   2  84 0.30717

# %%
if results[results.adjustedP <= alpha].shape[0] > 0:
    for pair in results.index.values[0:3]:
        g = sns.FacetGrid(df_all[[pair[0], pair[1], 'critical_reaction']], col='critical_reaction', height=6, aspect=1, margin_titles=True)
        g.map(sns.kdeplot, pair[0], pair[1], cmap='Reds', shade=True, shade_lowest=False, alpha=0.65)
        g.savefig('hallelujah_reaction_distributions_{}_{}_{}_by_reaction.pdf'.format(notebook_song_name, pair[0], pair[1]))
else:
    print('No significant results to plot')
# Out:
# No significant results to plot
