# %% [markdown]
# # Exploratory Visualization

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import pandas as pd
import scipy.stats as sps
import seaborn as sns
import sklearn

from pathlib import Path

# %% [markdown]
# ## Retrieve and Subset Datasource
#
# Retrieve all good trials for IDs that came from Javier's algorithm.

# %%
notebook_song_name = 'into_dust'

# %%
data_root = Path('../../neural_nets/fastai/data')

df_all = pd.read_csv(data_root / 'good_reaction_trials_categorified_q90_javier_all_no_impute.csv')

df_all = df_all[df_all.song == notebook_song_name]

pd.set_option('display.max_columns', None)
df_all.describe()
# Out:
#               age  personality_trusting  personality_artistic  \
# count  175.000000             78.000000             78.000000
# mean    26.720000              3.782051              2.282051
# std     14.212929              0.962241              1.267961
# min      8.000000              1.000000              1.000000
# 25%     16.000000              3.000000              1.000000
# 50%     23.000000              4.000000              2.000000
# 75%     31.000000              4.000000              3.000000
# max     81.000000              5.000000              5.000000
#
#        personality_imagination  personality_reserved  personality_outgoing  \
# count                78.000000             78.000000             78.000000
# mean                  3.910256              3.102564              3.243590
# std                   0.995912              1.179806              1.175352
# min                   2.000000              1.000000              1.000000
# 25%                   3.000000              2.000000              2.000000
# 50%                   4.000000              3.000000              3.000000
# 75%                   5.000000              4.000000              4.000000
# max                   5.000000              5.000000              5.000000
#
#        personality_lazy  personality_stress  personality_nervous  \
# count         78.000000           78.000000            78.000000
# mean           3.615385            3.166667             3.769231
# std            1.229832            1.242292             1.115686
# min            1.000000            1.000000             1.000000
# 25%            3.000000            2.000000             3.000000
# 50%            4.000000            3.000000             4.000000
# 75%            4.000000            4.000000             5.000000
# max            5.000000            5.000000             5.000000
#
#        personality_fault  personality_thorough  musical_expertise  \
# count          78.000000             78.000000         125.000000
# mean            3.192308              3.153846           2.704000
# std             1.173934              1.140482           1.077811
# min             1.000000              1.000000           1.000000
# 25%             2.000000              2.000000           2.000000
# 50%             3.000000              3.000000           3.000000
# 75%             4.000000              4.000000           3.000000
# max             5.000000              5.000000           5.000000
#
#        concentration  control_power  control_like_dislike  control_tension  \
# count      78.000000      78.000000             78.000000        78.000000
# mean        3.897436       3.102564              2.871795         3.294872
# std         1.100056       1.146307              1.342212         1.152174
# min         1.000000       1.000000              1.000000         1.000000
# 25%         4.000000       2.000000              2.000000         3.000000
# 50%         4.000000       3.000000              3.000000         3.000000
# 75%         5.000000       4.000000              4.000000         4.000000
# max         5.000000       5.000000              5.000000         5.000000
#
#        control_engagement  control_activity  control_positivity  \
# count           78.000000         78.000000           78.000000
# mean             2.897436          2.820513            3.064103
# std              1.223044          1.053671            1.073164
# min              1.000000          1.000000            1.000000
# 25%              2.000000          2.000000            2.000000
# 50%              3.000000          3.000000            3.000000
# 75%              4.000000          3.000000            4.000000
# max              5.000000          5.000000            5.000000
#
#        control_familiarity  song_power  song_like_dislike  song_tension  \
# count                 78.0   88.000000         157.000000    167.000000
# mean                  -1.0    3.284091           3.426752      4.000000
# std                    0.0    1.338629           1.387692      1.092141
# min                   -1.0    1.000000           1.000000      1.000000
# 25%                   -1.0    2.000000           2.000000      4.000000
# 50%                   -1.0    3.000000           4.000000      4.000000
# 75%                   -1.0    4.000000           5.000000      5.000000
# max                   -1.0    5.000000           5.000000      5.000000
#
#        song_engagement  song_activity  song_positivity  song_familiarity  \
# count       157.000000     157.000000       157.000000        157.000000
# mean          3.369427       3.414013         3.305732          1.872611
# std           1.410976       1.062439         1.152825          1.212785
# min           1.000000       1.000000         1.000000          1.000000
# 25%           2.000000       3.000000         3.000000          1.000000
# 50%           4.000000       4.000000         3.000000          1.000000
# 75%           5.000000       4.000000         4.000000          3.000000
# max           5.000000       5.000000         5.000000          5.000000
#
#        visual_impairments  song_inspired  song_wonder  song_spirituality  \
# count                 0.0            0.0    10.000000                0.0
# mean                  NaN            NaN     3.400000                NaN
# std                   NaN            NaN     0.843274                NaN
# min                   NaN            NaN     2.000000                NaN
# 25%                   NaN            NaN     3.000000                NaN
# 50%                   NaN            NaN     3.000000                NaN
# 75%                   NaN            NaN     4.000000                NaN
# max                   NaN            NaN     5.000000                NaN
#
#        song_thrills  song_chills  song_tenderness  song_nostalgia  \
# count           0.0          0.0        10.000000       10.000000
# mean            NaN          NaN         3.400000        2.800000
# std             NaN          NaN         0.843274        1.032796
# min             NaN          NaN         2.000000        1.000000
# 25%             NaN          NaN         3.000000        2.000000
# 50%             NaN          NaN         4.000000        3.000000
# 75%             NaN          NaN         4.000000        3.750000
# max             NaN          NaN         4.000000        4.000000
#
#        song_goosebumps  song_overwhelmed  song_shivers  \
# count              0.0               0.0           0.0
# mean               NaN               NaN           NaN
# std                NaN               NaN           NaN
# min                NaN               NaN           NaN
# 25%                NaN               NaN           NaN
# 50%                NaN               NaN           NaN
# 75%                NaN               NaN           NaN
# max                NaN               NaN           NaN
#
#        song_chillsshiversthrills  song_transcendence  song_sadness  \
# count                  79.000000           10.000000     10.000000
# mean                    1.772152            3.100000      3.200000
# std                     1.085444            1.197219      1.316561
# min                     1.000000            1.000000      1.000000
# 25%                     1.000000            2.250000      2.250000
# 50%                     1.000000            3.000000      3.000000
# 75%                     2.000000            4.000000      4.000000
# max                     5.000000            5.000000      5.000000
#
#        song_joyfulactivation  song_peacefulness  musicpref_rock  \
# count              10.000000          10.000000      175.000000
# mean                1.800000           3.900000        0.531429
# std                 0.788811           0.875595        0.500443
# min                 1.000000           3.000000        0.000000
# 25%                 1.000000           3.000000        0.000000
# 50%                 2.000000           4.000000        1.000000
# 75%                 2.000000           4.750000        1.000000
# max                 3.000000           5.000000        1.000000
#
#        musicpref_traditional_irish  musicpref_hip_hop  musicpref_jazz  \
# count                   175.000000         175.000000      175.000000
# mean                      0.085714           0.131429        0.182857
# std                       0.280745           0.338838        0.387659
# min                       0.000000           0.000000        0.000000
# 25%                       0.000000           0.000000        0.000000
# 50%                       0.000000           0.000000        0.000000
# 75%                       0.000000           0.000000        0.000000
# max                       1.000000           1.000000        1.000000
#
#        musicpref_pop  musicpref_hiphop  musicpref_world  musicpref_none  \
# count     175.000000        175.000000       175.000000             0.0
# mean        0.691429          0.057143         0.228571             NaN
# std         0.463229          0.232781         0.421117             NaN
# min         0.000000          0.000000         0.000000             NaN
# 25%         0.000000          0.000000         0.000000             NaN
# 50%         1.000000          0.000000         0.000000             NaN
# 75%         1.000000          0.000000         0.000000             NaN
# max         1.000000          1.000000         1.000000             NaN
#
#        musicpref_classical  musicpref_folk  musicpref_dance
# count           175.000000      175.000000       175.000000
# mean              0.342857        0.028571         0.205714
# std               0.476026        0.167077         0.405383
# min               0.000000        0.000000         0.000000
# 25%               0.000000        0.000000         0.000000
# 50%               0.000000        0.000000         0.000000
# 75%               1.000000        0.000000         0.000000
# max               1.000000        1.000000         1.000000

# %%
df_reaction = df_all[df_all['critical_reaction'] == True]
df_no_reaction = df_all[df_all['critical_reaction'] == False]

# %%
df_all.columns
# Out:
# Index(['_id', 'location', 'language', 'nationality', 'age', 'sex',
#        'hearing_impairments', 'personality_trusting', 'personality_artistic',
#        'personality_imagination', 'personality_reserved',
#        'personality_outgoing', 'personality_lazy', 'personality_stress',
#        'personality_nervous', 'personality_fault', 'personality_thorough',
#        'musical_expertise', 'concentration', 'critical_reaction',
#        'control_power', 'control_like_dislike', 'control_tension',
#        'control_engagement', 'control_activity', 'control_positivity',
#        'control_familiarity', 'song_power', 'song_like_dislike',
#        'song_tension', 'song_engagement', 'song_activity', 'song_positivity',
#        'song_familiarity', 'musical_background', 'visual_impairments',
#        'song_inspired', 'song_wonder', 'song_spirituality', 'song_thrills',
#        'song_chills', 'song_tenderness', 'song_nostalgia', 'song_goosebumps',
#        'song_overwhelmed', 'song_shivers', 'song_chillsshiversthrills',
#        'song_transcendence', 'song_sadness', 'song_joyfulactivation',
#        'song_peacefulness', 'song', 'musicpref_rock',
#        'musicpref_traditional_irish', 'musicpref_hip_hop', 'musicpref_jazz',
#        'musicpref_pop', 'musicpref_hiphop', 'musicpref_world',
#        'musicpref_none', 'musicpref_classical', 'musicpref_folk',
#        'musicpref_dance'],
#       dtype='object')

# %%
cat_cols = ['location', 'language', 'nationality', 'sex', 'hearing_impairments']

ord_cols = ['personality_trusting', 'personality_artistic', 'personality_imagination', 'personality_reserved', 
            'personality_outgoing', 'personality_lazy', 'personality_stress', 'personality_nervous', 
            'personality_fault', 'personality_thorough', 'musical_expertise', 'concentration', 'song_power', 
            'song_like_dislike', 'song_tension', 'song_engagement', 'song_activity', 'song_positivity', 
            'song_familiarity', 'musical_background', 'song_chillsshiversthrills', 'musicpref_rock', 
            'musicpref_traditional_irish', 'musicpref_hip_hop', 'musicpref_jazz', 'musicpref_pop', 
            'musicpref_hiphop', 'musicpref_world', 'musicpref_none', 'musicpref_classical', 'musicpref_folk', 
            'musicpref_dance']

cont_cols = ['age']

# %%
nationality_counts = df_all['nationality'].value_counts()
patches, texts = plt.pie(nationality_counts, 
                                    explode=[0.1] * len(nationality_counts));

labels = ['{}: {}'.format(x.capitalize(), nationality_counts[x]) for x in nationality_counts.index]

plt.legend(patches, labels)
plt.savefig('hallelujah_reaction_pie_nationalities_redux_{}.pdf'.format(notebook_song_name))

# %%
language_counts = df_all['language'].value_counts()
patches, texts = plt.pie(language_counts, 
                                    explode=[0.1] * len(language_counts));

languages = list(language_counts.index)
for i in range(len(languages)):
    language = languages[i]
    if language == 'en':
        languages[i] = 'English'
    elif language == 'zh_TW':
        languages[i] = 'Taiwanese'

labels = ['{}: {}'.format(languages[i].capitalize(), language_counts[x]) for i, x in enumerate(language_counts.index)]

plt.legend(patches, labels)
plt.savefig('hallelujah_reaction_pie_languages_redux_{}.pdf'.format(notebook_song_name))

# %%
def mardia(data, unbiased_cov=True):
    """
    data should have observations in rows
    """
    import numpy as np
    import scipy.stats as sps
    
    n = data.shape[0]
    p = data.shape[1]

    S = None
    if unbiased_cov:
        S = ((n - 1.) / n) * np.cov(data, rowvar=False)
    else:
        S = np.cov(data, rowvar=False)

    data_scaled = (data - data.mean(axis=0))

    D = np.matmul(np.matmul(data_scaled, np.linalg.pinv(S, rcond=1e-25)), data_scaled.T)

    product = D * D * D
    skewness = np.sum(product) / n**2
    kurtosis = (D * D).diagonal().sum() / n
    df = p * (p + 1) * (p + 2) / 6
    k = ((p + 1)*(n + 1)*(n + 3))/(n*((n + 1)*(p + 1) - 6))
    
    skew, kurt, skew_p, kurt_p = None, None, None, None
    if n < 20:
        skew = n * k * skewness / 6.
    else:
        skew = n * skewness / 6.
    
    chi2_test_skew = sps.chi2(df)
    skew_p = 1. - chi2_test_skew.cdf(skew)
    
    skew_result = False
    if skew_p > 0.05:
        skew_result = True
    
    kurt = (kurtosis - p * (p + 2)) * np.sqrt(n / (8 * p * (p + 2)))
    
    normal_test_kurt = sps.norm()
    kurt_p = 2. * (1. - normal_test_kurt.cdf(np.abs(kurt)))
    
    kurt_result = False
    if kurt_p  > 0.05:
        kurt_result = True
    
    result_skewness = {
        'test': 'Mardia Skewness',
        'statistic': skew,
        'p-value': skew_p,
        'result': skew_result
    }
    
    result_kurtosis = {
        'test': 'Mardia Kurtosis',
        'statistic': kurt,
        'p-value': kurt_p,
        'result': kurt_result
    }
    
    result = {
        'test': 'MVN',
        'statistic': None,
        'p-value': None,
        'result': skew_result and kurt_result
    }
    
    return result_skewness, result_kurtosis, result

# %%
def run_tests(x_label, dist_var, bins=None, normed=False, kde=True, bw='normal_reference', x_lim=None, plots=False, print_output=False):
    
    if plots:
        f = plt.figure(figsize=(8, 4))
        sns.distplot(df_all[dist_var].dropna(), bins=bins, norm_hist=normed, kde=kde, rug=True, kde_kws={'bw': bw})
        plt.xlabel('')
        if x_lim is not None:
            plt.xlim([0.5, 5.5])

        g = sns.FacetGrid(df_all, hue='critical_reaction', height=4, aspect=2)
        g.map(sns.distplot, dist_var, bins=bins, norm_hist=normed, kde=kde, kde_kws={'bw': bw})
        g.set_xlabels(x_label)
        if x_lim is not None:
            g.axes[0,0].set_xlim([0.5, 5.5])
        g.fig.suptitle('Distribution of {} by reaction group'.format(dist_var), y=1.0)
        g.add_legend(title='Hallelujah Reaction');

        fig_file = 'hallelujah_reaction_distribution_all_stimuli_{}.pdf'.format(dist_var)
        g.savefig(fig_file, orientation='landscape')
        
    mean_true = df_all[df_all['critical_reaction'] == True][dist_var].dropna()
    mean_false = df_all[df_all['critical_reaction'] == False][dist_var].dropna()
    
    alpha = 0.05
    _, equal_variance_p = sps.levene(mean_true, mean_false)
    
    equal_var = None
    if equal_variance_p >= alpha:
        equal_var = True
    else:
        equal_var = False
    
    t_stat, t_p = sps.ttest_ind(mean_true, mean_false, equal_var=equal_var)
    u_stat, u_p = sps.mannwhitneyu(mean_true, mean_false, alternative='two-sided')

    if print_output:
        print('Student\'s t-test for difference in mean {} between Hallelujah Reaction groups'.format(x_label.capitalize()))

        print('T test statistic: {:.4f}'.format(t_stat))
        print('T test p-value: {:.4f}'.format(t_p))

        print('Mann-Whitney U test statistic: {:.4f}'.format(u_stat))
        print('Mann-Whitney U test p-value: {:.4f}'.format(u_p))

        if t_p <= alpha or u_p <= alpha:
            print('**** Significant Result ****')
    
    return {
        'mean_true': mean_true.mean(),
        'mean_false': mean_false.mean(),
        'median_true': mean_true.median(),
        'median_false': mean_false.median(),
        't_stat': t_stat,
        't_p': t_p,
        'u_stat': u_stat,
        'u_p': u_p
    }

# %%
df_results = pd.DataFrame({})

for c in ord_cols:
    result = run_tests(c, c)
    df_results = pd.concat([df_results, pd.DataFrame(result, index=[c])])
# Out:
# /home/paperspace/anaconda3/envs/fastai/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/paperspace/anaconda3/envs/fastai/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/paperspace/anaconda3/envs/fastai/lib/python3.7/site-packages/scipy/stats/stats.py:4911: RuntimeWarning: divide by zero encountered in double_scalars
#   z = (bigu - meanrank) / sd

# %%
df_results = df_results.sort_values(by='u_p')

i = np.arange(1, len(ord_cols) + len(cont_cols))
m = len(i)
Q = 0.25
benjamini_hochberg = ((i * 1.) / m) * Q
df_results['bh_threshold'] = benjamini_hochberg
df_results['significant'] = df_results.u_p < df_results.bh_threshold

df_results
# Out:
#                              mean_true  mean_false  median_true  median_false  \
# musicpref_none                     NaN         NaN          NaN           NaN
# personality_fault             2.571429    3.540000          3.0           4.0
# personality_imagination       4.178571    3.760000          4.0           4.0
# musical_expertise             2.551020    2.802632          2.0           3.0
# personality_outgoing          3.535714    3.080000          3.5           3.0
# song_activity                 3.557377    3.322917          4.0           4.0
# personality_trusting          3.928571    3.700000          4.0           4.0
# musicpref_pop                 0.637681    0.726415          1.0           1.0
# personality_stress            3.392857    3.040000          3.0           3.0
# song_engagement               3.213115    3.468750          4.0           4.0
# song_like_dislike             3.295082    3.510417          3.0           4.0
# musicpref_folk                0.014493    0.037736          0.0           0.0
# musicpref_hip_hop             0.159420    0.113208          0.0           0.0
# musicpref_dance               0.173913    0.226415          0.0           0.0
# song_chillsshiversthrills     1.878788    1.695652          1.0           1.0
# song_positivity               3.229508    3.354167          3.0           3.0
# musicpref_hiphop              0.043478    0.066038          0.0           0.0
# personality_reserved          2.964286    3.180000          3.0           3.0
# musicpref_traditional_irish   0.072464    0.094340          0.0           0.0
# musicpref_world               0.246377    0.216981          0.0           0.0
# personality_lazy              3.500000    3.680000          4.0           4.0
# personality_nervous           3.678571    3.820000          4.0           4.0
# song_familiarity              1.836066    1.895833          1.0           1.0
# concentration                 3.821429    3.940000          4.0           4.0
# musicpref_jazz                0.173913    0.188679          0.0           0.0
# musicpref_classical           0.333333    0.349057          0.0           0.0
# musical_background            0.428571    0.461538          0.0           0.0
# personality_thorough          3.107143    3.180000          3.0           3.0
# song_tension                  3.924242    4.049505          4.0           4.0
# song_power                    3.303030    3.272727          3.0           3.0
# musicpref_rock                0.536232    0.528302          1.0           1.0
# personality_artistic          2.250000    2.300000          2.0           2.0
#
#                                t_stat       t_p  u_stat       u_p  \
# musicpref_none                    NaN       NaN     0.0  0.000000
# personality_fault           -3.786038  0.000304   398.5  0.001119
# personality_imagination      1.806579  0.074786   864.5  0.071548
# musical_expertise           -1.277440  0.203853  1554.5  0.105065
# personality_outgoing         1.661303  0.100773   838.5  0.138666
# song_activity                1.351335  0.178557  3273.0  0.192492
# personality_trusting         1.006448  0.317394   813.0  0.204057
# musicpref_pop               -1.240289  0.216548  3332.5  0.216285
# personality_stress           1.206913  0.231209   811.5  0.233781
# song_engagement             -1.107302  0.269879  2652.5  0.309708
# song_like_dislike           -0.947390  0.344915  2673.0  0.346560
# musicpref_folk              -0.898870  0.369971  3572.0  0.371281
# musicpref_hip_hop            0.881148  0.379460  3826.0  0.379344
# musicpref_dance             -0.836556  0.403996  3465.0  0.403663
# song_chillsshiversthrills    0.737419  0.463109   823.0  0.481289
# song_positivity             -0.659205  0.510742  2749.0  0.506987
# musicpref_hiphop            -0.625429  0.532514  3574.5  0.533463
# personality_reserved        -0.772583  0.442165   644.0  0.549314
# musicpref_traditional_irish -0.502663  0.615841  3577.0  0.616654
# musicpref_world              0.450237  0.653103  3764.5  0.653307
# personality_lazy            -0.617578  0.538700   666.5  0.717943
# personality_nervous         -0.534550  0.594522   671.5  0.761777
# song_familiarity            -0.300098  0.764504  2854.5  0.765852
# concentration               -0.454289  0.650916   675.0  0.785858
# musicpref_jazz              -0.245585  0.806295  3603.0  0.807253
# musicpref_classical         -0.212949  0.831617  3599.5  0.832358
# musical_background          -0.221270  0.825883   264.0  0.832753
# personality_thorough        -0.269010  0.788651   680.0  0.833919
# song_tension                -0.723591  0.470342  3286.0  0.871065
# song_power                   0.102221  0.918819   923.5  0.891173
# musicpref_rock               0.102150  0.918756  3686.0  0.919808
# personality_artistic        -0.166005  0.868594   702.0  0.987050
#
#                              bh_threshold  significant
# musicpref_none                   0.007812         True
# personality_fault                0.015625         True
# personality_imagination          0.023438        False
# musical_expertise                0.031250        False
# personality_outgoing             0.039062        False
# song_activity                    0.046875        False
# personality_trusting             0.054688        False
# musicpref_pop                    0.062500        False
# personality_stress               0.070312        False
# song_engagement                  0.078125        False
# song_like_dislike                0.085938        False
# musicpref_folk                   0.093750        False
# musicpref_hip_hop                0.101562        False
# musicpref_dance                  0.109375        False
# song_chillsshiversthrills        0.117188        False
# song_positivity                  0.125000        False
# musicpref_hiphop                 0.132812        False
# personality_reserved             0.140625        False
# musicpref_traditional_irish      0.148438        False
# musicpref_world                  0.156250        False
# personality_lazy                 0.164062        False
# personality_nervous              0.171875        False
# song_familiarity                 0.179688        False
# concentration                    0.187500        False
# musicpref_jazz                   0.195312        False
# musicpref_classical              0.203125        False
# musical_background               0.210938        False
# personality_thorough             0.218750        False
# song_tension                     0.226562        False
# song_power                       0.234375        False
# musicpref_rock                   0.242188        False
# personality_artistic             0.250000        False

# %%
sns.countplot(x='sex', hue='critical_reaction', data=df_all)

# %%
# Chi-squared test of male/female proportions

cross = pd.crosstab(df_all['sex'], df_all['critical_reaction'])
display(cross)
chi2, p, dof, table = sps.chi2_contingency(cross)
print('Chi-squared test of sex vs hallelujah reaction proportions')
print('Test statistic: {:.4f}'.format(chi2))
print('p-value: {:.4f}'.format(p))
print('Degrees of freedom: {}'.format(dof))
# Out:
# critical_reaction  False  True
# sex
# female                41     34
# male                  65     35
# Chi-squared test of sex vs hallelujah reaction proportions
# Test statistic: 1.5079
# p-value: 0.2195
# Degrees of freedom: 1

# %%
sns.countplot(x='location', hue='critical_reaction', data=df_all)

# %%
# Chi-squared test of location proportions

cross = pd.crosstab(df_all['location'], df_all['critical_reaction'])
display(cross)
chi2, p, dof, table = sps.chi2_contingency(cross)
print('Chi-squared test of location vs hallelujah reaction proportions')
print('Test statistic: {:.4f}'.format(chi2))
print('p-value: {:.4f}'.format(p))
print('Degrees of freedom: {}'.format(dof))
# Out:
# critical_reaction  False  True
# location
# dublin                56     41
# taichung_city         15      7
# taipei_city           35     21
# Chi-squared test of location vs hallelujah reaction proportions
# Test statistic: 0.9482
# p-value: 0.6224
# Degrees of freedom: 2

# %%
sns.countplot(x='language', hue='critical_reaction', data=df_all)

# %%
# Chi-squared test of language proportions

cross = pd.crosstab(df_all['language'], df_all['critical_reaction'])
display(cross)
chi2, p, dof, table = sps.chi2_contingency(cross)
print('Chi-squared test of language vs hallelujah reaction proportions (for Taiwanese, English, and NA)')
print('Test statistic: {:.4f}'.format(chi2))
print('p-value: {:.4f}'.format(p))
print('Degrees of freedom: {}'.format(dof))
# Out:
# critical_reaction  False  True
# language
# en                    39     19
# zh_TW                 11      9
# Chi-squared test of language vs hallelujah reaction proportions (for Taiwanese, English, and NA)
# Test statistic: 0.5095
# p-value: 0.4753
# Degrees of freedom: 1

# %% [markdown]
# Sources for Hotelling's $T^2$:
# - https://ncss-wpengine.netdna-ssl.com/wp-content/themes/ncss/pdf/Procedures/NCSS/Hotellings_Two-Sample_T2.pdf
# - https://onlinecourses.science.psu.edu/stat505/node/100/

# %%
def hotelling_t2(X_1, X_2, alpha):
    
    import scipy.stats as sps
    
    n_1 = len(X_1)
    n_2 = len(X_2)

    y_1 = X_1.mean().as_matrix()
    y_1 = y_1.reshape(len(y_1), -1)
    y_2 = X_2.mean().as_matrix()
    y_2 = y_2.reshape(len(y_2), -1)

    # Covariance matrices
    S_1 = np.cov(X_1.astype(np.float64).T)
    S_2 = np.cov(X_2.astype(np.float64).T)

    # Pooled variance
    S_pooled_num = ((n_1 - 1) * S_1) + ((n_2 - 1) * S_2)
    S_pooled_denom = n_1 + n_2 - 2
    S_pooled = S_pooled_num / S_pooled_denom
    
    T_2 = (n_1 * n_2) / (n_1 + n_2)
    T_2 = T_2 * np.matmul((y_1 - y_2).T, np.linalg.pinv(S_pooled))
    T_2 = np.matmul(T_2, (y_1 - y_2))
    T_2 = T_2.squeeze()
    
    p = len(X_1.columns)
    F_num = n_1 + n_2 - p - 1
    F_denom = p * (n_1 + n_2 - 2)
    F = (F_num / F_denom) * T_2
    F = F.squeeze()
    
    df_1 = p
    df_2 = n_1 + n_2 - p - 1
    F_dist = sps.f(df_1, df_2)
    p_value = F_dist.cdf(F)
    
    # Calculate effect size
    D_2 = ((n_1 + n_2) * T_2) / (n_1 * n_2)
    
    return({
        'T2': T_2,
        'F': F,
        'df': (df_1, df_2),
        'p': p_value,
        'D2': D_2
    })

# %% [markdown]
# # Pairwise Hotelling's $T^2$

# %%
import itertools

plot_vars = ['song_activity', 
             'song_engagement', 
             'song_familiarity', 
             'song_like_dislike', 
             'song_positivity', 
             'song_tension', 
             'age', 
             'musical_expertise', 
             'concentration', 
             'personality_artistic', 
             'personality_fault', 
             'personality_imagination', 
             'personality_lazy', 
             'personality_nervous', 
             'personality_outgoing', 
             'personality_reserved', 
             'personality_stress', 
             'personality_thorough', 
             'personality_trusting']

pairs = list(itertools.combinations(plot_vars, 2))

results = pd.DataFrame(columns=['p', 'adjustedP', 'F', 'T2', 'df1', 'df2', 'D2'])

for pair in pairs:
    
    test_vars = list(pair)
    test_vars.append('critical_reaction')
    df_pair = df_all[test_vars].dropna()
    df_pair_1 = df_pair[df_pair['critical_reaction'] == False].drop(['critical_reaction'], axis=1)
    df_pair_2 = df_pair[df_pair['critical_reaction'] == True].drop(['critical_reaction'], axis=1)
    
    mardia_result = mardia(df_pair.drop(['critical_reaction'], axis=1), unbiased_cov=True)
    if mardia_result[2]['result']:
        pass

    t2_results = hotelling_t2(df_pair_1, df_pair_2, 0.05)
    p = t2_results['p']
    adjusted_p = p * len(pairs)
    if adjusted_p > 1:
        adjusted_p = 1
        
    row = pd.DataFrame(
        {
            'p': t2_results['p'], 
            'adjustedP': adjusted_p,
            'F': t2_results['F'], 
            'T2': t2_results['T2'], 
            'df1': t2_results['df'][0], 
            'df2': t2_results['df'][1],
            'D2': t2_results['D2']
        }, 
        index=[pair])

    results = pd.concat([results, row])
    
alpha = 0.5
    
with pd.option_context('display.max_rows', None, 'display.float_format', lambda x: '%.5f' % x):
    display('Tests for difference between combined means of {} and {} between hallelujah reaction groups:'.format(pair[0], pair[1]))
    display(results.sort_values(by='p'))

results.to_csv('hotelling_comparisons_{}.csv'.format(notebook_song_name))
# Out:
# /home/paperspace/anaconda3/envs/fastai/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# /home/paperspace/anaconda3/envs/fastai/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.
# 'Tests for difference between combined means of personality_thorough and personality_trusting between hallelujah reaction groups:'
#                                                       p adjustedP       F  \
# (song_tension, personality_artistic)            0.03635         1 0.03705
# (personality_artistic, personality_thorough)    0.04331         1 0.04430
# (song_tension, personality_thorough)            0.05638         1 0.05807
# (song_tension, concentration)                   0.09677         1 0.10192
# (concentration, personality_artistic)           0.12201         1 0.13034
# (song_familiarity, song_tension)                0.12695         1 0.13588
# (concentration, personality_thorough)           0.12713         1 0.13621
# (personality_artistic, personality_nervous)     0.14369         1 0.15545
# (song_like_dislike, personality_artistic)       0.14839         1 0.16097
# (song_like_dislike, concentration)              0.15643         1 0.17049
# (song_tension, personality_nervous)             0.16051         1 0.17536
# (song_like_dislike, personality_thorough)       0.17287         1 0.19027
# (personality_artistic, personality_lazy)        0.17360         1 0.19116
# (personality_nervous, personality_thorough)     0.17595         1 0.19402
# (musical_expertise, personality_artistic)       0.17738         1 0.19577
# (musical_expertise, personality_thorough)       0.17922         1 0.19802
# (song_tension, personality_lazy)                0.21987         1 0.24911
# (song_positivity, song_tension)                 0.23585         1 0.26946
# (musical_expertise, concentration)              0.23858         1 0.27356
# (personality_lazy, personality_nervous)         0.23875         1 0.27379
# (song_familiarity, song_positivity)             0.24740         1 0.28474
# (song_tension, personality_reserved)            0.25686         1 0.29804
# (personality_artistic, personality_reserved)    0.26380         1 0.30751
# (personality_nervous, personality_reserved)     0.26495         1 0.30909
# (song_positivity, personality_artistic)         0.26534         1 0.30962
# (song_positivity, concentration)                0.27094         1 0.31734
# (song_positivity, personality_thorough)         0.27522         1 0.32327
# (song_like_dislike, personality_nervous)        0.27557         1 0.32376
# (personality_reserved, personality_thorough)    0.27813         1 0.32733
# (personality_lazy, personality_thorough)        0.27913         1 0.32873
# (concentration, personality_nervous)            0.28372         1 0.33517
# (concentration, personality_lazy)               0.29166         1 0.34641
# (age, personality_thorough)                     0.29788         1 0.35533
# (age, personality_artistic)                     0.29804         1 0.35556
# (song_engagement, concentration)                0.31079         1 0.37406
# (song_like_dislike, personality_lazy)           0.31715         1 0.38342
# (song_engagement, personality_artistic)         0.32294         1 0.39203
# (song_familiarity, musical_expertise)           0.32494         1 0.39444
# (age, personality_nervous)                      0.32798         1 0.39958
# (song_engagement, personality_thorough)         0.32890         1 0.40096
# (musical_expertise, personality_nervous)        0.32983         1 0.40237
# (song_like_dislike, personality_reserved)       0.33256         1 0.40650
# (personality_lazy, personality_reserved)        0.33891         1 0.41616
# (age, concentration)                            0.34841         1 0.43079
# (musical_expertise, personality_reserved)       0.35010         1 0.43342
# (song_tension, musical_expertise)               0.35456         1 0.43951
# (musical_expertise, personality_lazy)           0.35790         1 0.44564
# (song_like_dislike, song_positivity)            0.35926         1 0.44641
# (concentration, personality_reserved)           0.36216         1 0.45238
# (song_like_dislike, song_tension)               0.37065         1 0.46447
# (song_positivity, personality_nervous)          0.37581         1 0.47428
# (personality_artistic, personality_trusting)    0.39347         1 0.50334
# (song_tension, personality_trusting)            0.39737         1 0.50989
# (song_positivity, personality_lazy)             0.40111         1 0.51619
# (age, personality_lazy)                         0.41416         1 0.53854
# (song_positivity, personality_reserved)         0.42038         1 0.54937
# (personality_thorough, personality_trusting)    0.42248         1 0.55306
# (song_familiarity, song_like_dislike)           0.43743         1 0.57739
# (song_familiarity, personality_artistic)        0.43773         1 0.58021
# (song_familiarity, personality_thorough)        0.43915         1 0.58279
# (song_engagement, personality_nervous)          0.44415         1 0.59189
# (song_like_dislike, personality_trusting)       0.44418         1 0.59193
# (age, personality_reserved)                     0.44711         1 0.59730
# (song_familiarity, concentration)               0.45291         1 0.60802
# (song_engagement, personality_lazy)             0.45412         1 0.61026
# (song_engagement, song_like_dislike)            0.45625         1 0.61169
# (song_engagement, song_positivity)              0.45780         1 0.61456
# (song_activity, personality_artistic)           0.46786         1 0.63619
# (concentration, personality_trusting)           0.46823         1 0.63690
# (song_engagement, personality_reserved)         0.47204         1 0.64420
# (song_activity, personality_thorough)           0.47336         1 0.64676
# (song_engagement, song_tension)                 0.47915         1 0.65507
# (song_activity, personality_nervous)            0.49554         1 0.69056
# (musical_expertise, personality_trusting)       0.49575         1 0.69096
# (personality_nervous, personality_trusting)     0.50252         1 0.70473
# (personality_nervous, personality_stress)       0.51196         1 0.72426
# (personality_lazy, personality_trusting)        0.51266         1 0.72573
# (age, personality_trusting)                     0.51516         1 0.73098
# (personality_artistic, personality_stress)      0.51554         1 0.73176
# (song_familiarity, personality_nervous)         0.52026         1 0.74176
# (song_like_dislike, musical_expertise)          0.52466         1 0.74908
# (song_positivity, personality_trusting)         0.52556         1 0.75309
# (song_engagement, song_familiarity)             0.52587         1 0.74991
# (song_engagement, personality_trusting)         0.54359         1 0.79262
# (song_activity, personality_lazy)               0.55906         1 0.82785
# (age, personality_stress)                       0.56282         1 0.83661
# (song_activity, personality_reserved)           0.56541         1 0.84268
# (personality_reserved, personality_trusting)    0.56760         1 0.84784
# (personality_lazy, personality_stress)          0.57318         1 0.86113
# (song_familiarity, personality_lazy)            0.57896         1 0.87508
# (song_familiarity, personality_reserved)        0.59898         1 0.92498
# (song_activity, concentration)                  0.60684         1 0.94525
# (song_familiarity, personality_trusting)        0.60730         1 0.94647
# (song_activity, song_familiarity)               0.60794         1 0.94206
# (song_tension, personality_stress)              0.61427         1 0.96482
# (personality_stress, personality_thorough)      0.61753         1 0.97353
# (personality_reserved, personality_stress)      0.61776         1 0.97414
# (personality_stress, personality_trusting)      0.62704         1 0.99937
# (song_activity, song_tension)                   0.64295         1 1.03681
# (song_activity, musical_expertise)              0.65065         1 1.06238
# (song_engagement, musical_expertise)            0.65974         1 1.08930
# (concentration, personality_stress)             0.67654         1 1.14583
# (musical_expertise, personality_stress)         0.67664         1 1.14616
# (song_activity, personality_stress)             0.69606         1 1.21003
# (song_like_dislike, personality_stress)         0.70145         1 1.22851
# (song_activity, personality_trusting)           0.70181         1 1.22977
# (song_activity, song_positivity)                0.73337         1 1.33332
# (song_positivity, musical_expertise)            0.73601         1 1.34903
# (personality_nervous, personality_outgoing)     0.73828         1 1.36472
# (personality_artistic, personality_outgoing)    0.73941         1 1.36922
# (personality_outgoing, personality_reserved)    0.74478         1 1.39079
# (personality_lazy, personality_outgoing)        0.74650         1 1.39779
# (song_familiarity, personality_stress)          0.75439         1 1.43064
# (song_positivity, personality_stress)           0.75978         1 1.45365
# (personality_outgoing, personality_stress)      0.76740         1 1.48716
# (song_engagement, personality_stress)           0.76860         1 1.49256
# (song_tension, personality_outgoing)            0.76875         1 1.49323
# (personality_outgoing, personality_trusting)    0.77329         1 1.51384
# (song_activity, song_like_dislike)              0.77935         1 1.52611
# (age, personality_outgoing)                     0.78444         1 1.56636
# (personality_artistic, personality_imagination) 0.79461         1 1.61673
# (song_like_dislike, personality_outgoing)       0.80153         1 1.65250
# (personality_imagination, personality_trusting) 0.80902         1 1.69269
# (personality_outgoing, personality_thorough)    0.81364         1 1.71830
# (personality_imagination, personality_lazy)     0.81758         1 1.74061
# (personality_imagination, personality_thorough) 0.82007         1 1.75501
# (song_tension, personality_imagination)         0.82212         1 1.76702
# (age, personality_imagination)                  0.82361         1 1.77581
# (song_positivity, personality_outgoing)         0.82554         1 1.78735
# (concentration, personality_imagination)        0.83167         1 1.82485
# (song_activity, song_engagement)                0.83304         1 1.81099
# (song_engagement, personality_outgoing)         0.83940         1 1.87417
# (concentration, personality_outgoing)           0.84835         1 1.93444
# (song_positivity, personality_imagination)      0.85287         1 1.96629
# (song_activity, personality_outgoing)           0.85288         1 1.96630
# (personality_imagination, personality_stress)   0.85654         1 1.99286
# (song_familiarity, personality_imagination)     0.85813         1 2.00457
# (song_like_dislike, personality_imagination)    0.86178         1 2.03209
# (personality_imagination, personality_nervous)  0.86269         1 2.03899
# (song_familiarity, personality_outgoing)        0.86401         1 2.04921
# (song_familiarity, age)                         0.86675         1 2.04213
# (musical_expertise, personality_imagination)    0.86787         1 2.07962
# (age, musical_expertise)                        0.86875         1 2.06481
# (song_engagement, personality_imagination)      0.87358         1 2.12628
# (musical_expertise, personality_outgoing)       0.87603         1 2.14688
# (personality_imagination, personality_reserved) 0.87784         1 2.16251
# (song_tension, age)                             0.89528         1 2.28784
# (personality_imagination, personality_outgoing) 0.90944         1 2.48037
# (song_activity, personality_imagination)        0.91431         1 2.53930
# (song_positivity, age)                          0.94227         1 2.90538
# (song_activity, age)                            0.94793         1 3.01264
# (song_like_dislike, age)                        0.96834         1 3.53137
# (song_engagement, age)                          0.96993         1 3.58521
# (personality_fault, personality_thorough)       0.99848         1 7.08132
# (song_tension, personality_fault)               0.99851         1 7.11010
# (song_like_dislike, personality_fault)          0.99854         1 7.13629
# (age, personality_fault)                        0.99856         1 7.15195
# (personality_fault, personality_reserved)       0.99861         1 7.18931
# (personality_fault, personality_nervous)        0.99865         1 7.22426
# (personality_fault, personality_trusting)       0.99870         1 7.27418
# (song_positivity, personality_fault)            0.99871         1 7.27628
# (personality_artistic, personality_fault)       0.99873         1 7.29760
# (song_engagement, personality_fault)            0.99877         1 7.33310
# (concentration, personality_fault)              0.99877         1 7.33374
# (personality_fault, personality_lazy)           0.99900         1 7.58806
# (musical_expertise, personality_fault)          0.99906         1 7.66423
# (personality_fault, personality_stress)         0.99912         1 7.73250
# (song_activity, personality_fault)              0.99916         1 7.78799
# (personality_fault, personality_outgoing)       0.99919         1 7.83721
# (song_familiarity, personality_fault)           0.99928         1 7.98558
# (personality_fault, personality_imagination)    0.99943         1 8.27083
#
#                                                       T2 df1  df2      D2
# (song_tension, personality_artistic)             0.07508   2   75 0.00418
# (personality_artistic, personality_thorough)     0.08978   2   75 0.00500
# (song_tension, personality_thorough)             0.11769   2   75 0.00656
# (song_tension, concentration)                    0.20655   2   75 0.01151
# (concentration, personality_artistic)            0.26416   2   75 0.01472
# (song_familiarity, song_tension)                 0.27353   2  154 0.00733
# (concentration, personality_thorough)            0.27605   2   75 0.01538
# (personality_artistic, personality_nervous)      0.31504   2   75 0.01755
# (song_like_dislike, personality_artistic)        0.32624   2   75 0.01818
# (song_like_dislike, concentration)               0.34554   2   75 0.01925
# (song_tension, personality_nervous)              0.35541   2   75 0.01980
# (song_like_dislike, personality_thorough)        0.38562   2   75 0.02148
# (personality_artistic, personality_lazy)         0.38742   2   75 0.02159
# (personality_nervous, personality_thorough)      0.39322   2   75 0.02191
# (musical_expertise, personality_artistic)        0.39676   2   75 0.02211
# (musical_expertise, personality_thorough)        0.40132   2   75 0.02236
# (song_tension, personality_lazy)                 0.50487   2   75 0.02813
# (song_positivity, song_tension)                  0.54243   2  154 0.01454
# (musical_expertise, concentration)               0.55441   2   75 0.03089
# (personality_lazy, personality_nervous)          0.55488   2   75 0.03091
# (song_familiarity, song_positivity)              0.57319   2  154 0.01537
# (song_tension, personality_reserved)             0.60404   2   75 0.03365
# (personality_artistic, personality_reserved)     0.62323   2   75 0.03472
# (personality_nervous, personality_reserved)      0.62642   2   75 0.03490
# (song_positivity, personality_artistic)          0.62750   2   75 0.03496
# (song_positivity, concentration)                 0.64314   2   75 0.03583
# (song_positivity, personality_thorough)          0.65516   2   75 0.03650
# (song_like_dislike, personality_nervous)         0.65616   2   75 0.03656
# (personality_reserved, personality_thorough)     0.66340   2   75 0.03696
# (personality_lazy, personality_thorough)         0.66622   2   75 0.03712
# (concentration, personality_nervous)             0.67927   2   75 0.03785
# (concentration, personality_lazy)                0.70207   2   75 0.03912
# (age, personality_thorough)                      0.72013   2   75 0.04012
# (age, personality_artistic)                      0.72059   2   75 0.04015
# (song_engagement, concentration)                 0.75809   2   75 0.04224
# (song_like_dislike, personality_lazy)            0.77707   2   75 0.04329
# (song_engagement, personality_artistic)          0.79451   2   75 0.04427
# (song_familiarity, musical_expertise)            0.79647   2  104 0.03149
# (age, personality_nervous)                       0.80982   2   75 0.04512
# (song_engagement, personality_thorough)          0.81262   2   75 0.04527
# (musical_expertise, personality_nervous)         0.81547   2   75 0.04543
# (song_like_dislike, personality_reserved)        0.82384   2   75 0.04590
# (personality_lazy, personality_reserved)         0.84341   2   75 0.04699
# (age, concentration)                             0.87307   2   75 0.04864
# (musical_expertise, personality_reserved)        0.87839   2   75 0.04894
# (song_tension, musical_expertise)                0.88674   2  114 0.03177
# (musical_expertise, personality_lazy)            0.90317   2   75 0.05032
# (song_like_dislike, song_positivity)             0.89863   2  154 0.02409
# (concentration, personality_reserved)            0.91683   2   75 0.05108
# (song_like_dislike, song_tension)                0.93497   2  154 0.02507
# (song_positivity, personality_nervous)           0.96120   2   75 0.05355
# (personality_artistic, personality_trusting)     1.02011   2   75 0.05683
# (song_tension, personality_trusting)             1.03338   2   75 0.05757
# (song_positivity, personality_lazy)              1.04615   2   75 0.05829
# (age, personality_lazy)                          1.09145   2   75 0.06081
# (song_positivity, personality_reserved)          1.11340   2   75 0.06203
# (personality_thorough, personality_trusting)     1.12086   2   75 0.06245
# (song_familiarity, song_like_dislike)            1.16227   2  154 0.03116
# (song_familiarity, personality_artistic)         1.17590   2   75 0.06551
# (song_familiarity, personality_thorough)         1.18112   2   75 0.06580
# (song_engagement, personality_nervous)           1.19956   2   75 0.06683
# (song_like_dislike, personality_trusting)        1.19965   2   75 0.06684
# (age, personality_reserved)                      1.21052   2   75 0.06744
# (song_familiarity, concentration)                1.23226   2   75 0.06865
# (song_engagement, personality_lazy)              1.23680   2   75 0.06891
# (song_engagement, song_like_dislike)             1.23132   2  154 0.03301
# (song_engagement, song_positivity)               1.23710   2  154 0.03317
# (song_activity, personality_artistic)            1.28935   2   75 0.07184
# (concentration, personality_trusting)            1.29077   2   75 0.07191
# (song_engagement, personality_reserved)          1.30557   2   75 0.07274
# (song_activity, personality_thorough)            1.31076   2   75 0.07303
# (song_engagement, song_tension)                  1.31864   2  154 0.03535
# (song_activity, personality_nervous)             1.39953   2   75 0.07797
# (musical_expertise, personality_trusting)        1.40035   2   75 0.07802
# (personality_nervous, personality_trusting)      1.42826   2   75 0.07957
# (personality_nervous, personality_stress)        1.46784   2   75 0.08178
# (personality_lazy, personality_trusting)         1.47081   2   75 0.08195
# (age, personality_trusting)                      1.48144   2   75 0.08254
# (personality_artistic, personality_stress)       1.48304   2   75 0.08263
# (song_familiarity, personality_nervous)          1.50330   2   75 0.08376
# (song_like_dislike, musical_expertise)           1.51256   2  104 0.05981
# (song_positivity, personality_trusting)          1.52626   2   75 0.08503
# (song_engagement, song_familiarity)              1.50956   2  154 0.04047
# (song_engagement, personality_trusting)          1.60637   2   75 0.08950
# (song_activity, personality_lazy)                1.67778   2   75 0.09348
# (age, personality_stress)                        1.69554   2   75 0.09447
# (song_activity, personality_reserved)            1.70783   2   75 0.09515
# (personality_reserved, personality_trusting)     1.71829   2   75 0.09573
# (personality_lazy, personality_stress)           1.74522   2   75 0.09723
# (song_familiarity, personality_lazy)             1.77351   2   75 0.09881
# (song_familiarity, personality_reserved)         1.87462   2   75 0.10444
# (song_activity, concentration)                   1.91570   2   75 0.10673
# (song_familiarity, personality_trusting)         1.91817   2   75 0.10687
# (song_activity, song_familiarity)                1.89635   2  154 0.05084
# (song_tension, personality_stress)               1.95536   2   75 0.10894
# (personality_stress, personality_thorough)       1.97303   2   75 0.10993
# (personality_reserved, personality_stress)       1.97426   2   75 0.10999
# (personality_stress, personality_trusting)       2.02539   2   75 0.11284
# (song_activity, song_tension)                    2.08708   2  154 0.05595
# (song_activity, musical_expertise)               2.14519   2  104 0.08482
# (song_engagement, musical_expertise)             2.19955   2  104 0.08697
# (concentration, personality_stress)              2.32222   2   75 0.12938
# (musical_expertise, personality_stress)          2.32289   2   75 0.12942
# (song_activity, personality_stress)              2.45234   2   75 0.13663
# (song_like_dislike, personality_stress)          2.48978   2   75 0.13872
# (song_activity, personality_trusting)            2.49232   2   75 0.13886
# (song_activity, song_positivity)                 2.68395   2  154 0.07196
# (song_positivity, musical_expertise)             2.72400   2  104 0.10771
# (personality_nervous, personality_outgoing)      2.76582   2   75 0.15410
# (personality_artistic, personality_outgoing)     2.77495   2   75 0.15460
# (personality_outgoing, personality_reserved)     2.81866   2   75 0.15704
# (personality_lazy, personality_outgoing)         2.83286   2   75 0.15783
# (song_familiarity, personality_stress)           2.89944   2   75 0.16154
# (song_positivity, personality_stress)            2.94606   2   75 0.16414
# (personality_outgoing, personality_stress)       3.01397   2   75 0.16792
# (song_engagement, personality_stress)            3.02493   2   75 0.16853
# (song_tension, personality_outgoing)             3.02627   2   75 0.16861
# (personality_outgoing, personality_trusting)     3.06805   2   75 0.17093
# (song_activity, song_like_dislike)               3.07204   2  154 0.08236
# (age, personality_outgoing)                      3.17448   2   75 0.17686
# (personality_artistic, personality_imagination)  3.27658   2   75 0.18255
# (song_like_dislike, personality_outgoing)        3.34906   2   75 0.18659
# (personality_imagination, personality_trusting)  3.43052   2   75 0.19113
# (personality_outgoing, personality_thorough)     3.48242   2   75 0.19402
# (personality_imagination, personality_lazy)      3.52763   2   75 0.19654
# (personality_imagination, personality_thorough)  3.55681   2   75 0.19817
# (song_tension, personality_imagination)          3.58116   2   75 0.19952
# (age, personality_imagination)                   3.59897   2   75 0.20051
# (song_positivity, personality_outgoing)          3.62236   2   75 0.20182
# (concentration, personality_imagination)         3.69836   2   75 0.20605
# (song_activity, song_engagement)                 3.64550   2  154 0.09774
# (song_engagement, personality_outgoing)          3.79832   2   75 0.21162
# (concentration, personality_outgoing)            3.92046   2   75 0.21843
# (song_positivity, personality_imagination)       3.98501   2   75 0.22202
# (song_activity, personality_outgoing)            3.98504   2   75 0.22202
# (personality_imagination, personality_stress)    4.03887   2   75 0.22502
# (song_familiarity, personality_imagination)      4.06259   2   75 0.22634
# (song_like_dislike, personality_imagination)     4.11837   2   75 0.22945
# (personality_imagination, personality_nervous)   4.13236   2   75 0.23023
# (song_familiarity, personality_outgoing)         4.15306   2   75 0.23138
# (song_familiarity, age)                          4.11077   2  154 0.11021
# (musical_expertise, personality_imagination)     4.21469   2   75 0.23482
# (age, musical_expertise)                         4.16346   2  122 0.13975
# (song_engagement, personality_imagination)       4.30926   2   75 0.24009
# (musical_expertise, personality_outgoing)        4.35102   2   75 0.24241
# (personality_imagination, personality_reserved)  4.38268   2   75 0.24418
# (song_tension, age)                              4.60359   2  164 0.11533
# (personality_imagination, personality_outgoing)  5.02689   2   75 0.28007
# (song_activity, personality_imagination)         5.14631   2   75 0.28672
# (song_positivity, age)                           5.84849   2  154 0.15680
# (song_activity, age)                             6.06440   2  154 0.16259
# (song_like_dislike, age)                         7.10861   2  154 0.19058
# (song_engagement, age)                           7.21699   2  154 0.19349
# (personality_fault, personality_thorough)       14.35148   2   75 0.79958
# (song_tension, personality_fault)               14.40980   2   75 0.80283
# (song_like_dislike, personality_fault)          14.46288   2   75 0.80579
# (age, personality_fault)                        14.49463   2   75 0.80756
# (personality_fault, personality_reserved)       14.57034   2   75 0.81178
# (personality_fault, personality_nervous)        14.64116   2   75 0.81572
# (personality_fault, personality_trusting)       14.74235   2   75 0.82136
# (song_positivity, personality_fault)            14.74660   2   75 0.82160
# (personality_artistic, personality_fault)       14.78980   2   75 0.82400
# (song_engagement, personality_fault)            14.86175   2   75 0.82801
# (concentration, personality_fault)              14.86304   2   75 0.82808
# (personality_fault, personality_lazy)           15.37847   2   75 0.85680
# (musical_expertise, personality_fault)          15.53285   2   75 0.86540
# (personality_fault, personality_stress)         15.67120   2   75 0.87311
# (song_activity, personality_fault)              15.78367   2   75 0.87938
# (personality_fault, personality_outgoing)       15.88341   2   75 0.88493
# (song_familiarity, personality_fault)           16.18411   2   75 0.90169
# (personality_fault, personality_imagination)    16.76221   2   75 0.93389

# %%
if results[results.adjustedP <= alpha].shape[0] > 0:
    for pair in results.index.values[0:3]:
        g = sns.FacetGrid(df_all[[pair[0], pair[1], 'critical_reaction']], col='critical_reaction', height=6, aspect=1, margin_titles=True)
        g.map(sns.kdeplot, pair[0], pair[1], cmap='Reds', shade=True, shade_lowest=False, alpha=0.65)
        g.savefig('hallelujah_reaction_distributions_{}_{}_{}_by_reaction.pdf'.format(notebook_song_name, pair[0], pair[1]))
else:
    print('No significant results to plot')
# Out:
# No significant results to plot
