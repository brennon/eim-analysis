# %% [markdown]
# # "Hallelujah Effect" Analysis
#
# This notebook models the "Hallelujah Effect" in terms of all basic features available in the dataset for those subjects that listened to the song and had an EDA quality >80%.

# %%
# %bash
pip uninstall -y google-cloud-dataflow
pip install --upgrade --force tensorflow_transform==0.6.0 apache-beam[gcp]

# %% [markdown]
# <b>Restart the kernel</b> after you do a pip install (click on the <b>Reset</b> button in Datalab)

# %%
# %bash
pip freeze | grep -e 'flow\|beam'
# Out:
# apache-airflow==1.9.0
# apache-beam==2.5.0
# tensorflow==1.8.0
# tensorflow-transform==0.6.0
# You are using pip version 9.0.3, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import tensorflow as tf
import tensorflow_transform as tft
import shutil
print(tf.__version__)
# Out:
# 1.8.0
# /usr/local/envs/py2env/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# Set bucket, project, and region
BUCKET = 'eim-muse'
PROJECT = 'eim-muse'
REGION = 'us-central1'

# %%
import os
os.environ['BUCKET'] = BUCKET
os.environ['PROJECT'] = PROJECT
os.environ['REGION'] = REGION

# %%
# %bash
gcloud config set project $PROJECT
gcloud config set compute/region $REGION
# Out:
# Updated property [core/project].
# Updated property [compute/region].

# %% [markdown]
# ## Retrieve and Subset Datasource
#
# Get data from BigQuery but defer filtering, etc. to Beam. Data in BigQuery has been pre-processed with Dataprep.

# %%
import google.datalab.bigquery as bq
def create_query(phase, EVERY_N):
  """
  phase: 1=train 2=valid
  """
  base_query = """
SELECT *
FROM
  `eim-muse.hallelujah_effect.full_hallelujah_trials_cleaned`
  """

  if EVERY_N == None:
    if phase < 2:
      # Training
      query = "{0} WHERE MOD(FARM_FINGERPRINT(id), 10) < 7".format(base_query)
    else:
      # Validation
      query = "{0} WHERE MOD(FARM_FINGERPRINT(id), 10) >= 7".format(base_query)
  else:
      query = "{0} WHERE MOD(FARM_FINGERPRINT(id), {1}) = {2}".format(base_query, EVERY_N, phase)
    
  return query

query = create_query(1, None)

# %%
df_valid = bq.Query(query).execute().result().to_dataframe()
df_valid.head()
df_valid.describe()
# Out:
#               age  concentration  musical_expertise    artistic       fault  \
# count  303.000000     303.000000         303.000000  303.000000  303.000000
# mean    24.726073       3.993500           2.547224    2.344099    3.175612
# std     13.931034       0.795258           1.009324    0.988361    0.891464
# min      1.000000       1.000000           1.000000    1.000000    1.000000
# 25%     16.000000       3.991266           2.000000    2.000000    3.000000
# 50%     21.000000       3.991266           2.529880    2.353712    3.144737
# 75%     31.000000       4.000000           3.000000    2.353712    4.000000
# max    121.000000       5.000000           5.000000    5.000000    5.000000
#
#        imagination        lazy     nervous    outgoing    reserved  \
# count   303.000000  303.000000  303.000000  303.000000  303.000000
# mean      3.852643    3.690403    3.629726    3.213016    3.145503
# std       0.821620    0.905895    0.875898    0.961299    0.891699
# min       1.000000    1.000000    1.000000    1.000000    1.000000
# 25%       3.824561    3.659389    3.596491    3.000000    3.000000
# 50%       3.824561    3.659389    3.596491    3.228070    3.117904
# 75%       4.000000    4.000000    4.000000    4.000000    4.000000
# max       5.000000    5.000000    5.000000    5.000000    5.000000
#
#                    ...               music_pref_none  music_pref_hiphop  \
# count              ...                    303.000000         303.000000
# mean               ...                      0.006601           0.138614
# std                ...                      0.081110           0.346115
# min                ...                      0.000000           0.000000
# 25%                ...                      0.000000           0.000000
# 50%                ...                      0.000000           0.000000
# 75%                ...                      0.000000           0.000000
# max                ...                      1.000000           1.000000
#
#        music_pref_dance  music_pref_world  music_pref_rock  music_pref_pop  \
# count        303.000000        303.000000       303.000000      303.000000
# mean           0.188119          0.132013         0.432343        0.673267
# std            0.391454          0.339065         0.496221        0.469794
# min            0.000000          0.000000         0.000000        0.000000
# 25%            0.000000          0.000000         0.000000        0.000000
# 50%            0.000000          0.000000         0.000000        1.000000
# 75%            0.000000          0.000000         1.000000        1.000000
# max            1.000000          1.000000         1.000000        1.000000
#
#        music_pref_classical  music_pref_jazz  music_pref_folk  \
# count            303.000000       303.000000       303.000000
# mean               0.306931         0.171617         0.089109
# std                0.461983         0.377671         0.285372
# min                0.000000         0.000000         0.000000
# 25%                0.000000         0.000000         0.000000
# 50%                0.000000         0.000000         0.000000
# 75%                1.000000         0.000000         0.000000
# max                1.000000         1.000000         1.000000
#
#        music_pref_traditional_irish
# count                    303.000000
# mean                       0.059406
# std                        0.236774
# min                        0.000000
# 25%                        0.000000
# 50%                        0.000000
# 75%                        0.000000
# max                        1.000000
#
# [8 rows x 29 columns]

# %%
train_query = create_query(1, None)
train_n = len(list(bq.Query(train_query).execute().result()))

eval_query = create_query(2, None)
eval_n = len(list(bq.Query(eval_query).execute().result()))

os.environ['TRAIN_N'] = str(train_n)
os.environ['EVAL_N'] = str(eval_n)

print('{} training examples / {} evaluation examples'.format(train_n, eval_n))
# Out:
# 303 training examples / 61 evaluation examples

# %%
df_valid.columns
# Out:
# Index([u'id', u'age', u'concentration', u'hearing_impairments',
#        u'musical_expertise', u'nationality', u'artistic', u'fault',
#        u'imagination', u'lazy', u'nervous', u'outgoing', u'reserved',
#        u'stress', u'thorough', u'trusting', u'activity', u'engagement',
#        u'familiarity', u'like_dislike', u'positivity', u'tension', u'sex',
#        u'hallelujah_reaction', u'location', u'language', u'music_pref_none',
#        u'music_pref_hiphop', u'music_pref_dance', u'music_pref_world',
#        u'music_pref_rock', u'music_pref_pop', u'music_pref_classical',
#        u'music_pref_jazz', u'music_pref_folk',
#        u'music_pref_traditional_irish'],
#       dtype='object')

# %% [markdown]
# ## Create ML dataset using tf.transform and Dataflow
#
# Let's use Cloud Dataflow to read in the BigQuery data and write it out as CSV files. Along the way, let's use tf.transform to do scaling and transforming. Using tf.transform allows us to save the metadata to ensure that the appropriate transformations get carried out during prediction as well.

# %%
# %writefile requirements.txt
tensorflow-transform==0.6.0
# Out:
# Overwriting requirements.txt

# %%
import datetime
import tensorflow as tf
import apache_beam as beam
import tensorflow_transform as tft
from tensorflow_transform.beam import impl as beam_impl

def is_valid(inputs):
    try:
        return True
    except:
        return False

float_features = [
    'activity',
    'age',
    'artistic',
    'concentration',
    'engagement',
    'familiarity',
    'fault',
    'imagination',
    'lazy',
    'like_dislike',
    'musical_expertise',
    'nervous',
    'outgoing',
    'positivity',
    'reserved',
    'stress',
    'tension',
    'thorough',
    'trusting'
]

boolean_features = [
    'hallelujah_reaction',
    'hearing_impairments',
    'music_pref_classical',
    'music_pref_dance',
    'music_pref_folk',
    'music_pref_hiphop',
    'music_pref_jazz',
    'music_pref_none',
    'music_pref_pop',
    'music_pref_rock',
    'music_pref_traditional_irish',
    'music_pref_world'
]

categorical_features = [
    'language',
    'location',
    'nationality',
    'sex'
]

def preprocess_tft(inputs):
    import datetime
    result = {}
    
    for feature in float_features:
        result[feature] = tft.scale_to_0_1(inputs[feature])
    
    for feature in boolean_features:
        result[feature] = tf.cast(inputs[feature], tf.int64)
    
    for feature in categorical_features:
        result[feature] = tf.identity(inputs[feature])
    
    return result

def preprocess(in_test_mode, EVERY_N=None):
  import os
  import os.path
  import tempfile
  from apache_beam.io import tfrecordio
  from tensorflow_transform.coders import example_proto_coder
  from tensorflow_transform.tf_metadata import dataset_metadata
  from tensorflow_transform.tf_metadata import dataset_schema
  from tensorflow_transform.beam import tft_beam_io
  from tensorflow_transform.beam.tft_beam_io import transform_fn_io

  job_name = 'hallelujah-effect-features' + '-' + datetime.datetime.now().strftime('%y%m%d-%H%M%S')    
  if in_test_mode:
    import shutil
    print 'Launching local job ... hang on'
    OUTPUT_DIR = './preproc_tft'
    shutil.rmtree(OUTPUT_DIR, ignore_errors=True)
    
  else:
    print 'Launching Dataflow job {} ... hang on'.format(job_name)
    OUTPUT_DIR = 'gs://{0}/analysis/hallelujah-effect/preproc_tft/'.format(BUCKET)
    import subprocess
    subprocess.call('gsutil rm -r {}'.format(OUTPUT_DIR).split())
  
  # Configure Beam pipeline options
  options = {
    'staging_location': os.path.join(OUTPUT_DIR, 'tmp', 'staging'),
    'temp_location': os.path.join(OUTPUT_DIR, 'tmp'),
    'job_name': job_name,
    'project': PROJECT,
    'max_num_workers': 24,
    'teardown_policy': 'TEARDOWN_ALWAYS',
    'no_save_main_session': True,
    'requirements_file': 'requirements.txt'
  }
  opts = beam.pipeline.PipelineOptions(flags=[], **options)
  if in_test_mode:
    RUNNER = 'DirectRunner'
  else:
    RUNNER = 'DataflowRunner'

  # Setup metadata
  raw_data_schema = {
    colname : dataset_schema.ColumnSchema(tf.string, [], dataset_schema.FixedColumnRepresentation())
                   for colname in categorical_features
  }
  raw_data_schema.update({
      colname : dataset_schema.ColumnSchema(tf.float32, [], dataset_schema.FixedColumnRepresentation())
                   for colname in float_features
    })
  raw_data_schema.update({
      colname : dataset_schema.ColumnSchema(tf.int64, [], dataset_schema.FixedColumnRepresentation())
                   for colname in boolean_features
    })
  raw_data_metadata = dataset_metadata.DatasetMetadata(dataset_schema.Schema(raw_data_schema))
  
  # run Beam  
  with beam.Pipeline(RUNNER, options=opts) as p:
    with beam_impl.Context(temp_dir=os.path.join(OUTPUT_DIR, 'tmp')):
      
      # Write the raw data metadata to disk
      # Without the overloaded operators: p.apply(tft_beam_io.WriteMetadata(os.path.join(OUTPUT_DIR, 'metadata/rawdata_metadata'), raw_data_metadata)
      _ = (raw_data_metadata
        | 'WriteInputMetadata' >> tft_beam_io.WriteMetadata(
            os.path.join(OUTPUT_DIR, 'metadata/rawdata_metadata'),
            pipeline=p))
           
      # Analyze and transform training data
      this_query = create_query(1, EVERY_N)
      
      # Read in training data from BigQuery table
      raw_data = (p
        # Get raw training data from BigQuery
        | 'train_read' >> beam.io.Read(beam.io.BigQuerySource(query=this_query, use_standard_sql=True))
        # Use our is_valid function to only retain valid examples from training data
        | 'train_filter' >> beam.Filter(is_valid))

      # Package raw training data and its metadata into a 'dataset'
      raw_dataset = (raw_data, raw_data_metadata)
      
      # Using the preprocessing function `preprocess_tft`, preprocess the training data
      # and produce a transformed training dataset and a function to transform other data later
      transformed_dataset, transform_fn = (
          raw_dataset | beam_impl.AnalyzeAndTransformDataset(preprocess_tft))
      
      # Break out the transformed training data and its metadata
      transformed_data, transformed_metadata = transformed_dataset
      
      # Write the transformed training data to files
      _ = transformed_data | 'WriteTrainData' >> tfrecordio.WriteToTFRecord(
          os.path.join(OUTPUT_DIR, 'train'),
          file_name_suffix='.gz',
          coder=example_proto_coder.ExampleProtoCoder(
              transformed_metadata.schema))
      
      # Read in test data from BigQuery table and filter as we did with training data
      raw_test_data = (p 
        | 'eval_read' >> beam.io.Read(beam.io.BigQuerySource(query=create_query(2, EVERY_N), use_standard_sql=True))
        | 'eval_filter' >> beam.Filter(is_valid))
      
      # Package test data and metadata into a dataset
      raw_test_dataset = (raw_test_data, raw_data_metadata)
      
      # Using the same transformation function that was calculated above, transform the test dataset
      transformed_test_dataset = (
          (raw_test_dataset, transform_fn) | beam_impl.TransformDataset())
      
      # Write the transformed test data to files
      transformed_test_data, _ = transformed_test_dataset
      _ = transformed_test_data | 'WriteTestData' >> tfrecordio.WriteToTFRecord(
          os.path.join(OUTPUT_DIR, 'eval'),
          file_name_suffix='.gz',
          coder=example_proto_coder.ExampleProtoCoder(
              transformed_metadata.schema))
      
      # Write the transformation function to a file, as well
      _ = (transform_fn
           | 'WriteTransformFn' >>
           transform_fn_io.WriteTransformFn(os.path.join(OUTPUT_DIR, 'metadata')))

# Preprocess the training/test data
preprocess(in_test_mode=True, EVERY_N=None)
# Out:
# Launching local job ... hang on
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./preproc_tft/tmp/tftransform_tmp/33b3c2175e674342acec8a75679a7e15/saved_model.pb
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./preproc_tft/tmp/tftransform_tmp/742f34884e704beaa5527063033984b5/saved_model.pb
# /usr/local/envs/py2env/lib/python2.7/site-packages/apache_beam/runners/direct/direct_runner.py:342: DeprecationWarning: options is deprecated since First stable release.. References to <pipeline>.options will not be supported
#   pipeline.replace_all(_get_transform_overrides(pipeline.options))
# WARNING:root:Dataset eim-muse:temp_dataset_d388b9dfd4664f1588005e30b27fb04f does not exist so we will create it as temporary with location=None
# WARNING:root:Dataset eim-muse:temp_dataset_addcbab71da7437b936ef9f3bac31633 does not exist so we will create it as temporary with location=None
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./preproc_tft/tmp/tftransform_tmp/a37f0c49ef7e46c99f70b715d910eab3/saved_model.pb
# INFO:tensorflow:SavedModel written to: ./preproc_tft/tmp/tftransform_tmp/a37f0c49ef7e46c99f70b715d910eab3/saved_model.pb
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-09 02:13:07.797008. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
# %bash
ls -ls preproc_tft
ls -ls preproc_tft/metadata
# gsutil ls -l gs://${BUCKET}/analysis/hallelujah-effect/preproc_tft/
# gsutil ls -l gs://${BUCKET}/analysis/hallelujah-effect/preproc_tft/metadata
# Out:
# total 24
#  4 -rw-r--r-- 1 root root  3059 Jul  9 02:13 eval-00000-of-00001.gz
#  4 drwxr-xr-x 5 root root  4096 Jul  9 02:13 metadata
#  4 drwxr-xr-x 3 root root  4096 Jul  9 02:13 tmp
# 12 -rw-r--r-- 1 root root 11622 Jul  9 02:13 train-00000-of-00001.gz
# total 12
# 4 drwxr-xr-x 3 root root 4096 Jul  9 02:13 rawdata_metadata
# 4 drwxr-xr-x 3 root root 4096 Jul  9 02:13 transformed_metadata
# 4 drwxr-xr-x 3 root root 4096 Jul  9 02:13 transform_fn

# %% [markdown]
# <h2> Train off preprocessed data </h2>

# %% [markdown]
# ### Local Manual Training

# %%
MODEL_NAME = 'basic_features'
os.environ['MODEL_NAME'] = MODEL_NAME

# %%
# %%bash
#
# OUTPUT_DIR=${PWD}/../models/${MODEL_NAME}
# rm -rf ${OUTPUT_DIR}
# export PYTHONPATH=${PYTHONPATH}:${PWD}/trainer
# python -m trainer.task \
#    --train_data_paths="${PWD}/preproc_tft/train*" \
#    --eval_data_paths="${PWD}/preproc_tft/eval*" \
#    --train_steps=25000 \
#    --train_batch_size=${TRAIN_N} \
#    --eval_steps=1 \
#    --output_dir=${OUTPUT_DIR} \
#    --job-dir=/tmp \
#    --metadata_path="${PWD}/preproc_tft/metadata"
# Out:
# /usr/local/envs/py2env/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 90, '_session_config': None, '_keep_checkpoint_max': 10, '_task_type': 'worker', '_train_distribute': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f353f970e50>, '_evaluation_master': '', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': '/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features', '_global_id_in_cluster': 0, '_save_summary_steps': 100}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 5 secs (eval_spec.throttle_secs) or training is finished.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow_transform/saved/input_fn_maker.py:557: read_batch_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:833: read_keyed_batch_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:542: read_keyed_batch_examples (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:550: queue_parsed_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# 2018-07-09 02:16:36.180602: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:loss = 200.29968, step = 1
# INFO:tensorflow:global_step/sec: 112.747
# INFO:tensorflow:loss = 168.70706, step = 101 (0.887 sec)
# INFO:tensorflow:global_step/sec: 92.5174
# INFO:tensorflow:loss = 155.99562, step = 201 (1.080 sec)
# INFO:tensorflow:global_step/sec: 140.356
# INFO:tensorflow:loss = 145.67995, step = 301 (0.713 sec)
# INFO:tensorflow:Saving checkpoints for 384 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:Loss for final step: 153.25093.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-09-02:16:42
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-384
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-09-02:16:43
# INFO:tensorflow:Saving dict for global step 384: accuracy = 0.6721311, accuracy_baseline = 0.6721312, auc = 0.5914635, auc_precision_recall = 0.37709624, average_loss = 0.6492189, global_step = 384, label/mean = 0.32786885, loss = 39.602352, precision = 0.0, prediction/mean = 0.23917192, recall = 0.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-384
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/export/exporter/temp-1531102604/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-384
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 385 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:loss = 147.45386, step = 385
# INFO:tensorflow:global_step/sec: 66.6104
# INFO:tensorflow:loss = 140.84633, step = 485 (1.501 sec)
# INFO:tensorflow:global_step/sec: 152.423
# INFO:tensorflow:loss = 143.51773, step = 585 (0.656 sec)
# INFO:tensorflow:global_step/sec: 155.488
# INFO:tensorflow:loss = 145.6718, step = 685 (0.643 sec)
# INFO:tensorflow:Saving checkpoints for 732 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:Loss for final step: 135.66612.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-09-02:16:52
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-732
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-09-02:16:53
# INFO:tensorflow:Saving dict for global step 732: accuracy = 0.6721311, accuracy_baseline = 0.6721312, auc = 0.57500005, auc_precision_recall = 0.35292786, average_loss = 0.67100114, global_step = 732, label/mean = 0.32786885, loss = 40.93107, precision = 0.0, prediction/mean = 0.22289464, recall = 0.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-732
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/export/exporter/temp-1531102613/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-732
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 733 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:loss = 137.23372, step = 733
# INFO:tensorflow:global_step/sec: 76.1828
# INFO:tensorflow:loss = 143.22101, step = 833 (1.313 sec)
# INFO:tensorflow:global_step/sec: 136.803
# INFO:tensorflow:loss = 149.67456, step = 933 (0.731 sec)
# INFO:tensorflow:global_step/sec: 138.967
# INFO:tensorflow:loss = 126.68894, step = 1033 (0.719 sec)
# INFO:tensorflow:Saving checkpoints for 1119 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:Loss for final step: 141.40607.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-09-02:17:01
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-1119
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-09-02:17:02
# INFO:tensorflow:Saving dict for global step 1119: accuracy = 0.6557377, accuracy_baseline = 0.6721312, auc = 0.567683, auc_precision_recall = 0.34722325, average_loss = 0.6947494, global_step = 1119, label/mean = 0.32786885, loss = 42.379715, precision = 0.0, prediction/mean = 0.21257606, recall = 0.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-1119
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/export/exporter/temp-1531102623/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-1119
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1120 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:loss = 132.99782, step = 1120
# INFO:tensorflow:global_step/sec: 111.957
# INFO:tensorflow:loss = 132.67052, step = 1220 (0.894 sec)
# INFO:tensorflow:global_step/sec: 88.5582
# INFO:tensorflow:loss = 135.66235, step = 1320 (1.130 sec)
# INFO:tensorflow:global_step/sec: 151.76
# INFO:tensorflow:loss = 131.74876, step = 1420 (0.657 sec)
# INFO:tensorflow:Saving checkpoints for 1507 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:Loss for final step: 128.60405.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-09-02:17:10
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-1507
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-09-02:17:11
# INFO:tensorflow:Saving dict for global step 1507: accuracy = 0.6557377, accuracy_baseline = 0.6721312, auc = 0.5579269, auc_precision_recall = 0.33269557, average_loss = 0.7161532, global_step = 1507, label/mean = 0.32786885, loss = 43.685345, precision = 0.0, prediction/mean = 0.20407952, recall = 0.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-1507
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/export/exporter/temp-1531102632/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-1507
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1508 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:loss = 133.23157, step = 1508
# INFO:tensorflow:global_step/sec: 124.975
# INFO:tensorflow:loss = 140.41507, step = 1608 (0.800 sec)
# INFO:tensorflow:global_step/sec: 85.9615
# INFO:tensorflow:loss = 121.51206, step = 1708 (1.163 sec)
# INFO:tensorflow:global_step/sec: 131.38
# INFO:tensorflow:loss = 107.360054, step = 1808 (0.761 sec)
# INFO:tensorflow:Saving checkpoints for 1889 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:Loss for final step: 120.03554.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-09-02:17:20
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-1889
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-09-02:17:21
# INFO:tensorflow:Saving dict for global step 1889: accuracy = 0.6393443, accuracy_baseline = 0.6721312, auc = 0.5603659, auc_precision_recall = 0.3327666, average_loss = 0.7362608, global_step = 1889, label/mean = 0.32786885, loss = 44.911907, precision = 0.0, prediction/mean = 0.19778557, recall = 0.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-1889
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/export/exporter/temp-1531102641/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-1889
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1890 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:loss = 119.861435, step = 1890
# INFO:tensorflow:global_step/sec: 70.4327
# INFO:tensorflow:loss = 117.865425, step = 1990 (1.420 sec)
# INFO:tensorflow:global_step/sec: 140.729
# INFO:tensorflow:loss = 119.136055, step = 2090 (0.710 sec)
# INFO:tensorflow:global_step/sec: 140.964
# INFO:tensorflow:loss = 110.99491, step = 2190 (0.709 sec)
# INFO:tensorflow:Saving checkpoints for 2260 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:Loss for final step: 113.30709.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-09-02:17:29
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-2260
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-09-02:17:30
# INFO:tensorflow:Saving dict for global step 2260: accuracy = 0.6393443, accuracy_baseline = 0.6721312, auc = 0.5554879, auc_precision_recall = 0.33126956, average_loss = 0.757857, global_step = 2260, label/mean = 0.32786885, loss = 46.22928, precision = 0.0, prediction/mean = 0.19159406, recall = 0.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-2260
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/export/exporter/temp-1531102651/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-2260
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2261 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:loss =
into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:loss = 6.8720922, step = 23977
# INFO:tensorflow:global_step/sec: 113.097
# INFO:tensorflow:loss = 10.396403, step = 24077 (0.885 sec)
# INFO:tensorflow:global_step/sec: 87.2443
# INFO:tensorflow:loss = 11.380329, step = 24177 (1.146 sec)
# INFO:tensorflow:global_step/sec: 137.266
# INFO:tensorflow:loss = 9.831581, step = 24277 (0.728 sec)
# INFO:tensorflow:Saving checkpoints for 24360 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:Loss for final step: 9.142531.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-09-02:26:35
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-24360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-09-02:26:36
# INFO:tensorflow:Saving dict for global step 24360: accuracy = 0.60655737, accuracy_baseline = 0.6721312, auc = 0.5067073, auc_precision_recall = 0.31237465, average_loss = 1.9273112, global_step = 24360, label/mean = 0.32786885, loss = 117.56598, precision = 0.25, prediction/mean = 0.1473432, recall = 0.1
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-24360
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/export/exporter/temp-1531103197/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-24360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 24361 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:loss = 8.984737, step = 24361
# INFO:tensorflow:global_step/sec: 76.1898
# INFO:tensorflow:loss = 8.535293, step = 24461 (1.312 sec)
# INFO:tensorflow:global_step/sec: 138.319
# INFO:tensorflow:loss = 8.452546, step = 24561 (0.723 sec)
# INFO:tensorflow:global_step/sec: 139.52
# INFO:tensorflow:loss = 8.754515, step = 24661 (0.717 sec)
# INFO:tensorflow:Saving checkpoints for 24717 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:Loss for final step: 9.750108.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-09-02:26:45
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-24717
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-09-02:26:46
# INFO:tensorflow:Saving dict for global step 24717: accuracy = 0.60655737, accuracy_baseline = 0.6721312, auc = 0.5067073, auc_precision_recall = 0.3083932, average_loss = 1.9393253, global_step = 24717, label/mean = 0.32786885, loss = 118.29884, precision = 0.25, prediction/mean = 0.1467825, recall = 0.1
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-24717
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/export/exporter/temp-1531103206/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-24717
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 24718 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:loss = 9.12041, step = 24718
# INFO:tensorflow:global_step/sec: 80.878
# INFO:tensorflow:loss = 9.252522, step = 24818 (1.236 sec)
# INFO:tensorflow:global_step/sec: 154.099
# INFO:tensorflow:loss = 6.6392035, step = 24918 (0.649 sec)
# INFO:tensorflow:Saving checkpoints for 25000 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:Loss for final step: 7.7822905.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-09-02:26:53
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-25000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-09-02:26:54
# INFO:tensorflow:Saving dict for global step 25000: accuracy = 0.60655737, accuracy_baseline = 0.6721312, auc = 0.5054878, auc_precision_recall = 0.30782944, average_loss = 1.9519312, global_step = 25000, label/mean = 0.32786885, loss = 119.0678, precision = 0.25, prediction/mean = 0.14571334, recall = 0.1
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-25000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/export/exporter/temp-1531103215/saved_model.pb
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-09 02:16:32.317003. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %% [markdown]
# Results for 25000 batches of 303 cases (25000 training epochs):
#
# - Accuracy = 0.60655737
# - Accuracy baseline = 0.6721312
# - AUC = 0.5054878
# - AUC-PR = 0.30782944
# - Average loss = 1.9519312
# - F1 score = 0.142857143
# - Label/mean = 0.32786885
# - Loss = 119.0678
# - Precision = 0.25
# - Prediction/mean = 0.14571334
# - Recall = 0.1

# %% [markdown]
# ### Local ML Engine Training

# %%
# %%bash
#
# OUTPUT_DIR=${PWD}/../models/${MODEL_NAME}
# rm -rf $OUTPUT_DIR
# gcloud ml-engine local train \
#    --module-name=trainer.task \
#    --package-path=${PWD}/trainer/trainer \
#    --job-dir=$OUTPUT_DIR \
#    -- \
#    --train_data_paths="${PWD}/preproc_tft/train*" \
#    --eval_data_paths="${PWD}/preproc_tft/eval*" \
#    --train_steps=25000 \
#    --train_batch_size=${TRAIN_N} \
#    --eval_steps=1 \
#    --output_dir=$OUTPUT_DIR \
#    --metadata_path="${PWD}/preproc_tft/metadata/"
# Out:
# /usr/local/envs/py2env/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:tensorflow:TF_CONFIG environment variable: {u'environment': u'cloud', u'cluster': {}, u'job': {u'args': [u'--train_data_paths=/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/preproc_tft/train*', u'--eval_data_paths=/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/preproc_tft/eval*', u'--train_steps=25000', u'--train_batch_size=303', u'--eval_steps=1', u'--output_dir=/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features', u'--metadata_path=/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/preproc_tft/metadata/', u'--job-dir', u'/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features'], u'job_name': u'trainer.task'}, u'task': {}}
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 90, '_session_config': None, '_keep_checkpoint_max': 10, '_task_type': 'worker', '_train_distribute': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fc036427690>, '_evaluation_master': '', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': '/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features', '_global_id_in_cluster': 0, '_save_summary_steps': 100}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 5 secs (eval_spec.throttle_secs) or training is finished.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow_transform/saved/input_fn_maker.py:557: read_batch_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:833: read_keyed_batch_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:542: read_keyed_batch_examples (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:550: queue_parsed_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# 2018-07-09 02:49:51.870429: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:loss = 208.70773, step = 1
# INFO:tensorflow:global_step/sec: 77.327
# INFO:tensorflow:loss = 175.65717, step = 101 (1.294 sec)
# INFO:tensorflow:global_step/sec: 143.035
# INFO:tensorflow:loss = 165.22826, step = 201 (0.698 sec)
# INFO:tensorflow:global_step/sec: 145.614
# INFO:tensorflow:loss = 170.12369, step = 301 (0.687 sec)
# INFO:tensorflow:Saving checkpoints for 375 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:Loss for final step: 155.12549.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-09-02:49:58
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-375
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-09-02:49:59
# INFO:tensorflow:Saving dict for global step 375: accuracy = 0.6721311, accuracy_baseline = 0.6721312, auc = 0.5225611, auc_precision_recall = 0.36398426, average_loss = 0.6519476, global_step = 375, label/mean = 0.32786885, loss = 39.768806, precision = 0.0, prediction/mean = 0.24871169, recall = 0.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-375
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/export/exporter/temp-1531104600/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-375
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 376 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:loss = 152.20122, step = 376
# INFO:tensorflow:global_step/sec: 77.4524
# INFO:tensorflow:loss = 156.76936, step = 476 (1.291 sec)
# INFO:tensorflow:global_step/sec: 157.148
# INFO:tensorflow:loss = 152.27206, step = 576 (0.636 sec)
# INFO:tensorflow:global_step/sec: 149.01
# INFO:tensorflow:loss = 152.00943, step = 676 (0.671 sec)
# INFO:tensorflow:Saving checkpoints for 757 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:Loss for final step: 165.07596.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-09-02:50:08
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-757
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-09-02:50:08
# INFO:tensorflow:Saving dict for global step 757: accuracy = 0.6721311, accuracy_baseline = 0.6721312, auc = 0.5189025, auc_precision_recall = 0.34121603, average_loss = 0.6695654, global_step = 757, label/mean = 0.32786885, loss = 40.843487, precision = 0.0, prediction/mean = 0.235569, recall = 0.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-757
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/export/exporter/temp-1531104609/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-757
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 758 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:loss = 146.72478, step = 758
# INFO:tensorflow:global_step/sec: 112.334
# INFO:tensorflow:loss = 155.9321, step = 858 (0.891 sec)
# INFO:tensorflow:global_step/sec: 89.8218
# INFO:tensorflow:loss = 132.23882, step = 958 (1.113 sec)
# INFO:tensorflow:global_step/sec: 142.093
# INFO:tensorflow:loss = 148.50679, step = 1058 (0.703 sec)
# INFO:tensorflow:Saving checkpoints for 1155 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:Loss for final step: 140.15634.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-09-02:50:17
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-1155
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-09-02:50:18
# INFO:tensorflow:Saving dict for global step 1155: accuracy = 0.6721311, accuracy_baseline = 0.6721312, auc = 0.4981708, auc_precision_recall = 0.34255248, average_loss = 0.6919648, global_step = 1155, label/mean = 0.32786885, loss = 42.209854, precision = 0.0, prediction/mean = 0.22309221, recall = 0.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-1155
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/export/exporter/temp-1531104618/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-1155
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1156 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:loss = 139.0983, step = 1156
# INFO:tensorflow:global_step/sec: 72.1656
# INFO:tensorflow:loss = 147.86932, step = 1256 (1.386 sec)
# INFO:tensorflow:global_step/sec: 139.257
# INFO:tensorflow:loss = 138.97478, step = 1356 (0.718 sec)
# INFO:tensorflow:global_step/sec: 138.479
# INFO:tensorflow:loss = 134.15744, step = 1456 (0.722 sec)
# INFO:tensorflow:Saving checkpoints for 1501 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:Loss for final step:

# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-09-02:51:03
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-3033
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-09-02:51:04
# INFO:tensorflow:Saving dict for global step 3033: accuracy = 0.6721311, accuracy_baseline = 0.6721312, auc = 0.47621956, auc_precision_recall = 0.30024445, average_loss = 0.7823234, global_step = 3033, label/mean = 0.32786885, loss = 47.72173, precision = 0.5, prediction/mean = 0.18685104, recall = 0.05
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-3033
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/export/exporter/temp-1531104665/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-3033
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3034 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:loss = 127.09922, step = 3034
# INFO:tensorflow:global_step/sec: 76.4966
# INFO:tensorflow:loss = 109.27672, step = 3134 (1.307 sec)
# INFO:tensorflow:global_step/sec: 141.925
# INFO:tensorflow:loss = 120.6979, step = 3234 (0.705 sec)
# INFO:tensorflow:global_step/sec: 147.361
# INFO:tensorflow:loss = 115.5832, step = 3334 (0.678 sec)
# INFO:tensorflow:Saving checkpoints for 3430 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:Loss for final step: 107.324615.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-09-02:51:13
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-3430
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-09-02:51:14
# INFO:tensorflow:Saving dict for global step 3430: accuracy = 0.6721311, accuracy_baseline = 0.6721312, auc = 0.47743908, auc_precision_recall = 0.32614666, average_loss = 0.80353665, global_step = 3430, label/mean = 0.32786885, loss = 49.015736, precision = 0.5, prediction/mean = 0.1781009, recall = 0.05
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-3430
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/export/exporter/temp-1531104674/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-3430
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3431 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:loss = 116.73962, step = 3431
# INFO:tensorflow:global_step/sec: 122.791
# INFO:tensorflow:loss = 104.52669, step = 3531 (0.814 sec)
# INFO:tensorflow:global_step/sec: 160.657
# INFO:tensorflow:loss = 115.09265, step = 3631 (0.622 sec)
# INFO:tensorflow:global_step/sec: 89.7437
# INFO:tensorflow:loss = 112.29949, step = 3731 (1.114 sec)
# INFO:tensorflow:global_step/sec: 141.762
# INFO:tensorflow:loss = 103.24324, step = 3831 (0.705 sec)
# INFO:tensorflow:Saving checkpoints for 3847 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:Loss for final step: 115.62106.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-09-02:51:22
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-3847
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-09-02:51:23
# INFO:tensorflow:Saving dict for global step 3847: accuracy = 0.6557377, accuracy_baseline = 0.6721312, auc = 0.4810976, auc_precision_recall = 0.3429619, average_loss = 0.81560206, global_step = 3847, label/mean = 0.32786885, loss = 49.751724, precision = 0.33333334, prediction/mean = 0.17812677, recall = 0.05
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-3847
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/export/exporter/temp-1531104683/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-3847
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3848 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:loss = 115.65426, step = 3848
# INFO:tensorflow:global_step/sec: 75.0051
# INFO:tensorflow:loss = 116.3685, step = 3948 (1.333 sec)
# INFO:tensorflow:global_step/sec: 139.469
# INFO:tensorflow:loss = 113.41434, step = 4048 (0.717 sec)
# INFO:tensorflow:global_step/sec: 134.112
# INFO:tensorflow:loss = 101.068405, step = 4148 (0.745 sec)
# INFO:tensorflow:Saving checkpoints for 4222 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:Loss for final step: 102.78342.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-09-02:51:31
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-4222
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-09-02:51:32
# INFO:tensorflow:Saving dict for global step 4222: accuracy = 0.6557377, accuracy_baseline = 0.6721312, auc = 0.47134155, auc_precision_recall = 0.3395571, average_loss = 0.830446, global_step = 4222, label/mean = 0.32786885, loss = 50.657207, precision = 0.33333334, prediction/mean = 0.1774901, recall = 0.05
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-4222
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/export/exporter/temp-1531104693/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-4222
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 4223 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:loss = 92.54156, step = 4223
# INFO:tensorflow:global_step/sec: 79.1596
# INFO:tensorflow:loss = 87.98771, step = 4323 (1.263 sec)
# INFO:tensorflow:global_step/sec: 157.571
# INFO:tensorflow:loss = 99.168335, step = 4423 (0.634 sec)
# INFO:tensorflow:global_step/sec: 154.767
# INFO:tensorflow:loss = 103.05713, step = 4523 (0.646 sec)
# INFO:tensorflow:global_step/sec: 163.63
# INFO:tensorflow:loss = 96.68903, step = 4623 (0.611 sec)
# INFO:tensorflow:Saving checkpoints for 4660 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:Loss for final step: 102.8218.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-09-02:51:40
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-4660
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-09-02:51:41
# INFO:tensorflow:Saving dict for global step 4660: accuracy = 0.6557377, accuracy_baseline = 0.6721312, auc = 0.46951225, auc_precision_recall = 0.33811796, average_loss = 0.8571449, global_step = 4660, label/mean = 0.32786885, loss = 52.28584, precision = 0.33333334, prediction/mean = 0.17165104, recall = 0.05
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-4660
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/export/exporter/temp-1531104702/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-4660
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ...
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-23703
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/export/exporter/temp-1531105133/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-23703
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 23704 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:loss = 12.358677, step = 23704
# INFO:tensorflow:global_step/sec: 108.3
# INFO:tensorflow:loss = 11.226491, step = 23804 (0.924 sec)
# INFO:tensorflow:global_step/sec: 80.0052
# INFO:tensorflow:loss = 10.736243, step = 23904 (1.249 sec)
# INFO:tensorflow:global_step/sec: 144.078
# INFO:tensorflow:loss = 12.038525, step = 24004 (0.694 sec)
# INFO:tensorflow:Saving checkpoints for 24088 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:Loss for final step: 11.823097.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-09-02:59:01
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-24088
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-09-02:59:02
# INFO:tensorflow:Saving dict for global step 24088: accuracy = 0.6229508, accuracy_baseline = 0.6721312, auc = 0.48719513, auc_precision_recall = 0.31905907, average_loss = 1.7757733, global_step = 24088, label/mean = 0.32786885, loss = 108.322174, precision = 0.2857143, prediction/mean = 0.14402153, recall = 0.1
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-24088
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/export/exporter/temp-1531105143/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-24088
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 24089 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:loss = 13.124471, step = 24089
# INFO:tensorflow:global_step/sec: 76.8352
# INFO:tensorflow:loss = 11.012311, step = 24189 (1.301 sec)
# INFO:tensorflow:global_step/sec: 129.478
# INFO:tensorflow:loss = 11.829604, step = 24289 (0.773 sec)
# INFO:tensorflow:global_step/sec: 126.375
# INFO:tensorflow:loss = 10.58531, step = 24389 (0.791 sec)
# INFO:tensorflow:Saving checkpoints for 24438 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:Loss for final step: 11.124158.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-09-02:59:10
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-24438
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-09-02:59:11
# INFO:tensorflow:Saving dict for global step 24438: accuracy = 0.6229508, accuracy_baseline = 0.6721312, auc = 0.48719516, auc_precision_recall = 0.31905907, average_loss = 1.7851038, global_step = 24438, label/mean = 0.32786885, loss = 108.891335, precision = 0.2857143, prediction/mean = 0.1447769, recall = 0.1
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-24438
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/export/exporter/temp-1531105152/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-24438
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 24439 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:loss = 12.313136, step = 24439
# INFO:tensorflow:global_step/sec: 125.568
# INFO:tensorflow:loss = 13.228766, step = 24539 (0.797 sec)
# INFO:tensorflow:global_step/sec: 99.9155
# INFO:tensorflow:loss = 8.510972, step = 24639 (1.000 sec)
# INFO:tensorflow:global_step/sec: 154.082
# INFO:tensorflow:loss = 11.931778, step = 24739 (0.649 sec)
# INFO:tensorflow:global_step/sec: 159.368
# INFO:tensorflow:loss = 12.653046, step = 24839 (0.628 sec)
# INFO:tensorflow:Saving checkpoints for 24886 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:Loss for final step: 12.534206.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-09-02:59:19
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-24886
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-09-02:59:20
# INFO:tensorflow:Saving dict for global step 24886: accuracy = 0.6229508, accuracy_baseline = 0.6721312, auc = 0.49146342, auc_precision_recall = 0.32125407, average_loss = 1.8012971, global_step = 24886, label/mean = 0.32786885, loss = 109.87912, precision = 0.2857143, prediction/mean = 0.14450642, recall = 0.1
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-24886
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/export/exporter/temp-1531105161/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-24886
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 24887 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:loss = 13.03441, step = 24887
# INFO:tensorflow:global_step/sec: 79.0113
# INFO:tensorflow:loss = 12.021494, step = 24987 (1.267 sec)
# INFO:tensorflow:Saving checkpoints for 25000 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt.
# INFO:tensorflow:Loss for final step: 11.57229.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-09-02:59:27
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-25000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-09-02:59:27
# INFO:tensorflow:Saving dict for global step 25000: accuracy = 0.6229508, accuracy_baseline = 0.6721312, auc = 0.49146342, auc_precision_recall = 0.3212541, average_loss = 1.8062559, global_step = 25000, label/mean = 0.32786885, loss = 110.18161, precision = 0.2857143, prediction/mean = 0.14424987, recall = 0.1
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/model.ckpt-25000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/../models/basic_features/export/exporter/temp-1531105168/saved_model.pb
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-09 02:49:47.224598. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %% [markdown]
# Results for 25000 batches of 303 cases (25000 training epochs):
#
# - Accuracy = 0.6229508
# - Accuracy baseline = 0.6721312
# - AUC = 0.49146342
# - AUC-PR = 0.3212541
# - Average loss = 1.8062559
# - F1 score = 0.14814815
# - Label/mean = 0.32786885
# - Loss = 110.18161
# - Precision = 0.2857143
# - Prediction/mean = 0.14424987
# - Recall = 0.1

# %% [markdown]
# ### Cloud ML Engine Training

# %%
# %%bash
#
# OUTPUT_DIR=gs://${BUCKET}/analysis/hallelujah-effect/models/${MODEL_NAME}
# JOBNAME=hallelujah_effect$(date -u +%y%m%d_%H%M%S)
# echo ${OUTPUT_DIR} ${REGION} ${JOBNAME}
# gsutil -m rm -rf ${OUTPUT_DIR}
# gcloud ml-engine jobs submit training ${JOBNAME} \
#    --region=${REGION} \
#    --package-path=${PWD}/trainer/trainer \
#    --module-name=trainer.task \
#    --job-dir=${OUTPUT_DIR} \
#    --scale-tier=STANDARD_1 \
#    --runtime-version=1.8 \
#    -- \
#    --train_data_paths="gs://${BUCKET}/analysis/hallelujah-effect/preproc_tft/train*" \
#    --eval_data_paths="gs://${BUCKET}/analysis/hallelujah-effect/preproc_tft/eval*" \
#    --output_dir=${OUTPUT_DIR} \
#    --train_steps=2500000 \
#    --train_batch_size=${TRAIN_N} \
#    --eval_steps=1 \
#    --metadata_path=gs://${BUCKET}/analysis/hallelujah-effect/preproc_tft/metadata/
# Out:
# gs://eim-muse/analysis/hallelujah-effect/models/basic_features us-central1 hallelujah_effect180710_142657
# jobId: hallelujah_effect180710_142657
# state: QUEUED
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/checkpoint#1531108730921226...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/#1531108727262402...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/eval/#1531105474116837...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/eval/events.out.tfevents.1531105474.cmle-training-master-8479dedb7c-0-9mhzl#1531108735858257...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/events.out.tfevents.1531105431.cmle-training-master-8479dedb7c-0-9mhzl#1531108746468766...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/exporter/#1531105478632676...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/#1531105478278103...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/exporter/1531105476/#1531105484593576...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/exporter/1531105476/saved_model.pb#1531105484909915...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/exporter/1531105476/variables/#1531105485196077...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/exporter/1531105476/variables/variables.data-00000-of-00001#1531105485523921...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/exporter/1531105476/variables/variables.index#1531105485850776...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/exporter/1531105564/#1531105572055902...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/exporter/1531105564/saved_model.pb#1531105572385816...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/exporter/1531105564/variables/#1531105572728514...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/exporter/1531105564/variables/variables.data-00000-of-00001#1531105573089430...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/exporter/1531105564/variables/variables.index#1531105573368863...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/exporter/1531105654/#1531105661065478...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/exporter/1531105654/saved_model.pb#1531105661451231...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/exporter/1531105654/variables/#1531105661771585...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/exporter/1531105654/variables/variables.index#1531105662401903...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/exporter/1531105654/variables/variables.data-00000-of-00001#1531105662087889...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/exporter/1531105750/#1531105756804532...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/exporter/1531105750/saved_model.pb#1531105757100638...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/exporter/1531105750/variables/#1531105757442134...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/exporter/1531