# %% [markdown]
# # "Hallelujah Effect" Analysis
#
# This notebook models the "Hallelujah Effect" in terms of all basic features available in the dataset for those subjects that listened to the song and had an EDA quality >80%.

# %%
# %bash
pip uninstall -y google-cloud-dataflow
pip install --upgrade --force tensorflow_transform==0.6.0 apache-beam[gcp]

# %% [markdown]
# <b>Restart the kernel</b> after you do a pip install (click on the <b>Reset</b> button in Datalab)

# %%
# %bash
pip freeze | grep -e 'flow\|beam'
# Out:
# apache-airflow==1.9.0
# apache-beam==2.5.0
# tensorflow==1.8.0
# tensorflow-transform==0.6.0
# You are using pip version 9.0.3, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import tensorflow as tf
import tensorflow_transform as tft
import shutil
print(tf.__version__)
# Out:
# 1.8.0
# /usr/local/envs/py2env/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# Set bucket, project, and region
BUCKET = 'eim-muse'
PROJECT = 'eim-muse'
REGION = 'us-central1'

# %%
import os
os.environ['BUCKET'] = BUCKET
os.environ['PROJECT'] = PROJECT
os.environ['REGION'] = REGION

# %%
# %bash
gcloud config set project $PROJECT
gcloud config set compute/region $REGION
# Out:
# Updated property [core/project].
# Updated property [compute/region].

# %% [markdown]
# ## Retrieve and Subset Datasource
#
# Get data from BigQuery but defer filtering, etc. to Beam. Data in BigQuery has been pre-processed with Dataprep.

# %%
import google.datalab.bigquery as bq
def create_query(phase, EVERY_N):
  """
  phase: 1=train 2=valid
  """
  base_query = """
SELECT *
FROM
  `eim-muse.hallelujah_effect.full_hallelujah_trials_cleaned`
  """

  if EVERY_N == None:
    if phase < 2:
      # Training
      query = "{0} WHERE MOD(FARM_FINGERPRINT(id), 10) < 7".format(base_query)
    else:
      # Validation
      query = "{0} WHERE MOD(FARM_FINGERPRINT(id), 10) >= 8".format(base_query)
  else:
      query = "{0} WHERE MOD(FARM_FINGERPRINT(id), {1}) = {2}".format(base_query, EVERY_N, phase)
    
  return query

query = create_query(2, None)
# Out:
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-03 20:04:06.738232. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
df_valid = bq.Query(query).execute().result().to_dataframe()
df_valid.head()
df_valid.describe()
# Out:
#              age  concentration  musical_expertise   artistic      fault  \
# count  34.000000      34.000000          34.000000  34.000000  34.000000
# mean   23.411765       3.966221           2.541715   2.353326   3.013545
# std    11.760534       0.758038           0.936682   0.814311   0.745692
# min     5.000000       2.000000           1.000000   1.000000   1.000000
# 25%    17.250000       3.991266           2.000000   2.000000   3.000000
# 50%    21.000000       3.991266           2.529880   2.353712   3.144737
# 75%    31.750000       4.000000           3.000000   2.353712   3.144737
# max    56.000000       5.000000           5.000000   4.000000   4.000000
#
#        imagination       lazy    nervous   outgoing   reserved  \
# count    34.000000  34.000000  34.000000  34.000000  34.000000
# mean      3.765222   3.564988   3.327657   3.378741   3.000128
# std       0.846546   0.788906   0.842047   0.522440   0.656813
# min       1.000000   1.000000   1.000000   2.000000   2.000000
# 25%       3.824561   3.659389   3.000000   3.228070   3.000000
# 50%       3.824561   3.659389   3.596491   3.228070   3.117904
# 75%       4.000000   4.000000   3.596491   4.000000   3.117904
# max       5.000000   5.000000   5.000000   4.000000   4.000000
#
#                    ...               music_pref_none  music_pref_hiphop  \
# count              ...                     34.000000          34.000000
# mean               ...                      0.029412           0.117647
# std                ...                      0.171499           0.327035
# min                ...                      0.000000           0.000000
# 25%                ...                      0.000000           0.000000
# 50%                ...                      0.000000           0.000000
# 75%                ...                      0.000000           0.000000
# max                ...                      1.000000           1.000000
#
#        music_pref_dance  music_pref_world  music_pref_rock  music_pref_pop  \
# count         34.000000         34.000000        34.000000       34.000000
# mean           0.176471          0.176471         0.323529        0.617647
# std            0.386953          0.386953         0.474858        0.493270
# min            0.000000          0.000000         0.000000        0.000000
# 25%            0.000000          0.000000         0.000000        0.000000
# 50%            0.000000          0.000000         0.000000        1.000000
# 75%            0.000000          0.000000         1.000000        1.000000
# max            1.000000          1.000000         1.000000        1.000000
#
#        music_pref_classical  music_pref_jazz  music_pref_folk  \
# count             34.000000        34.000000        34.000000
# mean               0.411765         0.205882         0.029412
# std                0.499554         0.410426         0.171499
# min                0.000000         0.000000         0.000000
# 25%                0.000000         0.000000         0.000000
# 50%                0.000000         0.000000         0.000000
# 75%                1.000000         0.000000         0.000000
# max                1.000000         1.000000         1.000000
#
#        music_pref_traditional_irish
# count                     34.000000
# mean                       0.088235
# std                        0.287902
# min                        0.000000
# 25%                        0.000000
# 50%                        0.000000
# 75%                        0.000000
# max                        1.000000
#
# [8 rows x 29 columns]
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-03 20:04:10.078001. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
df_valid.columns
# Out:
# Index([u'id', u'age', u'concentration', u'hearing_impairments',
#        u'musical_expertise', u'nationality', u'artistic', u'fault',
#        u'imagination', u'lazy', u'nervous', u'outgoing', u'reserved',
#        u'stress', u'thorough', u'trusting', u'activity', u'engagement',
#        u'familiarity', u'like_dislike', u'positivity', u'tension', u'sex',
#        u'hallelujah_reaction', u'location', u'language', u'music_pref_none',
#        u'music_pref_hiphop', u'music_pref_dance', u'music_pref_world',
#        u'music_pref_rock', u'music_pref_pop', u'music_pref_classical',
#        u'music_pref_jazz', u'music_pref_folk',
#        u'music_pref_traditional_irish'],
#       dtype='object')
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-03 20:04:19.447051. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %% [markdown]
# ## Create ML dataset using tf.transform and Dataflow
#
# Let's use Cloud Dataflow to read in the BigQuery data and write it out as CSV files. Along the way, let's use tf.transform to do scaling and transforming. Using tf.transform allows us to save the metadata to ensure that the appropriate transformations get carried out during prediction as well.

# %%
# %writefile requirements.txt
tensorflow-transform==0.6.0
# Out:
# Overwriting requirements.txt
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-03 20:04:25.703204. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
import datetime
import tensorflow as tf
import apache_beam as beam
import tensorflow_transform as tft
from tensorflow_transform.beam import impl as beam_impl

def is_valid(inputs):
    try:
        return True
    except:
        return False

float_features = [
    'activity',
    'age',
    'artistic',
    'concentration',
    'engagement',
    'familiarity',
    'fault',
    'imagination',
    'lazy',
    'like_dislike',
    'musical_expertise',
    'nervous',
    'outgoing',
    'positivity',
    'reserved',
    'stress',
    'tension',
    'thorough',
    'trusting'
]

boolean_features = [
    'hallelujah_reaction',
    'hearing_impairments',
    'music_pref_classical',
    'music_pref_dance',
    'music_pref_folk',
    'music_pref_hiphop',
    'music_pref_jazz',
    'music_pref_none',
    'music_pref_pop',
    'music_pref_rock',
    'music_pref_traditional_irish',
    'music_pref_world'
]

categorical_features = [
    'language',
    'location',
    'nationality',
    'sex'
]

def preprocess_tft(inputs):
    import datetime
    result = {}
    
    for feature in float_features:
        result[feature] = tft.scale_to_0_1(inputs[feature])
    
    for feature in boolean_features:
        result[feature] = tf.cast(inputs[feature], tf.int64)
    
    for feature in categorical_features:
        result[feature] = tf.identity(inputs[feature])
    
    return result

def preprocess(in_test_mode, EVERY_N=None):
  import os
  import os.path
  import tempfile
  from apache_beam.io import tfrecordio
  from tensorflow_transform.coders import example_proto_coder
  from tensorflow_transform.tf_metadata import dataset_metadata
  from tensorflow_transform.tf_metadata import dataset_schema
  from tensorflow_transform.beam import tft_beam_io
  from tensorflow_transform.beam.tft_beam_io import transform_fn_io

  job_name = 'hallelujah-effect-features' + '-' + datetime.datetime.now().strftime('%y%m%d-%H%M%S')    
  if in_test_mode:
    import shutil
    print 'Launching local job ... hang on'
    OUTPUT_DIR = './preproc_tft'
    shutil.rmtree(OUTPUT_DIR, ignore_errors=True)
    
  else:
    print 'Launching Dataflow job {} ... hang on'.format(job_name)
    OUTPUT_DIR = 'gs://{0}/analysis/hallelujah-effect/preproc_tft/'.format(BUCKET)
    import subprocess
    subprocess.call('gsutil rm -r {}'.format(OUTPUT_DIR).split())
  
  # Configure Beam pipeline options
  options = {
    'staging_location': os.path.join(OUTPUT_DIR, 'tmp', 'staging'),
    'temp_location': os.path.join(OUTPUT_DIR, 'tmp'),
    'job_name': job_name,
    'project': PROJECT,
    'max_num_workers': 24,
    'teardown_policy': 'TEARDOWN_ALWAYS',
    'no_save_main_session': True,
    'requirements_file': 'requirements.txt'
  }
  opts = beam.pipeline.PipelineOptions(flags=[], **options)
  if in_test_mode:
    RUNNER = 'DirectRunner'
  else:
    RUNNER = 'DataflowRunner'

  # Setup metadata
  raw_data_schema = {
    colname : dataset_schema.ColumnSchema(tf.string, [], dataset_schema.FixedColumnRepresentation())
                   for colname in categorical_features
  }
  raw_data_schema.update({
      colname : dataset_schema.ColumnSchema(tf.float32, [], dataset_schema.FixedColumnRepresentation())
                   for colname in float_features
    })
  raw_data_schema.update({
      colname : dataset_schema.ColumnSchema(tf.int64, [], dataset_schema.FixedColumnRepresentation())
                   for colname in boolean_features
    })
  raw_data_metadata = dataset_metadata.DatasetMetadata(dataset_schema.Schema(raw_data_schema))
  
  # run Beam  
  with beam.Pipeline(RUNNER, options=opts) as p:
    with beam_impl.Context(temp_dir=os.path.join(OUTPUT_DIR, 'tmp')):
      
      # Write the raw data metadata to disk
      # Without the overloaded operators: p.apply(tft_beam_io.WriteMetadata(os.path.join(OUTPUT_DIR, 'metadata/rawdata_metadata'), raw_data_metadata)
      _ = (raw_data_metadata
        | 'WriteInputMetadata' >> tft_beam_io.WriteMetadata(
            os.path.join(OUTPUT_DIR, 'metadata/rawdata_metadata'),
            pipeline=p))
           
      # Analyze and transform training data
      this_query = create_query(1, EVERY_N)
      
      # Read in training data from BigQuery table
      raw_data = (p
        # Get raw training data from BigQuery
        | 'train_read' >> beam.io.Read(beam.io.BigQuerySource(query=this_query, use_standard_sql=True))
        # Use our is_valid function to only retain valid examples from training data
        | 'train_filter' >> beam.Filter(is_valid))

      # Package raw training data and its metadata into a 'dataset'
      raw_dataset = (raw_data, raw_data_metadata)
      
      # Using the preprocessing function `preprocess_tft`, preprocess the training data
      # and produce a transformed training dataset and a function to transform other data later
      transformed_dataset, transform_fn = (
          raw_dataset | beam_impl.AnalyzeAndTransformDataset(preprocess_tft))
      
      # Break out the transformed training data and its metadata
      transformed_data, transformed_metadata = transformed_dataset
      
      # Write the transformed training data to files
      _ = transformed_data | 'WriteTrainData' >> tfrecordio.WriteToTFRecord(
          os.path.join(OUTPUT_DIR, 'train'),
          file_name_suffix='.gz',
          coder=example_proto_coder.ExampleProtoCoder(
              transformed_metadata.schema))
      
      # Read in test data from BigQuery table and filter as we did with training data
      raw_test_data = (p 
        | 'eval_read' >> beam.io.Read(beam.io.BigQuerySource(query=create_query(2, EVERY_N), use_standard_sql=True))
        | 'eval_filter' >> beam.Filter(is_valid))
      
      # Package test data and metadata into a dataset
      raw_test_dataset = (raw_test_data, raw_data_metadata)
      
      # Using the same transformation function that was calculated above, transform the test dataset
      transformed_test_dataset = (
          (raw_test_dataset, transform_fn) | beam_impl.TransformDataset())
      
      # Write the transformed test data to files
      transformed_test_data, _ = transformed_test_dataset
      _ = transformed_test_data | 'WriteTestData' >> tfrecordio.WriteToTFRecord(
          os.path.join(OUTPUT_DIR, 'eval'),
          file_name_suffix='.gz',
          coder=example_proto_coder.ExampleProtoCoder(
              transformed_metadata.schema))
      
      # Write the transformation function to a file, as well
      _ = (transform_fn
           | 'WriteTransformFn' >>
           transform_fn_io.WriteTransformFn(os.path.join(OUTPUT_DIR, 'metadata')))

# Preprocess the training/test data
preprocess(in_test_mode=True, EVERY_N=10)
# Out:
# Launching local job ... hang on
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./preproc_tft/tmp/tftransform_tmp/239652e3623a43b98db4271a06c1c2c7/saved_model.pb
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./preproc_tft/tmp/tftransform_tmp/df60e500741f4954ac1fe5f6fcfd0f7e/saved_model.pb
# /usr/local/envs/py2env/lib/python2.7/site-packages/apache_beam/runners/direct/direct_runner.py:342: DeprecationWarning: options is deprecated since First stable release.. References to <pipeline>.options will not be supported
#   pipeline.replace_all(_get_transform_overrides(pipeline.options))
# WARNING:root:Dataset eim-muse:temp_dataset_d4af6153834349d58c4c41c9dcaabacb does not exist so we will create it as temporary with location=None
# WARNING:root:Dataset eim-muse:temp_dataset_9184416006ed407696ca64cd9677d9e1 does not exist so we will create it as temporary with location=None
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./preproc_tft/tmp/tftransform_tmp/7330a1ee5eb24b5dbc8b7680ea811e6a/saved_model.pb
# INFO:tensorflow:SavedModel written to: ./preproc_tft/tmp/tftransform_tmp/7330a1ee5eb24b5dbc8b7680ea811e6a/saved_model.pb
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-03 20:04:28.654474. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
# %bash
ls -ls preproc_tft
ls -ls preproc_tft/metadata
# gsutil ls -l gs://${BUCKET}/analysis/hallelujah-effect/preproc_tft/
# gsutil ls -l gs://${BUCKET}/analysis/hallelujah-effect/preproc_tft/metadata
# Out:
# total 16
# 4 -rw-r--r-- 1 root root 1369 Jul  3 20:04 eval-00000-of-00001.gz
# 4 drwxr-xr-x 5 root root 4096 Jul  3 20:04 metadata
# 4 drwxr-xr-x 3 root root 4096 Jul  3 20:04 tmp
# 4 -rw-r--r-- 1 root root 1585 Jul  3 20:04 train-00000-of-00001.gz
# total 12
# 4 drwxr-xr-x 3 root root 4096 Jul  3 20:04 rawdata_metadata
# 4 drwxr-xr-x 3 root root 4096 Jul  3 20:04 transformed_metadata
# 4 drwxr-xr-x 3 root root 4096 Jul  3 20:04 transform_fn
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-03 20:05:01.421686. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %% [markdown]
# <h2> Train off preprocessed data </h2>

# %% [markdown]
# ### Local Manual Training

# %%
MODEL_NAME = 'basic_features'
os.environ['MODEL_NAME'] = MODEL_NAME
# Out:
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-03 20:05:09.006219. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
# %%bash
#
# rm -rf ${PWD}/models/${MODEL_NAME}
# export PYTHONPATH=${PYTHONPATH}:$PWD/trainer
# python -m trainer.task \
#    --train_data_paths="${PWD}/preproc_tft/train*" \
#    --eval_data_paths="${PWD}/preproc_tft/eval*" \
#    --train_steps=25000 \
#    --train_batch_size=64 \
#    --eval_steps=1 \
#    --output_dir=${PWD}/models/${MODEL_NAME} \
#    --job-dir=/tmp \
#    --metadata_path="${PWD}/preproc_tft/metadata"
# Out:
# /usr/local/envs/py2env/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 60, '_session_config': None, '_keep_checkpoint_max': 10, '_task_type': 'worker', '_train_distribute': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f429b4b0dd0>, '_evaluation_master': '', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': '/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features', '_global_id_in_cluster': 0, '_save_summary_steps': 100}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 5 secs (eval_spec.throttle_secs) or training is finished.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow_transform/saved/input_fn_maker.py:557: read_batch_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:833: read_keyed_batch_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:542: read_keyed_batch_examples (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:550: queue_parsed_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# 2018-07-03 20:16:28.558161: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/model.ckpt.
# INFO:tensorflow:loss = 42.547966, step = 1
# INFO:tensorflow:global_step/sec: 255.571
# INFO:tensorflow:loss = 21.875755, step = 101 (0.391 sec)
# INFO:tensorflow:global_step/sec: 342.839
# INFO:tensorflow:loss = 17.072304, step = 201 (0.294 sec)
# INFO:tensorflow:global_step/sec: 347.494
# INFO:tensorflow:loss = 12.101704, step = 301 (0.286 sec)
# INFO:tensorflow:global_step/sec: 335.909
# INFO:tensorflow:loss = 8.536378, step = 401 (0.298 sec)
# INFO:tensorflow:global_step/sec: 354.699
# INFO:tensorflow:loss = 8.433989, step = 501 (0.282 sec)
# INFO:tensorflow:global_step/sec: 352.854
# INFO:tensorflow:loss = 7.572583, step = 601 (0.284 sec)
# INFO:tensorflow:global_step/sec: 344.715
# INFO:tensorflow:loss = 7.8077116, step = 701 (0.290 sec)
# INFO:tensorflow:global_step/sec: 346.338
# INFO:tensorflow:loss = 8.994015, step = 801 (0.289 sec)
# INFO:tensorflow:global_step/sec: 361.915
# INFO:tensorflow:loss = 6.705299, step = 901 (0.276 sec)
# INFO:tensorflow:global_step/sec: 353.28
# INFO:tensorflow:loss = 3.1906073, step = 1001 (0.285 sec)
# INFO:tensorflow:Saving checkpoints for 1073 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/model.ckpt.
# INFO:tensorflow:Loss for final step: 9.036243.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-03-20:16:34
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/model.ckpt-1073
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-03-20:16:35
# INFO:tensorflow:Saving dict for global step 1073: accuracy = 0.9375, accuracy_baseline = 0.9375, auc = 0.30000067, auc_precision_recall = 0.038461592, average_loss = 0.30323786, global_step = 1073, label/mean = 0.0625, loss = 4.8518057, precision = 0.0, prediction/mean = 0.020439204, recall = 0.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/model.ckpt-1073
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/export/exporter/temp-1530648996/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/model.ckpt-1073
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1074 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/model.ckpt.
# INFO:tensorflow:loss =
into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.7674465.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-03-20:20:02
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/model.ckpt-24416
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-03-20:20:02
# INFO:tensorflow:Saving dict for global step 24416: accuracy = 0.9375, accuracy_baseline = 0.9375, auc = 0.5000004, auc_precision_recall = 0.53124946, average_loss = 0.5919861, global_step = 24416, label/mean = 0.0625, loss = 9.471778, precision = 0.0, prediction/mean = 0.00068374805, recall = 0.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/model.ckpt-24416
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/export/exporter/temp-1530649203/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/model.ckpt-24416
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 24417 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/model.ckpt.
# INFO:tensorflow:loss = 8.064211, step = 24417
# INFO:tensorflow:global_step/sec: 252.061
# INFO:tensorflow:loss = 9.2120075, step = 24517 (0.398 sec)
# INFO:tensorflow:global_step/sec: 366.87
# INFO:tensorflow:loss = 5.185504, step = 24617 (0.271 sec)
# INFO:tensorflow:global_step/sec: 344.084
# INFO:tensorflow:loss = 4.610259, step = 24717 (0.291 sec)
# INFO:tensorflow:global_step/sec: 340.607
# INFO:tensorflow:loss = 6.3303466, step = 24817 (0.294 sec)
# INFO:tensorflow:global_step/sec: 342.298
# INFO:tensorflow:loss = 4.6065264, step = 24917 (0.292 sec)
# INFO:tensorflow:Saving checkpoints for 25000 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.175743.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-03-20:20:09
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/model.ckpt-25000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-03-20:20:10
# INFO:tensorflow:Saving dict for global step 25000: accuracy = 0.9375, accuracy_baseline = 0.9375, auc = 0.5000004, auc_precision_recall = 0.53124946, average_loss = 0.5944193, global_step = 25000, label/mean = 0.0625, loss = 9.510709, precision = 0.0, prediction/mean = 0.00066745654, recall = 0.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/model.ckpt-25000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/export/exporter/temp-1530649211/saved_model.pb
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-03 20:16:25.011549. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %% [markdown]
# Results for 25000 batches of 64 cases:
#
# - Accuracy = 0.9375
# - Accuracy baseline = 0.9375
# - AUC = 0.5000004
# - AUC-PR= 0.53124946
# - Average loss = 0.5944193
# - Label/mean = 0.0625
# - Loss = 9.510709
# - Precision = 0.0
# - Prediction/mean = 0.00066745654
# - Recall = 0.0

# %% [markdown]
# ### Local ML Engine Training

# %%
# %%bash
#
# OUTDIR=${PWD}/models/${MODEL_NAME}
# rm -rf $OUTDIR
# gcloud ml-engine local train \
#    --module-name=trainer.task \
#    --package-path=${PWD}/trainer/trainer \
#    --job-dir=$OUTDIR \
#    -- \
#    --train_data_paths="${PWD}/preproc_tft/train*" \
#    --eval_data_paths="${PWD}/preproc_tft/eval*" \
#    --train_steps=25000 \
#    --train_batch_size=64 \
#    --eval_steps=1 \
#    --output_dir=$OUTDIR \
#    --metadata_path="${PWD}/preproc_tft/metadata/"
# Out:
# /usr/local/envs/py2env/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:tensorflow:TF_CONFIG environment variable: {u'environment': u'cloud', u'cluster': {}, u'job': {u'args': [u'--train_data_paths=/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/preproc_tft/train*', u'--eval_data_paths=/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/preproc_tft/eval*', u'--train_steps=25000', u'--train_batch_size=64', u'--eval_steps=1', u'--output_dir=/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features', u'--metadata_path=/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/preproc_tft/metadata/', u'--job-dir', u'/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features'], u'job_name': u'trainer.task'}, u'task': {}}
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 60, '_session_config': None, '_keep_checkpoint_max': 10, '_task_type': 'worker', '_train_distribute': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fa26895c590>, '_evaluation_master': '', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': '/content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features', '_global_id_in_cluster': 0, '_save_summary_steps': 100}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 5 secs (eval_spec.throttle_secs) or training is finished.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow_transform/saved/input_fn_maker.py:557: read_batch_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:833: read_keyed_batch_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:542: read_keyed_batch_examples (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# WARNING:tensorflow:From /usr/local/envs/py2env/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/learn_io/graph_io.py:550: queue_parsed_features (from tensorflow.contrib.learn.python.learn.learn_io.graph_io) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.data.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# 2018-07-03 20:27:37.659925: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/model.ckpt.
# INFO:tensorflow:loss =
into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/model.ckpt.
# INFO:tensorflow:loss = 0.022973727, step = 23269
# INFO:tensorflow:global_step/sec: 246.954
# INFO:tensorflow:loss = 0.017430115, step = 23369 (0.403 sec)
# INFO:tensorflow:global_step/sec: 337.024
# INFO:tensorflow:loss = 0.02452502, step = 23469 (0.297 sec)
# INFO:tensorflow:global_step/sec: 157.577
# INFO:tensorflow:loss = 0.021386856, step = 23569 (0.634 sec)
# INFO:tensorflow:global_step/sec: 371.638
# INFO:tensorflow:loss = 0.026681501, step = 23669 (0.269 sec)
# INFO:tensorflow:global_step/sec: 351.332
# INFO:tensorflow:loss = 0.027754577, step = 23769 (0.285 sec)
# INFO:tensorflow:global_step/sec: 352.659
# INFO:tensorflow:loss = 0.029665655, step = 23869 (0.284 sec)
# INFO:tensorflow:global_step/sec: 362.701
# INFO:tensorflow:loss = 0.026350692, step = 23969 (0.276 sec)
# INFO:tensorflow:global_step/sec: 361.192
# INFO:tensorflow:loss = 0.016375108, step = 24069 (0.277 sec)
# INFO:tensorflow:global_step/sec: 346.946
# INFO:tensorflow:loss = 0.03040599, step = 24169 (0.288 sec)
# INFO:tensorflow:Saving checkpoints for 24214 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.030827504.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-03-20:31:15
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/model.ckpt-24214
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-03-20:31:15
# INFO:tensorflow:Saving dict for global step 24214: accuracy = 0.9375, accuracy_baseline = 0.9375, auc = 0.43333384, auc_precision_recall = 0.031250246, average_loss = 0.85834605, global_step = 24214, label/mean = 0.0625, loss = 13.733537, precision = 0.0, prediction/mean = 0.0013321013, recall = 0.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/model.ckpt-24214
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/export/exporter/temp-1530649876/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/model.ckpt-24214
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 24215 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/model.ckpt.
# INFO:tensorflow:loss = 0.025840482, step = 24215
# INFO:tensorflow:global_step/sec: 133.705
# INFO:tensorflow:loss = 0.02452569, step = 24315 (0.748 sec)
# INFO:tensorflow:global_step/sec: 456.902
# INFO:tensorflow:loss = 0.019955197, step = 24415 (0.219 sec)
# INFO:tensorflow:global_step/sec: 456.784
# INFO:tensorflow:loss = 0.020555548, step = 24515 (0.219 sec)
# INFO:tensorflow:global_step/sec: 395.812
# INFO:tensorflow:loss = 0.020247275, step = 24615 (0.252 sec)
# INFO:tensorflow:global_step/sec: 350.123
# INFO:tensorflow:loss = 0.029513516, step = 24715 (0.286 sec)
# INFO:tensorflow:global_step/sec: 351.876
# INFO:tensorflow:loss = 0.024346365, step = 24815 (0.284 sec)
# INFO:tensorflow:global_step/sec: 353.94
# INFO:tensorflow:loss = 0.02398599, step = 24915 (0.283 sec)
# INFO:tensorflow:Saving checkpoints for 25000 into /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.022936773.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-03-20:31:23
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/model.ckpt-25000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-07-03-20:31:24
# INFO:tensorflow:Saving dict for global step 25000: accuracy = 0.9375, accuracy_baseline = 0.9375, auc = 0.43333384, auc_precision_recall = 0.031250246, average_loss = 0.8623238, global_step = 25000, label/mean = 0.0625, loss = 13.797181, precision = 0.0, prediction/mean = 0.0013066535, recall = 0.0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'age': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'activity': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/model.ckpt-25000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /content/datalab/notebooks/eim-analysis/Hallelujah_Effect/basic_features/models/basic_features/export/exporter/temp-1530649884/saved_model.pb
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-03 20:27:33.566633. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %% [markdown]
# Results for 25000 batches of 64 cases:
#
# - Accuracy = 0.9375
# - Accuracy baseline = 0.9375
# - AUC = 0.43333384
# - AUC-PR = 0.031250246
# - Average loss = 0.8623238
# - Label/mean = 0.0625
# - Loss = 13.797181
# - Precision = 0.0
# - Prediction/mean = 0.0013066535
# - Recall = 0.0

# %% [markdown]
# ### Cloud ML Engine Training

# %%
# %%bash
#
# OUTDIR=gs://${BUCKET}/analysis/hallelujah-effect/models/${MODEL_NAME}
# JOBNAME=hallelujah_effect$(date -u +%y%m%d_%H%M%S)
# echo $OUTDIR $REGION $JOBNAME
# gsutil -m rm -rf $OUTDIR
# gcloud ml-engine jobs submit training $JOBNAME \
#    --region=$REGION \
#    --package-path=${PWD}/trainer/trainer \
#    --module-name=trainer.task \
#    --job-dir=$OUTDIR \
#    --scale-tier=STANDARD_1 \
#    --runtime-version=1.4 \
#    -- \
#    --train_data_paths="gs://${BUCKET}/analysis/hallelujah-effect/preproc_tft/train*" \
#    --eval_data_paths="gs://${BUCKET}/analysis/hallelujah-effect/preproc_tft/eval*" \
#    --output_dir=$OUTDIR \
#    --train_steps=100000 \
#    --train_batch_size=64 \
#    --eval_steps=1 \
#    --metadata_path=gs://${BUCKET}/analysis/hallelujah-effect/preproc_tft/metadata/
#
# #    --config=hyperparam.yaml
# # --staging-bucket=gs://eim-muse-staging \
# Out:
# gs://eim-muse/analysis/hallelujah-effect/models/basic_features us-central1 hallelujah_effect180703_225948
# jobId: hallelujah_effect180703_225948
# state: QUEUED
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/#1530648087211189...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/exporter/#1530648101070273...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/checkpoint#1530648091423560...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/eval/#1530648096320868...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/#1530648100860566...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/eval/events.out.tfevents.1530648096.cmle-training-master-fd397ae675-0-jcdb2#1530648098067026...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/exporter/1530648099/#1530648107356633...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/events.out.tfevents.1530648060.cmle-training-master-fd397ae675-0-jcdb2#1530648109222043...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/exporter/1530648099/saved_model.pb#1530648107642470...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/exporter/1530648099/variables/#1530648107935464...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/exporter/1530648099/variables/variables.data-00000-of-00001#1530648108281375...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/graph.pbtxt#1530648083983637...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/export/exporter/1530648099/variables/variables.index#1530648108617162...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/model.ckpt-106.data-00000-of-00003#1530648089450386...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/model.ckpt-106.data-00001-of-00003#1530648088926656...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/model.ckpt-106.data-00002-of-00003#1530648088434210...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/model.ckpt-106.index#1530648089963793...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/model.ckpt-106.meta#1530648092595532...
# Removing gs://eim-muse/analysis/hallelujah-effect/models/basic_features/packages/6dd71bcd61938880606e58b713de40a80ce31f96ec164281424b521954c132fd/trainer-0.1.tar.gz#1530647840617125...
# / [19/19 objects] 100% Done
# Operation completed over 19 objects.
# Job [hallelujah_effect180703_225948] submitted successfully.
# Your job is still active. You may view the status of your job with the command
#
#   $ gcloud ml-engine jobs describe hallelujah_effect180703_225948
#
# or continue streaming the logs with the command
#
#   $ gcloud ml-engine jobs stream-logs hallelujah_effect180703_225948
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-03 22:59:48.250304. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %% [markdown]
# Results:
#
# - Accuracy = 0.588235
# - Accuracy baseline = 0.735294
# - AUC = 0.328889
# - AUC-PR = 0.176113
# - Average loss = 2.61672
# - Label/mean = 0.264706
# - Loss = 88.9685
# - Prediction/mean = 0.151901

# %% [markdown]
# ## View Results in TensorBoard

# %%
from google.datalab.ml import TensorBoard
TensorBoard().start('gs://eim-muse/analysis/hallelujah-effect/models')
# Out:
# <p>TensorBoard was started successfully with pid 327. Click <a href="/_proxy/50955/" target="_blank">here</a> to access it.</p>
# 327

# %%
TensorBoard.stop(327)

# %%
# %writefile /tmp/test.json
{"age":"29.0","activity":3.0}

# %%
# %bash
model_dir=$(ls $PWD/hallelujah-effect_trained/export/exporter/)
gcloud ml-engine local predict \
    --model-dir=./hallelujah-effect_trained/export/exporter/${model_dir} \
    --json-instances=/tmp/test.json

# %% [markdown]
# # To Do
#
# - LASSO to identify important features
# - Hyperparameter search
# - More plots and statistics from the dataset with which I'm working here
# - Bring in rows with missing values
# - Feature engineering (physiological signals, MIR, feature crosses, variable-width binning)
# - Include signals with good quality only in reaction range
# - Customize estimator to add additional metrics

# %%
print('gs://{}/analysis/hallelujah-effect/models/{}'.format(BUCKET, MODEL_NAME))
# Out:
# gs://eim-muse/analysis/hallelujah-effect/models/basic_features
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-01 20:34:08.418586. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
# %%bash
#
# tensorboard --inspect --logdir gs://eim-muse/analysis/hallelujah-effect/models/basic_features
# Out:
# ======================================================================
# Processing event files... (this can take a few minutes)
# ======================================================================
#
# Found event files in:
# gs://eim-muse/analysis/hallelujah-effect/models/basic_features
# gs://eim-muse/analysis/hallelujah-effect/models/basic_features/eval/
#
# These tags are in gs://eim-muse/analysis/hallelujah-effect/models/basic_features:
# audio -
# histograms
#    dnn/dnn/hiddenlayer_0/activation
#    dnn/dnn/hiddenlayer_1/activation
#    dnn/dnn/hiddenlayer_2/activation
#    dnn/dnn/logits/activation
# images -
# scalars
#    average_loss
#    dnn/dnn/hiddenlayer_0/fraction_of_zero_values
#    dnn/dnn/hiddenlayer_1/fraction_of_zero_values
#    dnn/dnn/hiddenlayer_2/fraction_of_zero_values
#    dnn/dnn/logits/fraction_of_zero_values
#    loss
#    read_batch_features/file_name_queue/fraction_of_32_full
#    read_batch_features/fraction_over_9970_of_30_full
#    read_batch_features/queue/parsed_features/read_batch_features/fifo_queue/fraction_of_100_full
# tensor -
# ======================================================================
#
# Event statistics for gs://eim-muse/analysis/hallelujah-effect/models/basic_features:
# audio -
# graph
#    first_step           0
#    last_step            0
#    max_step             0
#    min_step             0
#    num_steps            1
#    outoforder_steps     []
# histograms
#    first_step           1
#    last_step            1
#    max_step             1
#    min_step             1
#    num_steps            1
#    outoforder_steps     []
# images -
# scalars
#    first_step           1
#    last_step            1
#    max_step             1
#    min_step             1
#    num_steps            1
#    outoforder_steps     []
# sessionlog:checkpoint
#    first_step           1
#    last_step            8
#    max_step             8
#    min_step             1
#    num_steps            8
#    outoforder_steps     []
# sessionlog:start
#    outoforder_steps     []
#    steps                [1L]
# sessionlog:stop -
# tensor -
# ======================================================================
#
# These tags are in gs://eim-muse/analysis/hallelujah-effect/models/basic_features/eval/:
# audio -
# histograms -
# images -
# scalars
#    accuracy
#    accuracy_baseline
#    auc
#    auc_precision_recall
#    average_loss
#    label/mean
#    loss
#    prediction/mean
# tensor -
# ======================================================================
#
# Event statistics for gs://eim-muse/analysis/hallelujah-effect/models/basic_features/eval/:
# audio -
# graph
#    first_step           0
#    last_step            0
#    max_step             0
#    min_step             0
#    num_steps            1
#    outoforder_steps     []
# histograms -
# images -
# scalars
#    first_step           1
#    last_step            14
#    max_step             14
#    min_step             1
#    num_steps            14
#    outoforder_steps     []
# sessionlog:checkpoint -
# sessionlog:start -
# sessionlog:stop -
# tensor -
# ======================================================================
# /usr/local/envs/py2env/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
ml = """
This is
a
multiline string.
"""

with open('./test.txt', 'w') as file:
  file.write(ml)
# Out:
# /usr/local/envs/py2env/lib/python2.7/site-packages/simplejson/encoder.py:286: DeprecationWarning: Interpreting naive datetime as local 2018-07-04 00:58:42.778246. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
